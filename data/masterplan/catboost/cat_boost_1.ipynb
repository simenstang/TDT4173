# %% [markdown]
# # The Cat Boost Notebook notebook
#
# - The y-set for location A, B and C are concatonated (time index)
# - The X-set for location A, B and C are concatonated (time index)
# - One hot encoding for location and whether or not set is from the estimated column
# - The y-set and the X-set are merged on date and location
# - Having date features
# - y-sets are normalized (MinMax)
# - Removes repeated values in y-set B and C
#
# It takes over from feature_engineering_1
# Adds some ratio features from feature_engineering_3
#
# **Takes over from catboost_3.ipynb**
#
#
# Uses catboost
#
#
# ***What's new?***
#
# Aims to visualize under- overestimations.
#
# ### CATBOOST VERSION 1

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import math
import csv
import seaborn as sns
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
train_a = pd.read_parquet('../../A/train_targets.parquet')
train_b = pd.read_parquet('../../B/train_targets.parquet')
train_c = pd.read_parquet('../../C/train_targets.parquet')

X_train_estimated_a = pd.read_parquet('../../A/X_train_estimated.parquet')
X_train_estimated_b = pd.read_parquet('../../B/X_train_estimated.parquet')
X_train_estimated_c = pd.read_parquet('../../C/X_train_estimated.parquet')

X_train_observed_a = pd.read_parquet('../../A/X_train_observed.parquet')
X_train_observed_b = pd.read_parquet('../../B/X_train_observed.parquet')
X_train_observed_c = pd.read_parquet('../../C/X_train_observed.parquet')

X_test_estimated_a = pd.read_parquet('../../A/X_test_estimated.parquet')
X_test_estimated_b = pd.read_parquet('../../B/X_test_estimated.parquet')
X_test_estimated_c = pd.read_parquet('../../C/X_test_estimated.parquet')

# %% [markdown]
# ## Handling the Y-set

# %%
def find_repeated_rows(df):
    '''
    Returns all indicies (from, to) which have the largest intervals of being constant. The output is sorted from 
    largest to smallest.
    '''
    df = df.reset_index()
    repeated_temp = []
    intervals = []

    first = True

    for index, row in df.iterrows():
        if index == 0:
            continue
        if row['pv_measurement'] == df.iloc[index - 1]['pv_measurement']:
            repeated_temp.append(index)
            if first: 
                repeated_temp.insert(0, index - 1)
                first = False
        else:
            if len(repeated_temp) > 1:
                intervals.append((repeated_temp[0], repeated_temp[-1]))
            repeated_temp = []
            first = True
            
    threshold = 6

    return sorted([t for t in intervals if t[1] - t[0] >= threshold], key=lambda t: t[1] - t[0], reverse=True)

# %%
all_y = [train_a, train_b, train_c]
labels = ['A', 'B', 'C']

table = {}

i = 0
for y in all_y:
    loc, intervals = labels[i], find_repeated_rows(y)
    if isinstance(intervals[0], (int, float)):
        intervals = np.asarray(intervals, dtype=float)
    intervals = list(intervals) + [np.nan] * (1421 - len(intervals))
    table[loc] = intervals
    print("The largest interval for", loc, intervals[0])
    i += 1

table = pd.DataFrame(table)
table.head()
# Out:
# The largest interval for A (5176, 5218)
# The largest interval for B (13409, 14466)
# The largest interval for C (18105, 18727)
#                 A               B               C
# 0    (5176, 5218)  (13409, 14466)  (18105, 18727)
# 1    (4526, 4547)  (19138, 20141)  (26048, 26669)
# 2  (22429, 22450)  (18690, 19137)  (27224, 27748)
# 3  (22933, 22954)  (10966, 11307)  (25400, 25876)
# 4        (67, 87)  (26115, 26353)  (10047, 10375)

# %%
i = 1
for y in all_y[1:]:
    loc, intervals = labels[i], find_repeated_rows(y)
    for start, end in intervals:
        for row_index in range(start, end + 1):
            y.at[row_index, 'pv_measurement'] = np.nan

    test = y.set_index('time')
    test['pv_measurement'].plot(title="PV measurments when removing all constant intervals in " + loc)
    plt.show()
    i += 1

# %%
train_a.set_index('time', inplace=True)
train_b.set_index('time', inplace=True)
train_c.set_index('time', inplace=True)

# %% [markdown]
# Normalizing values

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_a = MinMaxScaler()
scaler_b = MinMaxScaler()
scaler_c = MinMaxScaler()

# %%
train_a['pv_measurement'] = scaler_a.fit_transform(train_a[['pv_measurement']])
train_b['pv_measurement'] = scaler_b.fit_transform(train_b[['pv_measurement']])
train_c['pv_measurement'] = scaler_c.fit_transform(train_c[['pv_measurement']])

# %%
train_a['location'] = 'A'
train_b['location'] = 'B'
train_c['location'] = 'C'

# %%
y = pd.concat([train_a, train_b, train_c])
y.index.name = 'time'
y = pd.get_dummies(y, prefix='location', columns=['location'])
encoded_columns = [col for col in y.columns if 'location_' in col]
y[encoded_columns] = y[encoded_columns].astype(int)

y.shape
y.head()
# Out:
#                      pv_measurement  location_A  location_B  location_C
# time
# 2019-06-02 22:00:00        0.000000           1           0           0
# 2019-06-02 23:00:00        0.000000           1           0           0
# 2019-06-03 00:00:00        0.000000           1           0           0
# 2019-06-03 01:00:00        0.000000           1           0           0
# 2019-06-03 02:00:00        0.003377           1           0           0

# %% [markdown]
# Setting the index to **date_forecast** and resampling with median.

# %%
X_train_observed_a['date_forecast'] = pd.to_datetime(X_train_observed_a['date_forecast'])
X_train_observed_a.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_observed_a:
    X_train_observed_a.drop("date_calc", axis=1, inplace=True)
X_train_observed_a = X_train_observed_a.resample('60min').median()


X_train_estimated_a['date_forecast'] = pd.to_datetime(X_train_estimated_a['date_forecast'])
X_train_estimated_a.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_observed_a:
    X_train_estimated_a.drop("date_calc", axis=1, inplace=True)
X_train_estimated_a = X_train_estimated_a.resample('60min').median()


X_train_observed_b['date_forecast'] = pd.to_datetime(X_train_observed_b['date_forecast'])
X_train_observed_b.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_observed_b:
    X_train_observed_b.drop("date_calc", axis=1, inplace=True)
X_train_observed_b = X_train_observed_b.resample('60min').median()


X_train_estimated_b['date_forecast'] = pd.to_datetime(X_train_estimated_b['date_forecast'])
X_train_estimated_b.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_estimated_b:
    X_train_estimated_b.drop("date_calc", axis=1, inplace=True)
X_train_estimated_b = X_train_estimated_b.resample('60min').median()


X_train_observed_c['date_forecast'] = pd.to_datetime(X_train_observed_c['date_forecast'])
X_train_observed_c.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_observed_c:
    X_train_observed_c.drop("date_calc", axis=1, inplace=True)
X_train_observed_c = X_train_observed_c.resample('60min').median()


X_train_estimated_c['date_forecast'] = pd.to_datetime(X_train_estimated_c['date_forecast'])
X_train_estimated_c.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_estimated_c:
    X_train_estimated_c.drop("date_calc", axis=1, inplace=True)
X_train_estimated_c = X_train_estimated_c.resample('60min').median()

# %%
X_train_estimated_a['is_day:idx'].describe()
# Out:
# count    4394.000000
# mean        0.350364
# std         0.470472
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: is_day:idx, dtype: float64

# %%
X_train_observed_a.columns
# Out:
# Index(['absolute_humidity_2m:gm3', 'air_density_2m:kgm3',
#        'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W',
#        'cloud_base_agl:m', 'dew_or_rime:idx', 'dew_point_2m:K',
#        'diffuse_rad:W', 'diffuse_rad_1h:J', 'direct_rad:W', 'direct_rad_1h:J',
#        'effective_cloud_cover:p', 'elevation:m', 'fresh_snow_12h:cm',
#        'fresh_snow_1h:cm', 'fresh_snow_24h:cm', 'fresh_snow_3h:cm',
#        'fresh_snow_6h:cm', 'is_day:idx', 'is_in_shadow:idx',
#        'msl_pressure:hPa', 'precip_5min:mm', 'precip_type_5min:idx',
#        'pressure_100m:hPa', 'pressure_50m:hPa', 'prob_rime:p',
#        'rain_water:kgm2', 'relative_humidity_1000hPa:p', 'sfc_pressure:hPa',
#        'snow_density:kgm3', 'snow_depth:cm', 'snow_drift:idx',
#        'snow_melt_10min:mm', 'snow_water:kgm2', 'sun_azimuth:d',
#        'sun_elevation:d', 'super_cooled_liquid_water:kgm2', 't_1000hPa:K',
#        'total_cloud_cover:p', 'visibility:m', 'wind_speed_10m:ms',
#        'wind_speed_u_10m:ms', 'wind_speed_v_10m:ms',
#        'wind_speed_w_1000hPa:ms'],
#       dtype='object')

# %%
def replace_outliers_with_nan(df, feature):
    '''Replaces thr 0.01 and 0.99'''
    Q1 = df[feature].quantile(0.01)
    Q99 = df[feature].quantile(0.99)

    df[feature] = np.where(
        (df[feature] < Q1) | (df[feature] > Q99),
        np.nan,
        df[feature]
    )

# %% [markdown]
# ### Removing 'outlier' features as this gave us 0.1 better score on Kaggle

# %%
outliers = ['air_density_2m:kgm3', 'msl_pressure:hPa', 'sfc_pressure:hPa']


for o in outliers:
    replace_outliers_with_nan(X_train_observed_a, o)
    replace_outliers_with_nan(X_train_observed_b, o)
    replace_outliers_with_nan(X_train_observed_c, o)

# %%
X_train_observed_a['location'], X_train_estimated_a['location'] = 'A', 'A'
X_train_observed_b['location'], X_train_estimated_b['location']= 'B', 'B'
X_train_observed_c['location'], X_train_estimated_c['location']= 'C', 'C'

X_train_observed_a['estimated'], X_train_estimated_a['estimated'] = 0, 1
X_train_observed_b['estimated'], X_train_estimated_b['estimated'] = 0, 1
X_train_observed_c['estimated'], X_train_estimated_c['estimated'] = 0, 1

# %%
X = pd.concat([X_train_observed_a, X_train_estimated_a, X_train_observed_b,
               X_train_estimated_b, X_train_observed_c, X_train_estimated_c
               ], ignore_index=False)
X = X.sort_index()

# %% [markdown]
# One hot encoding on location

# %%
# One hot encoding
X = pd.get_dummies(X, prefix='location', columns=['location'])
encoded_columns = [col for col in X.columns if 'location_' in col]
X[encoded_columns] = X[encoded_columns].astype(int)

# %%
df = pd.merge(y, X, left_on=[y.index, 'location_A', 'location_B', 'location_C'],
              right_on=[X.index, 'location_A', 'location_B', 'location_C'])

df.set_index('key_0', inplace=True)
df.index.name = "time"
df = df.sort_index()

df.head()
# Out:
#                      pv_measurement  location_A  location_B  location_C  \
# time
# 2019-01-01 00:00:00             NaN           0           1           0
# 2019-01-01 00:00:00             NaN           0           0           1
# 2019-01-01 01:00:00             NaN           0           0           1
# 2019-01-01 01:00:00             NaN           0           1           0
# 2019-01-01 02:00:00             NaN           0           1           0
#
#                      absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# time
# 2019-01-01 00:00:00                      5.55               1.2395
# 2019-01-01 00:00:00                      5.45               1.2410
# 2019-01-01 01:00:00                      5.35               1.2400
# 2019-01-01 01:00:00                      5.40               1.2395
# 2019-01-01 02:00:00                      5.40               1.2385
#
#                      ceiling_height_agl:m  clear_sky_energy_1h:J  \
# time
# 2019-01-01 00:00:00           1200.700012                    0.0
# 2019-01-01 00:00:00           1130.049988                    0.0
# 2019-01-01 01:00:00           1066.699951                    0.0
# 2019-01-01 01:00:00           1131.449951                    0.0
# 2019-01-01 02:00:00           1061.049988                    0.0
#
#                      clear_sky_rad:W  cloud_base_agl:m  ...  \
# time                                                    ...
# 2019-01-01 00:00:00              0.0       1200.700012  ...
# 2019-01-01 00:00:00              0.0       1130.049988  ...
# 2019-01-01 01:00:00              0.0       1066.699951  ...
# 2019-01-01 01:00:00              0.0       1131.449951  ...
# 2019-01-01 02:00:00              0.0       1061.049988  ...
#
#                      super_cooled_liquid_water:kgm2  t_1000hPa:K  \
# time
# 2019-01-01 00:00:00                             0.0   278.250000
# 2019-01-01 00:00:00                             0.0   278.349991
# 2019-01-01 01:00:00                             0.0   278.200012
# 2019-01-01 01:00:00                             0.0   278.100006
# 2019-01-01 02:00:00                             0.1   278.050003
#
#                      total_cloud_cover:p  visibility:m  wind_speed_10m:ms  \
# time
# 2019-01-01 00:00:00            87.500000  16823.399902               2.80
# 2019-01-01 00:00:00            85.350002  16512.299805               2.90
# 2019-01-01 01:00:00            99.099998  13277.399902               3.65
# 2019-01-01 01:00:00            99.099998  12777.449707               3.55
# 2019-01-01 02:00:00            97.849998  11142.549805               4.05
#
#                      wind_speed_u_10m:ms  wind_speed_v_10m:ms  \
# time
# 2019-01-01 00:00:00                 1.20                 2.55
# 2019-01-01 00:00:00                 1.10                 2.65
# 2019-01-01 01:00:00                 1.40                 3.35
# 2019-01-01 01:00:00                 1.50                 3.20
# 2019-01-01 02:00:00                 2.15                 3.45
#
#                      wind_speed_w_1000hPa:ms  estimated  date_calc
# time
# 2019-01-01 00:00:00                     -0.0          0        NaT
# 2019-01-01 00:00:00                     -0.0          0        NaT
# 2019-01-01 01:00:00                     -0.0          0        NaT
# 2019-01-01 01:00:00                     -0.0          0        NaT
# 2019-01-01 02:00:00                     -0.0          0        NaT
#
# [5 rows x 51 columns]

# %%
def create_features(df):
    """
    Create Features
    """
    
    df = df.copy()
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week

    df['is_weekend'] = (df.index.weekday >= 5).astype(int)
    df['season'] = df.index.month.map(get_season)

    # Set a threshold for sun elevation (in degrees)
    elevation_threshold = 10  

    # Binary feature for significant sun elevation
    df['sun_above_threshold'] = (df['sun_elevation:d'] > elevation_threshold).astype(int)

    # Cosine and sine transformations of sun azimuth
    df['cos_sun_azimuth'] = np.cos(np.radians(df['sun_azimuth:d']))
    df['sin_sun_azimuth'] = np.sin(np.radians(df['sun_azimuth:d']))

    df['interaction_clear_sky_rad_sun_elevation'] = df['clear_sky_rad:W'] * df['sun_elevation:d']
    df['interaction_clear_sky_rad_effective_cloud_cover'] = df['clear_sky_rad:W'] * df['effective_cloud_cover:p']

    df['ratio_clear_sky_rad_to_cloud_cover'] = df['clear_sky_rad:W'] / (df['effective_cloud_cover:p'] + 1e-8)  # added a small number to avoid division by zero

    df['ratio_direct_to_diffuse_rad'] = df['direct_rad:W'] / (df['diffuse_rad:W'] + 1e-8)

    df['ratio_air_density_to_humidity'] = df['air_density_2m:kgm3'] / (df['absolute_humidity_2m:gm3'] + 1e-8)

    df['ratio_wind_speed_10m_to_1000hPa'] = df['wind_speed_v_10m:ms'] / (df['wind_speed_w_1000hPa:ms'] + 1e-8)

    return df

def get_season(month):
    if 3 <= month <= 5:
        return 0  # spring
    elif 6 <= month <= 8:
        return 1  # summer
    elif 9 <= month <= 11:
        return 2  # fall
    else:
        return 3  # winter

df = create_features(df)

df.head()
# Out:
#                      pv_measurement  location_A  location_B  location_C  \
# time
# 2019-01-01 00:00:00             NaN           0           1           0
# 2019-01-01 00:00:00             NaN           0           0           1
# 2019-01-01 01:00:00             NaN           0           0           1
# 2019-01-01 01:00:00             NaN           0           1           0
# 2019-01-01 02:00:00             NaN           0           1           0
#
#                      absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# time
# 2019-01-01 00:00:00                      5.55               1.2395
# 2019-01-01 00:00:00                      5.45               1.2410
# 2019-01-01 01:00:00                      5.35               1.2400
# 2019-01-01 01:00:00                      5.40               1.2395
# 2019-01-01 02:00:00                      5.40               1.2385
#
#                      ceiling_height_agl:m  clear_sky_energy_1h:J  \
# time
# 2019-01-01 00:00:00           1200.700012                    0.0
# 2019-01-01 00:00:00           1130.049988                    0.0
# 2019-01-01 01:00:00           1066.699951                    0.0
# 2019-01-01 01:00:00           1131.449951                    0.0
# 2019-01-01 02:00:00           1061.049988                    0.0
#
#                      clear_sky_rad:W  cloud_base_agl:m  ...  season  \
# time                                                    ...
# 2019-01-01 00:00:00              0.0       1200.700012  ...       3
# 2019-01-01 00:00:00              0.0       1130.049988  ...       3
# 2019-01-01 01:00:00              0.0       1066.699951  ...       3
# 2019-01-01 01:00:00              0.0       1131.449951  ...       3
# 2019-01-01 02:00:00              0.0       1061.049988  ...       3
#
#                      sun_above_threshold  cos_sun_azimuth  sin_sun_azimuth  \
# time
# 2019-01-01 00:00:00                    0         0.934996         0.354658
# 2019-01-01 00:00:00                    0         0.934934         0.354821
# 2019-01-01 01:00:00                    0         0.761584         0.648067
# 2019-01-01 01:00:00                    0         0.761815         0.647794
# 2019-01-01 02:00:00                    0         0.531894         0.846811
#
#                      interaction_clear_sky_rad_sun_elevation  \
# time
# 2019-01-01 00:00:00                                     -0.0
# 2019-01-01 00:00:00                                     -0.0
# 2019-01-01 01:00:00                                     -0.0
# 2019-01-01 01:00:00                                     -0.0
# 2019-01-01 02:00:00                                     -0.0
#
#                      interaction_clear_sky_rad_effective_cloud_cover  \
# time
# 2019-01-01 00:00:00                                              0.0
# 2019-01-01 00:00:00                                              0.0
# 2019-01-01 01:00:00                                              0.0
# 2019-01-01 01:00:00                                              0.0
# 2019-01-01 02:00:00                                              0.0
#
#                      ratio_clear_sky_rad_to_cloud_cover  \
# time
# 2019-01-01 00:00:00                                 0.0
# 2019-01-01 00:00:00                                 0.0
# 2019-01-01 01:00:00                                 0.0
# 2019-01-01 01:00:00                                 0.0
# 2019-01-01 02:00:00                                 0.0
#
#                      ratio_direct_to_diffuse_rad  \
# time
# 2019-01-01 00:00:00                          0.0
# 2019-01-01 00:00:00                          0.0
# 2019-01-01 01:00:00                          0.0
# 2019-01-01 01:00:00                          0.0
# 2019-01-01 02:00:00                          0.0
#
#                      ratio_air_density_to_humidity  \
# time
# 2019-01-01 00:00:00                       0.223333
# 2019-01-01 00:00:00                       0.227706
# 2019-01-01 01:00:00                       0.231776
# 2019-01-01 01:00:00                       0.229537
# 2019-01-01 02:00:00                       0.229352
#
#                      ratio_wind_speed_10m_to_1000hPa
# time
# 2019-01-01 00:00:00                     2.550000e+08
# 2019-01-01 00:00:00                     2.650000e+08
# 2019-01-01 01:00:00                     3.350000e+08
# 2019-01-01 01:00:00                     3.200000e+08
# 2019-01-01 02:00:00                     3.450000e+08
#
# [5 rows x 70 columns]

# %% [markdown]
# ### Selecting features
#
# Everything except:
#
# - snow_density:kgm3
# - cloud_base_agl:m
# - ceiling_height_agl:m
#
# They have a lot of NaN values.

# %%
FEATURES = [
    'absolute_humidity_2m:gm3', 'air_density_2m:kgm3',
    'clear_sky_energy_1h:J', 'clear_sky_rad:W',
    'dew_or_rime:idx', 'dew_point_2m:K',
    'diffuse_rad:W', 'diffuse_rad_1h:J', 'direct_rad:W', 'direct_rad_1h:J',
    'effective_cloud_cover:p', 'elevation:m', 'fresh_snow_12h:cm',
    'fresh_snow_1h:cm', 'fresh_snow_24h:cm', 'fresh_snow_3h:cm',
    'fresh_snow_6h:cm', 'is_day:idx', 'is_in_shadow:idx',
    'msl_pressure:hPa', 'precip_5min:mm', 'precip_type_5min:idx',
    'pressure_100m:hPa', 'pressure_50m:hPa', 'prob_rime:p',
    'rain_water:kgm2', 'relative_humidity_1000hPa:p', 'sfc_pressure:hPa',
    'snow_depth:cm', 'snow_drift:idx',
    'snow_melt_10min:mm', 'snow_water:kgm2', 'sun_azimuth:d',
    'sun_elevation:d', 'super_cooled_liquid_water:kgm2', 't_1000hPa:K',
    'total_cloud_cover:p', 'visibility:m', 'wind_speed_10m:ms',
    'wind_speed_u_10m:ms', 'wind_speed_v_10m:ms', 'wind_speed_w_1000hPa:ms',
    'hour', 'dayofweek', 'quarter', 'month', 'year', 'dayofyear',
    'dayofmonth', 'weekofyear', 'is_weekend', 'season', 'sun_above_threshold',
    'cos_sun_azimuth', 'sin_sun_azimuth', 'interaction_clear_sky_rad_sun_elevation',
    'interaction_clear_sky_rad_effective_cloud_cover',
    'location_A', 'location_B', 'location_C', 'estimated'
]

TARGET = 'pv_measurement'

# %%
relevant = FEATURES.copy()
relevant.append(TARGET)

df = df[relevant]

# %%
print(df.isna().sum())
before = df.shape

train = df.dropna()
print(train.isna().sum())
after = train.shape

dif = before[0] - after[0]

df = df.dropna()
print("DROPNA RESULTED IN", dif, "ROWS BEING DROPPED. THE DATASET HAS", after[0], "ROWS IN TOTAL.")
# Out:
# absolute_humidity_2m:gm3       72
# air_density_2m:kgm3          1824
# clear_sky_energy_1h:J          72
# clear_sky_rad:W                72
# dew_or_rime:idx                72
#                             ...
# location_A                      0
# location_B                      0
# location_C                      0
# estimated                       0
# pv_measurement              40896
# Length: 62, dtype: int64
# absolute_humidity_2m:gm3    0
# air_density_2m:kgm3         0
# clear_sky_energy_1h:J       0
# clear_sky_rad:W             0
# dew_or_rime:idx             0
#                            ..
# location_A                  0
# location_B                  0
# location_C                  0
# estimated                   0
# pv_measurement              0
# Length: 62, dtype: int64
# DROPNA RESULTED IN 42788 ROWS BEING DROPPED. THE DATASET HAS 56298 ROWS IN TOTAL.

# %%
color_pal = sns.color_palette()

df["pv_measurement"].plot(style='.',
        figsize=(15, 5),
        color=color_pal[1],
        title='PV measurment against time')
plt.show()

# %% [markdown]
# ### Preparing test data
#
# - Excluding dates that should not be tested
# - Including only the features we have defined

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

def prepare_test_data(x, location):
    x_test = x.copy()
    x_test.set_index('date_forecast', inplace = True)
    x_test.drop('date_calc', axis=1, inplace = True)
    x_test['estimated'] = 1

    x_test = x_test.resample('60min').median()

    x_test = create_features(x_test)

    if location == 'A':
        x_test['location_A'] =  1
        x_test['location_B'] = 0
        x_test['location_C'] = 0
    elif location == 'B':
        x_test['location_A'] =  0
        x_test['location_B'] = 1
        x_test['location_C'] = 0
    elif location == 'C':
        x_test['location_A'] =  0
        x_test['location_B'] = 0
        x_test['location_C'] = 1

    return x_test

# %%
x_test_a = prepare_test_data(X_test_estimated_a, 'A')
x_test_b = prepare_test_data(X_test_estimated_b, 'B')
x_test_c = prepare_test_data(X_test_estimated_c, 'C')

# %%
test_sub = pd.read_csv('../../test.csv')
valid_dates = pd.to_datetime(test_sub['time'].unique())

# %%
x_test_a = x_test_a.loc[valid_dates]
x_test_b = x_test_b.loc[valid_dates]
x_test_c = x_test_c.loc[valid_dates]

# %%
X_test = pd.concat([x_test_a, x_test_b, x_test_c])
X_test = X_test[FEATURES]

# %% [markdown]
# ### Disability Check
#
# Check if the training data and the test data contains the same columns.

# %%
check_df = df.copy()
check_train = check_df[FEATURES]
if X_test.columns.equals(check_train.columns):
    print("EQUAL")
else:
    print("NOT EQUAL")
    print("DIFFERENCE\n", X_test.columns.difference(check_train.columns))
# Out:
# EQUAL

# %% [markdown]
# Check if test data has the right amount of rows.

# %%
if X_test.shape[0] != 2160:
    print("X_test has wrong amount of rows!")
    print("Shape =", X_test.shape[0])
else:
    print("GOOD")
# Out:
# GOOD

# %%
X = df[FEATURES]
y = df[TARGET]

# %% [markdown]
# ### Define parameters you want to tune
#
# NOTE we have gotten issues by tuning too many paramters. Be carefull!

# %%
from sklearn.model_selection import validation_curve
from sklearn.model_selection import TimeSeriesSplit
from catboost import CatBoostRegressor
import optuna
from sklearn.metrics import mean_absolute_error


def objective(trial):
    param = {
    "iterations": trial.suggest_int("iterations", 500, 1500),
    "learning_rate": trial.suggest_float("learning_rate", 1e-4, 1e-1, log=True),
    "depth": trial.suggest_int("depth", 1, 16),
    "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 1.0),
    "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 1, 300),
    "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1e-8, 10.0, log=True),
    "border_count": trial.suggest_int("border_count", 1, 255),
    "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 100.0),
    'loss_function':'MAE'
    }

    cv = TimeSeriesSplit(n_splits=3, test_size=24*30*3)

    model = CatBoostRegressor(**param)

    maes = []

    for train_index, val_index in cv.split(X):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        model.fit(X_train, y_train, verbose=0)
        y_pred = model.predict(X_val)
        mae = mean_absolute_error(y_val, y_pred)
        maes.append(mae)
        
    avg_mae = np.mean(maes)

    return avg_mae

# %% [markdown]
# ### Spesify number of trials
#
# A higher number of trials tries out more parameters

# %%
trials = 2

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=trials, n_jobs=-1, show_progress_bar=True)
# Out:
# [I 2023-10-25 17:25:19,664] A new study created in memory with name: no-name-6b4b616f-e737-4ad8-9fcf-79880877e35d
#   0%|          | 0/2 [00:00<?, ?it/s]
# [I 2023-10-25 17:25:42,164] Trial 0 finished with value: 0.04118156840541904 and parameters: {'iterations': 923, 'learning_rate': 0.0020440794164507965, 'depth': 7, 'colsample_bylevel': 0.14956146538950943, 'min_data_in_leaf': 104, 'l2_leaf_reg': 3.3707353223295646, 'border_count': 153, 'bagging_temperature': 11.736125374897988}. Best is trial 0 with value: 0.04118156840541904.
# [I 2023-10-25 17:25:45,014] Trial 1 finished with value: 0.03773778318316107 and parameters: {'iterations': 1087, 'learning_rate': 0.0028058785760371532, 'depth': 5, 'colsample_bylevel': 0.7252211400007484, 'min_data_in_leaf': 207, 'l2_leaf_reg': 0.00018232173647996443, 'border_count': 189, 'bagging_temperature': 55.52473017795734}. Best is trial 1 with value: 0.03773778318316107.

# %%
best_params = study.best_params
print('Best parameters:', best_params)

#Best parameters: {'iterations': 854, 'learning_rate': 0.017432099489773544, 'depth': 14, 'colsample_bylevel': 0.43559465187532453, 'min_data_in_leaf': 257, 'l2_leaf_reg': 9.179321889625692, 'border_count': 129, 'random_strength': 0.8781261706316226, 'bagging_temperature': 11.599929150721326, 'grow_policy': 'Lossguide', 'max_leaves': 192}
# Out:
# Best parameters: {'iterations': 1087, 'learning_rate': 0.0028058785760371532, 'depth': 5, 'colsample_bylevel': 0.7252211400007484, 'min_data_in_leaf': 207, 'l2_leaf_reg': 0.00018232173647996443, 'border_count': 189, 'bagging_temperature': 55.52473017795734}

# %% [markdown]
# ### Now visualising the predictions
#
# This is done by using the validation sets from cross validation. We have used Timeseries cross validation with a test size of three months (that which we are trying to predict in our test sets).

# %%
model = CatBoostRegressor(**best_params)

# %%
cv = TimeSeriesSplit(n_splits=3, test_size=24*30*3)

residuals = []
predictions = []
actuals = []
dates_list = []  

# Cross-validation loop
for train_index, val_index in cv.split(X):
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]
    
    # Train the model
    model.fit(X_train, y_train, verbose=0)
    
    # Make predictions
    y_pred = model.predict(X_val)
    
    # Store results
    res = y_val - y_pred
    residuals.extend(res)
    predictions.extend(y_pred)
    actuals.extend(y_val)
    dates_list.extend(X_val.index)

# %%
residuals = np.array(residuals)
predictions = np.array(predictions)
actuals = np.array(actuals)

# %%
color_pal = sns.color_palette()

# %%
# Scatter Plot for Actual vs Predicted
plt.figure(figsize=(15, 7))
plt.subplot(2, 1, 1)
plt.scatter(dates_list, actuals, label='Actual', color=color_pal[0], s=5)  
plt.scatter(dates_list, predictions, label='Predicted', color=color_pal[1], s=5)  
plt.title('Actual vs Predicted PV Measurements Over Time')
plt.xlabel('Date')
plt.ylabel('PV Measurement')
plt.legend()
plt.grid(True)

# Residual Plot
plt.subplot(2, 1, 2)
plt.scatter(dates_list, residuals, label='Residuals', color=color_pal[2], s=5)
plt.axhline(y=0, color='black', linestyle='--')  # Add a horizontal line at y=0 for reference
plt.title('Residuals Over Time')
plt.xlabel('Date')
plt.ylabel('Residuals')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Here is a box plot to further assist your understanding of the residuals

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create a DataFrame with dates and residuals
dfr = pd.DataFrame({
    'Date': pd.to_datetime(dates_list),
    'Residuals': residuals
})

# Extract week number from dates
dfr['Week'] = dfr['Date'].dt.strftime('%Y-%U')

# Box plot using Seaborn
plt.figure(figsize=(15,7))
sns.boxplot(x='Week', y='Residuals', data=dfr)

# Formatting the plot
plt.xticks(rotation=45) # Rotate x-labels for better visibility
plt.title('Boxplot of Residuals by Week')
plt.xlabel('Week')
plt.ylabel('Residuals')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # THE MAIN FIGURE TO WORRY ABOUT
#
# ### Residual = Actual - Pred

# %%
print("The average residuals:")
print(np.mean(residuals))
# Out:
# The average residuals:
# -0.007285055822268351

# %%
model.fit(X_train, y_train)
# Out:
# 0:	learn: 0.2084151	total: 10.7ms	remaining: 11.6s
# 1:	learn: 0.2079699	total: 18.2ms	remaining: 9.9s
# 2:	learn: 0.2075202	total: 24.6ms	remaining: 8.89s
# 3:	learn: 0.2070779	total: 32.7ms	remaining: 8.86s
# 4:	learn: 0.2066328	total: 40ms	remaining: 8.64s
# 5:	learn: 0.2061866	total: 47.4ms	remaining: 8.55s
# 6:	learn: 0.2057391	total: 52.9ms	remaining: 8.15s
# 7:	learn: 0.2052935	total: 57.8ms	remaining: 7.8s
# 8:	learn: 0.2048514	total: 63.6ms	remaining: 7.62s
# 9:	learn: 0.2044108	total: 69.2ms	remaining: 7.45s
# 10:	learn: 0.2039741	total: 74.1ms	remaining: 7.25s
# 11:	learn: 0.2035406	total: 80.4ms	remaining: 7.21s
# 12:	learn: 0.2031036	total: 86ms	remaining: 7.1s
# 13:	learn: 0.2026669	total: 91.2ms	remaining: 6.99s
# 14:	learn: 0.2022278	total: 97.9ms	remaining: 6.99s
# 15:	learn: 0.2017957	total: 103ms	remaining: 6.92s
# 16:	learn: 0.2013710	total: 109ms	remaining: 6.89s
# 17:	learn: 0.2009334	total: 116ms	remaining: 6.88s
# 18:	learn: 0.2005005	total: 121ms	remaining: 6.79s
# 19:	learn: 0.2000725	total: 126ms	remaining: 6.74s
# 20:	learn: 0.1996559	total: 133ms	remaining: 6.73s
# 21:	learn: 0.1992311	total: 138ms	remaining: 6.66s
# 22:	learn: 0.1988120	total: 143ms	remaining: 6.62s
# 23:	learn: 0.1983874	total: 149ms	remaining: 6.61s
# 24:	learn: 0.1979727	total: 156ms	remaining: 6.61s
# 25:	learn: 0.1975567	total: 163ms	remaining: 6.64s
# 26:	learn: 0.1971468	total: 168ms	remaining: 6.58s
# 27:	learn: 0.1967306	total: 173ms	remaining: 6.53s
# 28:	learn: 0.1963156	total: 179ms	remaining: 6.53s
# 29:	learn: 0.1959033	total: 184ms	remaining: 6.49s
# 30:	learn: 0.1954940	total: 190ms	remaining: 6.47s
# 31:	learn: 0.1950813	total: 196ms	remaining: 6.45s
# 32:	learn: 0.1946764	total: 202ms	remaining: 6.46s
# 33:	learn: 0.1942655	total: 210ms	remaining: 6.5s
# 34:	learn: 0.1938556	total: 215ms	remaining: 6.47s
# 35:	learn: 0.1934583	total: 221ms	remaining: 6.45s
# 36:	learn: 0.1930554	total: 226ms	remaining: 6.43s
# 37:	learn: 0.1926508	total: 233ms	remaining: 6.43s
# 38:	learn: 0.1922529	total: 240ms	remaining: 6.45s
# 39:	learn: 0.1918481	total: 248ms	remaining: 6.5s
# 40:	learn: 0.1914424	total: 254ms	remaining: 6.47s
# 41:	learn: 0.1910430	total: 260ms	remaining: 6.47s
# 42:	learn: 0.1906492	total: 267ms	remaining: 6.48s
# 43:	learn: 0.1902527	total: 273ms	remaining: 6.46s
# 44:	learn: 0.1898613	total: 279ms	remaining: 6.47s
# 45:	learn: 0.1894726	total: 285ms	remaining: 6.44s
# 46:	learn: 0.1890838	total: 290ms	remaining: 6.42s
# 47:	learn: 0.1886946	total: 296ms	remaining: 6.41s
# 48:	learn: 0.1883053	total: 302ms	remaining: 6.39s
# 49:	learn: 0.1879247	total: 308ms	remaining: 6.39s
# 50:	learn: 0.1875421	total: 314ms	remaining: 6.37s
# 51:	learn: 0.1871560	total: 319ms	remaining: 6.35s
# 52:	learn: 0.1867729	total: 325ms	remaining: 6.34s
# 53:	learn: 0.1863934	total: 330ms	remaining: 6.32s
# 54:	learn: 0.1860151	total: 336ms	remaining: 6.3s
# 55:	learn: 0.1856328	total: 342ms	remaining: 6.3s
# 56:	learn: 0.1852558	total: 348ms	remaining: 6.29s
# 57:	learn: 0.1848801	total: 353ms	remaining: 6.27s
# 58:	learn: 0.1845073	total: 359ms	remaining: 6.26s
# 59:	learn: 0.1841349	total: 365ms	remaining: 6.24s
# 60:	learn: 0.1837669	total: 370ms	remaining: 6.23s
# 61:	learn: 0.1833899	total: 377ms	remaining: 6.22s
# 62:	learn: 0.1830203	total: 382ms	remaining: 6.21s
# 63:	learn: 0.1826480	total: 388ms	remaining: 6.21s
# 64:	learn: 0.1822801	total: 394ms	remaining: 6.2s
# 65:	learn: 0.1819102	total: 399ms	remaining: 6.18s
# 66:	learn: 0.1815456	total: 405ms	remaining: 6.16s
# 67:	learn: 0.1811776	total: 411ms	remaining: 6.16s
# 68:	learn: 0.1808162	total: 417ms	remaining: 6.15s
# 69:	learn: 0.1804544	total: 423ms	remaining: 6.15s
# 70:	learn: 0.1800917	total: 429ms	remaining: 6.14s
# 71:	learn: 0.1797302	total: 434ms	remaining: 6.12s
# 72:	learn: 0.1793732	total: 440ms	remaining: 6.12s
# 73:	learn: 0.1790207	total: 446ms	remaining: 6.1s
# 74:	learn: 0.1786698	total: 451ms	remaining: 6.08s
# 75:	learn: 0.1783176	total: 458ms	remaining: 6.09s
# 76:	learn: 0.1779625	total: 463ms	remaining: 6.07s
# 77:	learn: 0.1776142	total: 469ms	remaining: 6.07s
# 78:	learn: 0.1772679	total: 476ms	remaining: 6.07s
# 79:	learn: 0.1769164	total: 481ms	remaining: 6.06s
# 80:	learn: 0.1765720	total: 486ms	remaining: 6.04s
# 81:	learn: 0.1762238	total: 492ms	remaining: 6.03s
# 82:	learn: 0.1758751	total: 497ms	remaining: 6.01s
# 83:	learn: 0.1755252	total: 502ms	remaining: 6s
# 84:	learn: 0.1751803	total: 508ms	remaining: 5.99s
# 85:	learn: 0.1748365	total: 513ms	remaining: 5.97s
# 86:	learn: 0.1744954	total: 519ms	remaining: 5.96s
# 87:	learn: 0.1741532	total: 523ms	remaining: 5.94s
# 88:	learn: 0.1738100	total: 528ms	remaining: 5.93s
# 89:	learn: 0.1734687	total: 533ms	remaining: 5.91s
# 90:	learn: 0.1731390	total: 539ms	remaining: 5.9s
# 91:	learn: 0.1728049	total: 544ms	remaining: 5.89s
# 92:	learn: 0.1724709	total: 550ms	remaining: 5.87s
# 93:	learn: 0.1721336	total: 555ms	remaining: 5.86s
# 94:	learn: 0.1718021	total: 561ms	remaining: 5.86s
# 95:	learn: 0.1714619	total: 567ms	remaining: 5.85s
# 96:	learn: 0.1711308	total: 572ms	remaining: 5.84s
# 97:	learn: 0.1708069	total: 577ms	remaining: 5.82s
# 98:	learn: 0.1704755	total: 582ms	remaining: 5.81s
# 99:	learn: 0.1701537	total: 588ms	remaining: 5.81s
# 100:	learn: 0.1698301	total: 594ms	remaining: 5.8s
# 101:	learn: 0.1695112	total: 602ms	remaining: 5.82s
# 102:	learn: 0.1691857	total: 608ms	remaining: 5.81s
# 103:	learn: 0.1688624	total: 614ms	remaining: 5.8s
# 104:	learn: 0.1685407	total: 619ms	remaining: 5.79s
# 105:	learn: 0.1682228	total: 625ms	remaining: 5.78s
# 106:	learn: 0.1679086	total: 630ms	remaining: 5.77s
# 107:	learn: 0.1675929	total: 636ms	remaining: 5.76s
# 108:	learn: 0.1672700	total: 641ms	remaining: 5.75s
# 109:	learn: 0.1669498	total: 646ms	remaining: 5.74s
# 110:	learn: 0.1666372	total: 651ms	remaining: 5.72s
# 111:	learn: 0.1663271	total: 656ms	remaining: 5.71s
# 112:	learn: 0.1660080	total: 661ms	remaining: 5.7s
# 113:	learn: 0.1656922	total: 666ms	remaining: 5.69s
# 114:	learn: 0.1653848	total: 672ms	remaining: 5.67s
# 115:	learn: 0.1650727	total: 677ms	remaining: 5.67s
# 116:	learn: 0.1647676	total: 683ms	remaining: 5.66s
# 117:	learn: 0.1644615	total: 688ms	remaining: 5.65s
# 118:	learn: 0.1641563	total: 693ms	remaining: 5.63s
# 119:	learn: 0.1638505	total: 697ms	remaining: 5.62s
# 120:	learn: 0.1635474	total: 702ms	remaining: 5.61s
# 121:	learn: 0.1632449	total: 707ms	remaining: 5.59s
# 122:	learn: 0.1629401	total: 712ms	remaining: 5.58s
# 123:	learn: 0.1626380	total: 717ms	remaining: 5.57s
# 124:	learn: 0.1623367	total: 722ms	remaining: 5.56s
# 125:	learn: 0.1620379	total: 727ms	remaining: 5.55s
# 126:	learn: 0.1617358	total: 733ms	remaining: 5.54s
# 127:	learn: 0.1614393	total: 738ms	remaining: 5.53s
# 128:	learn: 0.1611391	total: 743ms	remaining: 5.51s
# 129:	learn: 0.1608387	total: 748ms	remaining: 5.5s
# 130:	learn: 0.1605477	total: 753ms	remaining: 5.5s
# 131:	learn: 0.1602594	total: 758ms	remaining: 5.49s
# 132:	learn: 0.1599628	total: 764ms	remaining: 5.48s
# 133:	learn: 0.1596674	total: 769ms	remaining: 5.47s
# 134:	learn: 0.1593798	total: 774ms	remaining: 5.46s
# 135:	learn: 0.1590940	total: 779ms	remaining: 5.44s
# 136:	learn: 0.1588082	total: 784ms	remaining: 5.44s
# 137:	learn: 0.1585202	total: 789ms	remaining: 5.43s
# 138:	learn: 0.1582332	total: 794ms	remaining: 5.41s
# 139:	learn: 0.1579481	total: 799ms	remaining: 5.4s
# 140:	learn: 0.1576648	total: 804ms	remaining: 5.39s
# 141:	learn: 0.1573794	total: 809ms	remaining: 5.38s
# 142:	learn: 0.1570967	total: 815ms	remaining: 5.38s
# 143:	learn: 0.1568101	total: 820ms	remaining: 5.37s
# 144:	learn: 0.1565270	total: 825ms	remaining: 5.36s
# 145:	learn: 0.1562481	total: 830ms	remaining: 5.35s
# 146:	learn: 0.1559709	total: 835ms	remaining: 5.34s
# 147:	learn: 0.1556911	total: 840ms	remaining: 5.33s
# 148:	learn: 0.1554158	total: 845ms	remaining: 5.32s
# 149:	learn: 0.1551449	total: 851ms	remaining: 5.31s
# 150:	learn: 0.1548678	total: 856ms	remaining: 5.3s
# 151:	learn: 0.1545949	total: 861ms	remaining: 5.29s
# 152:	learn: 0.1543268	total: 866ms	remaining: 5.29s
# 153:	learn: 0.1540558	total: 871ms	remaining: 5.28s
# 154:	learn: 0.1537855	total: 876ms	remaining: 5.27s
# 155:	learn: 0.1535118	total: 881ms	remaining: 5.26s
# 156:	learn: 0.1532478	total: 887ms	remaining: 5.25s
# 157:	learn: 0.1529817	total: 892ms	remaining: 5.24s
# 158:	learn: 0.1527114	total: 897ms	remaining: 5.23s
# 159:	learn: 0.1524443	total: 901ms	remaining: 5.22s
# 160:	learn: 0.1521772	total: 906ms	remaining: 5.21s
# 161:	learn: 0.1519160	total: 912ms	remaining: 5.2s
# 162:	learn: 0.1516542	total: 917ms	remaining: 5.2s
# 163:	learn: 0.1513928	total: 921ms	remaining: 5.19s
# 164:	learn: 0.1511283	total: 926ms	remaining: 5.17s
# 165:	learn: 0.1508668	total: 931ms	remaining: 5.17s
# 166:	learn: 0.1506070	total: 936ms	remaining: 5.16s
# 167:	learn: 0.1503438	total: 941ms	remaining: 5.15s
# 168:	learn: 0.1500864	total: 946ms	remaining: 5.14s
# 169:	learn: 0.1498300	total: 951ms	remaining: 5.13s
# 170:	learn: 0.1495730	total: 956ms	remaining: 5.12s
# 171:	learn: 0.1493207	total: 962ms	remaining: 5.12s
# 172:	learn: 0.1490645	total: 967ms	remaining: 5.11s
# 173:	learn: 0.1488090	total: 972ms	remaining: 5.1s
# 174:	learn: 0.1485562	total: 977ms	remaining: 5.09s
# 175:	learn: 0.1483048	total: 984ms	remaining: 5.09s
# 176:	learn: 0.1480523	total: 989ms	remaining: 5.08s
# 177:	learn: 0.1478019	total: 994ms	remaining: 5.08s
# 178:	learn: 0.1475507	total: 1s	remaining: 5.07s
# 179:	learn: 0.1473020	total: 1s	remaining: 5.06s
# 180:	learn: 0.1470537	total: 1.01s	remaining: 5.06s
# 181:	learn: 0.1468074	total: 1.02s	remaining: 5.05s
# 182:	learn: 0.1465582	total: 1.02s	remaining: 5.05s
# 183:	learn: 0.1463098	total: 1.03s	remaining: 5.04s
# 184:	learn: 0.1460625	total: 1.03s	remaining: 5.04s
# 185:	learn: 0.1458195	total: 1.04s	remaining: 5.03s
# 186:	learn: 0.1455742	total: 1.04s	remaining: 5.02s
# 187:	learn: 0.1453320	total: 1.05s	remaining: 5.02s
# 188:	learn: 0.1450870	total: 1.05s	remaining: 5.01s
# 189:	learn: 0.1448455	total: 1.06s	remaining: 5s
# 190:	learn: 0.1446067	total: 1.06s	remaining: 4.99s
# 191:	learn: 0.1443694	total: 1.07s	remaining: 4.99s
# 192:	learn: 0.1441371	total: 1.07s	remaining: 4.98s
# 193:	learn: 0.1439027	total: 1.08s	remaining: 4.97s
# 194:	learn: 0.1436724	total: 1.08s	remaining: 4.96s
# 195:	learn: 0.1434376	total: 1.09s	remaining: 4.95s
# 196:	learn: 0.1432010	total: 1.09s	remaining: 4.95s
# 197:	learn: 0.1429698	total: 1.1s	remaining: 4.94s
# 198:	learn: 0.1427400	total: 1.11s	remaining: 4.94s
# 199:	learn: 0.1425095	total: 1.11s	remaining: 4.93s
# 200:	learn: 0.1422819	total: 1.12s	remaining: 4.93s
# 201:	learn: 0.1420504	total: 1.12s	remaining: 4.92s
# 202:	learn: 0.1418212	total: 1.13s	remaining: 4.92s
# 203:	learn: 0.1415982	total: 1.13s	remaining: 4.91s
# 204:	learn: 0.1413755	total: 1.14s	remaining: 4.9s
# 205:	learn: 0.1411489	total: 1.15s	remaining: 4.9s
# 206:	learn: 0.1409254	total: 1.15s	remaining: 4.89s
# 207:	learn: 0.1406981	total: 1.16s	remaining: 4.88s
# 208:	learn: 0.1404718	total: 1.16s	remaining: 4.88s
# 209:	learn: 0.1402545	total: 1.17s	remaining: 4.88s
# 210:	learn: 0.1400323	total: 1.17s	remaining: 4.87s
# 211:	learn: 0.1398123	total: 1.18s	remaining: 4.86s
# 212:	learn: 0.1395878	total: 1.18s	remaining: 4.86s
# 213:	learn: 0.1393663	total: 1.19s	remaining: 4.86s
# 214:	learn: 0.1391497	total: 1.2s	remaining: 4.85s
# 215:	learn: 0.1389315	total: 1.2s	remaining: 4.84s
# 216:	learn: 0.1387145	total: 1.21s	remaining: 4.84s
# 217:	learn: 0.1384950	total: 1.21s	remaining: 4.83s
# 218:	learn: 0.1382827	total: 1.22s	remaining: 4.83s
# 219:	learn: 0.1380650	total: 1.22s	remaining: 4.82s
# 220:	learn: 0.1378516	total: 1.23s	remaining: 4.82s
# 221:	learn: 0.1376363	total: 1.24s	remaining: 4.81s
# 222:	learn: 0.1374270	total: 1.24s	remaining: 4.81s
# 223:	learn: 0.1372144	total: 1.25s	remaining: 4.8s
# 224:	learn: 0.1370011	total: 1.25s	remaining: 4.8s
# 225:	learn: 0.1367941	total: 1.26s	remaining: 4.79s
# 226:	learn: 0.1365921	total: 1.26s	remaining: 4.79s
# 227:	learn: 0.1363845	total: 1.27s	remaining: 4.78s
# 228:	learn: 0.1361754	total: 1.28s	remaining: 4.78s
# 229:	learn: 0.1359724	total: 1.28s	remaining: 4.78s
# 230:	learn: 0.1357676	total: 1.28s	remaining: 4.76s
# 231:	learn: 0.1355656	total: 1.29s	remaining: 4.76s
# 232:	learn: 0.1353597	total: 1.3s	remaining: 4.76s
# 233:	learn: 0.1351538	total: 1.3s	remaining: 4.75s
# 234:	learn: 0.1349514	total: 1.31s	remaining: 4.75s
# 235:	learn: 0.1347479	total: 1.31s	remaining: 4.74s
# 236:	learn: 0.1345453	total: 1.32s	remaining: 4.74s
# 237:	learn: 0.1343441	total: 1.33s	remaining: 4.73s
# 238:	learn: 0.1341432	total: 1.33s	remaining: 4.73s
# 239:	learn: 0.1339419	total: 1.34s	remaining: 4.72s
# 240:	learn: 0.1337444	total: 1.34s	remaining: 4.72s
# 241:	learn: 0.1335418	total: 1.35s	remaining: 4.71s
# 242:	learn: 0.1333433	total: 1.35s	remaining: 4.7s
# 243:	learn: 0.1331473	total: 1.36s	remaining: 4.7s
# 244:	learn: 0.1329547	total: 1.36s	remaining: 4.69s
# 245:	learn: 0.1327558	total: 1.37s	remaining: 4.69s
# 246:	learn: 0.1325628	total: 1.38s	remaining: 4.68s
# 247:	learn: 0.1323678	total: 1.38s	remaining: 4.67s
# 248:	learn: 0.1321736	total: 1.39s	remaining: 4.67s
# 249:	learn: 0.1319832	total: 1.39s	remaining: 4.67s
# 250:	learn: 0.1317928	total: 1.4s	remaining: 4.66s
# 251:	learn: 0.1316039	total: 1.4s	remaining: 4.65s
# 252:	learn: 0.1314134	total: 1.41s	remaining: 4.65s
# 253:	learn: 0.1312261	total: 1.41s	remaining: 4.64s
# 254:	learn: 0.1310363	total: 1.42s	remaining: 4.63s
# 255:	learn: 0.1308554	total: 1.43s	remaining: 4.63s
# 256:	learn: 0.1306648	total: 1.43s	remaining: 4.62s
# 257:	learn: 0.1304746	total: 1.44s	remaining: 4.62s
# 258:	learn: 0.1302921	total: 1.44s	remaining: 4.61s
# 259:	learn: 0.1301108	total: 1.45s	remaining: 4.61s
# 260:	learn: 0.1299243	total: 1.45s	remaining: 4.6s
# 261:	learn: 0.1297400	total: 1.46s	remaining: 4.6s
# 262:	learn: 0.1295550	total: 1.47s	remaining: 4.59s
# 263:	learn: 0.1293738	total: 1.47s	remaining: 4.59s
# 264:	learn: 0.1291879	total: 1.48s	remaining: 4.58s
# 265:	learn: 0.1290059	total: 1.48s	remaining: 4.58s
# 266:	learn: 0.1288258	total: 1.49s	remaining: 4.57s
# 267:	learn: 0.1286515	total: 1.5s	remaining: 4.57s
# 268:	learn: 0.1284698	total: 1.5s	remaining: 4.56s
# 269:	learn: 0.1282898	total: 1.51s	remaining: 4.56s
# 270:	learn: 0.1281162	total: 1.51s	remaining: 4.55s
# 271:	learn: 0.1279398	total: 1.52s	remaining: 4.55s
# 272:	learn: 0.1277642	total: 1.52s	remaining: 4.55s
# 273:	learn: 0.1275886	total: 1.53s	remaining: 4.54s
# 274:	learn: 0.1274107	total: 1.54s	remaining: 4.54s
# 275:	learn: 0.1272366	total: 1.54s	remaining: 4.53s
# 276:	learn: 0.1270655	total: 1.55s	remaining: 4.52s
# 277:	learn: 0.1268937	total: 1.55s	remaining: 4.52s
# 278:	learn: 0.1267200	total: 1.56s	remaining: 4.52s
# 279:	learn: 0.1265470	total: 1.56s	remaining: 4.51s
# 280:	learn: 0.1263771	total: 1.57s	remaining: 4.51s
# 281:	learn: 0.1262057	total: 1.58s	remaining: 4.5s
# 282:	learn: 0.1260371	total: 1.58s	remaining: 4.49s
# 283:	learn: 0.1258668	total: 1.59s	remaining: 4.49s
# 284:	learn: 0.1256996	total: 1.59s	remaining: 4.49s
# 285:	learn: 0.1255317	total: 1.6s	remaining: 4.48s
# 286:	learn: 0.1253637	total: 1.6s	remaining: 4.48s
# 287:	learn: 0.1251944	total: 1.61s	remaining: 4.47s
# 288:	learn: 0.1250261	total: 1.61s	remaining: 4.46s
# 289:	learn: 0.1248589	total: 1.62s	remaining: 4.46s
# 290:	learn: 0.1246918	total: 1.63s	remaining: 4.45s
# 291:	learn: 0.1245274	total: 1.63s	remaining: 4.45s
# 292:	learn: 0.1243665	total: 1.64s	remaining: 4.44s
# 293:	learn: 0.1242072	total: 1.64s	remaining: 4.43s
# 294:	learn: 0.1240473	total: 1.65s	remaining: 4.43s
# 295:	learn: 0.1238871	total: 1.66s	remaining: 4.43s
# 296:	learn: 0.1237255	total: 1.66s	remaining: 4.42s
# 297:	learn: 0.1235611	total: 1.67s	remaining: 4.41s
# 298:	learn: 0.1233989	total: 1.67s	remaining: 4.41s
# 299:	learn: 0.1232412	total: 1.68s	remaining: 4.4s
# 300:	learn: 0.1230835	total: 1.68s	remaining: 4.4s
# 301:	learn: 0.1229248	total: 1.69s	remaining: 4.39s
# 302:	learn: 0.1227695	total: 1.69s	remaining: 4.38s
# 303:	learn: 0.1226136	total: 1.7s	remaining: 4.38s
# 304:	learn: 0.1224542	total: 1.71s	remaining: 4.37s
# 305:	learn: 0.1222990	total: 1.71s	remaining: 4.37s
# 306:	learn: 0.1221448	total: 1.72s	remaining: 4.36s
# 307:	learn: 0.1219888	total: 1.72s	remaining: 4.36s
# 308:	learn: 0.1218366	total: 1.73s	remaining: 4.35s
# 309:	learn: 0.1216833	total: 1.73s	remaining: 4.35s
# 310:	learn: 0.1215287	total: 1.74s	remaining: 4.34s
# 311:	learn: 0.1213713	total: 1.74s	remaining: 4.33s
# 312:	learn: 0.1212193	total: 1.75s	remaining: 4.33s
# 313:	learn: 0.1210701	total: 1.76s	remaining: 4.32s
# 314:	learn: 0.1209197	total: 1.76s	remaining: 4.32s
# 315:	learn: 0.1207702	total: 1.77s	remaining: 4.31s
# 316:	learn: 0.1206240	total: 1.77s	remaining: 4.31s
# 317:	learn: 0.1204752	total: 1.78s	remaining: 4.3s
# 318:	learn: 0.1203286	total: 1.78s	remaining: 4.3s
# 319:	learn: 0.1201739	total: 1.79s	remaining: 4.29s
# 320:	learn: 0.1200256	total: 1.79s	remaining: 4.28s
# 321:	learn: 0.1198798	total: 1.8s	remaining: 4.28s
# 322:	learn: 0.1197345	total: 1.81s	remaining: 4.27s
# 323:	learn: 0.1195858	total: 1.81s	remaining: 4.26s
# 324:	learn: 0.1194408	total: 1.82s	remaining: 4.26s
# 325:	learn: 0.1192968	total: 1.82s	remaining: 4.25s
# 326:	learn: 0.1191533	total: 1.83s	remaining: 4.25s
# 327:	learn: 0.1190086	total: 1.83s	remaining: 4.24s
# 328:	learn: 0.1188630	total: 1.84s	remaining: 4.24s
# 329:	learn: 0.1187235	total: 1.84s	remaining: 4.23s
# 330:	learn: 0.1185833	total: 1.85s	remaining: 4.22s
# 331:	learn: 0.1184397	total: 1.85s	remaining: 4.22s
# 332:	learn: 0.1182977	total: 1.86s	remaining: 4.21s
# 333:	learn: 0.1181558	total: 1.86s	remaining: 4.21s
# 334:	learn: 0.1180160	total: 1.87s	remaining: 4.2s
# 335:	learn: 0.1178758	total: 1.88s	remaining: 4.19s
# 336:	learn: 0.1177355	total: 1.88s	remaining: 4.19s
# 337:	learn: 0.1175943	total: 1.89s	remaining: 4.18s
# 338:	learn: 0.1174570	total: 1.89s	remaining: 4.17s
# 339:	learn: 0.1173202	total: 1.9s	remaining: 4.17s
# 340:	learn: 0.1171791	total: 1.9s	remaining: 4.16s
# 341:	learn: 0.1170392	total: 1.91s	remaining: 4.15s
# 342:	learn: 0.1169030	total: 1.91s	remaining: 4.15s
# 343:	learn: 0.1167666	total: 1.92s	remaining: 4.14s
# 344:	learn: 0.1166339	total: 1.92s	remaining: 4.13s
# 345:	learn: 0.1165003	total: 1.93s	remaining: 4.13s
# 346:	learn: 0.1163692	total: 1.94s	remaining: 4.14s
# 347:	learn: 0.1162337	total: 1.95s	remaining: 4.14s
# 348:	learn: 0.1161008	total: 1.96s	remaining: 4.15s
# 349:	learn: 0.1159732	total: 1.97s	remaining: 4.15s
# 350:	learn: 0.1158416	total: 1.98s	remaining: 4.14s
# 351:	learn: 0.1157075	total: 1.98s	remaining: 4.14s
# 352:	learn: 0.1155781	total: 1.99s	remaining: 4.13s
# 353:	learn: 0.1154490	total: 1.99s	remaining: 4.12s
# 354:	learn: 0.1153194	total: 2s	remaining: 4.12s
# 355:	learn: 0.1151937	total: 2s	remaining: 4.11s
# 356:	learn: 0.1150626	total: 2.01s	remaining: 4.1s
# 357:	learn: 0.1149305	total: 2.01s	remaining: 4.09s
# 358:	learn: 0.1148028	total: 2.02s	remaining: 4.09s
# 359:	learn: 0.1146757	total: 2.02s	remaining: 4.08s
# 360:	learn: 0.1145505	total: 2.03s	remaining: 4.08s
# 361:	learn: 0.1144254	total: 2.03s	remaining: 4.07s
# 362:	learn: 0.1142965	total: 2.04s	remaining: 4.06s
# 363:	learn: 0.1141712	total: 2.04s	remaining: 4.06s
# 364:	learn: 0.1140475	total: 2.05s	remaining: 4.05s
# 365:	learn: 0.1139238	total: 2.05s	remaining: 4.04s
# 366:	learn: 0.1138001	total: 2.06s	remaining: 4.04s
# 367:	learn: 0.1136775	total: 2.06s	remaining: 4.03s
# 368:	learn: 0.1135507	total: 2.07s	remaining: 4.02s
# 369:	learn: 0.1134288	total: 2.07s	remaining: 4.02s
# 370:	learn: 0.1133028	total: 2.08s	remaining: 4.01s
# 371:	learn: 0.1131826	total: 2.08s	remaining: 4s
# 372:	learn: 0.1130561	total: 2.09s	remaining: 4s
# 373:	learn: 0.1129381	total: 2.09s	remaining: 3.99s
# 374:	learn: 0.1128163	total: 2.1s	remaining: 3.98s
# 375:	learn: 0.1126951	total: 2.1s	remaining: 3.98s
# 376:	learn: 0.1125776	total: 2.11s	remaining: 3.97s
# 377:	learn: 0.1124555	total: 2.11s	remaining: 3.97s
# 378:	learn: 0.1123416	total: 2.12s	remaining: 3.96s
# 379:	learn: 0.1122273	total: 2.12s	remaining: 3.95s
# 380:	learn: 0.1121139	total: 2.13s	remaining: 3.95s
# 381:	learn: 0.1119949	total: 2.13s	remaining: 3.94s
# 382:	learn: 0.1118761	total: 2.14s	remaining: 3.93s
# 383:	learn: 0.1117607	total: 2.14s	remaining: 3.92s
# 384:	learn: 0.1116443	total: 2.15s	remaining: 3.92s
# 385:	learn: 0.1115264	total: 2.15s	remaining: 3.91s
# 386:	learn: 0.1114133	total: 2.16s	remaining: 3.91s
# 387:	learn: 0.1112959	total: 2.17s	remaining: 3.9s
# 388:	learn: 0.1111827	total: 2.17s	remaining: 3.9s
# 389:	learn: 0.1110670	total: 2.18s	remaining: 3.89s
# 390:	learn: 0.1109514	total: 2.18s	remaining: 3.88s
# 391:	learn: 0.1108420	total: 2.19s	remaining: 3.88s
# 392:	learn: 0.1107315	total: 2.19s	remaining: 3.87s
# 393:	learn: 0.1106193	total: 2.2s	remaining: 3.87s
# 394:	learn: 0.1105083	total: 2.2s	remaining: 3.86s
# 395:	learn: 0.1103972	total: 2.21s	remaining: 3.85s
# 396:	learn: 0.1102851	total: 2.21s	remaining: 3.85s
# 397:	learn: 0.1101729	total: 2.22s	remaining: 3.84s
# 398:	learn: 0.1100638	total: 2.22s	remaining: 3.83s
# 399:	learn: 0.1099524	total: 2.23s	remaining: 3.83s
# 400:	learn: 0.1098420	total: 2.23s	remaining: 3.82s
# 401:	learn: 0.1097342	total: 2.25s	remaining: 3.83s
# 402:	learn: 0.1096276	total: 2.27s	remaining: 3.85s
# 403:	learn: 0.1095206	total: 2.28s	remaining: 3.86s
# 404:	learn: 0.1094140	total: 2.29s	remaining: 3.86s
# 405:	learn: 0.1093091	total: 2.3s	remaining: 3.86s
# 406:	learn: 0.1092078	total: 2.31s	remaining: 3.86s
# 407:	learn: 0.1091014	total: 2.31s	remaining: 3.85s
# 408:	learn: 0.1089972	total: 2.32s	remaining: 3.84s
# 409:	learn: 0.1088950	total: 2.32s	remaining: 3.84s
# 410:	learn: 0.1087923	total: 2.33s	remaining: 3.83s
# 411:	learn: 0.1086882	total: 2.33s	remaining: 3.82s
# 412:	learn: 0.1085857	total: 2.34s	remaining: 3.82s
# 413:	learn: 0.1084806	total: 2.34s	remaining: 3.81s
# 414:	learn: 0.1083794	total: 2.35s	remaining: 3.81s
# 415:	learn: 0.1082784	total: 2.35s	remaining: 3.8s
# 416:	learn: 0.1081763	total: 2.36s	remaining: 3.79s
# 417:	learn: 0.1080727	total: 2.37s	remaining: 3.79s
# 418:	learn: 0.1079731	total: 2.37s	remaining: 3.78s
# 419:	learn: 0.1078724	total: 2.38s	remaining: 3.77s
# 420:	learn: 0.1077713	total: 2.38s	remaining: 3.77s
# 421:	learn: 0.1076687	total: 2.38s	remaining: 3.76s
# 422:	learn: 0.1075698	total: 2.39s	remaining: 3.75s
# 423:	learn: 0.1074703	total: 2.4s	remaining: 3.75s
# 424:	learn: 0.1073740	total: 2.4s	remaining: 3.74s
# 425:	learn: 0.1072746	total: 2.41s	remaining: 3.73s
# 426:	learn: 0.1071769	total: 2.41s	remaining: 3.73s
# 427:	learn: 0.1070778	total: 2.42s	remaining: 3.72s
# 428:	learn: 0.1069789	total: 2.42s	remaining: 3.71s
# 429:	learn: 0.1068848	total: 2.43s	remaining: 3.71s
# 430:	learn: 0.1067909	total: 2.43s	remaining: 3.7s
# 431:	learn: 0.1066976	total: 2.44s	remaining: 3.7s
# 432:	learn: 0.1066030	total: 2.44s	remaining: 3.69s
# 433:	learn: 0.1065066	total: 2.45s	remaining: 3.68s
# 434:	learn: 0.1064137	total: 2.45s	remaining: 3.68s
# 435:	learn: 0.1063183	total: 2.46s	remaining: 3.67s
# 436:	learn: 0.1062245	total: 2.46s	remaining: 3.67s
# 437:	learn: 0.1061284	total: 2.47s	remaining: 3.66s
# 438:	learn: 0.1060337	total: 2.47s	remaining: 3.65s
# 439:	learn: 0.1059426	total: 2.48s	remaining: 3.65s
# 440:	learn: 0.1058496	total: 2.48s	remaining: 3.64s
# 441:	learn: 0.1057573	total: 2.49s	remaining: 3.63s
# 442:	learn: 0.1056651	total: 2.49s	remaining: 3.63s
# 443:	learn: 0.1055719	total: 2.5s	remaining: 3.62s
# 444:	learn: 0.1054842	total: 2.5s	remaining: 3.61s
# 445:	learn: 0.1053925	total: 2.51s	remaining: 3.61s
# 446:	learn: 0.1053013	total: 2.51s	remaining: 3.6s
# 447:	learn: 0.1052108	total: 2.52s	remaining: 3.59s
# 448:	learn: 0.1051189	total: 2.52s	remaining: 3.59s
# 449:	learn: 0.1050310	total: 2.53s	remaining: 3.58s
# 450:	learn: 0.1049411	total: 2.53s	remaining: 3.57s
# 451:	learn: 0.1048540	total: 2.54s	remaining: 3.57s
# 452:	learn: 0.1047617	total: 2.54s	remaining: 3.56s
# 453:	learn: 0.1046719	total: 2.55s	remaining: 3.56s
# 454:	learn: 0.1045851	total: 2.56s	remaining: 3.55s
# 455:	learn: 0.1045017	total: 2.56s	remaining: 3.54s
# 456:	learn: 0.1044178	total: 2.57s	remaining: 3.54s
# 457:	learn: 0.1043319	total: 2.57s	remaining: 3.53s
# 458:	learn: 0.1042469	total: 2.58s	remaining: 3.53s
# 459:	learn: 0.1041597	total: 2.58s	remaining: 3.52s
# 460:	learn: 0.1040752	total: 2.59s	remaining: 3.51s
# 461:	learn: 0.1039911	total: 2.59s	remaining: 3.51s
# 462:	learn: 0.1039078	total: 2.6s	remaining: 3.5s
# 463:	learn: 0.1038238	total: 2.6s	remaining: 3.5s
# 464:	learn: 0.1037397	total: 2.61s	remaining: 3.49s
# 465:	learn: 0.1036563	total: 2.61s	remaining: 3.48s
# 466:	learn: 0.1035758	total: 2.62s	remaining: 3.48s
# 467:	learn: 0.1034909	total: 2.62s	remaining: 3.47s
# 468:	learn: 0.1034061	total: 2.63s	remaining: 3.46s
# 469:	learn: 0.1033237	total: 2.63s	remaining: 3.46s
# 470:	learn: 0.1032421	total: 2.64s	remaining: 3.45s
# 471:	learn: 0.1031623	total: 2.64s	remaining: 3.45s
# 472:	learn: 0.1030821	total: 2.65s	remaining: 3.44s
# 473:	learn: 0.1030030	total: 2.65s	remaining: 3.43s
# 474:	learn: 0.1029199	total: 2.66s	remaining: 3.43s
# 475:	learn: 0.1028402	total: 2.67s	remaining: 3.42s
# 476:	learn: 0.1027627	total: 2.67s	remaining: 3.42s
# 477:	learn: 0.1026805	total: 2.67s	remaining: 3.41s
# 478:	learn: 0.1026008	total: 2.68s	remaining: 3.4s
# 479:	learn: 0.1025214	total: 2.69s	remaining: 3.4s
# 480:	learn: 0.1024380	total: 2.69s	remaining: 3.39s
# 481:	learn: 0.1023597	total: 2.7s	remaining: 3.38s
# 482:	learn: 0.1022846	total: 2.7s	remaining: 3.38s
# 483:	learn: 0.1022064	total: 2.71s	remaining: 3.37s
# 484:	learn: 0.1021283	total: 2.71s	remaining: 3.37s
# 485:	learn: 0.1020512	total: 2.72s	remaining: 3.36s
# 486:	learn: 0.1019740	total: 2.72s	remaining: 3.35s
# 487:	learn: 0.1018971	total: 2.73s	remaining: 3.35s
# 488:	learn: 0.1018192	total: 2.73s	remaining: 3.34s
# 489:	learn: 0.1017431	total: 2.74s	remaining: 3.34s
# 490:	learn: 0.1016660	total: 2.74s	remaining: 3.33s
# 491:	learn: 0.1015911	total: 2.75s	remaining: 3.32s
# 492:	learn: 0.1015140	total: 2.75s	remaining: 3.32s
# 493:	learn: 0.1014375	total: 2.76s	remaining: 3.31s
# 494:	learn: 0.1013633	total: 2.76s	remaining: 3.31s
# 495:	learn: 0.1012903	total: 2.77s	remaining: 3.3s
# 496:	learn: 0.1012173	total: 2.77s	remaining: 3.29s
# 497:	learn: 0.1011426	total: 2.78s	remaining: 3.29s
# 498:	learn: 0.1010692	total: 2.78s	remaining: 3.28s
# 499:	learn: 0.1009943	total: 2.79s	remaining: 3.27s
# 500:	learn: 0.1009172	total: 2.79s	remaining: 3.27s
# 501:	learn: 0.1008463	total: 2.8s	remaining: 3.26s
# 502:	learn: 0.1007718	total: 2.81s	remaining: 3.26s
# 503:	learn: 0.1007019	total: 2.81s	remaining: 3.25s
# 504:	learn: 0.1006294	total: 2.82s	remaining: 3.25s
# 505:	learn: 0.1005564	total: 2.82s	remaining: 3.24s
# 506:	learn: 0.1004822	total: 2.83s	remaining: 3.23s
# 507:	learn: 0.1004103	total: 2.83s	remaining: 3.23s
# 508:	learn: 0.1003387	total: 2.84s	remaining: 3.22s
# 509:	learn: 0.1002700	total: 2.84s	remaining: 3.21s
# 510:	learn: 0.1001980	total: 2.85s	remaining: 3.21s
# 511:	learn: 0.1001273	total: 2.85s	remaining: 3.2s
# 512:	learn: 0.1000605	total: 2.86s	remaining: 3.2s
# 513:	learn: 0.0999889	total: 2.86s	remaining: 3.19s
# 514:	learn: 0.0999222	total: 2.87s	remaining: 3.19s
# 515:	learn: 0.0998557	total: 2.87s	remaining: 3.18s
# 516:	learn: 0.0997854	total: 2.88s	remaining: 3.17s
# 517:	learn: 0.0997153	total: 2.88s	remaining: 3.17s
# 518:	learn: 0.0996513	total: 2.89s	remaining: 3.16s
# 519:	learn: 0.0995825	total: 2.89s	remaining: 3.15s
# 520:	learn: 0.0995157	total: 2.9s	remaining: 3.15s
# 521:	learn: 0.0994485	total: 2.9s	remaining: 3.14s
# 522:	learn: 0.0993816	total: 2.91s	remaining: 3.14s
# 523:	learn: 0.0993145	total: 2.91s	remaining: 3.13s
# 524:	learn: 0.0992506	total: 2.92s	remaining: 3.13s
# 525:	learn: 0.0991803	total: 2.92s	remaining: 3.12s
# 526:	learn: 0.0991134	total: 2.93s	remaining: 3.11s
# 527:	learn: 0.0990465	total: 2.94s	remaining: 3.11s
# 528:	learn: 0.0989823	total: 2.94s	remaining: 3.1s
# 529:	learn: 0.0989167	total: 2.94s	remaining: 3.1s
# 530:	learn: 0.0988536	total: 2.95s	remaining: 3.09s
# 531:	learn: 0.0987884	total: 2.96s	remaining: 3.08s
# 532:	learn: 0.0987232	total: 2.96s	remaining: 3.08s
# 533:	learn: 0.0986588	total: 2.96s	remaining: 3.07s
# 534:	learn: 0.0985953	total: 2.97s	remaining: 3.06s
# 535:	learn: 0.0985287	total: 2.98s	remaining: 3.06s
# 536:	learn: 0.0984651	total: 2.98s	remaining: 3.05s
# 537:	learn: 0.0984033	total: 2.98s	remaining: 3.05s
# 538:	learn: 0.0983416	total: 2.99s	remaining: 3.04s
# 539:	learn: 0.0982786	total: 3s	remaining: 3.03s
# 540:	learn: 0.0982159	total: 3s	remaining: 3.03s
# 541:	learn: 0.0981539	total: 3s	remaining: 3.02s
# 542:	learn: 0.0980935	total: 3.01s	remaining: 3.02s
# 543:	learn: 0.0980322	total: 3.02s	remaining: 3.01s
# 544:	learn: 0.0979713	total: 3.02s	remaining: 3s
# 545:	learn: 0.0979092	total: 3.02s	remaining: 3s
# 546:	learn: 0.0978465	total: 3.03s	remaining: 2.99s
# 547:	learn: 0.0977851	total: 3.04s	remaining: 2.99s
# 548:	learn: 0.0977232	total: 3.04s	remaining: 2.98s
# 549:	learn: 0.0976639	total: 3.05s	remaining: 2.98s
# 550:	learn: 0.0976044	total: 3.05s	remaining: 2.97s
# 551:	learn: 0.0975447	total: 3.06s	remaining: 2.96s
# 552:	learn: 0.0974871	total: 3.06s	remaining: 2.96s
# 553:	learn: 0.0974285	total: 3.07s	remaining: 2.95s
# 554:	learn: 0.0973709	total: 3.07s	remaining: 2.95s
# 555:	learn: 0.0973153	total: 3.08s	remaining: 2.94s
# 556:	learn: 0.0972532	total: 3.08s	remaining: 2.93s
# 557:	learn: 0.0971944	total: 3.09s	remaining: 2.93s
# 558:	learn: 0.0971374	total: 3.09s	remaining: 2.92s
# 559:	learn: 0.0970804	total: 3.1s	remaining: 2.92s
# 560:	learn: 0.0970243	total: 3.1s	remaining: 2.91s
# 561:	learn: 0.0969679	total: 3.11s	remaining: 2.9s
# 562:	learn: 0.0969095	total: 3.11s	remaining: 2.9s
# 563:	learn: 0.0968501	total: 3.12s	remaining: 2.89s
# 564:	learn: 0.0967918	total: 3.12s	remaining: 2.89s
# 565:	learn: 0.0967335	total: 3.13s	remaining: 2.88s
# 566:	learn: 0.0966781	total: 3.13s	remaining: 2.88s
# 567:	learn: 0.0966248	total: 3.14s	remaining: 2.87s
# 568:	learn: 0.0965708	total: 3.15s	remaining: 2.86s
# 569:	learn: 0.0965184	total: 3.15s	remaining: 2.86s
# 570:	learn: 0.0964626	total: 3.16s	remaining: 2.85s
# 571:	learn: 0.0964049	total: 3.16s	remaining: 2.85s
# 572:	learn: 0.0963516	total: 3.17s	remaining: 2.84s
# 573:	learn: 0.0962971	total: 3.17s	remaining: 2.83s
# 574:	learn: 0.0962433	total: 3.18s	remaining: 2.83s
# 575:	learn: 0.0961900	total: 3.18s	remaining: 2.82s
# 576:	learn: 0.0961348	total: 3.19s	remaining: 2.82s
# 577:	learn: 0.0960803	total: 3.19s	remaining: 2.81s
# 578:	learn: 0.0960290	total: 3.2s	remaining: 2.81s
# 579:	learn: 0.0959751	total: 3.2s	remaining: 2.8s
# 580:	learn: 0.0959228	total: 3.21s	remaining: 2.79s
# 581:	learn: 0.0958712	total: 3.21s	remaining: 2.79s
# 582:	learn: 0.0958190	total: 3.22s	remaining: 2.78s
# 583:	learn: 0.0957654	total: 3.22s	remaining: 2.77s
# 584:	learn: 0.0957104	total: 3.23s	remaining: 2.77s
# 585:	learn: 0.0956618	total: 3.23s	remaining: 2.76s
# 586:	learn: 0.0956117	total: 3.24s	remaining: 2.76s
# 587:	learn: 0.0955624	total: 3.24s	remaining: 2.75s
# 588:	learn: 0.0955121	total: 3.25s	remaining: 2.75s
# 589:	learn: 0.0954595	total: 3.25s	remaining: 2.74s
# 590:	learn: 0.0954086	total: 3.26s	remaining: 2.73s
# 591:	learn: 0.0953593	total: 3.26s	remaining: 2.73s
# 592:	learn: 0.0953094	total: 3.27s	remaining: 2.72s
# 593:	learn: 0.0952603	total: 3.27s	remaining: 2.72s
# 594:	learn: 0.0952120	total: 3.28s	remaining: 2.71s
# 595:	learn: 0.0951636	total: 3.28s	remaining: 2.71s
# 596:	learn: 0.0951096	total: 3.29s	remaining: 2.7s
# 597:	learn: 0.0950575	total: 3.29s	remaining: 2.69s
# 598:	learn: 0.0950074	total: 3.3s	remaining: 2.69s
# 599:	learn: 0.0949560	total: 3.3s	remaining: 2.68s
# 600:	learn: 0.0949057	total: 3.31s	remaining: 2.67s
# 601:	learn: 0.0948568	total: 3.31s	remaining: 2.67s
# 602:	learn: 0.0948091	total: 3.32s	remaining: 2.66s
# 603:	learn: 0.0947585	total: 3.32s	remaining: 2.66s
# 604:	learn: 0.0947097	total: 3.33s	remaining: 2.65s
# 605:	learn: 0.0946640	total: 3.33s	remaining: 2.65s
# 606:	learn: 0.0946169	total: 3.34s	remaining: 2.64s
# 607:	learn: 0.0945698	total: 3.34s	remaining: 2.63s
# 608:	learn: 0.0945191	total: 3.35s	remaining: 2.63s
# 609:	learn: 0.0944693	total: 3.35s	remaining: 2.62s
# 610:	learn: 0.0944236	total: 3.36s	remaining: 2.62s
# 611:	learn: 0.0943754	total: 3.37s	remaining: 2.61s
# 612:	learn: 0.0943283	total: 3.37s	remaining: 2.6s
# 613:	learn: 0.0942811	total: 3.38s	remaining: 2.6s
# 614:	learn: 0.0942362	total: 3.38s	remaining: 2.59s
# 615:	learn: 0.0941900	total: 3.38s	remaining: 2.59s
# 616:	learn: 0.0941389	total: 3.39s	remaining: 2.58s
# 617:	learn: 0.0940920	total: 3.4s	remaining: 2.58s
# 618:	learn: 0.0940467	total: 3.4s	remaining: 2.57s
# 619:	learn: 0.0939971	total: 3.4s	remaining: 2.56s
# 620:	learn: 0.0939475	total: 3.41s	remaining: 2.56s
# 621:	learn: 0.0939024	total: 3.42s	remaining: 2.55s
# 622:	learn: 0.0938551	total: 3.42s	remaining: 2.55s
# 623:	learn: 0.0938101	total: 3.42s	remaining: 2.54s
# 624:	learn: 0.0937667	total: 3.43s	remaining: 2.54s
# 625:	learn: 0.0937206	total: 3.44s	remaining: 2.53s
# 626:	learn: 0.0936730	total: 3.44s	remaining: 2.52s
# 627:	learn: 0.0936312	total: 3.45s	remaining: 2.52s
# 628:	learn: 0.0935907	total: 3.45s	remaining: 2.51s
# 629:	learn: 0.0935475	total: 3.46s	remaining: 2.51s
# 630:	learn: 0.0935047	total: 3.46s	remaining: 2.5s
# 631:	learn: 0.0934605	total: 3.47s	remaining: 2.5s
# 632:	learn: 0.0934190	total: 3.47s	remaining: 2.49s
# 633:	learn: 0.0933765	total: 3.48s	remaining: 2.48s
# 634:	learn: 0.0933368	total: 3.48s	remaining: 2.48s
# 635:	learn: 0.0932939	total: 3.49s	remaining: 2.47s
# 636:	learn: 0.0932488	total: 3.49s	remaining: 2.47s
# 637:	learn: 0.0932039	total: 3.5s	remaining: 2.46s
# 638:	learn: 0.0931615	total: 3.5s	remaining: 2.46s
# 639:	learn: 0.0931183	total: 3.51s	remaining: 2.45s
# 640:	learn: 0.0930773	total: 3.51s	remaining: 2.44s
# 641:	learn: 0.0930337	total: 3.52s	remaining: 2.44s
# 642:	learn: 0.0929920	total: 3.52s	remaining: 2.43s
# 643:	learn: 0.0929509	total: 3.53s	remaining: 2.43s
# 644:	learn: 0.0929108	total: 3.53s	remaining: 2.42s
# 645:	learn: 0.0928690	total: 3.54s	remaining: 2.42s
# 646:	learn: 0.0928288	total: 3.54s	remaining: 2.41s
# 647:	learn: 0.0927872	total: 3.55s	remaining: 2.4s
# 648:	learn: 0.0927462	total: 3.55s	remaining: 2.4s
# 649:	learn: 0.0927057	total: 3.56s	remaining: 2.39s
# 650:	learn: 0.0926650	total: 3.56s	remaining: 2.39s
# 651:	learn: 0.0926255	total: 3.57s	remaining: 2.38s
# 652:	learn: 0.0925848	total: 3.57s	remaining: 2.38s
# 653:	learn: 0.0925470	total: 3.58s	remaining: 2.37s
# 654:	learn: 0.0925021	total: 3.58s	remaining: 2.36s
# 655:	learn: 0.0924618	total: 3.59s	remaining: 2.36s
# 656:	learn: 0.0924239	total: 3.59s	remaining: 2.35s
# 657:	learn: 0.0923858	total: 3.6s	remaining: 2.35s
# 658:	learn: 0.0923419	total: 3.6s	remaining: 2.34s
# 659:	learn: 0.0923060	total: 3.61s	remaining: 2.33s
# 660:	learn: 0.0922688	total: 3.62s	remaining: 2.33s
# 661:	learn: 0.0922255	total: 3.62s	remaining: 2.32s
# 662:	learn: 0.0921875	total: 3.63s	remaining: 2.32s
# 663:	learn: 0.0921516	total: 3.63s	remaining: 2.31s
# 664:	learn: 0.0921160	total: 3.64s	remaining: 2.31s
# 665:	learn: 0.0920783	total: 3.64s	remaining: 2.3s
# 666:	learn: 0.0920402	total: 3.65s	remaining: 2.3s
# 667:	learn: 0.0920040	total: 3.65s	remaining: 2.29s
# 668:	learn: 0.0919684	total: 3.66s	remaining: 2.28s
# 669:	learn: 0.0919319	total: 3.66s	remaining: 2.28s
# 670:	learn: 0.0918965	total: 3.67s	remaining: 2.27s
# 671:	learn: 0.0918622	total: 3.67s	remaining: 2.27s
# 672:	learn: 0.0918206	total: 3.68s	remaining: 2.26s
# 673:	learn: 0.0917803	total: 3.68s	remaining: 2.26s
# 674:	learn: 0.0917460	total: 3.69s	remaining: 2.25s
# 675:	learn: 0.0917052	total: 3.69s	remaining: 2.24s
# 676:	learn: 0.0916668	total: 3.7s	remaining: 2.24s
# 677:	learn: 0.0916287	total: 3.7s	remaining: 2.23s
# 678:	learn: 0.0915912	total: 3.71s	remaining: 2.23s
# 679:	learn: 0.0915550	total: 3.71s	remaining: 2.22s
# 680:	learn: 0.0915143	total: 3.72s	remaining: 2.22s
# 681:	learn: 0.0914787	total: 3.72s	remaining: 2.21s
# 682:	learn: 0.0914442	total: 3.73s	remaining: 2.21s
# 683:	learn: 0.0914104	total: 3.73s	remaining: 2.2s
# 684:	learn: 0.0913752	total: 3.74s	remaining: 2.19s
# 685:	learn: 0.0913402	total: 3.74s	remaining: 2.19s
# 686:	learn: 0.0913079	total: 3.75s	remaining: 2.18s
# 687:	learn: 0.0912690	total: 3.75s	remaining: 2.18s
# 688:	learn: 0.0912352	total: 3.76s	remaining: 2.17s
# 689:	learn: 0.0912000	total: 3.77s	remaining: 2.17s
# 690:	learn: 0.0911631	total: 3.77s	remaining: 2.16s
# 691:	learn: 0.0911286	total: 3.77s	remaining: 2.15s
# 692:	learn: 0.0910954	total: 3.78s	remaining: 2.15s
# 693:	learn: 0.0910629	total: 3.79s	remaining: 2.14s
# 694:	learn: 0.0910278	total: 3.79s	remaining: 2.14s
# 695:	learn: 0.0909916	total: 3.8s	remaining: 2.13s
# 696:	learn: 0.0909557	total: 3.8s	remaining: 2.13s
# 697:	learn: 0.0909224	total: 3.81s	remaining: 2.12s
# 698:	learn: 0.0908895	total: 3.81s	remaining: 2.12s
# 699:	learn: 0.0908554	total: 3.82s	remaining: 2.11s
# 700:	learn: 0.0908211	total: 3.82s	remaining: 2.1s
# 701:	learn: 0.0907854	total: 3.83s	remaining: 2.1s
# 702:	learn: 0.0907527	total: 3.83s	remaining: 2.09s
# 703:	learn: 0.0907197	total: 3.84s	remaining: 2.09s
# 704:	learn: 0.0906871	total: 3.84s	remaining: 2.08s
# 705:	learn: 0.0906548	total: 3.85s	remaining: 2.08s
# 706:	learn: 0.0906212	total: 3.85s	remaining: 2.07s
# 707:	learn: 0.0905890	total: 3.86s	remaining: 2.06s
# 708:	learn: 0.0905527	total: 3.86s	remaining: 2.06s
# 709:	learn: 0.0905219	total: 3.87s	remaining: 2.05s
# 710:	learn: 0.0904882	total: 3.87s	remaining: 2.05s
# 711:	learn: 0.0904578	total: 3.88s	remaining: 2.04s
# 712:	learn: 0.0904273	total: 3.88s	remaining: 2.04s
# 713:	learn: 0.0903960	total: 3.89s	remaining: 2.03s
# 714:	learn: 0.0903630	total: 3.89s	remaining: 2.03s
# 715:	learn: 0.0903340	total: 3.9s	remaining: 2.02s
# 716:	learn: 0.0903043	total: 3.9s	remaining: 2.02s
# 717:	learn: 0.0902717	total: 3.91s	remaining: 2.01s
# 718:	learn: 0.0902415	total: 3.91s	remaining: 2s
# 719:	learn: 0.0902107	total: 3.92s	remaining: 2s
# 720:	learn: 0.0901770	total: 3.92s	remaining: 1.99s
# 721:	learn: 0.0901480	total: 3.93s	remaining: 1.99s
# 722:	learn: 0.0901180	total: 3.93s	remaining: 1.98s
# 723:	learn: 0.0900887	total: 3.94s	remaining: 1.98s
# 724:	learn: 0.0900611	total: 3.94s	remaining: 1.97s
# 725:	learn: 0.0900324	total: 3.95s	remaining: 1.96s
# 726:	learn: 0.0900039	total: 3.96s	remaining: 1.96s
# 727:	learn: 0.0899731	total: 3.96s	remaining: 1.95s
# 728:	learn: 0.0899461	total: 3.97s	remaining: 1.95s
# 729:	learn: 0.0899162	total: 3.97s	remaining: 1.94s
# 730:	learn: 0.0898856	total: 3.98s	remaining: 1.94s
# 731:	learn: 0.0898567	total: 3.98s	remaining: 1.93s
# 732:	learn: 0.0898259	total: 3.99s	remaining: 1.93s
# 733:	learn: 0.0897966	total: 3.99s	remaining: 1.92s
# 734:	learn: 0.0897684	total: 4s	remaining: 1.91s
# 735:	learn: 0.0897390	total: 4s	remaining: 1.91s
# 736:	learn: 0.0897096	total: 4.01s	remaining: 1.9s
# 737:	learn: 0.0896763	total: 4.01s	remaining: 1.9s
# 738:	learn: 0.0896499	total: 4.02s	remaining: 1.89s
# 739:	learn: 0.0896217	total: 4.02s	remaining: 1.89s
# 740:	learn: 0.0895930	total: 4.03s	remaining: 1.88s
# 741:	learn: 0.0895626	total: 4.03s	remaining: 1.87s
# 742:	learn: 0.0895338	total: 4.04s	remaining: 1.87s
# 743:	learn: 0.0895063	total: 4.04s	remaining: 1.86s
# 744:	learn: 0.0894795	total: 4.05s	remaining: 1.86s
# 745:	learn: 0.0894496	total: 4.05s	remaining: 1.85s
# 746:	learn: 0.0894215	total: 4.06s	remaining: 1.85s
# 747:	learn: 0.0893883	total: 4.06s	remaining: 1.84s
# 748:	learn: 0.0893610	total: 4.07s	remaining: 1.83s
# 749:	learn: 0.0893336	total: 4.07s	remaining: 1.83s
# 750:	learn: 0.0893061	total: 4.08s	remaining: 1.82s
# 751:	learn: 0.0892779	total: 4.08s	remaining: 1.82s
# 752:	learn: 0.0892519	total: 4.09s	remaining: 1.81s
# 753:	learn: 0.0892247	total: 4.09s	remaining: 1.81s
# 754:	learn: 0.0891990	total: 4.1s	remaining: 1.8s
# 755:	learn: 0.0891724	total: 4.1s	remaining: 1.8s
# 756:	learn: 0.0891462	total: 4.11s	remaining: 1.79s
# 757:	learn: 0.0891186	total: 4.11s	remaining: 1.78s
# 758:	learn: 0.0890880	total: 4.12s	remaining: 1.78s
# 759:	learn: 0.0890628	total: 4.12s	remaining: 1.77s
# 760:	learn: 0.0890361	total: 4.13s	remaining: 1.77s
# 761:	learn: 0.0890102	total: 4.13s	remaining: 1.76s
# 762:	learn: 0.0889845	total: 4.14s	remaining: 1.76s
# 763:	learn: 0.0889575	total: 4.14s	remaining: 1.75s
# 764:	learn: 0.0889332	total: 4.15s	remaining: 1.75s
# 765:	learn: 0.0889079	total: 4.15s	remaining: 1.74s
# 766:	learn: 0.0888814	total: 4.16s	remaining: 1.73s
# 767:	learn: 0.0888563	total: 4.16s	remaining: 1.73s
# 768:	learn: 0.0888311	total: 4.17s	remaining: 1.72s
# 769:	learn: 0.0888055	total: 4.17s	remaining: 1.72s
# 770:	learn: 0.0887803	total: 4.18s	remaining: 1.71s
# 771:	learn: 0.0887554	total: 4.18s	remaining: 1.71s
# 772:	learn: 0.0887316	total: 4.19s	remaining: 1.7s
# 773:	learn: 0.0887050	total: 4.19s	remaining: 1.7s
# 774:	learn: 0.0886804	total: 4.2s	remaining: 1.69s
# 775:	learn: 0.0886563	total: 4.2s	remaining: 1.68s
# 776:	learn: 0.0886312	total: 4.21s	remaining: 1.68s
# 777:	learn: 0.0886075	total: 4.21s	remaining: 1.67s
# 778:	learn: 0.0885835	total: 4.22s	remaining: 1.67s
# 779:	learn: 0.0885592	total: 4.22s	remaining: 1.66s
# 780:	learn: 0.0885348	total: 4.23s	remaining: 1.66s
# 781:	learn: 0.0885067	total: 4.24s	remaining: 1.65s
# 782:	learn: 0.0884825	total: 4.24s	remaining: 1.65s
# 783:	learn: 0.0884593	total: 4.25s	remaining: 1.64s
# 784:	learn: 0.0884336	total: 4.25s	remaining: 1.64s
# 785:	learn: 0.0884111	total: 4.25s	remaining: 1.63s
# 786:	learn: 0.0883838	total: 4.26s	remaining: 1.62s
# 787:	learn: 0.0883603	total: 4.27s	remaining: 1.62s
# 788:	learn: 0.0883331	total: 4.27s	remaining: 1.61s
# 789:	learn: 0.0883095	total: 4.28s	remaining: 1.61s
# 790:	learn: 0.0882811	total: 4.28s	remaining: 1.6s
# 791:	learn: 0.0882577	total: 4.29s	remaining: 1.6s
# 792:	learn: 0.0882351	total: 4.29s	remaining: 1.59s
# 793:	learn: 0.0882116	total: 4.3s	remaining: 1.59s
# 794:	learn: 0.0881885	total: 4.3s	remaining: 1.58s
# 795:	learn: 0.0881654	total: 4.31s	remaining: 1.57s
# 796:	learn: 0.0881420	total: 4.31s	remaining: 1.57s
# 797:	learn: 0.0881168	total: 4.32s	remaining: 1.56s
# 798:	learn: 0.0880950	total: 4.32s	remaining: 1.56s
# 799:	learn: 0.0880725	total: 4.33s	remaining: 1.55s
# 800:	learn: 0.0880494	total: 4.33s	remaining: 1.55s
# 801:	learn: 0.0880265	total: 4.34s	remaining: 1.54s
# 802:	learn: 0.0880002	total: 4.34s	remaining: 1.54s
# 803:	learn: 0.0879781	total: 4.35s	remaining: 1.53s
# 804:	learn: 0.0879535	total: 4.35s	remaining: 1.52s
# 805:	learn: 0.0879315	total: 4.36s	remaining: 1.52s
# 806:	learn: 0.0879075	total: 4.36s	remaining: 1.51s
# 807:	learn: 0.0878840	total: 4.37s	remaining: 1.51s
# 808:	learn: 0.0878614	total: 4.37s	remaining: 1.5s
# 809:	learn: 0.0878407	total: 4.38s	remaining: 1.5s
# 810:	learn: 0.0878179	total: 4.38s	remaining: 1.49s
# 811:	learn: 0.0877932	total: 4.39s	remaining: 1.49s
# 812:	learn: 0.0877670	total: 4.39s	remaining: 1.48s
# 813:	learn: 0.0877447	total: 4.4s	remaining: 1.48s
# 814:	learn: 0.0877238	total: 4.41s	remaining: 1.47s
# 815:	learn: 0.0877022	total: 4.41s	remaining: 1.47s
# 816:	learn: 0.0876812	total: 4.42s	remaining: 1.46s
# 817:	learn: 0.0876588	total: 4.42s	remaining: 1.45s
# 818:	learn: 0.0876344	total: 4.43s	remaining: 1.45s
# 819:	learn: 0.0876096	total: 4.43s	remaining: 1.44s
# 820:	learn: 0.0875876	total: 4.44s	remaining: 1.44s
# 821:	learn: 0.0875631	total: 4.44s	remaining: 1.43s
# 822:	learn: 0.0875416	total: 4.45s	remaining: 1.43s
# 823:	learn: 0.0875218	total: 4.45s	remaining: 1.42s
# 824:	learn: 0.0874983	total: 4.46s	remaining: 1.42s
# 825:	learn: 0.0874779	total: 4.46s	remaining: 1.41s
# 826:	learn: 0.0874565	total: 4.47s	remaining: 1.41s
# 827:	learn: 0.0874336	total: 4.47s	remaining: 1.4s
# 828:	learn: 0.0874120	total: 4.48s	remaining: 1.39s
# 829:	learn: 0.0873918	total: 4.48s	remaining: 1.39s
# 830:	learn: 0.0873696	total: 4.49s	remaining: 1.38s
# 831:	learn: 0.0873457	total: 4.5s	remaining: 1.38s
# 832:	learn: 0.0873248	total: 4.5s	remaining: 1.37s
# 833:	learn: 0.0873017	total: 4.5s	remaining: 1.37s
# 834:	learn: 0.0872800	total: 4.51s	remaining: 1.36s
# 835:	learn: 0.0872607	total: 4.51s	remaining: 1.35s
# 836:	learn: 0.0872394	total: 4.52s	remaining: 1.35s
# 837:	learn: 0.0872194	total: 4.53s	remaining: 1.34s
# 838:	learn: 0.0871950	total: 4.53s	remaining: 1.34s
# 839:	learn: 0.0871753	total: 4.54s	remaining: 1.33s
# 840:	learn: 0.0871555	total: 4.54s	remaining: 1.33s
# 841:	learn: 0.0871318	total: 4.55s	remaining: 1.32s
# 842:	learn: 0.0871122	total: 4.55s	remaining: 1.32s
# 843:	learn: 0.0870894	total: 4.55s	remaining: 1.31s
# 844:	learn: 0.0870708	total: 4.56s	remaining: 1.31s
# 845:	learn: 0.0870521	total: 4.57s	remaining: 1.3s
# 846:	learn: 0.0870330	total: 4.57s	remaining: 1.29s
# 847:	learn: 0.0870110	total: 4.58s	remaining: 1.29s
# 848:	learn: 0.0869913	total: 4.58s	remaining: 1.28s
# 849:	learn: 0.0869724	total: 4.59s	remaining: 1.28s
# 850:	learn: 0.0869537	total: 4.59s	remaining: 1.27s
# 851:	learn: 0.0869359	total: 4.6s	remaining: 1.27s
# 852:	learn: 0.0869161	total: 4.6s	remaining: 1.26s
# 853:	learn: 0.0868980	total: 4.61s	remaining: 1.26s
# 854:	learn: 0.0868799	total: 4.61s	remaining: 1.25s
# 855:	learn: 0.0868589	total: 4.62s	remaining: 1.25s
# 856:	learn: 0.0868380	total: 4.62s	remaining: 1.24s
# 857:	learn: 0.0868152	total: 4.63s	remaining: 1.24s
# 858:	learn: 0.0867970	total: 4.63s	remaining: 1.23s
# 859:	learn: 0.0867766	total: 4.64s	remaining: 1.22s
# 860:	learn: 0.0867542	total: 4.64s	remaining: 1.22s
# 861:	learn: 0.0867364	total: 4.65s	remaining: 1.21s
# 862:	learn: 0.0867167	total: 4.65s	remaining: 1.21s
# 863:	learn: 0.0866985	total: 4.66s	remaining: 1.2s
# 864:	learn: 0.0866775	total: 4.66s	remaining: 1.2s
# 865:	learn: 0.0866596	total: 4.67s	remaining: 1.19s
# 866:	learn: 0.0866402	total: 4.67s	remaining: 1.19s
# 867:	learn: 0.0866201	total: 4.68s	remaining: 1.18s
# 868:	learn: 0.0866013	total: 4.68s	remaining: 1.18s
# 869:	learn: 0.0865830	total: 4.69s	remaining: 1.17s
# 870:	learn: 0.0865652	total: 4.7s	remaining: 1.16s
# 871:	learn: 0.0865472	total: 4.7s	remaining: 1.16s
# 872:	learn: 0.0865300	total: 4.71s	remaining: 1.15s
# 873:	learn: 0.0865128	total: 4.71s	remaining: 1.15s
# 874:	learn: 0.0864954	total: 4.72s	remaining: 1.14s
# 875:	learn: 0.0864760	total: 4.72s	remaining: 1.14s
# 876:	learn: 0.0864573	total: 4.73s	remaining: 1.13s
# 877:	learn: 0.0864408	total: 4.73s	remaining: 1.13s
# 878:	learn: 0.0864230	total: 4.74s	remaining: 1.12s
# 879:	learn: 0.0864054	total: 4.74s	remaining: 1.11s
# 880:	learn: 0.0863891	total: 4.75s	remaining: 1.11s
# 881:	learn: 0.0863728	total: 4.75s	remaining: 1.1s
# 882:	learn: 0.0863563	total: 4.76s	remaining: 1.1s
# 883:	learn: 0.0863392	total: 4.76s	remaining: 1.09s
# 884:	learn: 0.0863224	total: 4.77s	remaining: 1.09s
# 885:	learn: 0.0863043	total: 4.77s	remaining: 1.08s
# 886:	learn: 0.0862861	total: 4.78s	remaining: 1.08s
# 887:	learn: 0.0862655	total: 4.78s	remaining: 1.07s
# 888:	learn: 0.0862494	total: 4.79s	remaining: 1.07s
# 889:	learn: 0.0862313	total: 4.79s	remaining: 1.06s
# 890:	learn: 0.0862151	total: 4.8s	remaining: 1.06s
# 891:	learn: 0.0861988	total: 4.81s	remaining: 1.05s
# 892:	learn: 0.0861795	total: 4.81s	remaining: 1.04s
# 893:	learn: 0.0861626	total: 4.82s	remaining: 1.04s
# 894:	learn: 0.0861464	total: 4.82s	remaining: 1.03s
# 895:	learn: 0.0861264	total: 4.83s	remaining: 1.03s
# 896:	learn: 0.0861102	total: 4.83s	remaining: 1.02s
# 897:	learn: 0.0860954	total: 4.84s	remaining: 1.02s
# 898:	learn: 0.0860786	total: 4.84s	remaining: 1.01s
# 899:	learn: 0.0860624	total: 4.85s	remaining: 1.01s
# 900:	learn: 0.0860472	total: 4.85s	remaining: 1s
# 901:	learn: 0.0860309	total: 4.86s	remaining: 996ms
# 902:	learn: 0.0860123	total: 4.86s	remaining: 991ms
# 903:	learn: 0.0859968	total: 4.87s	remaining: 985ms
# 904:	learn: 0.0859816	total: 4.87s	remaining: 980ms
# 905:	learn: 0.0859668	total: 4.88s	remaining: 975ms
# 906:	learn: 0.0859509	total: 4.88s	remaining: 969ms
# 907:	learn: 0.0859339	total: 4.89s	remaining: 964ms
# 908:	learn: 0.0859185	total: 4.89s	remaining: 958ms
# 909:	learn: 0.0859014	total: 4.9s	remaining: 953ms
# 910:	learn: 0.0858854	total: 4.9s	remaining: 948ms
# 911:	learn: 0.0858669	total: 4.91s	remaining: 942ms
# 912:	learn: 0.0858522	total: 4.91s	remaining: 937ms
# 913:	learn: 0.0858345	total: 4.92s	remaining: 931ms
# 914:	learn: 0.0858197	total: 4.92s	remaining: 926ms
# 915:	learn: 0.0858024	total: 4.93s	remaining: 920ms
# 916:	learn: 0.0857854	total: 4.94s	remaining: 915ms
# 917:	learn: 0.0857656	total: 4.94s	remaining: 910ms
# 918:	learn: 0.0857500	total: 4.95s	remaining: 904ms
# 919:	learn: 0.0857348	total: 4.95s	remaining: 899ms
# 920:	learn: 0.0857175	total: 4.96s	remaining: 893ms
# 921:	learn: 0.0857014	total: 4.96s	remaining: 888ms
# 922:	learn: 0.0856868	total: 4.97s	remaining: 883ms
# 923:	learn: 0.0856728	total: 4.97s	remaining: 877ms
# 924:	learn: 0.0856588	total: 4.98s	remaining: 872ms
# 925:	learn: 0.0856429	total: 4.98s	remaining: 866ms
# 926:	learn: 0.0856280	total: 4.99s	remaining: 861ms
# 927:	learn: 0.0856136	total: 4.99s	remaining: 856ms
# 928:	learn: 0.0855952	total: 5s	remaining: 850ms
# 929:	learn: 0.0855809	total: 5s	remaining: 845ms
# 930:	learn: 0.0855642	total: 5.01s	remaining: 839ms
# 931:	learn: 0.0855482	total: 5.01s	remaining: 834ms
# 932:	learn: 0.0855322	total: 5.02s	remaining: 829ms
# 933:	learn: 0.0855161	total: 5.03s	remaining: 823ms
# 934:	learn: 0.0854971	total: 5.03s	remaining: 818ms
# 935:	learn: 0.0854823	total: 5.04s	remaining: 812ms
# 936:	learn: 0.0854683	total: 5.04s	remaining: 807ms
# 937:	learn: 0.0854525	total: 5.05s	remaining: 802ms
# 938:	learn: 0.0854393	total: 5.05s	remaining: 796ms
# 939:	learn: 0.0854230	total: 5.06s	remaining: 791ms
# 940:	learn: 0.0854087	total: 5.06s	remaining: 785ms
# 941:	learn: 0.0853958	total: 5.07s	remaining: 780ms
# 942:	learn: 0.0853820	total: 5.07s	remaining: 774ms
# 943:	learn: 0.0853696	total: 5.08s	remaining: 769ms
# 944:	learn: 0.0853559	total: 5.08s	remaining: 764ms
# 945:	learn: 0.0853391	total: 5.09s	remaining: 758ms
# 946:	learn: 0.0853237	total: 5.09s	remaining: 753ms
# 947:	learn: 0.0853107	total: 5.1s	remaining: 747ms
# 948:	learn: 0.0852971	total: 5.1s	remaining: 742ms
# 949:	learn: 0.0852830	total: 5.11s	remaining: 737ms
# 950:	learn: 0.0852683	total: 5.11s	remaining: 731ms
# 951:	learn: 0.0852551	total: 5.12s	remaining: 726ms
# 952:	learn: 0.0852411	total: 5.12s	remaining: 721ms
# 953:	learn: 0.0852280	total: 5.13s	remaining: 715ms
# 954:	learn: 0.0852128	total: 5.13s	remaining: 710ms
# 955:	learn: 0.0851960	total: 5.14s	remaining: 704ms
# 956:	learn: 0.0851827	total: 5.14s	remaining: 699ms
# 957:	learn: 0.0851676	total: 5.15s	remaining: 693ms
# 958:	learn: 0.0851529	total: 5.16s	remaining: 688ms
# 959:	learn: 0.0851397	total: 5.16s	remaining: 683ms
# 960:	learn: 0.0851241	total: 5.17s	remaining: 677ms
# 961:	learn: 0.0851112	total: 5.17s	remaining: 672ms
# 962:	learn: 0.0850980	total: 5.17s	remaining: 666ms
# 963:	learn: 0.0850828	total: 5.18s	remaining: 661ms
# 964:	learn: 0.0850703	total: 5.18s	remaining: 656ms
# 965:	learn: 0.0850573	total: 5.19s	remaining: 650ms
# 966:	learn: 0.0850412	total: 5.2s	remaining: 645ms
# 967:	learn: 0.0850279	total: 5.2s	remaining: 639ms
# 968:	learn: 0.0850151	total: 5.21s	remaining: 634ms
# 969:	learn: 0.0850021	total: 5.21s	remaining: 629ms
# 970:	learn: 0.0849855	total: 5.22s	remaining: 623ms
# 971:	learn: 0.0849706	total: 5.22s	remaining: 618ms
# 972:	learn: 0.0849555	total: 5.23s	remaining: 612ms
# 973:	learn: 0.0849434	total: 5.23s	remaining: 607ms
# 974:	learn: 0.0849299	total: 5.24s	remaining: 602ms
# 975:	learn: 0.0849180	total: 5.24s	remaining: 596ms
# 976:	learn: 0.0849062	total: 5.25s	remaining: 591ms
# 977:	learn: 0.0848938	total: 5.25s	remaining: 585ms
# 978:	learn: 0.0848761	total: 5.26s	remaining: 580ms
# 979:	learn: 0.0848639	total: 5.26s	remaining: 575ms
# 980:	learn: 0.0848513	total: 5.27s	remaining: 569ms
# 981:	learn: 0.0848394	total: 5.27s	remaining: 564ms
# 982:	learn: 0.0848249	total: 5.28s	remaining: 559ms
# 983:	learn: 0.0848103	total: 5.28s	remaining: 553ms
# 984:	learn: 0.0847996	total: 5.29s	remaining: 548ms
# 985:	learn: 0.0847881	total: 5.29s	remaining: 542ms
# 986:	learn: 0.0847751	total: 5.3s	remaining: 537ms
# 987:	learn: 0.0847636	total: 5.3s	remaining: 531ms
# 988:	learn: 0.0847508	total: 5.31s	remaining: 526ms
# 989:	learn: 0.0847378	total: 5.31s	remaining: 521ms
# 990:	learn: 0.0847250	total: 5.32s	remaining: 515ms
# 991:	learn: 0.0847122	total: 5.32s	remaining: 510ms
# 992:	learn: 0.0846997	total: 5.33s	remaining: 504ms
# 993:	learn: 0.0846868	total: 5.33s	remaining: 499ms
# 994:	learn: 0.0846750	total: 5.34s	remaining: 494ms
# 995:	learn: 0.0846631	total: 5.34s	remaining: 488ms
# 996:	learn: 0.0846519	total: 5.35s	remaining: 483ms
# 997:	learn: 0.0846406	total: 5.35s	remaining: 477ms
# 998:	learn: 0.0846253	total: 5.36s	remaining: 472ms
# 999:	learn: 0.0846146	total: 5.36s	remaining: 467ms
# 1000:	learn: 0.0846033	total: 5.37s	remaining: 461ms
# 1001:	learn: 0.0845927	total: 5.37s	remaining: 456ms
# 1002:	learn: 0.0845817	total: 5.38s	remaining: 450ms
# 1003:	learn: 0.0845663	total: 5.38s	remaining: 445ms
# 1004:	learn: 0.0845542	total: 5.39s	remaining: 440ms
# 1005:	learn: 0.0845428	total: 5.39s	remaining: 434ms
# 1006:	learn: 0.0845315	total: 5.4s	remaining: 429ms
# 1007:	learn: 0.0845201	total: 5.4s	remaining: 424ms
# 1008:	learn: 0.0845039	total: 5.41s	remaining: 418ms
# 1009:	learn: 0.0844900	total: 5.42s	remaining: 413ms
# 1010:	learn: 0.0844781	total: 5.42s	remaining: 407ms
# 1011:	learn: 0.0844663	total: 5.42s	remaining: 402ms
# 1012:	learn: 0.0844549	total: 5.43s	remaining: 397ms
# 1013:	learn: 0.0844429	total: 5.44s	remaining: 391ms
# 1014:	learn: 0.0844312	total: 5.44s	remaining: 386ms
# 1015:	learn: 0.0844212	total: 5.45s	remaining: 381ms
# 1016:	learn: 0.0844084	total: 5.45s	remaining: 375ms
# 1017:	learn: 0.0843974	total: 5.46s	remaining: 370ms
# 1018:	learn: 0.0843827	total: 5.46s	remaining: 365ms
# 1019:	learn: 0.0843690	total: 5.47s	remaining: 359ms
# 1020:	learn: 0.0843539	total: 5.47s	remaining: 354ms
# 1021:	learn: 0.0843428	total: 5.48s	remaining: 348ms
# 1022:	learn: 0.0843317	total: 5.48s	remaining: 343ms
# 1023:	learn: 0.0843212	total: 5.49s	remaining: 338ms
# 1024:	learn: 0.0843113	total: 5.49s	remaining: 332ms
# 1025:	learn: 0.0843006	total: 5.5s	remaining: 327ms
# 1026:	learn: 0.0842901	total: 5.5s	remaining: 322ms
# 1027:	learn: 0.0842794	total: 5.51s	remaining: 316ms
# 1028:	learn: 0.0842686	total: 5.51s	remaining: 311ms
# 1029:	learn: 0.0842579	total: 5.52s	remaining: 305ms
# 1030:	learn: 0.0842445	total: 5.52s	remaining: 300ms
# 1031:	learn: 0.0842343	total: 5.53s	remaining: 295ms
# 1032:	learn: 0.0842245	total: 5.53s	remaining: 289ms
# 1033:	learn: 0.0842132	total: 5.54s	remaining: 284ms
# 1034:	learn: 0.0842023	total: 5.54s	remaining: 279ms
# 1035:	learn: 0.0841913	total: 5.55s	remaining: 273ms
# 1036:	learn: 0.0841810	total: 5.55s	remaining: 268ms
# 1037:	learn: 0.0841714	total: 5.56s	remaining: 262ms
# 1038:	learn: 0.0841606	total: 5.57s	remaining: 257ms
# 1039:	learn: 0.0841505	total: 5.57s	remaining: 252ms
# 1040:	learn: 0.0841404	total: 5.58s	remaining: 246ms
# 1041:	learn: 0.0841263	total: 5.58s	remaining: 241ms
# 1042:	learn: 0.0841157	total: 5.58s	remaining: 236ms
# 1043:	learn: 0.0841048	total: 5.59s	remaining: 230ms
# 1044:	learn: 0.0840946	total: 5.59s	remaining: 225ms
# 1045:	learn: 0.0840842	total: 5.6s	remaining: 220ms
# 1046:	learn: 0.0840737	total: 5.61s	remaining: 214ms
# 1047:	learn: 0.0840632	total: 5.61s	remaining: 209ms
# 1048:	learn: 0.0840513	total: 5.62s	remaining: 203ms
# 1049:	learn: 0.0840414	total: 5.62s	remaining: 198ms
# 1050:	learn: 0.0840315	total: 5.63s	remaining: 193ms
# 1051:	learn: 0.0840200	total: 5.63s	remaining: 187ms
# 1052:	learn: 0.0840098	total: 5.64s	remaining: 182ms
# 1053:	learn: 0.0840005	total: 5.64s	remaining: 177ms
# 1054:	learn: 0.0839887	total: 5.65s	remaining: 171ms
# 1055:	learn: 0.0839785	total: 5.65s	remaining: 166ms
# 1056:	learn: 0.0839691	total: 5.66s	remaining: 161ms
# 1057:	learn: 0.0839581	total: 5.66s	remaining: 155ms
# 1058:	learn: 0.0839472	total: 5.67s	remaining: 150ms
# 1059:	learn: 0.0839379	total: 5.67s	remaining: 144ms
# 1060:	learn: 0.0839276	total: 5.68s	remaining: 139ms
# 1061:	learn: 0.0839182	total: 5.68s	remaining: 134ms
# 1062:	learn: 0.0839080	total: 5.69s	remaining: 128ms
# 1063:	learn: 0.0838981	total: 5.69s	remaining: 123ms
# 1064:	learn: 0.0838880	total: 5.7s	remaining: 118ms
# 1065:	learn: 0.0838736	total: 5.7s	remaining: 112ms
# 1066:	learn: 0.0838648	total: 5.71s	remaining: 107ms
# 1067:	learn: 0.0838551	total: 5.71s	remaining: 102ms
# 1068:	learn: 0.0838449	total: 5.72s	remaining: 96.3ms
# 1069:	learn: 0.0838330	total: 5.72s	remaining: 91ms
# 1070:	learn: 0.0838232	total: 5.73s	remaining: 85.6ms
# 1071:	learn: 0.0838139	total: 5.74s	remaining: 80.3ms
# 1072:	learn: 0.0838050	total: 5.74s	remaining: 74.9ms
# 1073:	learn: 0.0837963	total: 5.75s	remaining: 69.6ms
# 1074:	learn: 0.0837844	total: 5.75s	remaining: 64.2ms
# 1075:	learn: 0.0837738	total: 5.76s	remaining: 58.9ms
# 1076:	learn: 0.0837636	total: 5.76s	remaining: 53.5ms
# 1077:	learn: 0.0837543	total: 5.77s	remaining: 48.1ms
# 1078:	learn: 0.0837416	total: 5.77s	remaining: 42.8ms
# 1079:	learn: 0.0837316	total: 5.78s	remaining: 37.4ms
# 1080:	learn: 0.0837229	total: 5.78s	remaining: 32.1ms
# 1081:	learn: 0.0837128	total: 5.79s	remaining: 26.7ms
# 1082:	learn: 0.0837037	total: 5.79s	remaining: 21.4ms
# 1083:	learn: 0.0836919	total: 5.8s	remaining: 16ms
# 1084:	learn: 0.0836839	total: 5.8s	remaining: 10.7ms
# 1085:	learn: 0.0836743	total: 5.81s	remaining: 5.35ms
# 1086:	learn: 0.0836665	total: 5.81s	remaining: 0us

# %% [markdown]
# ### Feature importance

# %%
feature_importances = model.get_feature_importance()
print("\nFeature Importances:\n")
for score, name in sorted(zip(feature_importances, X_train.columns), reverse=True):
    print(f'{name}: {score:.2f}')
# Out:
# Feature Importances:
#
# direct_rad:W: 36.58
# clear_sky_rad:W: 10.70
# interaction_clear_sky_rad_sun_elevation: 10.64
# sun_elevation:d: 10.51
# direct_rad_1h:J: 9.06
# diffuse_rad:W: 3.20
# clear_sky_energy_1h:J: 2.39
# location_A: 1.84
# elevation:m: 1.71
# visibility:m: 1.69
# wind_speed_u_10m:ms: 1.22
# sun_above_threshold: 1.18
# effective_cloud_cover:p: 1.03
# diffuse_rad_1h:J: 0.98
# cos_sun_azimuth: 0.89
# interaction_clear_sky_rad_effective_cloud_cover: 0.74
# hour: 0.73
# precip_type_5min:idx: 0.71
# fresh_snow_24h:cm: 0.52
# sun_azimuth:d: 0.49
# sin_sun_azimuth: 0.42
# t_1000hPa:K: 0.41
# precip_5min:mm: 0.32
# snow_water:kgm2: 0.31
# rain_water:kgm2: 0.19
# relative_humidity_1000hPa:p: 0.19
# wind_speed_10m:ms: 0.14
# fresh_snow_12h:cm: 0.14
# absolute_humidity_2m:gm3: 0.13
# weekofyear: 0.13
# is_in_shadow:idx: 0.12
# total_cloud_cover:p: 0.08
# pressure_100m:hPa: 0.08
# msl_pressure:hPa: 0.08
# dew_point_2m:K: 0.08
# dayofyear: 0.07
# pressure_50m:hPa: 0.07
# sfc_pressure:hPa: 0.06
# month: 0.06
# is_day:idx: 0.04
# year: 0.02
# season: 0.01
# super_cooled_liquid_water:kgm2: 0.01
# location_B: 0.01
# snow_depth:cm: 0.00
# location_C: 0.00
# wind_speed_v_10m:ms: 0.00
# air_density_2m:kgm3: 0.00
# quarter: 0.00
# snow_melt_10min:mm: 0.00
# dew_or_rime:idx: 0.00
# wind_speed_w_1000hPa:ms: 0.00
# snow_drift:idx: 0.00
# prob_rime:p: 0.00
# is_weekend: 0.00
# fresh_snow_6h:cm: 0.00
# fresh_snow_3h:cm: 0.00
# fresh_snow_1h:cm: 0.00
# estimated: 0.00
# dayofweek: 0.00
# dayofmonth: 0.00

# %% [markdown]
# ### Predict and make csv

# %%
predictions = model.predict(X_test)

# %%
predictions = pd.DataFrame(predictions, columns=['prediction'])

predictions.reset_index(drop=True, inplace=True)

predictions.head()
# Out:
#    prediction
# 0    0.010956
# 1    0.011081
# 2    0.011057
# 3    0.013675
# 4    0.059663

# %%
loc_a = predictions.iloc[:len(predictions)//3]
loc_b = predictions.iloc[len(predictions)//3:2*len(predictions)//3]
loc_c = predictions.iloc[2*len(predictions)//3:]

# %%
n = len(predictions)

# De-normalizing

loc_a.loc[:, 'prediction'] = scaler_a.inverse_transform(loc_a['prediction'].values.reshape(-1, 1))
loc_b.loc[:, 'prediction'] = scaler_b.inverse_transform(loc_b['prediction'].values.reshape(-1, 1))
loc_c.loc[:, 'prediction'] = scaler_c.inverse_transform(loc_c['prediction'].values.reshape(-1, 1))

# %%
predictions = pd.concat([loc_a, loc_b, loc_c])

# %%
predictions.head(10)
# Out:
#     prediction
# 0    62.816769
# 1    63.531212
# 2    63.394067
# 3    78.404117
# 4   342.071048
# 5   831.629472
# 6  1530.558704
# 7  2115.867588
# 8  2602.457461
# 9  2938.523886

# %%
predictions.reset_index(inplace=True)
predictions.rename(columns={'index': 'id'}, inplace=True)
predictions.to_csv('predictions.csv', index=False)

# %% [markdown]
# Remove negative values

# %%
predictions.loc[predictions['prediction'] < 0, 'prediction'] = 0
predictions.to_csv('predictions.csv', index=False)

# %% [markdown]
# Redifing the training sets

# %%
train_a = pd.read_parquet('../../A/train_targets.parquet')
train_b = pd.read_parquet('../../B/train_targets.parquet')
train_c = pd.read_parquet('../../C/train_targets.parquet')

train_a.set_index('time', inplace=True)
train_b.set_index('time', inplace=True)
train_c.set_index('time', inplace=True)

# %% [markdown]
# ### Plotting A

# %%
loc_a.set_index(valid_dates, inplace=True)

plt.figure(figsize=(9, 4))

loc_a['prediction'].plot(style='.', label='Prediction')
train_a['pv_measurement'].plot(style='.', label='Actual', color='red', linewidth=2)

plt.legend(loc='upper left')
plt.title('Predictions vs. Actual A')
plt.xlabel('Time')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plotting B

# %%
loc_b.set_index(valid_dates, inplace=True)

plt.figure(figsize=(9, 4))

loc_b['prediction'].plot(style='.', label='Prediction')
train_b['pv_measurement'].plot(style='.', label='Actual', color='red', linewidth=2)

plt.legend(loc='upper left')
plt.title('Predictions vs. Actual B')
plt.xlabel('Time')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
loc_c.set_index(valid_dates, inplace=True)

plt.figure(figsize=(9, 4))

loc_c['prediction'].plot(style='.', label='Prediction')
train_c['pv_measurement'].plot(style='.', label='Actual', color='red', linewidth=2)

plt.legend(loc='upper left')
plt.title('Predictions vs. Actual C')
plt.xlabel('Time')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()
