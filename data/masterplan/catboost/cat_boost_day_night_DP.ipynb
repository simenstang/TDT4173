# %% [markdown]
# # The Cat Boost Notebook
#
# - The y-set for location A, B and C are concatonated (time index)
# - The X-set for location A, B and C are concatonated (time index)
# - One hot encoding for location and whether or not set is from the estimated column
# - The y-set and the X-set are merged on date and location
# - Having date features
# - y-sets are normalized (MinMax)
# - Removes repeated values in y-set B and C
#
# It takes over from feature_engineering_1
# Adds some ratio features from feature_engineering_3
#
# ***What's new?***
#
# We try to change the data preprocessing such that the model only trains and predicts data when is_day = 1.
#
#
# When the predictions are ready, we manually insert 0 for every hour when is_day = 0.
#
# ### CATBOOST VERSION 2

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import math
import csv
import seaborn as sns
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
train_a = pd.read_parquet('../../A/train_targets.parquet')
train_b = pd.read_parquet('../../B/train_targets.parquet')
train_c = pd.read_parquet('../../C/train_targets.parquet')

X_train_estimated_a = pd.read_parquet('../../A/X_train_estimated.parquet')
X_train_estimated_b = pd.read_parquet('../../B/X_train_estimated.parquet')
X_train_estimated_c = pd.read_parquet('../../C/X_train_estimated.parquet')

X_train_observed_a = pd.read_parquet('../../A/X_train_observed.parquet')
X_train_observed_b = pd.read_parquet('../../B/X_train_observed.parquet')
X_train_observed_c = pd.read_parquet('../../C/X_train_observed.parquet')

X_test_estimated_a = pd.read_parquet('../../A/X_test_estimated.parquet')
X_test_estimated_b = pd.read_parquet('../../B/X_test_estimated.parquet')
X_test_estimated_c = pd.read_parquet('../../C/X_test_estimated.parquet')

# %% [markdown]
# ## Handling the Y-set

# %%
def find_repeated_rows(df):
    '''
    Returns all indicies (from, to) which have the largest intervals of being constant. The output is sorted from 
    largest to smallest.
    '''
    df = df.reset_index()
    repeated_temp = []
    intervals = []

    first = True

    for index, row in df.iterrows():
        if index == 0:
            continue
        if row['pv_measurement'] == df.iloc[index - 1]['pv_measurement']:
            repeated_temp.append(index)
            if first: 
                repeated_temp.insert(0, index - 1)
                first = False
        else:
            if len(repeated_temp) > 1:
                intervals.append((repeated_temp[0], repeated_temp[-1]))
            repeated_temp = []
            first = True
            
    threshold = 6

    return sorted([t for t in intervals if t[1] - t[0] >= threshold], key=lambda t: t[1] - t[0], reverse=True)

# %%
all_y = [train_a, train_b, train_c]
labels = ['A', 'B', 'C']

table = {}

i = 0
for y in all_y:
    loc, intervals = labels[i], find_repeated_rows(y)
    if isinstance(intervals[0], (int, float)):
        intervals = np.asarray(intervals, dtype=float)
    intervals = list(intervals) + [np.nan] * (1421 - len(intervals))
    table[loc] = intervals
    print("The largest interval for", loc, intervals[0])
    i += 1

table = pd.DataFrame(table)
table.head()
# Out:
# The largest interval for A (5176, 5218)
# The largest interval for B (13409, 14466)
# The largest interval for C (18105, 18727)
#                 A               B               C
# 0    (5176, 5218)  (13409, 14466)  (18105, 18727)
# 1    (4526, 4547)  (19138, 20141)  (26048, 26669)
# 2  (22429, 22450)  (18690, 19137)  (27224, 27748)
# 3  (22933, 22954)  (10966, 11307)  (25400, 25876)
# 4        (67, 87)  (26115, 26353)  (10047, 10375)

# %%
i = 1
for y in all_y[1:]:
    loc, intervals = labels[i], find_repeated_rows(y)
    for start, end in intervals:
        for row_index in range(start, end + 1):
            y.at[row_index, 'pv_measurement'] = np.nan

    test = y.set_index('time')
    test['pv_measurement'].plot(title="PV measurments when removing all constant intervals in " + loc)
    plt.show()
    i += 1

# %%
train_a.set_index('time', inplace=True)
train_b.set_index('time', inplace=True)
train_c.set_index('time', inplace=True)

# %% [markdown]
# Normalizing values

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_a = MinMaxScaler()
scaler_b = MinMaxScaler()
scaler_c = MinMaxScaler()

# %%
train_a['pv_measurement'] = scaler_a.fit_transform(train_a[['pv_measurement']])
train_b['pv_measurement'] = scaler_b.fit_transform(train_b[['pv_measurement']])
train_c['pv_measurement'] = scaler_c.fit_transform(train_c[['pv_measurement']])

# %%
train_a['location'] = 'A'
train_b['location'] = 'B'
train_c['location'] = 'C'

# %%
y = pd.concat([train_a, train_b, train_c])
y.index.name = 'time'
y = pd.get_dummies(y, prefix='location', columns=['location'])
encoded_columns = [col for col in y.columns if 'location_' in col]
y[encoded_columns] = y[encoded_columns].astype(int)

y.shape
y.head()
# Out:
#                      pv_measurement  location_A  location_B  location_C
# time
# 2019-06-02 22:00:00        0.000000           1           0           0
# 2019-06-02 23:00:00        0.000000           1           0           0
# 2019-06-03 00:00:00        0.000000           1           0           0
# 2019-06-03 01:00:00        0.000000           1           0           0
# 2019-06-03 02:00:00        0.003377           1           0           0

# %% [markdown]
# Setting the index to **date_forecast** and resampling with median.

# %%
X_train_observed_a['date_forecast'] = pd.to_datetime(X_train_observed_a['date_forecast'])
X_train_observed_a.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_observed_a:
    X_train_observed_a.drop("date_calc", axis=1, inplace=True)
agg_methods = {col: 'median' for col in X_train_observed_a.columns}
agg_methods['is_day:idx'] = 'sum'
X_train_observed_a = X_train_observed_a.resample('60min').agg(agg_methods)


X_train_estimated_a['date_forecast'] = pd.to_datetime(X_train_estimated_a['date_forecast'])
X_train_estimated_a.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_observed_a:
    X_train_estimated_a.drop("date_calc", axis=1, inplace=True)
agg_methods = {col: 'median' for col in X_train_estimated_a.columns}
agg_methods['is_day:idx'] = 'sum'
X_train_estimated_a = X_train_estimated_a.resample('60min').agg(agg_methods)


X_train_observed_b['date_forecast'] = pd.to_datetime(X_train_observed_b['date_forecast'])
X_train_observed_b.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_observed_b:
    X_train_observed_b.drop("date_calc", axis=1, inplace=True)
agg_methods = {col: 'median' for col in X_train_observed_b.columns}
agg_methods['is_day:idx'] = 'sum'
X_train_observed_b = X_train_observed_b.resample('60min').agg(agg_methods)


X_train_estimated_b['date_forecast'] = pd.to_datetime(X_train_estimated_b['date_forecast'])
X_train_estimated_b.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_estimated_b:
    X_train_estimated_b.drop("date_calc", axis=1, inplace=True)
agg_methods = {col: 'median' for col in X_train_estimated_b.columns}
agg_methods['is_day:idx'] = 'sum'
X_train_estimated_b = X_train_estimated_b.resample('60min').agg(agg_methods)


X_train_observed_c['date_forecast'] = pd.to_datetime(X_train_observed_c['date_forecast'])
X_train_observed_c.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_observed_c:
    X_train_observed_c.drop("date_calc", axis=1, inplace=True)
agg_methods = {col: 'median' for col in X_train_observed_c.columns}
agg_methods['is_day:idx'] = 'sum'
X_train_observed_c = X_train_observed_c.resample('60min').agg(agg_methods)


X_train_estimated_c['date_forecast'] = pd.to_datetime(X_train_estimated_c['date_forecast'])
X_train_estimated_c.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_estimated_c:
    X_train_estimated_c.drop("date_calc", axis=1, inplace=True)
agg_methods = {col: 'median' for col in X_train_estimated_c.columns}
agg_methods['is_day:idx'] = 'sum'
X_train_estimated_c = X_train_estimated_c.resample('60min').agg(agg_methods)

# %%
X_train_estimated_a['is_day:idx'].head()
# Out:
# date_forecast
# 2022-10-28 22:00:00    0.0
# 2022-10-28 23:00:00    0.0
# 2022-10-29 00:00:00    0.0
# 2022-10-29 01:00:00    0.0
# 2022-10-29 02:00:00    0.0
# Freq: 60T, Name: is_day:idx, dtype: float32

# %%
X_train_observed_a.columns
# Out:
# Index(['absolute_humidity_2m:gm3', 'air_density_2m:kgm3',
#        'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W',
#        'cloud_base_agl:m', 'dew_or_rime:idx', 'dew_point_2m:K',
#        'diffuse_rad:W', 'diffuse_rad_1h:J', 'direct_rad:W', 'direct_rad_1h:J',
#        'effective_cloud_cover:p', 'elevation:m', 'fresh_snow_12h:cm',
#        'fresh_snow_1h:cm', 'fresh_snow_24h:cm', 'fresh_snow_3h:cm',
#        'fresh_snow_6h:cm', 'is_day:idx', 'is_in_shadow:idx',
#        'msl_pressure:hPa', 'precip_5min:mm', 'precip_type_5min:idx',
#        'pressure_100m:hPa', 'pressure_50m:hPa', 'prob_rime:p',
#        'rain_water:kgm2', 'relative_humidity_1000hPa:p', 'sfc_pressure:hPa',
#        'snow_density:kgm3', 'snow_depth:cm', 'snow_drift:idx',
#        'snow_melt_10min:mm', 'snow_water:kgm2', 'sun_azimuth:d',
#        'sun_elevation:d', 'super_cooled_liquid_water:kgm2', 't_1000hPa:K',
#        'total_cloud_cover:p', 'visibility:m', 'wind_speed_10m:ms',
#        'wind_speed_u_10m:ms', 'wind_speed_v_10m:ms',
#        'wind_speed_w_1000hPa:ms'],
#       dtype='object')

# %%
def replace_outliers_with_nan(df, feature):
    '''Replaces thr 0.01 and 0.99'''
    Q1 = df[feature].quantile(0.01)
    Q99 = df[feature].quantile(0.99)

    df[feature] = np.where(
        (df[feature] < Q1) | (df[feature] > Q99),
        np.nan,
        df[feature]
    )

# %% [markdown]
# ### Removing 'outlier' features as this gave us 0.1 better score on Kaggle

# %%
outliers = ['air_density_2m:kgm3', 'msl_pressure:hPa', 'sfc_pressure:hPa']


for o in outliers:
    replace_outliers_with_nan(X_train_observed_a, o)
    replace_outliers_with_nan(X_train_observed_b, o)
    replace_outliers_with_nan(X_train_observed_c, o)

# %%
X_train_observed_a['location'], X_train_estimated_a['location'] = 'A', 'A'
X_train_observed_b['location'], X_train_estimated_b['location']= 'B', 'B'
X_train_observed_c['location'], X_train_estimated_c['location']= 'C', 'C'

X_train_observed_a['estimated'], X_train_estimated_a['estimated'] = 0, 1
X_train_observed_b['estimated'], X_train_estimated_b['estimated'] = 0, 1
X_train_observed_c['estimated'], X_train_estimated_c['estimated'] = 0, 1

# %%
X = pd.concat([X_train_observed_a, X_train_estimated_a, X_train_observed_b,
               X_train_estimated_b, X_train_observed_c, X_train_estimated_c
               ], ignore_index=False)
X = X.sort_index()

# %% [markdown]
# One hot encoding on location

# %%
# One hot encoding
X = pd.get_dummies(X, prefix='location', columns=['location'])
encoded_columns = [col for col in X.columns if 'location_' in col]
X[encoded_columns] = X[encoded_columns].astype(int)

# %%
df = pd.merge(y, X, left_on=[y.index, 'location_A', 'location_B', 'location_C'],
              right_on=[X.index, 'location_A', 'location_B', 'location_C'])

df.set_index('key_0', inplace=True)
df.index.name = "time"
df = df.sort_index()

df.head()
# Out:
#                      pv_measurement  location_A  location_B  location_C  \
# time
# 2019-01-01 00:00:00             NaN           0           1           0
# 2019-01-01 00:00:00             NaN           0           0           1
# 2019-01-01 01:00:00             NaN           0           0           1
# 2019-01-01 01:00:00             NaN           0           1           0
# 2019-01-01 02:00:00             NaN           0           1           0
#
#                      absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# time
# 2019-01-01 00:00:00                      5.55               1.2395
# 2019-01-01 00:00:00                      5.45               1.2410
# 2019-01-01 01:00:00                      5.35               1.2400
# 2019-01-01 01:00:00                      5.40               1.2395
# 2019-01-01 02:00:00                      5.40               1.2385
#
#                      ceiling_height_agl:m  clear_sky_energy_1h:J  \
# time
# 2019-01-01 00:00:00           1200.699951                    0.0
# 2019-01-01 00:00:00           1130.050049                    0.0
# 2019-01-01 01:00:00           1066.699951                    0.0
# 2019-01-01 01:00:00           1131.449951                    0.0
# 2019-01-01 02:00:00           1061.050049                    0.0
#
#                      clear_sky_rad:W  cloud_base_agl:m  ...  \
# time                                                    ...
# 2019-01-01 00:00:00              0.0       1200.699951  ...
# 2019-01-01 00:00:00              0.0       1130.050049  ...
# 2019-01-01 01:00:00              0.0       1066.699951  ...
# 2019-01-01 01:00:00              0.0       1131.449951  ...
# 2019-01-01 02:00:00              0.0       1061.050049  ...
#
#                      super_cooled_liquid_water:kgm2  t_1000hPa:K  \
# time
# 2019-01-01 00:00:00                             0.0   278.250000
# 2019-01-01 00:00:00                             0.0   278.349976
# 2019-01-01 01:00:00                             0.0   278.200012
# 2019-01-01 01:00:00                             0.0   278.100006
# 2019-01-01 02:00:00                             0.1   278.049988
#
#                      total_cloud_cover:p  visibility:m  wind_speed_10m:ms  \
# time
# 2019-01-01 00:00:00            87.500000  16823.399902               2.80
# 2019-01-01 00:00:00            85.350006  16512.299805               2.90
# 2019-01-01 01:00:00            99.099998  13277.399902               3.65
# 2019-01-01 01:00:00            99.099998  12777.449707               3.55
# 2019-01-01 02:00:00            97.849998  11142.549805               4.05
#
#                      wind_speed_u_10m:ms  wind_speed_v_10m:ms  \
# time
# 2019-01-01 00:00:00                 1.20                 2.55
# 2019-01-01 00:00:00                 1.10                 2.65
# 2019-01-01 01:00:00                 1.40                 3.35
# 2019-01-01 01:00:00                 1.50                 3.20
# 2019-01-01 02:00:00                 2.15                 3.45
#
#                      wind_speed_w_1000hPa:ms  estimated  date_calc
# time
# 2019-01-01 00:00:00                     -0.0          0        NaT
# 2019-01-01 00:00:00                     -0.0          0        NaT
# 2019-01-01 01:00:00                     -0.0          0        NaT
# 2019-01-01 01:00:00                     -0.0          0        NaT
# 2019-01-01 02:00:00                     -0.0          0        NaT
#
# [5 rows x 51 columns]

# %%
def create_features(df):
    """
    Create Features
    """
    
    df = df.copy()
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week

    df['is_weekend'] = (df.index.weekday >= 5).astype(int)
    df['season'] = df.index.month.map(get_season)

    # Set a threshold for sun elevation (in degrees)
    elevation_threshold = 10  

    # Binary feature for significant sun elevation
    df['sun_above_threshold'] = (df['sun_elevation:d'] > elevation_threshold).astype(int)

    # Cosine and sine transformations of sun azimuth
    df['cos_sun_azimuth'] = np.cos(np.radians(df['sun_azimuth:d']))
    df['sin_sun_azimuth'] = np.sin(np.radians(df['sun_azimuth:d']))

    df['interaction_clear_sky_rad_sun_elevation'] = df['clear_sky_rad:W'] * df['sun_elevation:d']
    df['interaction_clear_sky_rad_effective_cloud_cover'] = df['clear_sky_rad:W'] * df['effective_cloud_cover:p']

    df['ratio_clear_sky_rad_to_cloud_cover'] = df['clear_sky_rad:W'] / (df['effective_cloud_cover:p'] + 1e-8)  # added a small number to avoid division by zero

    df['ratio_direct_to_diffuse_rad'] = df['direct_rad:W'] / (df['diffuse_rad:W'] + 1e-8)

    df['ratio_air_density_to_humidity'] = df['air_density_2m:kgm3'] / (df['absolute_humidity_2m:gm3'] + 1e-8)

    df['ratio_wind_speed_10m_to_1000hPa'] = df['wind_speed_v_10m:ms'] / (df['wind_speed_w_1000hPa:ms'] + 1e-8)

    return df

def get_season(month):
    if 3 <= month <= 5:
        return 0  # spring
    elif 6 <= month <= 8:
        return 1  # summer
    elif 9 <= month <= 11:
        return 2  # fall
    else:
        return 3  # winter

df = create_features(df)

df.head()
# Out:
#                      pv_measurement  location_A  location_B  location_C  \
# time
# 2019-01-01 00:00:00             NaN           0           1           0
# 2019-01-01 00:00:00             NaN           0           0           1
# 2019-01-01 01:00:00             NaN           0           0           1
# 2019-01-01 01:00:00             NaN           0           1           0
# 2019-01-01 02:00:00             NaN           0           1           0
#
#                      absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# time
# 2019-01-01 00:00:00                      5.55               1.2395
# 2019-01-01 00:00:00                      5.45               1.2410
# 2019-01-01 01:00:00                      5.35               1.2400
# 2019-01-01 01:00:00                      5.40               1.2395
# 2019-01-01 02:00:00                      5.40               1.2385
#
#                      ceiling_height_agl:m  clear_sky_energy_1h:J  \
# time
# 2019-01-01 00:00:00           1200.699951                    0.0
# 2019-01-01 00:00:00           1130.050049                    0.0
# 2019-01-01 01:00:00           1066.699951                    0.0
# 2019-01-01 01:00:00           1131.449951                    0.0
# 2019-01-01 02:00:00           1061.050049                    0.0
#
#                      clear_sky_rad:W  cloud_base_agl:m  ...  season  \
# time                                                    ...
# 2019-01-01 00:00:00              0.0       1200.699951  ...       3
# 2019-01-01 00:00:00              0.0       1130.050049  ...       3
# 2019-01-01 01:00:00              0.0       1066.699951  ...       3
# 2019-01-01 01:00:00              0.0       1131.449951  ...       3
# 2019-01-01 02:00:00              0.0       1061.050049  ...       3
#
#                      sun_above_threshold  cos_sun_azimuth  sin_sun_azimuth  \
# time
# 2019-01-01 00:00:00                    0         0.934996         0.354658
# 2019-01-01 00:00:00                    0         0.934934         0.354821
# 2019-01-01 01:00:00                    0         0.761584         0.648067
# 2019-01-01 01:00:00                    0         0.761815         0.647794
# 2019-01-01 02:00:00                    0         0.531894         0.846811
#
#                      interaction_clear_sky_rad_sun_elevation  \
# time
# 2019-01-01 00:00:00                                     -0.0
# 2019-01-01 00:00:00                                     -0.0
# 2019-01-01 01:00:00                                     -0.0
# 2019-01-01 01:00:00                                     -0.0
# 2019-01-01 02:00:00                                     -0.0
#
#                      interaction_clear_sky_rad_effective_cloud_cover  \
# time
# 2019-01-01 00:00:00                                              0.0
# 2019-01-01 00:00:00                                              0.0
# 2019-01-01 01:00:00                                              0.0
# 2019-01-01 01:00:00                                              0.0
# 2019-01-01 02:00:00                                              0.0
#
#                      ratio_clear_sky_rad_to_cloud_cover  \
# time
# 2019-01-01 00:00:00                                 0.0
# 2019-01-01 00:00:00                                 0.0
# 2019-01-01 01:00:00                                 0.0
# 2019-01-01 01:00:00                                 0.0
# 2019-01-01 02:00:00                                 0.0
#
#                      ratio_direct_to_diffuse_rad  \
# time
# 2019-01-01 00:00:00                          0.0
# 2019-01-01 00:00:00                          0.0
# 2019-01-01 01:00:00                          0.0
# 2019-01-01 01:00:00                          0.0
# 2019-01-01 02:00:00                          0.0
#
#                      ratio_air_density_to_humidity  \
# time
# 2019-01-01 00:00:00                       0.223333
# 2019-01-01 00:00:00                       0.227706
# 2019-01-01 01:00:00                       0.231776
# 2019-01-01 01:00:00                       0.229537
# 2019-01-01 02:00:00                       0.229352
#
#                      ratio_wind_speed_10m_to_1000hPa
# time
# 2019-01-01 00:00:00                      255000016.0
# 2019-01-01 00:00:00                      265000016.0
# 2019-01-01 01:00:00                      335000000.0
# 2019-01-01 01:00:00                      320000000.0
# 2019-01-01 02:00:00                      345000000.0
#
# [5 rows x 70 columns]

# %% [markdown]
# ### Selecting features
#
# Everything except:
#
# - snow_density:kgm3
# - cloud_base_agl:m
# - ceiling_height_agl:m
#
# They have a lot of NaN values.

# %%
FEATURES = [
    'absolute_humidity_2m:gm3', 'air_density_2m:kgm3',
    'clear_sky_energy_1h:J', 'clear_sky_rad:W',
    'dew_or_rime:idx', 'dew_point_2m:K',
    'diffuse_rad:W', 'diffuse_rad_1h:J', 'direct_rad:W', 'direct_rad_1h:J',
    'effective_cloud_cover:p', 'elevation:m', 'fresh_snow_12h:cm',
    'fresh_snow_1h:cm', 'fresh_snow_24h:cm', 'fresh_snow_3h:cm',
    'fresh_snow_6h:cm', 'is_day:idx', 'is_in_shadow:idx',
    'msl_pressure:hPa', 'precip_5min:mm', 'precip_type_5min:idx',
    'pressure_100m:hPa', 'pressure_50m:hPa', 'prob_rime:p',
    'rain_water:kgm2', 'relative_humidity_1000hPa:p', 'sfc_pressure:hPa',
    'snow_depth:cm', 'snow_drift:idx',
    'snow_melt_10min:mm', 'snow_water:kgm2', 'sun_azimuth:d',
    'sun_elevation:d', 'super_cooled_liquid_water:kgm2', 't_1000hPa:K',
    'total_cloud_cover:p', 'visibility:m', 'wind_speed_10m:ms',
    'wind_speed_u_10m:ms', 'wind_speed_v_10m:ms', 'wind_speed_w_1000hPa:ms',
    'hour', 'dayofweek', 'quarter', 'month', 'year', 'dayofyear',
    'dayofmonth', 'weekofyear', 'is_weekend', 'season', 'sun_above_threshold',
    'cos_sun_azimuth', 'sin_sun_azimuth', 'interaction_clear_sky_rad_sun_elevation',
    'interaction_clear_sky_rad_effective_cloud_cover',
    'location_A', 'location_B', 'location_C', 'estimated'
]

TARGET = 'pv_measurement'

# %%
relevant = FEATURES.copy()
relevant.append(TARGET)

df = df[relevant]

# %%
print(df.isna().sum())
before = df.shape

train = df.dropna()
print(train.isna().sum())
after = train.shape

dif = before[0] - after[0]

df = df.dropna()
print("DROPNA RESULTED IN", dif, "ROWS BEING DROPPED. THE DATASET HAS", after[0], "ROWS IN TOTAL.")
# Out:
# absolute_humidity_2m:gm3       72
# air_density_2m:kgm3          1824
# clear_sky_energy_1h:J          72
# clear_sky_rad:W                72
# dew_or_rime:idx                72
#                             ...
# location_A                      0
# location_B                      0
# location_C                      0
# estimated                       0
# pv_measurement              40896
# Length: 62, dtype: int64
# absolute_humidity_2m:gm3    0
# air_density_2m:kgm3         0
# clear_sky_energy_1h:J       0
# clear_sky_rad:W             0
# dew_or_rime:idx             0
#                            ..
# location_A                  0
# location_B                  0
# location_C                  0
# estimated                   0
# pv_measurement              0
# Length: 62, dtype: int64
# DROPNA RESULTED IN 42788 ROWS BEING DROPPED. THE DATASET HAS 56298 ROWS IN TOTAL.

# %%
df.head()
# Out:
#                      absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# time
# 2019-01-01 10:00:00                      5.70               1.2505
# 2019-01-01 11:00:00                      5.60               1.2540
# 2019-01-01 12:00:00                      5.45               1.2570
# 2019-01-01 13:00:00                      5.30               1.2625
# 2019-01-02 10:00:00                      4.25               1.2980
#
#                      clear_sky_energy_1h:J  clear_sky_rad:W  dew_or_rime:idx  \
# time
# 2019-01-01 10:00:00           45179.900391            20.65              0.0
# 2019-01-01 11:00:00           90826.597656            27.10              0.0
# 2019-01-01 12:00:00           89853.601562            20.15              0.0
# 2019-01-01 13:00:00           42863.000000             2.45              0.0
# 2019-01-02 10:00:00           46925.400391            21.25              0.0
#
#                      dew_point_2m:K  diffuse_rad:W  diffuse_rad_1h:J  \
# time
# 2019-01-01 10:00:00      275.600006           3.40       7203.199707
# 2019-01-01 11:00:00      275.349976           5.35      15655.649902
# 2019-01-01 12:00:00      274.899994           7.35      22645.500000
# 2019-01-01 13:00:00      274.500000           0.95      15217.299805
# 2019-01-02 10:00:00      271.649994           4.60      10360.799805
#
#                      direct_rad:W  direct_rad_1h:J  ...  sun_above_threshold  \
# time                                                ...
# 2019-01-01 10:00:00          0.00        36.849999  ...                    0
# 2019-01-01 11:00:00          0.00        48.600000  ...                    0
# 2019-01-01 12:00:00          0.20       343.850006  ...                    0
# 2019-01-01 13:00:00          0.00       294.900009  ...                    0
# 2019-01-02 10:00:00          0.05        50.850000  ...                    0
#
#                      cos_sun_azimuth  sin_sun_azimuth  \
# time
# 2019-01-01 10:00:00        -0.972082         0.234642
# 2019-01-01 11:00:00        -0.999990        -0.004564
# 2019-01-01 12:00:00        -0.969915        -0.243446
# 2019-01-01 13:00:00        -0.885227        -0.465159
# 2019-01-02 10:00:00        -0.971601         0.236626
#
#                      interaction_clear_sky_rad_sun_elevation  \
# time
# 2019-01-01 10:00:00                                56.333199
# 2019-01-01 11:00:00                                93.738907
# 2019-01-01 12:00:00                                53.750126
# 2019-01-01 13:00:00                                 0.665175
# 2019-01-02 10:00:00                                59.446877
#
#                      interaction_clear_sky_rad_effective_cloud_cover  \
# time
# 2019-01-01 10:00:00                                      2061.902588
# 2019-01-01 11:00:00                                      2689.675049
# 2019-01-01 12:00:00                                      1940.445068
# 2019-01-01 13:00:00                                       233.607513
# 2019-01-02 10:00:00                                      2125.000000
#
#                      location_A  location_B  location_C  estimated  \
# time
# 2019-01-01 10:00:00           0           1           0          0
# 2019-01-01 11:00:00           0           1           0          0
# 2019-01-01 12:00:00           0           1           0          0
# 2019-01-01 13:00:00           0           1           0          0
# 2019-01-02 10:00:00           0           1           0          0
#
#                      pv_measurement
# time
# 2019-01-01 10:00:00        0.000749
# 2019-01-01 11:00:00        0.008982
# 2019-01-01 12:00:00        0.004491
# 2019-01-01 13:00:00        0.000749
# 2019-01-02 10:00:00        0.002994
#
# [5 rows x 62 columns]

# %%
df.columns
# Out:
# Index(['absolute_humidity_2m:gm3', 'air_density_2m:kgm3',
#        'clear_sky_energy_1h:J', 'clear_sky_rad:W', 'dew_or_rime:idx',
#        'dew_point_2m:K', 'diffuse_rad:W', 'diffuse_rad_1h:J', 'direct_rad:W',
#        'direct_rad_1h:J', 'effective_cloud_cover:p', 'elevation:m',
#        'fresh_snow_12h:cm', 'fresh_snow_1h:cm', 'fresh_snow_24h:cm',
#        'fresh_snow_3h:cm', 'fresh_snow_6h:cm', 'is_day:idx',
#        'is_in_shadow:idx', 'msl_pressure:hPa', 'precip_5min:mm',
#        'precip_type_5min:idx', 'pressure_100m:hPa', 'pressure_50m:hPa',
#        'prob_rime:p', 'rain_water:kgm2', 'relative_humidity_1000hPa:p',
#        'sfc_pressure:hPa', 'snow_depth:cm', 'snow_drift:idx',
#        'snow_melt_10min:mm', 'snow_water:kgm2', 'sun_azimuth:d',
#        'sun_elevation:d', 'super_cooled_liquid_water:kgm2', 't_1000hPa:K',
#        'total_cloud_cover:p', 'visibility:m', 'wind_speed_10m:ms',
#        'wind_speed_u_10m:ms', 'wind_speed_v_10m:ms', 'wind_speed_w_1000hPa:ms',
#        'hour', 'dayofweek', 'quarter', 'month', 'year', 'dayofyear',
#        'dayofmonth', 'weekofyear', 'is_weekend', 'season',
#        'sun_above_threshold', 'cos_sun_azimuth', 'sin_sun_azimuth',
#        'interaction_clear_sky_rad_sun_elevation',
#        'interaction_clear_sky_rad_effective_cloud_cover', 'location_A',
#        'location_B', 'location_C', 'estimated', 'pv_measurement'],
#       dtype='object')

# %% [markdown]
# ## Lets drop nightime rows

# %%
test_df = df.copy()

# %%
test_df = test_df[test_df['is_day:idx'] > 0]

# %%
test_df.shape, df.shape
# Out:
# ((39457, 62), (56298, 62))

# %%
df = test_df

# %%
'''
import plotly.graph_objects as go

# Extract the index and values
x_data = df.index
y_data = df["pv_measurement"]

# Create a figure
fig = go.Figure()

# Add line plot
fig.add_trace(go.Scatter(x=x_data, y=y_data,
                         mode='markers',
                         marker=dict(color=color_pal[1]),
                         name='PV Measurement'))

# Set title and labels
fig.update_layout(title='PV Measurement against time',
                  xaxis_title='Time',
                  yaxis_title='PV Measurement')

# Show the figure
fig.show()
'''

color_pal = sns.color_palette()

df["pv_measurement"].plot(style='.',
        figsize=(15, 5),
        color=color_pal[1],
        title='PV measurment against time')
plt.show()

# %% [markdown]
# ### Preparing test data
#
# - Excluding dates that should not be tested
# - Including only the features we have defined

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

def prepare_test_data(x, location):
    x_test = x.copy()
    x_test.set_index('date_forecast', inplace = True)
    x_test.drop('date_calc', axis=1, inplace = True)
    x_test['estimated'] = 1

    agg_methods = {col: 'median' for col in x_test.columns}
    agg_methods['is_day:idx'] = 'sum'
    x_test = x_test.resample('60min').agg(agg_methods)
 

    x_test = create_features(x_test)

    if location == 'A':
        x_test['location_A'] =  1
        x_test['location_B'] = 0
        x_test['location_C'] = 0
    elif location == 'B':
        x_test['location_A'] =  0
        x_test['location_B'] = 1
        x_test['location_C'] = 0
    elif location == 'C':
        x_test['location_A'] =  0
        x_test['location_B'] = 0
        x_test['location_C'] = 1


    x_test = x_test[x_test['is_day:idx'] > 0]   

    return x_test

# %%
x_test_a = prepare_test_data(X_test_estimated_a, 'A')
x_test_b = prepare_test_data(X_test_estimated_b, 'B')
x_test_c = prepare_test_data(X_test_estimated_c, 'C')

# %%
test_sub = pd.read_csv('../../test.csv')
valid_dates = pd.to_datetime(test_sub['time'].unique())

# %% [markdown]
# valid_dates have nightime dates, we need to remove them

# %%
# Find the intersection of indices
common_dates = x_test_a.index.intersection(x_test_b.index).intersection(x_test_c.index)

print(common_dates)
# Out:
# DatetimeIndex(['2023-05-01 03:00:00', '2023-05-01 04:00:00',
#                '2023-05-01 05:00:00', '2023-05-01 06:00:00',
#                '2023-05-01 07:00:00', '2023-05-01 08:00:00',
#                '2023-05-01 09:00:00', '2023-05-01 10:00:00',
#                '2023-05-01 11:00:00', '2023-05-01 12:00:00',
#                ...
#                '2023-07-03 12:00:00', '2023-07-03 13:00:00',
#                '2023-07-03 14:00:00', '2023-07-03 15:00:00',
#                '2023-07-03 16:00:00', '2023-07-03 17:00:00',
#                '2023-07-03 18:00:00', '2023-07-03 19:00:00',
#                '2023-07-03 20:00:00', '2023-07-03 21:00:00'],
#               dtype='datetime64[us]', name='date_forecast', length=598, freq=None)

# %%
x_test_a = x_test_a.loc[common_dates]
x_test_b = x_test_b.loc[common_dates]
x_test_c = x_test_c.loc[common_dates]

# %%
X_test = pd.concat([x_test_a, x_test_b, x_test_c])
X_test = X_test[FEATURES]

# %% [markdown]
# ### Disability Check
#
# Check if the training data and the test data contains the same columns.

# %%
check_df = df.copy()
check_train = check_df[FEATURES]
if X_test.columns.equals(check_train.columns):
    print("EQUAL")
else:
    print("NOT EQUAL")
    print("DIFFERENCE\n", X_test.columns.difference(check_train.columns))
# Out:
# EQUAL

# %% [markdown]
# Check if test data has the right amount of rows. Now it is 1794 instead if 2160 because we have removed nightime dates.

# %%
if X_test.shape[0] != 1794:
    print("X_test has wrong amount of rows!")
    print("Shape =", X_test.shape[0])
else:
    print("GOOD")
# Out:
# GOOD

# %%
X = df[FEATURES]
y = df[TARGET]

# %% [markdown]
# ### Define parameters you want to tune
#
# NOTE we have gotten issues by tuning too many paramters. Be carefull!

# %%
from sklearn.model_selection import validation_curve
from sklearn.model_selection import TimeSeriesSplit
from catboost import CatBoostRegressor
import optuna
from sklearn.metrics import mean_absolute_error


def objective(trial):
    param = {
    "iterations": trial.suggest_int("iterations", 500, 1500),
    "learning_rate": trial.suggest_float("learning_rate", 1e-4, 1e-1, log=True),
    "depth": trial.suggest_int("depth", 1, 16),
    "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 1.0),
    "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 1, 300),
    "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1e-8, 10.0, log=True),
    "random_strength": trial.suggest_float("random_strength", 1e-8, 10.0, log=True),
    "border_count": trial.suggest_int("border_count", 1, 255),
    "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 100.0),
    'loss_function':'MAE'
    }

    cv = TimeSeriesSplit(n_splits=3)

    model = CatBoostRegressor(**param)

    maes = []

    for train_index, val_index in cv.split(X):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        model.fit(X_train, y_train, verbose=0)
        y_pred = model.predict(X_val)
        mae = mean_absolute_error(y_val, y_pred)
        maes.append(mae)
        
    avg_mae = np.mean(maes)

    return avg_mae

# %% [markdown]
# ### Spesify number of trials
#
# A higher number of trials tries out more parameters

# %%
trials = 100

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=trials, n_jobs=-1, show_progress_bar=True)
# Out:
# [I 2023-10-25 19:53:00,572] A new study created in memory with name: no-name-b60031b7-ce5d-4519-90ab-058fcd301294
#   0%|          | 0/2 [00:00<?, ?it/s]
# [I 2023-10-25 19:53:08,077] Trial 1 finished with value: 0.10762611327545653 and parameters: {'iterations': 621, 'learning_rate': 0.00134183177640265, 'depth': 3, 'colsample_bylevel': 0.43920765466432526, 'min_data_in_leaf': 277, 'l2_leaf_reg': 0.0001280709597670519, 'border_count': 27, 'bagging_temperature': 98.6033586212691}. Best is trial 1 with value: 0.10762611327545653.
# [I 2023-10-25 19:53:37,597] Trial 0 finished with value: 0.06056178491717776 and parameters: {'iterations': 1211, 'learning_rate': 0.018517153049761044, 'depth': 9, 'colsample_bylevel': 0.6650021700278108, 'min_data_in_leaf': 254, 'l2_leaf_reg': 3.8601283548210475e-06, 'border_count': 100, 'bagging_temperature': 23.403057418097852}. Best is trial 0 with value: 0.06056178491717776.

# %%
best_params = study.best_params
print('Best parameters:', best_params)

#Best parameters: {'iterations': 854, 'learning_rate': 0.017432099489773544, 'depth': 14, 'colsample_bylevel': 0.43559465187532453, 'min_data_in_leaf': 257, 'l2_leaf_reg': 9.179321889625692, 'border_count': 129, 'random_strength': 0.8781261706316226, 'bagging_temperature': 11.599929150721326, 'grow_policy': 'Lossguide', 'max_leaves': 192}
# Out:
# Best parameters: {'iterations': 1211, 'learning_rate': 0.018517153049761044, 'depth': 9, 'colsample_bylevel': 0.6650021700278108, 'min_data_in_leaf': 254, 'l2_leaf_reg': 3.8601283548210475e-06, 'border_count': 100, 'bagging_temperature': 23.403057418097852}

# %% [markdown]
# ### Now visualising the predictions
#
# This is done by using the validation sets from cross validation. We have used Timeseries cross validation with a test size of three months (that which we are trying to predict in our test sets).

# %%
model = CatBoostRegressor(**best_params)

# %%
cv = TimeSeriesSplit(n_splits=3, test_size=24*30*3)

residuals = []
predictions = []
actuals = []
dates_list = []  

# Cross-validation loop
for train_index, val_index in cv.split(X):
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]
    
    # Train the model
    model.fit(X_train, y_train, verbose=0)
    
    # Make predictions
    y_pred = model.predict(X_val)
    
    # Store results
    res = y_val - y_pred
    residuals.extend(res)
    predictions.extend(y_pred)
    actuals.extend(y_val)
    dates_list.extend(X_val.index)

# %%
residuals = np.array(residuals)
predictions = np.array(predictions)
actuals = np.array(actuals)

# %%
color_pal = sns.color_palette()

# %%
# Scatter Plot for Actual vs Predicted
plt.figure(figsize=(15, 7))
plt.subplot(2, 1, 1)
plt.scatter(dates_list, actuals, label='Actual', color=color_pal[0], s=5)  
plt.scatter(dates_list, predictions, label='Predicted', color=color_pal[1], s=5)  
plt.title('Actual vs Predicted PV Measurements Over Time')
plt.xlabel('Date')
plt.ylabel('PV Measurement')
plt.legend()
plt.grid(True)

# Residual Plot
plt.subplot(2, 1, 2)
plt.scatter(dates_list, residuals, label='Residuals', color=color_pal[2], s=5)
plt.axhline(y=0, color='black', linestyle='--')  # Add a horizontal line at y=0 for reference
plt.title('Residuals Over Time')
plt.xlabel('Date')
plt.ylabel('Residuals')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Here is a box plot to further assist your understanding of the residuals

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create a DataFrame with dates and residuals
dfr = pd.DataFrame({
    'Date': pd.to_datetime(dates_list),
    'Residuals': residuals
})

# Extract week number from dates
dfr['Week'] = dfr['Date'].dt.strftime('%Y-%U')

# Box plot using Seaborn
plt.figure(figsize=(15,7))
sns.boxplot(x='Week', y='Residuals', data=dfr)

# Formatting the plot
plt.xticks(rotation=45) # Rotate x-labels for better visibility
plt.title('Boxplot of Residuals by Week')
plt.xlabel('Week')
plt.ylabel('Residuals')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # THE MAIN FIGURE TO WORRY ABOUT
#
# ### Residual = Actual - Pred

# %%
print("The average residuals:")
print(np.mean(residuals))
# Out:
# The average residuals:
# -0.0018527560123523011

# %%
model.fit(X_train, y_train)
# Out:
# 0:	learn: 0.2238013	total: 19.8ms	remaining: 24s
# 1:	learn: 0.2207240	total: 38.7ms	remaining: 23.4s
# 2:	learn: 0.2176755	total: 52.4ms	remaining: 21.1s
# 3:	learn: 0.2147074	total: 63.7ms	remaining: 19.2s
# 4:	learn: 0.2118099	total: 75.7ms	remaining: 18.3s
# 5:	learn: 0.2089655	total: 87.9ms	remaining: 17.7s
# 6:	learn: 0.2061251	total: 102ms	remaining: 17.6s
# 7:	learn: 0.2034465	total: 113ms	remaining: 17s
# 8:	learn: 0.2007684	total: 124ms	remaining: 16.5s
# 9:	learn: 0.1981510	total: 136ms	remaining: 16.3s
# 10:	learn: 0.1956088	total: 150ms	remaining: 16.4s
# 11:	learn: 0.1931280	total: 162ms	remaining: 16.2s
# 12:	learn: 0.1906641	total: 177ms	remaining: 16.3s
# 13:	learn: 0.1882812	total: 189ms	remaining: 16.2s
# 14:	learn: 0.1859840	total: 204ms	remaining: 16.2s
# 15:	learn: 0.1836945	total: 215ms	remaining: 16.1s
# 16:	learn: 0.1814122	total: 227ms	remaining: 15.9s
# 17:	learn: 0.1792818	total: 238ms	remaining: 15.8s
# 18:	learn: 0.1770825	total: 253ms	remaining: 15.9s
# 19:	learn: 0.1750326	total: 265ms	remaining: 15.8s
# 20:	learn: 0.1729512	total: 280ms	remaining: 15.9s
# 21:	learn: 0.1709626	total: 296ms	remaining: 16s
# 22:	learn: 0.1690371	total: 310ms	remaining: 16s
# 23:	learn: 0.1670976	total: 321ms	remaining: 15.9s
# 24:	learn: 0.1652945	total: 334ms	remaining: 15.9s
# 25:	learn: 0.1634889	total: 346ms	remaining: 15.8s
# 26:	learn: 0.1617366	total: 360ms	remaining: 15.8s
# 27:	learn: 0.1599867	total: 372ms	remaining: 15.7s
# 28:	learn: 0.1583213	total: 386ms	remaining: 15.7s
# 29:	learn: 0.1566746	total: 399ms	remaining: 15.7s
# 30:	learn: 0.1550523	total: 413ms	remaining: 15.7s
# 31:	learn: 0.1534928	total: 425ms	remaining: 15.7s
# 32:	learn: 0.1519545	total: 444ms	remaining: 15.9s
# 33:	learn: 0.1504591	total: 458ms	remaining: 15.9s
# 34:	learn: 0.1489679	total: 473ms	remaining: 15.9s
# 35:	learn: 0.1475612	total: 492ms	remaining: 16.1s
# 36:	learn: 0.1461810	total: 522ms	remaining: 16.6s
# 37:	learn: 0.1447715	total: 573ms	remaining: 17.7s
# 38:	learn: 0.1434361	total: 594ms	remaining: 17.9s
# 39:	learn: 0.1421208	total: 608ms	remaining: 17.8s
# 40:	learn: 0.1408360	total: 620ms	remaining: 17.7s
# 41:	learn: 0.1395988	total: 632ms	remaining: 17.6s
# 42:	learn: 0.1384099	total: 644ms	remaining: 17.5s
# 43:	learn: 0.1372616	total: 657ms	remaining: 17.4s
# 44:	learn: 0.1361118	total: 669ms	remaining: 17.3s
# 45:	learn: 0.1350165	total: 680ms	remaining: 17.2s
# 46:	learn: 0.1339160	total: 693ms	remaining: 17.2s
# 47:	learn: 0.1328449	total: 703ms	remaining: 17s
# 48:	learn: 0.1317795	total: 714ms	remaining: 16.9s
# 49:	learn: 0.1307869	total: 725ms	remaining: 16.8s
# 50:	learn: 0.1298034	total: 735ms	remaining: 16.7s
# 51:	learn: 0.1288131	total: 746ms	remaining: 16.6s
# 52:	learn: 0.1278471	total: 756ms	remaining: 16.5s
# 53:	learn: 0.1269244	total: 767ms	remaining: 16.4s
# 54:	learn: 0.1260098	total: 780ms	remaining: 16.4s
# 55:	learn: 0.1251585	total: 792ms	remaining: 16.3s
# 56:	learn: 0.1243085	total: 804ms	remaining: 16.3s
# 57:	learn: 0.1234404	total: 817ms	remaining: 16.2s
# 58:	learn: 0.1226699	total: 829ms	remaining: 16.2s
# 59:	learn: 0.1218780	total: 842ms	remaining: 16.1s
# 60:	learn: 0.1211189	total: 857ms	remaining: 16.2s
# 61:	learn: 0.1203479	total: 869ms	remaining: 16.1s
# 62:	learn: 0.1196618	total: 878ms	remaining: 16s
# 63:	learn: 0.1189217	total: 888ms	remaining: 15.9s
# 64:	learn: 0.1182048	total: 903ms	remaining: 15.9s
# 65:	learn: 0.1175049	total: 918ms	remaining: 15.9s
# 66:	learn: 0.1168688	total: 933ms	remaining: 15.9s
# 67:	learn: 0.1162772	total: 947ms	remaining: 15.9s
# 68:	learn: 0.1156604	total: 958ms	remaining: 15.9s
# 69:	learn: 0.1150531	total: 970ms	remaining: 15.8s
# 70:	learn: 0.1144962	total: 984ms	remaining: 15.8s
# 71:	learn: 0.1139173	total: 996ms	remaining: 15.8s
# 72:	learn: 0.1133781	total: 1s	remaining: 15.7s
# 73:	learn: 0.1128245	total: 1.02s	remaining: 15.6s
# 74:	learn: 0.1122962	total: 1.02s	remaining: 15.5s
# 75:	learn: 0.1117768	total: 1.04s	remaining: 15.5s
# 76:	learn: 0.1112419	total: 1.05s	remaining: 15.5s
# 77:	learn: 0.1107595	total: 1.06s	remaining: 15.5s
# 78:	learn: 0.1102692	total: 1.08s	remaining: 15.4s
# 79:	learn: 0.1097782	total: 1.09s	remaining: 15.4s
# 80:	learn: 0.1093187	total: 1.1s	remaining: 15.4s
# 81:	learn: 0.1088392	total: 1.11s	remaining: 15.3s
# 82:	learn: 0.1083842	total: 1.12s	remaining: 15.2s
# 83:	learn: 0.1079454	total: 1.13s	remaining: 15.2s
# 84:	learn: 0.1075412	total: 1.14s	remaining: 15.1s
# 85:	learn: 0.1071352	total: 1.15s	remaining: 15.1s
# 86:	learn: 0.1067220	total: 1.16s	remaining: 15s
# 87:	learn: 0.1063490	total: 1.17s	remaining: 15s
# 88:	learn: 0.1059555	total: 1.18s	remaining: 14.9s
# 89:	learn: 0.1055777	total: 1.19s	remaining: 14.8s
# 90:	learn: 0.1052124	total: 1.2s	remaining: 14.8s
# 91:	learn: 0.1048734	total: 1.21s	remaining: 14.7s
# 92:	learn: 0.1045169	total: 1.23s	remaining: 14.7s
# 93:	learn: 0.1041456	total: 1.24s	remaining: 14.7s
# 94:	learn: 0.1038340	total: 1.25s	remaining: 14.7s
# 95:	learn: 0.1035407	total: 1.26s	remaining: 14.7s
# 96:	learn: 0.1032547	total: 1.27s	remaining: 14.6s
# 97:	learn: 0.1029492	total: 1.28s	remaining: 14.6s
# 98:	learn: 0.1026452	total: 1.29s	remaining: 14.6s
# 99:	learn: 0.1023580	total: 1.3s	remaining: 14.5s
# 100:	learn: 0.1020843	total: 1.32s	remaining: 14.5s
# 101:	learn: 0.1018053	total: 1.32s	remaining: 14.4s
# 102:	learn: 0.1015294	total: 1.34s	remaining: 14.4s
# 103:	learn: 0.1012638	total: 1.35s	remaining: 14.4s
# 104:	learn: 0.1010125	total: 1.37s	remaining: 14.4s
# 105:	learn: 0.1007367	total: 1.38s	remaining: 14.4s
# 106:	learn: 0.1004951	total: 1.39s	remaining: 14.3s
# 107:	learn: 0.1002455	total: 1.4s	remaining: 14.3s
# 108:	learn: 0.1000292	total: 1.41s	remaining: 14.3s
# 109:	learn: 0.0997917	total: 1.42s	remaining: 14.2s
# 110:	learn: 0.0995654	total: 1.43s	remaining: 14.2s
# 111:	learn: 0.0993022	total: 1.44s	remaining: 14.1s
# 112:	learn: 0.0990556	total: 1.45s	remaining: 14.1s
# 113:	learn: 0.0988586	total: 1.46s	remaining: 14s
# 114:	learn: 0.0986265	total: 1.47s	remaining: 14s
# 115:	learn: 0.0984055	total: 1.48s	remaining: 14s
# 116:	learn: 0.0981934	total: 1.49s	remaining: 13.9s
# 117:	learn: 0.0979909	total: 1.5s	remaining: 13.9s
# 118:	learn: 0.0978016	total: 1.51s	remaining: 13.9s
# 119:	learn: 0.0975822	total: 1.52s	remaining: 13.8s
# 120:	learn: 0.0974209	total: 1.53s	remaining: 13.8s
# 121:	learn: 0.0972521	total: 1.54s	remaining: 13.8s
# 122:	learn: 0.0970774	total: 1.55s	remaining: 13.7s
# 123:	learn: 0.0969143	total: 1.56s	remaining: 13.7s
# 124:	learn: 0.0967064	total: 1.57s	remaining: 13.6s
# 125:	learn: 0.0965618	total: 1.58s	remaining: 13.6s
# 126:	learn: 0.0963965	total: 1.59s	remaining: 13.6s
# 127:	learn: 0.0962312	total: 1.6s	remaining: 13.6s
# 128:	learn: 0.0960624	total: 1.61s	remaining: 13.5s
# 129:	learn: 0.0958599	total: 1.62s	remaining: 13.5s
# 130:	learn: 0.0957148	total: 1.64s	remaining: 13.5s
# 131:	learn: 0.0955701	total: 1.65s	remaining: 13.5s
# 132:	learn: 0.0954144	total: 1.66s	remaining: 13.4s
# 133:	learn: 0.0952618	total: 1.67s	remaining: 13.4s
# 134:	learn: 0.0951118	total: 1.68s	remaining: 13.4s
# 135:	learn: 0.0949561	total: 1.69s	remaining: 13.4s
# 136:	learn: 0.0948419	total: 1.7s	remaining: 13.3s
# 137:	learn: 0.0947225	total: 1.71s	remaining: 13.3s
# 138:	learn: 0.0946253	total: 1.72s	remaining: 13.3s
# 139:	learn: 0.0945100	total: 1.73s	remaining: 13.3s
# 140:	learn: 0.0943818	total: 1.74s	remaining: 13.2s
# 141:	learn: 0.0942446	total: 1.75s	remaining: 13.2s
# 142:	learn: 0.0941316	total: 1.79s	remaining: 13.4s
# 143:	learn: 0.0940188	total: 1.8s	remaining: 13.4s
# 144:	learn: 0.0938983	total: 1.82s	remaining: 13.4s
# 145:	learn: 0.0937727	total: 1.83s	remaining: 13.4s
# 146:	learn: 0.0936561	total: 1.85s	remaining: 13.4s
# 147:	learn: 0.0935382	total: 1.86s	remaining: 13.4s
# 148:	learn: 0.0933791	total: 1.87s	remaining: 13.4s
# 149:	learn: 0.0933080	total: 1.89s	remaining: 13.3s
# 150:	learn: 0.0931933	total: 1.9s	remaining: 13.3s
# 151:	learn: 0.0930710	total: 1.91s	remaining: 13.3s
# 152:	learn: 0.0929580	total: 1.92s	remaining: 13.3s
# 153:	learn: 0.0928428	total: 1.93s	remaining: 13.3s
# 154:	learn: 0.0927591	total: 1.94s	remaining: 13.3s
# 155:	learn: 0.0926640	total: 1.95s	remaining: 13.2s
# 156:	learn: 0.0925640	total: 1.97s	remaining: 13.2s
# 157:	learn: 0.0924850	total: 1.98s	remaining: 13.2s
# 158:	learn: 0.0923799	total: 1.99s	remaining: 13.2s
# 159:	learn: 0.0922490	total: 2s	remaining: 13.2s
# 160:	learn: 0.0921617	total: 2.01s	remaining: 13.1s
# 161:	learn: 0.0920855	total: 2.02s	remaining: 13.1s
# 162:	learn: 0.0919904	total: 2.03s	remaining: 13.1s
# 163:	learn: 0.0919154	total: 2.04s	remaining: 13.1s
# 164:	learn: 0.0918197	total: 2.05s	remaining: 13s
# 165:	learn: 0.0917609	total: 2.06s	remaining: 13s
# 166:	learn: 0.0916526	total: 2.07s	remaining: 13s
# 167:	learn: 0.0915742	total: 2.08s	remaining: 12.9s
# 168:	learn: 0.0914915	total: 2.1s	remaining: 12.9s
# 169:	learn: 0.0914153	total: 2.1s	remaining: 12.9s
# 170:	learn: 0.0913552	total: 2.12s	remaining: 12.9s
# 171:	learn: 0.0912992	total: 2.12s	remaining: 12.8s
# 172:	learn: 0.0912086	total: 2.13s	remaining: 12.8s
# 173:	learn: 0.0911129	total: 2.15s	remaining: 12.8s
# 174:	learn: 0.0910299	total: 2.16s	remaining: 12.8s
# 175:	learn: 0.0909629	total: 2.17s	remaining: 12.8s
# 176:	learn: 0.0908614	total: 2.19s	remaining: 12.8s
# 177:	learn: 0.0907983	total: 2.2s	remaining: 12.8s
# 178:	learn: 0.0907102	total: 2.21s	remaining: 12.8s
# 179:	learn: 0.0906518	total: 2.22s	remaining: 12.7s
# 180:	learn: 0.0905993	total: 2.23s	remaining: 12.7s
# 181:	learn: 0.0905441	total: 2.25s	remaining: 12.7s
# 182:	learn: 0.0904706	total: 2.26s	remaining: 12.7s
# 183:	learn: 0.0903889	total: 2.27s	remaining: 12.7s
# 184:	learn: 0.0903199	total: 2.29s	remaining: 12.7s
# 185:	learn: 0.0902658	total: 2.3s	remaining: 12.7s
# 186:	learn: 0.0901826	total: 2.32s	remaining: 12.7s
# 187:	learn: 0.0900985	total: 2.33s	remaining: 12.7s
# 188:	learn: 0.0900315	total: 2.34s	remaining: 12.7s
# 189:	learn: 0.0899566	total: 2.35s	remaining: 12.7s
# 190:	learn: 0.0898681	total: 2.37s	remaining: 12.6s
# 191:	learn: 0.0898114	total: 2.38s	remaining: 12.6s
# 192:	learn: 0.0897429	total: 2.39s	remaining: 12.6s
# 193:	learn: 0.0896782	total: 2.4s	remaining: 12.6s
# 194:	learn: 0.0896122	total: 2.41s	remaining: 12.6s
# 195:	learn: 0.0895497	total: 2.42s	remaining: 12.5s
# 196:	learn: 0.0894855	total: 2.43s	remaining: 12.5s
# 197:	learn: 0.0894436	total: 2.44s	remaining: 12.5s
# 198:	learn: 0.0893960	total: 2.45s	remaining: 12.5s
# 199:	learn: 0.0893422	total: 2.46s	remaining: 12.5s
# 200:	learn: 0.0892840	total: 2.47s	remaining: 12.4s
# 201:	learn: 0.0892208	total: 2.48s	remaining: 12.4s
# 202:	learn: 0.0891356	total: 2.49s	remaining: 12.4s
# 203:	learn: 0.0891035	total: 2.5s	remaining: 12.4s
# 204:	learn: 0.0890055	total: 2.51s	remaining: 12.3s
# 205:	learn: 0.0889556	total: 2.52s	remaining: 12.3s
# 206:	learn: 0.0889126	total: 2.53s	remaining: 12.3s
# 207:	learn: 0.0888565	total: 2.54s	remaining: 12.3s
# 208:	learn: 0.0888051	total: 2.56s	remaining: 12.3s
# 209:	learn: 0.0887012	total: 2.57s	remaining: 12.2s
# 210:	learn: 0.0886467	total: 2.58s	remaining: 12.2s
# 211:	learn: 0.0885892	total: 2.59s	remaining: 12.2s
# 212:	learn: 0.0885308	total: 2.6s	remaining: 12.2s
# 213:	learn: 0.0884594	total: 2.61s	remaining: 12.2s
# 214:	learn: 0.0884157	total: 2.62s	remaining: 12.1s
# 215:	learn: 0.0883638	total: 2.63s	remaining: 12.1s
# 216:	learn: 0.0883209	total: 2.64s	remaining: 12.1s
# 217:	learn: 0.0882808	total: 2.65s	remaining: 12.1s
# 218:	learn: 0.0881820	total: 2.66s	remaining: 12s
# 219:	learn: 0.0881203	total: 2.67s	remaining: 12s
# 220:	learn: 0.0880743	total: 2.68s	remaining: 12s
# 221:	learn: 0.0880341	total: 2.69s	remaining: 12s
# 222:	learn: 0.0879715	total: 2.7s	remaining: 12s
# 223:	learn: 0.0879175	total: 2.71s	remaining: 12s
# 224:	learn: 0.0878602	total: 2.73s	remaining: 12s
# 225:	learn: 0.0878144	total: 2.74s	remaining: 12s
# 226:	learn: 0.0877514	total: 2.76s	remaining: 12s
# 227:	learn: 0.0877290	total: 2.78s	remaining: 12s
# 228:	learn: 0.0876895	total: 2.79s	remaining: 12s
# 229:	learn: 0.0876451	total: 2.81s	remaining: 12s
# 230:	learn: 0.0875929	total: 2.83s	remaining: 12s
# 231:	learn: 0.0875528	total: 2.85s	remaining: 12s
# 232:	learn: 0.0875023	total: 2.86s	remaining: 12s
# 233:	learn: 0.0874328	total: 2.88s	remaining: 12s
# 234:	learn: 0.0873945	total: 2.89s	remaining: 12s
# 235:	learn: 0.0873098	total: 2.91s	remaining: 12s
# 236:	learn: 0.0872486	total: 2.93s	remaining: 12s
# 237:	learn: 0.0871519	total: 2.94s	remaining: 12s
# 238:	learn: 0.0870571	total: 2.96s	remaining: 12s
# 239:	learn: 0.0870178	total: 2.98s	remaining: 12.1s
# 240:	learn: 0.0869789	total: 2.99s	remaining: 12s
# 241:	learn: 0.0869382	total: 3s	remaining: 12s
# 242:	learn: 0.0868848	total: 3.01s	remaining: 12s
# 243:	learn: 0.0868292	total: 3.02s	remaining: 12s
# 244:	learn: 0.0867910	total: 3.04s	remaining: 12s
# 245:	learn: 0.0867509	total: 3.04s	remaining: 11.9s
# 246:	learn: 0.0867110	total: 3.06s	remaining: 11.9s
# 247:	learn: 0.0866844	total: 3.07s	remaining: 11.9s
# 248:	learn: 0.0866384	total: 3.08s	remaining: 11.9s
# 249:	learn: 0.0865917	total: 3.09s	remaining: 11.9s
# 250:	learn: 0.0865180	total: 3.11s	remaining: 11.9s
# 251:	learn: 0.0864800	total: 3.13s	remaining: 11.9s
# 252:	learn: 0.0864311	total: 3.14s	remaining: 11.9s
# 253:	learn: 0.0863754	total: 3.16s	remaining: 11.9s
# 254:	learn: 0.0863301	total: 3.17s	remaining: 11.9s
# 255:	learn: 0.0862497	total: 3.19s	remaining: 11.9s
# 256:	learn: 0.0862101	total: 3.21s	remaining: 11.9s
# 257:	learn: 0.0861766	total: 3.22s	remaining: 11.9s
# 258:	learn: 0.0861126	total: 3.23s	remaining: 11.9s
# 259:	learn: 0.0860801	total: 3.25s	remaining: 11.9s
# 260:	learn: 0.0860357	total: 3.26s	remaining: 11.9s
# 261:	learn: 0.0859468	total: 3.27s	remaining: 11.8s
# 262:	learn: 0.0858817	total: 3.28s	remaining: 11.8s
# 263:	learn: 0.0857622	total: 3.29s	remaining: 11.8s
# 264:	learn: 0.0857076	total: 3.3s	remaining: 11.8s
# 265:	learn: 0.0856717	total: 3.31s	remaining: 11.8s
# 266:	learn: 0.0856326	total: 3.33s	remaining: 11.8s
# 267:	learn: 0.0855818	total: 3.34s	remaining: 11.7s
# 268:	learn: 0.0855118	total: 3.35s	remaining: 11.7s
# 269:	learn: 0.0854605	total: 3.36s	remaining: 11.7s
# 270:	learn: 0.0853739	total: 3.37s	remaining: 11.7s
# 271:	learn: 0.0852979	total: 3.38s	remaining: 11.7s
# 272:	learn: 0.0852367	total: 3.4s	remaining: 11.7s
# 273:	learn: 0.0851510	total: 3.42s	remaining: 11.7s
# 274:	learn: 0.0851312	total: 3.43s	remaining: 11.7s
# 275:	learn: 0.0851005	total: 3.44s	remaining: 11.7s
# 276:	learn: 0.0850769	total: 3.46s	remaining: 11.7s
# 277:	learn: 0.0850412	total: 3.47s	remaining: 11.6s
# 278:	learn: 0.0850173	total: 3.48s	remaining: 11.6s
# 279:	learn: 0.0849560	total: 3.5s	remaining: 11.6s
# 280:	learn: 0.0849066	total: 3.51s	remaining: 11.6s
# 281:	learn: 0.0848800	total: 3.53s	remaining: 11.6s
# 282:	learn: 0.0848318	total: 3.55s	remaining: 11.6s
# 283:	learn: 0.0847937	total: 3.57s	remaining: 11.7s
# 284:	learn: 0.0847645	total: 3.58s	remaining: 11.6s
# 285:	learn: 0.0847260	total: 3.6s	remaining: 11.7s
# 286:	learn: 0.0846426	total: 3.62s	remaining: 11.7s
# 287:	learn: 0.0845572	total: 3.64s	remaining: 11.7s
# 288:	learn: 0.0845009	total: 3.65s	remaining: 11.7s
# 289:	learn: 0.0844680	total: 3.67s	remaining: 11.7s
# 290:	learn: 0.0844475	total: 3.69s	remaining: 11.7s
# 291:	learn: 0.0843830	total: 3.7s	remaining: 11.6s
# 292:	learn: 0.0843683	total: 3.71s	remaining: 11.6s
# 293:	learn: 0.0843451	total: 3.73s	remaining: 11.6s
# 294:	learn: 0.0843062	total: 3.74s	remaining: 11.6s
# 295:	learn: 0.0842277	total: 3.76s	remaining: 11.6s
# 296:	learn: 0.0841643	total: 3.78s	remaining: 11.6s
# 297:	learn: 0.0841332	total: 3.79s	remaining: 11.6s
# 298:	learn: 0.0841039	total: 3.81s	remaining: 11.6s
# 299:	learn: 0.0840477	total: 3.83s	remaining: 11.6s
# 300:	learn: 0.0840106	total: 3.84s	remaining: 11.6s
# 301:	learn: 0.0839709	total: 3.85s	remaining: 11.6s
# 302:	learn: 0.0839261	total: 3.87s	remaining: 11.6s
# 303:	learn: 0.0838442	total: 3.88s	remaining: 11.6s
# 304:	learn: 0.0838156	total: 3.89s	remaining: 11.6s
# 305:	learn: 0.0837831	total: 3.91s	remaining: 11.6s
# 306:	learn: 0.0837030	total: 3.92s	remaining: 11.5s
# 307:	learn: 0.0836347	total: 3.93s	remaining: 11.5s
# 308:	learn: 0.0836070	total: 3.94s	remaining: 11.5s
# 309:	learn: 0.0835263	total: 3.96s	remaining: 11.5s
# 310:	learn: 0.0834443	total: 3.98s	remaining: 11.5s
# 311:	learn: 0.0833851	total: 4s	remaining: 11.5s
# 312:	learn: 0.0833407	total: 4.01s	remaining: 11.5s
# 313:	learn: 0.0832590	total: 4.03s	remaining: 11.5s
# 314:	learn: 0.0832115	total: 4.04s	remaining: 11.5s
# 315:	learn: 0.0831918	total: 4.06s	remaining: 11.5s
# 316:	learn: 0.0831474	total: 4.07s	remaining: 11.5s
# 317:	learn: 0.0831106	total: 4.09s	remaining: 11.5s
# 318:	learn: 0.0830716	total: 4.1s	remaining: 11.5s
# 319:	learn: 0.0829883	total: 4.12s	remaining: 11.5s
# 320:	learn: 0.0829459	total: 4.13s	remaining: 11.5s
# 321:	learn: 0.0828871	total: 4.14s	remaining: 11.4s
# 322:	learn: 0.0828272	total: 4.16s	remaining: 11.4s
# 323:	learn: 0.0827938	total: 4.17s	remaining: 11.4s
# 324:	learn: 0.0827521	total: 4.18s	remaining: 11.4s
# 325:	learn: 0.0827222	total: 4.19s	remaining: 11.4s
# 326:	learn: 0.0826079	total: 4.2s	remaining: 11.4s
# 327:	learn: 0.0825447	total: 4.21s	remaining: 11.3s
# 328:	learn: 0.0825139	total: 4.22s	remaining: 11.3s
# 329:	learn: 0.0824652	total: 4.23s	remaining: 11.3s
# 330:	learn: 0.0824086	total: 4.24s	remaining: 11.3s
# 331:	learn: 0.0823782	total: 4.25s	remaining: 11.3s
# 332:	learn: 0.0823495	total: 4.26s	remaining: 11.2s
# 333:	learn: 0.0822677	total: 4.27s	remaining: 11.2s
# 334:	learn: 0.0822096	total: 4.29s	remaining: 11.2s
# 335:	learn: 0.0820895	total: 4.29s	remaining: 11.2s
# 336:	learn: 0.0820243	total: 4.31s	remaining: 11.2s
# 337:	learn: 0.0819898	total: 4.32s	remaining: 11.2s
# 338:	learn: 0.0819731	total: 4.33s	remaining: 11.1s
# 339:	learn: 0.0819481	total: 4.33s	remaining: 11.1s
# 340:	learn: 0.0818897	total: 4.35s	remaining: 11.1s
# 341:	learn: 0.0818567	total: 4.36s	remaining: 11.1s
# 342:	learn: 0.0818286	total: 4.37s	remaining: 11.1s
# 343:	learn: 0.0817903	total: 4.38s	remaining: 11s
# 344:	learn: 0.0817465	total: 4.39s	remaining: 11s
# 345:	learn: 0.0817095	total: 4.4s	remaining: 11s
# 346:	learn: 0.0816473	total: 4.41s	remaining: 11s
# 347:	learn: 0.0816175	total: 4.42s	remaining: 11s
# 348:	learn: 0.0815710	total: 4.42s	remaining: 10.9s
# 349:	learn: 0.0815346	total: 4.44s	remaining: 10.9s
# 350:	learn: 0.0814901	total: 4.45s	remaining: 10.9s
# 351:	learn: 0.0814394	total: 4.46s	remaining: 10.9s
# 352:	learn: 0.0813954	total: 4.47s	remaining: 10.9s
# 353:	learn: 0.0813712	total: 4.48s	remaining: 10.8s
# 354:	learn: 0.0813473	total: 4.49s	remaining: 10.8s
# 355:	learn: 0.0812790	total: 4.51s	remaining: 10.8s
# 356:	learn: 0.0812259	total: 4.52s	remaining: 10.8s
# 357:	learn: 0.0811571	total: 4.53s	remaining: 10.8s
# 358:	learn: 0.0811199	total: 4.54s	remaining: 10.8s
# 359:	learn: 0.0810801	total: 4.55s	remaining: 10.8s
# 360:	learn: 0.0810149	total: 4.56s	remaining: 10.7s
# 361:	learn: 0.0809893	total: 4.57s	remaining: 10.7s
# 362:	learn: 0.0809548	total: 4.58s	remaining: 10.7s
# 363:	learn: 0.0808658	total: 4.59s	remaining: 10.7s
# 364:	learn: 0.0808297	total: 4.61s	remaining: 10.7s
# 365:	learn: 0.0807851	total: 4.62s	remaining: 10.7s
# 366:	learn: 0.0807345	total: 4.64s	remaining: 10.7s
# 367:	learn: 0.0806616	total: 4.65s	remaining: 10.7s
# 368:	learn: 0.0806106	total: 4.66s	remaining: 10.6s
# 369:	learn: 0.0805493	total: 4.67s	remaining: 10.6s
# 370:	learn: 0.0805012	total: 4.68s	remaining: 10.6s
# 371:	learn: 0.0804341	total: 4.7s	remaining: 10.6s
# 372:	learn: 0.0803636	total: 4.71s	remaining: 10.6s
# 373:	learn: 0.0803449	total: 4.72s	remaining: 10.6s
# 374:	learn: 0.0803220	total: 4.73s	remaining: 10.6s
# 375:	learn: 0.0802937	total: 4.74s	remaining: 10.5s
# 376:	learn: 0.0802631	total: 4.76s	remaining: 10.5s
# 377:	learn: 0.0802409	total: 4.78s	remaining: 10.5s
# 378:	learn: 0.0801863	total: 4.85s	remaining: 10.6s
# 379:	learn: 0.0801469	total: 4.88s	remaining: 10.7s
# 380:	learn: 0.0800935	total: 4.89s	remaining: 10.7s
# 381:	learn: 0.0800587	total: 4.91s	remaining: 10.6s
# 382:	learn: 0.0800461	total: 4.92s	remaining: 10.6s
# 383:	learn: 0.0800139	total: 4.93s	remaining: 10.6s
# 384:	learn: 0.0799903	total: 4.95s	remaining: 10.6s
# 385:	learn: 0.0799468	total: 4.96s	remaining: 10.6s
# 386:	learn: 0.0798857	total: 4.98s	remaining: 10.6s
# 387:	learn: 0.0798569	total: 5s	remaining: 10.6s
# 388:	learn: 0.0798177	total: 5.02s	remaining: 10.6s
# 389:	learn: 0.0797644	total: 5.03s	remaining: 10.6s
# 390:	learn: 0.0797388	total: 5.05s	remaining: 10.6s
# 391:	learn: 0.0796849	total: 5.06s	remaining: 10.6s
# 392:	learn: 0.0796236	total: 5.07s	remaining: 10.6s
# 393:	learn: 0.0796140	total: 5.08s	remaining: 10.5s
# 394:	learn: 0.0795786	total: 5.09s	remaining: 10.5s
# 395:	learn: 0.0795491	total: 5.11s	remaining: 10.5s
# 396:	learn: 0.0795199	total: 5.12s	remaining: 10.5s
# 397:	learn: 0.0794481	total: 5.13s	remaining: 10.5s
# 398:	learn: 0.0794045	total: 5.15s	remaining: 10.5s
# 399:	learn: 0.0793659	total: 5.16s	remaining: 10.5s
# 400:	learn: 0.0793496	total: 5.18s	remaining: 10.5s
# 401:	learn: 0.0793002	total: 5.19s	remaining: 10.4s
# 402:	learn: 0.0792665	total: 5.2s	remaining: 10.4s
# 403:	learn: 0.0792407	total: 5.21s	remaining: 10.4s
# 404:	learn: 0.0792124	total: 5.23s	remaining: 10.4s
# 405:	learn: 0.0791700	total: 5.24s	remaining: 10.4s
# 406:	learn: 0.0791307	total: 5.25s	remaining: 10.4s
# 407:	learn: 0.0790799	total: 5.26s	remaining: 10.4s
# 408:	learn: 0.0790468	total: 5.28s	remaining: 10.3s
# 409:	learn: 0.0789892	total: 5.29s	remaining: 10.3s
# 410:	learn: 0.0789223	total: 5.3s	remaining: 10.3s
# 411:	learn: 0.0788679	total: 5.32s	remaining: 10.3s
# 412:	learn: 0.0788376	total: 5.33s	remaining: 10.3s
# 413:	learn: 0.0787912	total: 5.34s	remaining: 10.3s
# 414:	learn: 0.0787133	total: 5.35s	remaining: 10.3s
# 415:	learn: 0.0786467	total: 5.36s	remaining: 10.2s
# 416:	learn: 0.0786198	total: 5.37s	remaining: 10.2s
# 417:	learn: 0.0785573	total: 5.39s	remaining: 10.2s
# 418:	learn: 0.0785008	total: 5.4s	remaining: 10.2s
# 419:	learn: 0.0784616	total: 5.42s	remaining: 10.2s
# 420:	learn: 0.0784314	total: 5.43s	remaining: 10.2s
# 421:	learn: 0.0783514	total: 5.44s	remaining: 10.2s
# 422:	learn: 0.0782830	total: 5.46s	remaining: 10.2s
# 423:	learn: 0.0782527	total: 5.47s	remaining: 10.2s
# 424:	learn: 0.0782078	total: 5.49s	remaining: 10.1s
# 425:	learn: 0.0781739	total: 5.5s	remaining: 10.1s
# 426:	learn: 0.0781263	total: 5.51s	remaining: 10.1s
# 427:	learn: 0.0781040	total: 5.52s	remaining: 10.1s
# 428:	learn: 0.0780530	total: 5.53s	remaining: 10.1s
# 429:	learn: 0.0779954	total: 5.54s	remaining: 10.1s
# 430:	learn: 0.0779739	total: 5.56s	remaining: 10.1s
# 431:	learn: 0.0779489	total: 5.58s	remaining: 10.1s
# 432:	learn: 0.0779051	total: 5.59s	remaining: 10.1s
# 433:	learn: 0.0778776	total: 5.61s	remaining: 10s
# 434:	learn: 0.0778385	total: 5.62s	remaining: 10s
# 435:	learn: 0.0778248	total: 5.63s	remaining: 10s
# 436:	learn: 0.0777918	total: 5.64s	remaining: 9.99s
# 437:	learn: 0.0777652	total: 5.65s	remaining: 9.97s
# 438:	learn: 0.0777226	total: 5.66s	remaining: 9.96s
# 439:	learn: 0.0776750	total: 5.67s	remaining: 9.94s
# 440:	learn: 0.0776460	total: 5.68s	remaining: 9.92s
# 441:	learn: 0.0776167	total: 5.69s	remaining: 9.9s
# 442:	learn: 0.0775803	total: 5.7s	remaining: 9.88s
# 443:	learn: 0.0775498	total: 5.71s	remaining: 9.87s
# 444:	learn: 0.0775252	total: 5.73s	remaining: 9.86s
# 445:	learn: 0.0775043	total: 5.74s	remaining: 9.85s
# 446:	learn: 0.0774602	total: 5.75s	remaining: 9.83s
# 447:	learn: 0.0774167	total: 5.76s	remaining: 9.81s
# 448:	learn: 0.0773975	total: 5.77s	remaining: 9.79s
# 449:	learn: 0.0773690	total: 5.78s	remaining: 9.78s
# 450:	learn: 0.0773268	total: 5.79s	remaining: 9.76s
# 451:	learn: 0.0772579	total: 5.8s	remaining: 9.74s
# 452:	learn: 0.0772275	total: 5.81s	remaining: 9.73s
# 453:	learn: 0.0772041	total: 5.82s	remaining: 9.71s
# 454:	learn: 0.0771784	total: 5.83s	remaining: 9.69s
# 455:	learn: 0.0771368	total: 5.84s	remaining: 9.68s
# 456:	learn: 0.0770915	total: 5.85s	remaining: 9.66s
# 457:	learn: 0.0770664	total: 5.86s	remaining: 9.64s
# 458:	learn: 0.0770202	total: 5.87s	remaining: 9.62s
# 459:	learn: 0.0769970	total: 5.89s	remaining: 9.61s
# 460:	learn: 0.0769674	total: 5.9s	remaining: 9.6s
# 461:	learn: 0.0768952	total: 5.92s	remaining: 9.59s
# 462:	learn: 0.0768721	total: 5.93s	remaining: 9.58s
# 463:	learn: 0.0768551	total: 5.94s	remaining: 9.56s
# 464:	learn: 0.0768065	total: 5.95s	remaining: 9.54s
# 465:	learn: 0.0767811	total: 5.96s	remaining: 9.53s
# 466:	learn: 0.0767258	total: 5.97s	remaining: 9.51s
# 467:	learn: 0.0766855	total: 5.98s	remaining: 9.49s
# 468:	learn: 0.0766222	total: 5.99s	remaining: 9.47s
# 469:	learn: 0.0765698	total: 6s	remaining: 9.46s
# 470:	learn: 0.0765190	total: 6.01s	remaining: 9.44s
# 471:	learn: 0.0764732	total: 6.02s	remaining: 9.43s
# 472:	learn: 0.0764571	total: 6.03s	remaining: 9.41s
# 473:	learn: 0.0764229	total: 6.04s	remaining: 9.39s
# 474:	learn: 0.0763823	total: 6.05s	remaining: 9.38s
# 475:	learn: 0.0763496	total: 6.06s	remaining: 9.36s
# 476:	learn: 0.0763243	total: 6.07s	remaining: 9.35s
# 477:	learn: 0.0763072	total: 6.09s	remaining: 9.33s
# 478:	learn: 0.0762655	total: 6.1s	remaining: 9.32s
# 479:	learn: 0.0762260	total: 6.11s	remaining: 9.3s
# 480:	learn: 0.0761852	total: 6.12s	remaining: 9.29s
# 481:	learn: 0.0761476	total: 6.13s	remaining: 9.27s
# 482:	learn: 0.0761117	total: 6.14s	remaining: 9.26s
# 483:	learn: 0.0760504	total: 6.15s	remaining: 9.24s
# 484:	learn: 0.0760043	total: 6.17s	remaining: 9.23s
# 485:	learn: 0.0759820	total: 6.18s	remaining: 9.21s
# 486:	learn: 0.0759372	total: 6.19s	remaining: 9.21s
# 487:	learn: 0.0758991	total: 6.21s	remaining: 9.19s
# 488:	learn: 0.0758490	total: 6.22s	remaining: 9.18s
# 489:	learn: 0.0758336	total: 6.23s	remaining: 9.17s
# 490:	learn: 0.0758013	total: 6.24s	remaining: 9.15s
# 491:	learn: 0.0757814	total: 6.25s	remaining: 9.13s
# 492:	learn: 0.0757503	total: 6.26s	remaining: 9.12s
# 493:	learn: 0.0757161	total: 6.27s	remaining: 9.1s
# 494:	learn: 0.0756665	total: 6.29s	remaining: 9.09s
# 495:	learn: 0.0756335	total: 6.3s	remaining: 9.08s
# 496:	learn: 0.0756044	total: 6.31s	remaining: 9.06s
# 497:	learn: 0.0755577	total: 6.32s	remaining: 9.04s
# 498:	learn: 0.0755295	total: 6.33s	remaining: 9.03s
# 499:	learn: 0.0754651	total: 6.34s	remaining: 9.02s
# 500:	learn: 0.0754217	total: 6.36s	remaining: 9.01s
# 501:	learn: 0.0753687	total: 6.37s	remaining: 8.99s
# 502:	learn: 0.0753322	total: 6.38s	remaining: 8.98s
# 503:	learn: 0.0752981	total: 6.39s	remaining: 8.97s
# 504:	learn: 0.0752715	total: 6.41s	remaining: 8.96s
# 505:	learn: 0.0752110	total: 6.42s	remaining: 8.94s
# 506:	learn: 0.0751891	total: 6.43s	remaining: 8.93s
# 507:	learn: 0.0751323	total: 6.44s	remaining: 8.91s
# 508:	learn: 0.0750716	total: 6.45s	remaining: 8.9s
# 509:	learn: 0.0750353	total: 6.46s	remaining: 8.88s
# 510:	learn: 0.0749847	total: 6.47s	remaining: 8.87s
# 511:	learn: 0.0749538	total: 6.48s	remaining: 8.85s
# 512:	learn: 0.0748940	total: 6.49s	remaining: 8.84s
# 513:	learn: 0.0748461	total: 6.5s	remaining: 8.82s
# 514:	learn: 0.0748273	total: 6.51s	remaining: 8.8s
# 515:	learn: 0.0747651	total: 6.52s	remaining: 8.79s
# 516:	learn: 0.0747430	total: 6.53s	remaining: 8.77s
# 517:	learn: 0.0746993	total: 6.54s	remaining: 8.76s
# 518:	learn: 0.0746524	total: 6.55s	remaining: 8.74s
# 519:	learn: 0.0746141	total: 6.57s	remaining: 8.72s
# 520:	learn: 0.0745744	total: 6.58s	remaining: 8.71s
# 521:	learn: 0.0745405	total: 6.59s	remaining: 8.69s
# 522:	learn: 0.0745138	total: 6.6s	remaining: 8.68s
# 523:	learn: 0.0744677	total: 6.61s	remaining: 8.66s
# 524:	learn: 0.0744489	total: 6.62s	remaining: 8.65s
# 525:	learn: 0.0744005	total: 6.63s	remaining: 8.64s
# 526:	learn: 0.0743413	total: 6.64s	remaining: 8.63s
# 527:	learn: 0.0743154	total: 6.66s	remaining: 8.61s
# 528:	learn: 0.0742641	total: 6.67s	remaining: 8.6s
# 529:	learn: 0.0742116	total: 6.68s	remaining: 8.58s
# 530:	learn: 0.0741892	total: 6.69s	remaining: 8.56s
# 531:	learn: 0.0741339	total: 6.7s	remaining: 8.55s
# 532:	learn: 0.0741011	total: 6.71s	remaining: 8.54s
# 533:	learn: 0.0740553	total: 6.72s	remaining: 8.52s
# 534:	learn: 0.0740385	total: 6.73s	remaining: 8.51s
# 535:	learn: 0.0740160	total: 6.74s	remaining: 8.49s
# 536:	learn: 0.0739946	total: 6.76s	remaining: 8.48s
# 537:	learn: 0.0739444	total: 6.77s	remaining: 8.47s
# 538:	learn: 0.0739143	total: 6.78s	remaining: 8.46s
# 539:	learn: 0.0738686	total: 6.79s	remaining: 8.44s
# 540:	learn: 0.0738359	total: 6.8s	remaining: 8.43s
# 541:	learn: 0.0737978	total: 6.82s	remaining: 8.41s
# 542:	learn: 0.0737721	total: 6.83s	remaining: 8.4s
# 543:	learn: 0.0737525	total: 6.84s	remaining: 8.38s
# 544:	learn: 0.0737239	total: 6.85s	remaining: 8.38s
# 545:	learn: 0.0736740	total: 6.87s	remaining: 8.36s
# 546:	learn: 0.0736251	total: 6.88s	remaining: 8.35s
# 547:	learn: 0.0735978	total: 6.89s	remaining: 8.34s
# 548:	learn: 0.0735852	total: 6.91s	remaining: 8.33s
# 549:	learn: 0.0735342	total: 6.92s	remaining: 8.32s
# 550:	learn: 0.0734923	total: 6.93s	remaining: 8.31s
# 551:	learn: 0.0734597	total: 6.95s	remaining: 8.29s
# 552:	learn: 0.0734263	total: 6.96s	remaining: 8.28s
# 553:	learn: 0.0733765	total: 6.97s	remaining: 8.26s
# 554:	learn: 0.0733286	total: 6.98s	remaining: 8.25s
# 555:	learn: 0.0733064	total: 6.99s	remaining: 8.23s
# 556:	learn: 0.0732861	total: 7s	remaining: 8.22s
# 557:	learn: 0.0732286	total: 7.01s	remaining: 8.2s
# 558:	learn: 0.0731891	total: 7.02s	remaining: 8.19s
# 559:	learn: 0.0731604	total: 7.03s	remaining: 8.18s
# 560:	learn: 0.0731183	total: 7.05s	remaining: 8.16s
# 561:	learn: 0.0730875	total: 7.06s	remaining: 8.15s
# 562:	learn: 0.0730579	total: 7.07s	remaining: 8.14s
# 563:	learn: 0.0730451	total: 7.09s	remaining: 8.13s
# 564:	learn: 0.0730215	total: 7.1s	remaining: 8.12s
# 565:	learn: 0.0729845	total: 7.11s	remaining: 8.11s
# 566:	learn: 0.0729597	total: 7.13s	remaining: 8.1s
# 567:	learn: 0.0729087	total: 7.14s	remaining: 8.08s
# 568:	learn: 0.0728875	total: 7.15s	remaining: 8.07s
# 569:	learn: 0.0728496	total: 7.16s	remaining: 8.05s
# 570:	learn: 0.0728263	total: 7.17s	remaining: 8.04s
# 571:	learn: 0.0727868	total: 7.18s	remaining: 8.03s
# 572:	learn: 0.0727311	total: 7.19s	remaining: 8.01s
# 573:	learn: 0.0727021	total: 7.21s	remaining: 8s
# 574:	learn: 0.0726815	total: 7.22s	remaining: 7.99s
# 575:	learn: 0.0726508	total: 7.23s	remaining: 7.97s
# 576:	learn: 0.0726175	total: 7.24s	remaining: 7.96s
# 577:	learn: 0.0725889	total: 7.25s	remaining: 7.94s
# 578:	learn: 0.0725498	total: 7.27s	remaining: 7.93s
# 579:	learn: 0.0725236	total: 7.28s	remaining: 7.92s
# 580:	learn: 0.0724911	total: 7.29s	remaining: 7.91s
# 581:	learn: 0.0724408	total: 7.31s	remaining: 7.9s
# 582:	learn: 0.0723794	total: 7.32s	remaining: 7.88s
# 583:	learn: 0.0723499	total: 7.33s	remaining: 7.87s
# 584:	learn: 0.0723179	total: 7.34s	remaining: 7.86s
# 585:	learn: 0.0722900	total: 7.35s	remaining: 7.84s
# 586:	learn: 0.0722571	total: 7.36s	remaining: 7.83s
# 587:	learn: 0.0722087	total: 7.37s	remaining: 7.81s
# 588:	learn: 0.0721632	total: 7.39s	remaining: 7.8s
# 589:	learn: 0.0721095	total: 7.39s	remaining: 7.78s
# 590:	learn: 0.0720479	total: 7.41s	remaining: 7.77s
# 591:	learn: 0.0720128	total: 7.42s	remaining: 7.75s
# 592:	learn: 0.0719538	total: 7.43s	remaining: 7.74s
# 593:	learn: 0.0719230	total: 7.44s	remaining: 7.73s
# 594:	learn: 0.0718773	total: 7.45s	remaining: 7.71s
# 595:	learn: 0.0718465	total: 7.46s	remaining: 7.7s
# 596:	learn: 0.0718296	total: 7.47s	remaining: 7.69s
# 597:	learn: 0.0717820	total: 7.49s	remaining: 7.67s
# 598:	learn: 0.0717610	total: 7.5s	remaining: 7.66s
# 599:	learn: 0.0717356	total: 7.51s	remaining: 7.65s
# 600:	learn: 0.0717078	total: 7.52s	remaining: 7.64s
# 601:	learn: 0.0716828	total: 7.53s	remaining: 7.62s
# 602:	learn: 0.0716598	total: 7.54s	remaining: 7.61s
# 603:	learn: 0.0716182	total: 7.55s	remaining: 7.59s
# 604:	learn: 0.0715978	total: 7.56s	remaining: 7.58s
# 605:	learn: 0.0715557	total: 7.57s	remaining: 7.56s
# 606:	learn: 0.0715227	total: 7.59s	remaining: 7.55s
# 607:	learn: 0.0714889	total: 7.6s	remaining: 7.53s
# 608:	learn: 0.0714456	total: 7.61s	remaining: 7.52s
# 609:	learn: 0.0714208	total: 7.62s	remaining: 7.5s
# 610:	learn: 0.0713951	total: 7.63s	remaining: 7.49s
# 611:	learn: 0.0713713	total: 7.64s	remaining: 7.48s
# 612:	learn: 0.0713507	total: 7.65s	remaining: 7.46s
# 613:	learn: 0.0713057	total: 7.66s	remaining: 7.45s
# 614:	learn: 0.0712787	total: 7.67s	remaining: 7.44s
# 615:	learn: 0.0712506	total: 7.68s	remaining: 7.42s
# 616:	learn: 0.0712263	total: 7.69s	remaining: 7.41s
# 617:	learn: 0.0712015	total: 7.7s	remaining: 7.39s
# 618:	learn: 0.0711570	total: 7.71s	remaining: 7.38s
# 619:	learn: 0.0711024	total: 7.72s	remaining: 7.36s
# 620:	learn: 0.0710737	total: 7.74s	remaining: 7.35s
# 621:	learn: 0.0710398	total: 7.75s	remaining: 7.34s
# 622:	learn: 0.0710072	total: 7.77s	remaining: 7.33s
# 623:	learn: 0.0709754	total: 7.79s	remaining: 7.32s
# 624:	learn: 0.0709596	total: 7.8s	remaining: 7.32s
# 625:	learn: 0.0709242	total: 7.82s	remaining: 7.3s
# 626:	learn: 0.0708916	total: 7.83s	remaining: 7.29s
# 627:	learn: 0.0708515	total: 7.84s	remaining: 7.28s
# 628:	learn: 0.0708248	total: 7.86s	remaining: 7.27s
# 629:	learn: 0.0707986	total: 7.87s	remaining: 7.26s
# 630:	learn: 0.0707680	total: 7.89s	remaining: 7.25s
# 631:	learn: 0.0707355	total: 7.9s	remaining: 7.24s
# 632:	learn: 0.0707071	total: 7.92s	remaining: 7.23s
# 633:	learn: 0.0706818	total: 7.93s	remaining: 7.22s
# 634:	learn: 0.0706392	total: 7.95s	remaining: 7.21s
# 635:	learn: 0.0706148	total: 7.96s	remaining: 7.2s
# 636:	learn: 0.0705825	total: 7.97s	remaining: 7.18s
# 637:	learn: 0.0705388	total: 7.99s	remaining: 7.17s
# 638:	learn: 0.0705131	total: 8s	remaining: 7.16s
# 639:	learn: 0.0704804	total: 8.01s	remaining: 7.15s
# 640:	learn: 0.0704309	total: 8.03s	remaining: 7.14s
# 641:	learn: 0.0703917	total: 8.04s	remaining: 7.12s
# 642:	learn: 0.0703705	total: 8.05s	remaining: 7.11s
# 643:	learn: 0.0703226	total: 8.06s	remaining: 7.1s
# 644:	learn: 0.0702783	total: 8.07s	remaining: 7.08s
# 645:	learn: 0.0702411	total: 8.08s	remaining: 7.07s
# 646:	learn: 0.0702096	total: 8.09s	remaining: 7.05s
# 647:	learn: 0.0701763	total: 8.1s	remaining: 7.04s
# 648:	learn: 0.0701287	total: 8.11s	remaining: 7.03s
# 649:	learn: 0.0701033	total: 8.12s	remaining: 7.01s
# 650:	learn: 0.0700735	total: 8.13s	remaining: 7s
# 651:	learn: 0.0700382	total: 8.14s	remaining: 6.98s
# 652:	learn: 0.0700005	total: 8.16s	remaining: 6.97s
# 653:	learn: 0.0699799	total: 8.17s	remaining: 6.96s
# 654:	learn: 0.0699426	total: 8.18s	remaining: 6.94s
# 655:	learn: 0.0699033	total: 8.19s	remaining: 6.93s
# 656:	learn: 0.0698823	total: 8.2s	remaining: 6.92s
# 657:	learn: 0.0698562	total: 8.22s	remaining: 6.91s
# 658:	learn: 0.0698135	total: 8.23s	remaining: 6.89s
# 659:	learn: 0.0697860	total: 8.24s	remaining: 6.88s
# 660:	learn: 0.0697579	total: 8.25s	remaining: 6.87s
# 661:	learn: 0.0697135	total: 8.26s	remaining: 6.85s
# 662:	learn: 0.0696700	total: 8.27s	remaining: 6.84s
# 663:	learn: 0.0696358	total: 8.28s	remaining: 6.82s
# 664:	learn: 0.0696067	total: 8.29s	remaining: 6.81s
# 665:	learn: 0.0695665	total: 8.3s	remaining: 6.8s
# 666:	learn: 0.0695359	total: 8.31s	remaining: 6.78s
# 667:	learn: 0.0694931	total: 8.33s	remaining: 6.77s
# 668:	learn: 0.0694547	total: 8.34s	remaining: 6.75s
# 669:	learn: 0.0694327	total: 8.35s	remaining: 6.74s
# 670:	learn: 0.0694157	total: 8.36s	remaining: 6.72s
# 671:	learn: 0.0693800	total: 8.37s	remaining: 6.71s
# 672:	learn: 0.0693474	total: 8.38s	remaining: 6.7s
# 673:	learn: 0.0693037	total: 8.39s	remaining: 6.68s
# 674:	learn: 0.0692454	total: 8.4s	remaining: 6.67s
# 675:	learn: 0.0692131	total: 8.41s	remaining: 6.66s
# 676:	learn: 0.0691765	total: 8.43s	remaining: 6.65s
# 677:	learn: 0.0691564	total: 8.44s	remaining: 6.63s
# 678:	learn: 0.0691311	total: 8.45s	remaining: 6.62s
# 679:	learn: 0.0691103	total: 8.47s	remaining: 6.61s
# 680:	learn: 0.0690699	total: 8.48s	remaining: 6.6s
# 681:	learn: 0.0690298	total: 8.49s	remaining: 6.58s
# 682:	learn: 0.0690102	total: 8.5s	remaining: 6.57s
# 683:	learn: 0.0689659	total: 8.51s	remaining: 6.55s
# 684:	learn: 0.0689331	total: 8.52s	remaining: 6.54s
# 685:	learn: 0.0689136	total: 8.53s	remaining: 6.53s
# 686:	learn: 0.0688943	total: 8.54s	remaining: 6.51s
# 687:	learn: 0.0688317	total: 8.55s	remaining: 6.5s
# 688:	learn: 0.0687883	total: 8.56s	remaining: 6.48s
# 689:	learn: 0.0687576	total: 8.57s	remaining: 6.47s
# 690:	learn: 0.0687218	total: 8.58s	remaining: 6.46s
# 691:	learn: 0.0686826	total: 8.59s	remaining: 6.44s
# 692:	learn: 0.0686362	total: 8.6s	remaining: 6.43s
# 693:	learn: 0.0686165	total: 8.61s	remaining: 6.41s
# 694:	learn: 0.0685850	total: 8.62s	remaining: 6.4s
# 695:	learn: 0.0685595	total: 8.63s	remaining: 6.39s
# 696:	learn: 0.0685194	total: 8.64s	remaining: 6.38s
# 697:	learn: 0.0684826	total: 8.66s	remaining: 6.36s
# 698:	learn: 0.0684533	total: 8.67s	remaining: 6.35s
# 699:	learn: 0.0684213	total: 8.68s	remaining: 6.34s
# 700:	learn: 0.0683811	total: 8.7s	remaining: 6.33s
# 701:	learn: 0.0683449	total: 8.71s	remaining: 6.31s
# 702:	learn: 0.0683118	total: 8.72s	remaining: 6.3s
# 703:	learn: 0.0682771	total: 8.73s	remaining: 6.29s
# 704:	learn: 0.0682621	total: 8.74s	remaining: 6.27s
# 705:	learn: 0.0682417	total: 8.75s	remaining: 6.26s
# 706:	learn: 0.0682177	total: 8.76s	remaining: 6.24s
# 707:	learn: 0.0681959	total: 8.77s	remaining: 6.23s
# 708:	learn: 0.0681745	total: 8.78s	remaining: 6.21s
# 709:	learn: 0.0681370	total: 8.79s	remaining: 6.2s
# 710:	learn: 0.0681091	total: 8.8s	remaining: 6.19s
# 711:	learn: 0.0680787	total: 8.81s	remaining: 6.17s
# 712:	learn: 0.0680435	total: 8.82s	remaining: 6.16s
# 713:	learn: 0.0680144	total: 8.83s	remaining: 6.14s
# 714:	learn: 0.0679710	total: 8.84s	remaining: 6.13s
# 715:	learn: 0.0679342	total: 8.85s	remaining: 6.12s
# 716:	learn: 0.0679088	total: 8.86s	remaining: 6.11s
# 717:	learn: 0.0678841	total: 8.87s	remaining: 6.09s
# 718:	learn: 0.0678305	total: 8.88s	remaining: 6.08s
# 719:	learn: 0.0678065	total: 8.89s	remaining: 6.06s
# 720:	learn: 0.0677740	total: 8.9s	remaining: 6.05s
# 721:	learn: 0.0677368	total: 8.91s	remaining: 6.04s
# 722:	learn: 0.0677030	total: 8.92s	remaining: 6.02s
# 723:	learn: 0.0676704	total: 8.93s	remaining: 6.01s
# 724:	learn: 0.0676239	total: 8.94s	remaining: 6s
# 725:	learn: 0.0675664	total: 8.95s	remaining: 5.98s
# 726:	learn: 0.0675414	total: 8.96s	remaining: 5.97s
# 727:	learn: 0.0675170	total: 8.97s	remaining: 5.95s
# 728:	learn: 0.0674969	total: 8.98s	remaining: 5.94s
# 729:	learn: 0.0674659	total: 9s	remaining: 5.93s
# 730:	learn: 0.0674308	total: 9.01s	remaining: 5.91s
# 731:	learn: 0.0673734	total: 9.02s	remaining: 5.9s
# 732:	learn: 0.0673312	total: 9.03s	remaining: 5.89s
# 733:	learn: 0.0673031	total: 9.04s	remaining: 5.88s
# 734:	learn: 0.0672802	total: 9.05s	remaining: 5.86s
# 735:	learn: 0.0672456	total: 9.06s	remaining: 5.85s
# 736:	learn: 0.0672238	total: 9.07s	remaining: 5.83s
# 737:	learn: 0.0672039	total: 9.08s	remaining: 5.82s
# 738:	learn: 0.0671438	total: 9.09s	remaining: 5.81s
# 739:	learn: 0.0671225	total: 9.1s	remaining: 5.79s
# 740:	learn: 0.0670975	total: 9.11s	remaining: 5.78s
# 741:	learn: 0.0670620	total: 9.12s	remaining: 5.77s
# 742:	learn: 0.0670432	total: 9.13s	remaining: 5.75s
# 743:	learn: 0.0670132	total: 9.14s	remaining: 5.74s
# 744:	learn: 0.0669903	total: 9.15s	remaining: 5.72s
# 745:	learn: 0.0669680	total: 9.16s	remaining: 5.71s
# 746:	learn: 0.0669341	total: 9.17s	remaining: 5.7s
# 747:	learn: 0.0669049	total: 9.18s	remaining: 5.68s
# 748:	learn: 0.0668769	total: 9.19s	remaining: 5.67s
# 749:	learn: 0.0668434	total: 9.2s	remaining: 5.66s
# 750:	learn: 0.0668201	total: 9.21s	remaining: 5.64s
# 751:	learn: 0.0668002	total: 9.22s	remaining: 5.63s
# 752:	learn: 0.0667753	total: 9.24s	remaining: 5.62s
# 753:	learn: 0.0667505	total: 9.25s	remaining: 5.6s
# 754:	learn: 0.0667239	total: 9.26s	remaining: 5.59s
# 755:	learn: 0.0667013	total: 9.27s	remaining: 5.58s
# 756:	learn: 0.0666697	total: 9.28s	remaining: 5.56s
# 757:	learn: 0.0666441	total: 9.29s	remaining: 5.55s
# 758:	learn: 0.0666066	total: 9.3s	remaining: 5.54s
# 759:	learn: 0.0665800	total: 9.31s	remaining: 5.52s
# 760:	learn: 0.0665644	total: 9.32s	remaining: 5.51s
# 761:	learn: 0.0665351	total: 9.33s	remaining: 5.5s
# 762:	learn: 0.0665156	total: 9.34s	remaining: 5.48s
# 763:	learn: 0.0664947	total: 9.35s	remaining: 5.47s
# 764:	learn: 0.0664718	total: 9.36s	remaining: 5.46s
# 765:	learn: 0.0664550	total: 9.37s	remaining: 5.45s
# 766:	learn: 0.0664087	total: 9.38s	remaining: 5.43s
# 767:	learn: 0.0663773	total: 9.39s	remaining: 5.42s
# 768:	learn: 0.0663377	total: 9.4s	remaining: 5.41s
# 769:	learn: 0.0663104	total: 9.42s	remaining: 5.39s
# 770:	learn: 0.0662853	total: 9.43s	remaining: 5.38s
# 771:	learn: 0.0662327	total: 9.44s	remaining: 5.37s
# 772:	learn: 0.0662079	total: 9.45s	remaining: 5.35s
# 773:	learn: 0.0661768	total: 9.46s	remaining: 5.34s
# 774:	learn: 0.0661571	total: 9.47s	remaining: 5.33s
# 775:	learn: 0.0661290	total: 9.48s	remaining: 5.31s
# 776:	learn: 0.0660635	total: 9.49s	remaining: 5.3s
# 777:	learn: 0.0660331	total: 9.5s	remaining: 5.29s
# 778:	learn: 0.0659979	total: 9.51s	remaining: 5.28s
# 779:	learn: 0.0659681	total: 9.52s	remaining: 5.26s
# 780:	learn: 0.0659440	total: 9.53s	remaining: 5.25s
# 781:	learn: 0.0659120	total: 9.54s	remaining: 5.24s
# 782:	learn: 0.0658943	total: 9.56s	remaining: 5.22s
# 783:	learn: 0.0658659	total: 9.57s	remaining: 5.21s
# 784:	learn: 0.0658334	total: 9.58s	remaining: 5.2s
# 785:	learn: 0.0658034	total: 9.59s	remaining: 5.18s
# 786:	learn: 0.0657840	total: 9.6s	remaining: 5.17s
# 787:	learn: 0.0657551	total: 9.61s	remaining: 5.16s
# 788:	learn: 0.0657291	total: 9.62s	remaining: 5.14s
# 789:	learn: 0.0657115	total: 9.63s	remaining: 5.13s
# 790:	learn: 0.0656671	total: 9.64s	remaining: 5.12s
# 791:	learn: 0.0656477	total: 9.65s	remaining: 5.1s
# 792:	learn: 0.0656215	total: 9.66s	remaining: 5.09s
# 793:	learn: 0.0656000	total: 9.67s	remaining: 5.08s
# 794:	learn: 0.0655673	total: 9.68s	remaining: 5.06s
# 795:	learn: 0.0655312	total: 9.69s	remaining: 5.05s
# 796:	learn: 0.0655035	total: 9.7s	remaining: 5.04s
# 797:	learn: 0.0654805	total: 9.71s	remaining: 5.02s
# 798:	learn: 0.0654533	total: 9.72s	remaining: 5.01s
# 799:	learn: 0.0654217	total: 9.73s	remaining: 5s
# 800:	learn: 0.0653829	total: 9.74s	remaining: 4.99s
# 801:	learn: 0.0653395	total: 9.75s	remaining: 4.97s
# 802:	learn: 0.0653202	total: 9.76s	remaining: 4.96s
# 803:	learn: 0.0652857	total: 9.78s	remaining: 4.95s
# 804:	learn: 0.0652622	total: 9.79s	remaining: 4.93s
# 805:	learn: 0.0652359	total: 9.8s	remaining: 4.92s
# 806:	learn: 0.0652254	total: 9.81s	remaining: 4.91s
# 807:	learn: 0.0651970	total: 9.82s	remaining: 4.9s
# 808:	learn: 0.0651658	total: 9.83s	remaining: 4.88s
# 809:	learn: 0.0651351	total: 9.84s	remaining: 4.87s
# 810:	learn: 0.0651126	total: 9.85s	remaining: 4.86s
# 811:	learn: 0.0650910	total: 9.86s	remaining: 4.84s
# 812:	learn: 0.0650612	total: 9.87s	remaining: 4.83s
# 813:	learn: 0.0650226	total: 9.88s	remaining: 4.82s
# 814:	learn: 0.0649798	total: 9.92s	remaining: 4.82s
# 815:	learn: 0.0649587	total: 9.93s	remaining: 4.81s
# 816:	learn: 0.0649327	total: 9.94s	remaining: 4.79s
# 817:	learn: 0.0649089	total: 9.95s	remaining: 4.78s
# 818:	learn: 0.0648847	total: 9.96s	remaining: 4.77s
# 819:	learn: 0.0648591	total: 9.97s	remaining: 4.76s
# 820:	learn: 0.0648291	total: 9.98s	remaining: 4.74s
# 821:	learn: 0.0648182	total: 9.99s	remaining: 4.73s
# 822:	learn: 0.0647969	total: 10s	remaining: 4.72s
# 823:	learn: 0.0647724	total: 10s	remaining: 4.7s
# 824:	learn: 0.0647367	total: 10s	remaining: 4.69s
# 825:	learn: 0.0647064	total: 10s	remaining: 4.68s
# 826:	learn: 0.0646876	total: 10s	remaining: 4.67s
# 827:	learn: 0.0646567	total: 10.1s	remaining: 4.65s
# 828:	learn: 0.0646283	total: 10.1s	remaining: 4.64s
# 829:	learn: 0.0646129	total: 10.1s	remaining: 4.63s
# 830:	learn: 0.0645906	total: 10.1s	remaining: 4.61s
# 831:	learn: 0.0645562	total: 10.1s	remaining: 4.6s
# 832:	learn: 0.0645296	total: 10.1s	remaining: 4.59s
# 833:	learn: 0.0644940	total: 10.1s	remaining: 4.57s
# 834:	learn: 0.0644797	total: 10.1s	remaining: 4.56s
# 835:	learn: 0.0644536	total: 10.1s	remaining: 4.55s
# 836:	learn: 0.0644226	total: 10.1s	remaining: 4.54s
# 837:	learn: 0.0643912	total: 10.2s	remaining: 4.52s
# 838:	learn: 0.0643558	total: 10.2s	remaining: 4.51s
# 839:	learn: 0.0643329	total: 10.2s	remaining: 4.5s
# 840:	learn: 0.0642979	total: 10.2s	remaining: 4.48s
# 841:	learn: 0.0642754	total: 10.2s	remaining: 4.47s
# 842:	learn: 0.0642488	total: 10.2s	remaining: 4.46s
# 843:	learn: 0.0642062	total: 10.2s	remaining: 4.44s
# 844:	learn: 0.0641787	total: 10.2s	remaining: 4.43s
# 845:	learn: 0.0641592	total: 10.2s	remaining: 4.42s
# 846:	learn: 0.0641273	total: 10.2s	remaining: 4.4s
# 847:	learn: 0.0641016	total: 10.3s	remaining: 4.39s
# 848:	learn: 0.0640844	total: 10.3s	remaining: 4.38s
# 849:	learn: 0.0640648	total: 10.3s	remaining: 4.36s
# 850:	learn: 0.0640282	total: 10.3s	remaining: 4.35s
# 851:	learn: 0.0640082	total: 10.3s	remaining: 4.34s
# 852:	learn: 0.0639810	total: 10.3s	remaining: 4.33s
# 853:	learn: 0.0639534	total: 10.3s	remaining: 4.31s
# 854:	learn: 0.0639108	total: 10.3s	remaining: 4.3s
# 855:	learn: 0.0638686	total: 10.3s	remaining: 4.29s
# 856:	learn: 0.0638314	total: 10.3s	remaining: 4.28s
# 857:	learn: 0.0637964	total: 10.4s	remaining: 4.26s
# 858:	learn: 0.0637750	total: 10.4s	remaining: 4.25s
# 859:	learn: 0.0637500	total: 10.4s	remaining: 4.24s
# 860:	learn: 0.0637221	total: 10.4s	remaining: 4.22s
# 861:	learn: 0.0636828	total: 10.4s	remaining: 4.21s
# 862:	learn: 0.0636574	total: 10.4s	remaining: 4.2s
# 863:	learn: 0.0636269	total: 10.4s	remaining: 4.18s
# 864:	learn: 0.0635964	total: 10.4s	remaining: 4.17s
# 865:	learn: 0.0635689	total: 10.4s	remaining: 4.16s
# 866:	learn: 0.0635548	total: 10.4s	remaining: 4.15s
# 867:	learn: 0.0635121	total: 10.5s	remaining: 4.13s
# 868:	learn: 0.0634785	total: 10.5s	remaining: 4.12s
# 869:	learn: 0.0634556	total: 10.5s	remaining: 4.11s
# 870:	learn: 0.0634211	total: 10.5s	remaining: 4.1s
# 871:	learn: 0.0633915	total: 10.5s	remaining: 4.08s
# 872:	learn: 0.0633639	total: 10.5s	remaining: 4.07s
# 873:	learn: 0.0633406	total: 10.5s	remaining: 4.06s
# 874:	learn: 0.0633186	total: 10.5s	remaining: 4.04s
# 875:	learn: 0.0632921	total: 10.5s	remaining: 4.03s
# 876:	learn: 0.0632391	total: 10.6s	remaining: 4.02s
# 877:	learn: 0.0632144	total: 10.6s	remaining: 4.01s
# 878:	learn: 0.0631913	total: 10.6s	remaining: 3.99s
# 879:	learn: 0.0631773	total: 10.6s	remaining: 3.98s
# 880:	learn: 0.0631462	total: 10.6s	remaining: 3.97s
# 881:	learn: 0.0631296	total: 10.6s	remaining: 3.96s
# 882:	learn: 0.0630911	total: 10.6s	remaining: 3.94s
# 883:	learn: 0.0630652	total: 10.6s	remaining: 3.93s
# 884:	learn: 0.0630462	total: 10.6s	remaining: 3.92s
# 885:	learn: 0.0630091	total: 10.6s	remaining: 3.9s
# 886:	learn: 0.0629698	total: 10.7s	remaining: 3.89s
# 887:	learn: 0.0629563	total: 10.7s	remaining: 3.88s
# 888:	learn: 0.0629353	total: 10.7s	remaining: 3.87s
# 889:	learn: 0.0629029	total: 10.7s	remaining: 3.85s
# 890:	learn: 0.0628663	total: 10.7s	remaining: 3.84s
# 891:	learn: 0.0628392	total: 10.7s	remaining: 3.83s
# 892:	learn: 0.0628120	total: 10.7s	remaining: 3.82s
# 893:	learn: 0.0627857	total: 10.7s	remaining: 3.8s
# 894:	learn: 0.0627668	total: 10.7s	remaining: 3.79s
# 895:	learn: 0.0627232	total: 10.8s	remaining: 3.78s
# 896:	learn: 0.0626939	total: 10.8s	remaining: 3.77s
# 897:	learn: 0.0626616	total: 10.8s	remaining: 3.75s
# 898:	learn: 0.0626388	total: 10.8s	remaining: 3.74s
# 899:	learn: 0.0626225	total: 10.8s	remaining: 3.73s
# 900:	learn: 0.0626046	total: 10.8s	remaining: 3.72s
# 901:	learn: 0.0625878	total: 10.8s	remaining: 3.71s
# 902:	learn: 0.0625467	total: 10.8s	remaining: 3.7s
# 903:	learn: 0.0625171	total: 10.9s	remaining: 3.69s
# 904:	learn: 0.0624984	total: 10.9s	remaining: 3.67s
# 905:	learn: 0.0624679	total: 10.9s	remaining: 3.66s
# 906:	learn: 0.0624272	total: 10.9s	remaining: 3.65s
# 907:	learn: 0.0624121	total: 10.9s	remaining: 3.64s
# 908:	learn: 0.0623828	total: 10.9s	remaining: 3.63s
# 909:	learn: 0.0623579	total: 10.9s	remaining: 3.61s
# 910:	learn: 0.0623374	total: 10.9s	remaining: 3.6s
# 911:	learn: 0.0623104	total: 10.9s	remaining: 3.59s
# 912:	learn: 0.0622902	total: 11s	remaining: 3.58s
# 913:	learn: 0.0622682	total: 11s	remaining: 3.56s
# 914:	learn: 0.0622142	total: 11s	remaining: 3.55s
# 915:	learn: 0.0621825	total: 11s	remaining: 3.54s
# 916:	learn: 0.0621517	total: 11s	remaining: 3.53s
# 917:	learn: 0.0621188	total: 11s	remaining: 3.51s
# 918:	learn: 0.0621047	total: 11s	remaining: 3.5s
# 919:	learn: 0.0620928	total: 11s	remaining: 3.49s
# 920:	learn: 0.0620783	total: 11s	remaining: 3.48s
# 921:	learn: 0.0620546	total: 11.1s	remaining: 3.46s
# 922:	learn: 0.0620374	total: 11.1s	remaining: 3.45s
# 923:	learn: 0.0620145	total: 11.1s	remaining: 3.44s
# 924:	learn: 0.0619875	total: 11.1s	remaining: 3.43s
# 925:	learn: 0.0619549	total: 11.1s	remaining: 3.41s
# 926:	learn: 0.0619278	total: 11.1s	remaining: 3.4s
# 927:	learn: 0.0619073	total: 11.1s	remaining: 3.39s
# 928:	learn: 0.0618681	total: 11.1s	remaining: 3.38s
# 929:	learn: 0.0618434	total: 11.1s	remaining: 3.36s
# 930:	learn: 0.0618154	total: 11.1s	remaining: 3.35s
# 931:	learn: 0.0617974	total: 11.2s	remaining: 3.34s
# 932:	learn: 0.0617701	total: 11.2s	remaining: 3.33s
# 933:	learn: 0.0617517	total: 11.2s	remaining: 3.31s
# 934:	learn: 0.0617278	total: 11.2s	remaining: 3.3s
# 935:	learn: 0.0617082	total: 11.2s	remaining: 3.29s
# 936:	learn: 0.0616892	total: 11.2s	remaining: 3.28s
# 937:	learn: 0.0616722	total: 11.2s	remaining: 3.26s
# 938:	learn: 0.0616495	total: 11.2s	remaining: 3.25s
# 939:	learn: 0.0616207	total: 11.2s	remaining: 3.24s
# 940:	learn: 0.0615900	total: 11.2s	remaining: 3.23s
# 941:	learn: 0.0615645	total: 11.3s	remaining: 3.21s
# 942:	learn: 0.0615379	total: 11.3s	remaining: 3.2s
# 943:	learn: 0.0615176	total: 11.3s	remaining: 3.19s
# 944:	learn: 0.0614991	total: 11.3s	remaining: 3.18s
# 945:	learn: 0.0614795	total: 11.3s	remaining: 3.16s
# 946:	learn: 0.0614489	total: 11.3s	remaining: 3.15s
# 947:	learn: 0.0614168	total: 11.3s	remaining: 3.14s
# 948:	learn: 0.0614039	total: 11.3s	remaining: 3.13s
# 949:	learn: 0.0613832	total: 11.3s	remaining: 3.11s
# 950:	learn: 0.0613522	total: 11.3s	remaining: 3.1s
# 951:	learn: 0.0613036	total: 11.4s	remaining: 3.09s
# 952:	learn: 0.0612799	total: 11.4s	remaining: 3.08s
# 953:	learn: 0.0612623	total: 11.4s	remaining: 3.06s
# 954:	learn: 0.0612362	total: 11.4s	remaining: 3.05s
# 955:	learn: 0.0612125	total: 11.4s	remaining: 3.04s
# 956:	learn: 0.0611820	total: 11.4s	remaining: 3.03s
# 957:	learn: 0.0611646	total: 11.4s	remaining: 3.02s
# 958:	learn: 0.0611329	total: 11.4s	remaining: 3s
# 959:	learn: 0.0611193	total: 11.4s	remaining: 2.99s
# 960:	learn: 0.0610965	total: 11.4s	remaining: 2.98s
# 961:	learn: 0.0610586	total: 11.5s	remaining: 2.97s
# 962:	learn: 0.0610240	total: 11.5s	remaining: 2.95s
# 963:	learn: 0.0610038	total: 11.5s	remaining: 2.94s
# 964:	learn: 0.0609869	total: 11.5s	remaining: 2.93s
# 965:	learn: 0.0609607	total: 11.5s	remaining: 2.92s
# 966:	learn: 0.0609396	total: 11.5s	remaining: 2.91s
# 967:	learn: 0.0608897	total: 11.5s	remaining: 2.89s
# 968:	learn: 0.0608685	total: 11.5s	remaining: 2.88s
# 969:	learn: 0.0608478	total: 11.6s	remaining: 2.87s
# 970:	learn: 0.0608272	total: 11.6s	remaining: 2.86s
# 971:	learn: 0.0608157	total: 11.6s	remaining: 2.85s
# 972:	learn: 0.0607855	total: 11.6s	remaining: 2.83s
# 973:	learn: 0.0607635	total: 11.6s	remaining: 2.82s
# 974:	learn: 0.0607366	total: 11.6s	remaining: 2.81s
# 975:	learn: 0.0607078	total: 11.6s	remaining: 2.8s
# 976:	learn: 0.0606776	total: 11.6s	remaining: 2.78s
# 977:	learn: 0.0606500	total: 11.6s	remaining: 2.77s
# 978:	learn: 0.0606258	total: 11.6s	remaining: 2.76s
# 979:	learn: 0.0605931	total: 11.7s	remaining: 2.75s
# 980:	learn: 0.0605793	total: 11.7s	remaining: 2.73s
# 981:	learn: 0.0605630	total: 11.7s	remaining: 2.72s
# 982:	learn: 0.0605224	total: 11.7s	remaining: 2.71s
# 983:	learn: 0.0604772	total: 11.7s	remaining: 2.7s
# 984:	learn: 0.0604482	total: 11.7s	remaining: 2.69s
# 985:	learn: 0.0604238	total: 11.7s	remaining: 2.68s
# 986:	learn: 0.0603996	total: 11.7s	remaining: 2.66s
# 987:	learn: 0.0603822	total: 11.8s	remaining: 2.65s
# 988:	learn: 0.0603569	total: 11.8s	remaining: 2.64s
# 989:	learn: 0.0603347	total: 11.8s	remaining: 2.63s
# 990:	learn: 0.0602984	total: 11.8s	remaining: 2.62s
# 991:	learn: 0.0602783	total: 11.8s	remaining: 2.6s
# 992:	learn: 0.0602477	total: 11.8s	remaining: 2.59s
# 993:	learn: 0.0602218	total: 11.8s	remaining: 2.58s
# 994:	learn: 0.0601710	total: 11.8s	remaining: 2.57s
# 995:	learn: 0.0601456	total: 11.8s	remaining: 2.56s
# 996:	learn: 0.0601209	total: 11.8s	remaining: 2.54s
# 997:	learn: 0.0600997	total: 11.9s	remaining: 2.53s
# 998:	learn: 0.0600820	total: 11.9s	remaining: 2.52s
# 999:	learn: 0.0600617	total: 11.9s	remaining: 2.51s
# 1000:	learn: 0.0600434	total: 11.9s	remaining: 2.5s
# 1001:	learn: 0.0600121	total: 11.9s	remaining: 2.48s
# 1002:	learn: 0.0599774	total: 11.9s	remaining: 2.47s
# 1003:	learn: 0.0599488	total: 11.9s	remaining: 2.46s
# 1004:	learn: 0.0599103	total: 11.9s	remaining: 2.45s
# 1005:	learn: 0.0598820	total: 12s	remaining: 2.44s
# 1006:	learn: 0.0598666	total: 12s	remaining: 2.42s
# 1007:	learn: 0.0598384	total: 12s	remaining: 2.41s
# 1008:	learn: 0.0598258	total: 12s	remaining: 2.4s
# 1009:	learn: 0.0597990	total: 12s	remaining: 2.39s
# 1010:	learn: 0.0597655	total: 12s	remaining: 2.38s
# 1011:	learn: 0.0597495	total: 12s	remaining: 2.36s
# 1012:	learn: 0.0597312	total: 12s	remaining: 2.35s
# 1013:	learn: 0.0597112	total: 12s	remaining: 2.34s
# 1014:	learn: 0.0596964	total: 12.1s	remaining: 2.33s
# 1015:	learn: 0.0596810	total: 12.1s	remaining: 2.32s
# 1016:	learn: 0.0596579	total: 12.1s	remaining: 2.3s
# 1017:	learn: 0.0596241	total: 12.1s	remaining: 2.29s
# 1018:	learn: 0.0595976	total: 12.1s	remaining: 2.28s
# 1019:	learn: 0.0595893	total: 12.1s	remaining: 2.27s
# 1020:	learn: 0.0595730	total: 12.1s	remaining: 2.25s
# 1021:	learn: 0.0595564	total: 12.1s	remaining: 2.24s
# 1022:	learn: 0.0595199	total: 12.1s	remaining: 2.23s
# 1023:	learn: 0.0595037	total: 12.1s	remaining: 2.22s
# 1024:	learn: 0.0594835	total: 12.2s	remaining: 2.21s
# 1025:	learn: 0.0594558	total: 12.2s	remaining: 2.19s
# 1026:	learn: 0.0594326	total: 12.2s	remaining: 2.18s
# 1027:	learn: 0.0594007	total: 12.2s	remaining: 2.17s
# 1028:	learn: 0.0593758	total: 12.2s	remaining: 2.16s
# 1029:	learn: 0.0593540	total: 12.2s	remaining: 2.15s
# 1030:	learn: 0.0593288	total: 12.2s	remaining: 2.13s
# 1031:	learn: 0.0593042	total: 12.2s	remaining: 2.12s
# 1032:	learn: 0.0592862	total: 12.2s	remaining: 2.11s
# 1033:	learn: 0.0592647	total: 12.3s	remaining: 2.1s
# 1034:	learn: 0.0592375	total: 12.3s	remaining: 2.08s
# 1035:	learn: 0.0592200	total: 12.3s	remaining: 2.07s
# 1036:	learn: 0.0592080	total: 12.3s	remaining: 2.06s
# 1037:	learn: 0.0591801	total: 12.3s	remaining: 2.05s
# 1038:	learn: 0.0591679	total: 12.3s	remaining: 2.04s
# 1039:	learn: 0.0591371	total: 12.3s	remaining: 2.02s
# 1040:	learn: 0.0591186	total: 12.3s	remaining: 2.01s
# 1041:	learn: 0.0590922	total: 12.3s	remaining: 2s
# 1042:	learn: 0.0590742	total: 12.3s	remaining: 1.99s
# 1043:	learn: 0.0590551	total: 12.4s	remaining: 1.98s
# 1044:	learn: 0.0590396	total: 12.4s	remaining: 1.96s
# 1045:	learn: 0.0590078	total: 12.4s	remaining: 1.95s
# 1046:	learn: 0.0589868	total: 12.4s	remaining: 1.94s
# 1047:	learn: 0.0589599	total: 12.4s	remaining: 1.93s
# 1048:	learn: 0.0589413	total: 12.4s	remaining: 1.92s
# 1049:	learn: 0.0589212	total: 12.4s	remaining: 1.9s
# 1050:	learn: 0.0588973	total: 12.4s	remaining: 1.89s
# 1051:	learn: 0.0588629	total: 12.4s	remaining: 1.88s
# 1052:	learn: 0.0588395	total: 12.4s	remaining: 1.87s
# 1053:	learn: 0.0588068	total: 12.5s	remaining: 1.85s
# 1054:	learn: 0.0587807	total: 12.5s	remaining: 1.84s
# 1055:	learn: 0.0587617	total: 12.5s	remaining: 1.83s
# 1056:	learn: 0.0587315	total: 12.5s	remaining: 1.82s
# 1057:	learn: 0.0586887	total: 12.5s	remaining: 1.81s
# 1058:	learn: 0.0586739	total: 12.5s	remaining: 1.79s
# 1059:	learn: 0.0586574	total: 12.5s	remaining: 1.78s
# 1060:	learn: 0.0586249	total: 12.5s	remaining: 1.77s
# 1061:	learn: 0.0586091	total: 12.5s	remaining: 1.76s
# 1062:	learn: 0.0585837	total: 12.6s	remaining: 1.75s
# 1063:	learn: 0.0585625	total: 12.6s	remaining: 1.74s
# 1064:	learn: 0.0585451	total: 12.6s	remaining: 1.72s
# 1065:	learn: 0.0585181	total: 12.6s	remaining: 1.71s
# 1066:	learn: 0.0584923	total: 12.6s	remaining: 1.7s
# 1067:	learn: 0.0584636	total: 12.6s	remaining: 1.69s
# 1068:	learn: 0.0584417	total: 12.6s	remaining: 1.68s
# 1069:	learn: 0.0584260	total: 12.6s	remaining: 1.66s
# 1070:	learn: 0.0584017	total: 12.6s	remaining: 1.65s
# 1071:	learn: 0.0583777	total: 12.6s	remaining: 1.64s
# 1072:	learn: 0.0583644	total: 12.7s	remaining: 1.63s
# 1073:	learn: 0.0583502	total: 12.7s	remaining: 1.61s
# 1074:	learn: 0.0583367	total: 12.7s	remaining: 1.6s
# 1075:	learn: 0.0583089	total: 12.7s	remaining: 1.59s
# 1076:	learn: 0.0582853	total: 12.7s	remaining: 1.58s
# 1077:	learn: 0.0582618	total: 12.7s	remaining: 1.57s
# 1078:	learn: 0.0582518	total: 12.7s	remaining: 1.56s
# 1079:	learn: 0.0582358	total: 12.7s	remaining: 1.54s
# 1080:	learn: 0.0582164	total: 12.7s	remaining: 1.53s
# 1081:	learn: 0.0582048	total: 12.8s	remaining: 1.52s
# 1082:	learn: 0.0581755	total: 12.8s	remaining: 1.51s
# 1083:	learn: 0.0581562	total: 12.8s	remaining: 1.5s
# 1084:	learn: 0.0581359	total: 12.8s	remaining: 1.48s
# 1085:	learn: 0.0581125	total: 12.8s	remaining: 1.47s
# 1086:	learn: 0.0580989	total: 12.8s	remaining: 1.46s
# 1087:	learn: 0.0580795	total: 12.8s	remaining: 1.45s
# 1088:	learn: 0.0580666	total: 12.8s	remaining: 1.44s
# 1089:	learn: 0.0580458	total: 12.8s	remaining: 1.42s
# 1090:	learn: 0.0580244	total: 12.8s	remaining: 1.41s
# 1091:	learn: 0.0579888	total: 12.9s	remaining: 1.4s
# 1092:	learn: 0.0579580	total: 12.9s	remaining: 1.39s
# 1093:	learn: 0.0579342	total: 12.9s	remaining: 1.38s
# 1094:	learn: 0.0579082	total: 12.9s	remaining: 1.36s
# 1095:	learn: 0.0578800	total: 12.9s	remaining: 1.35s
# 1096:	learn: 0.0578555	total: 12.9s	remaining: 1.34s
# 1097:	learn: 0.0578318	total: 12.9s	remaining: 1.33s
# 1098:	learn: 0.0578138	total: 12.9s	remaining: 1.32s
# 1099:	learn: 0.0577943	total: 12.9s	remaining: 1.3s
# 1100:	learn: 0.0577793	total: 12.9s	remaining: 1.29s
# 1101:	learn: 0.0577594	total: 13s	remaining: 1.28s
# 1102:	learn: 0.0577347	total: 13s	remaining: 1.27s
# 1103:	learn: 0.0577118	total: 13s	remaining: 1.26s
# 1104:	learn: 0.0576952	total: 13s	remaining: 1.25s
# 1105:	learn: 0.0576737	total: 13s	remaining: 1.23s
# 1106:	learn: 0.0576615	total: 13s	remaining: 1.22s
# 1107:	learn: 0.0576515	total: 13s	remaining: 1.21s
# 1108:	learn: 0.0576328	total: 13s	remaining: 1.2s
# 1109:	learn: 0.0576119	total: 13s	remaining: 1.19s
# 1110:	learn: 0.0575945	total: 13.1s	remaining: 1.17s
# 1111:	learn: 0.0575723	total: 13.1s	remaining: 1.16s
# 1112:	learn: 0.0575450	total: 13.1s	remaining: 1.15s
# 1113:	learn: 0.0575224	total: 13.1s	remaining: 1.14s
# 1114:	learn: 0.0574962	total: 13.1s	remaining: 1.13s
# 1115:	learn: 0.0574689	total: 13.1s	remaining: 1.11s
# 1116:	learn: 0.0574493	total: 13.1s	remaining: 1.1s
# 1117:	learn: 0.0574309	total: 13.1s	remaining: 1.09s
# 1118:	learn: 0.0574070	total: 13.1s	remaining: 1.08s
# 1119:	learn: 0.0573935	total: 13.1s	remaining: 1.07s
# 1120:	learn: 0.0573767	total: 13.2s	remaining: 1.06s
# 1121:	learn: 0.0573424	total: 13.2s	remaining: 1.04s
# 1122:	learn: 0.0573225	total: 13.2s	remaining: 1.03s
# 1123:	learn: 0.0573065	total: 13.2s	remaining: 1.02s
# 1124:	learn: 0.0572873	total: 13.2s	remaining: 1.01s
# 1125:	learn: 0.0572655	total: 13.2s	remaining: 997ms
# 1126:	learn: 0.0572509	total: 13.2s	remaining: 985ms
# 1127:	learn: 0.0572293	total: 13.2s	remaining: 973ms
# 1128:	learn: 0.0572081	total: 13.2s	remaining: 962ms
# 1129:	learn: 0.0571829	total: 13.3s	remaining: 950ms
# 1130:	learn: 0.0571552	total: 13.3s	remaining: 938ms
# 1131:	learn: 0.0571273	total: 13.3s	remaining: 926ms
# 1132:	learn: 0.0571159	total: 13.3s	remaining: 915ms
# 1133:	learn: 0.0570937	total: 13.3s	remaining: 903ms
# 1134:	learn: 0.0570765	total: 13.3s	remaining: 891ms
# 1135:	learn: 0.0570610	total: 13.3s	remaining: 879ms
# 1136:	learn: 0.0570385	total: 13.3s	remaining: 867ms
# 1137:	learn: 0.0570236	total: 13.3s	remaining: 855ms
# 1138:	learn: 0.0570034	total: 13.3s	remaining: 843ms
# 1139:	learn: 0.0569894	total: 13.4s	remaining: 832ms
# 1140:	learn: 0.0569613	total: 13.4s	remaining: 820ms
# 1141:	learn: 0.0569418	total: 13.4s	remaining: 808ms
# 1142:	learn: 0.0569268	total: 13.4s	remaining: 796ms
# 1143:	learn: 0.0569059	total: 13.4s	remaining: 784ms
# 1144:	learn: 0.0568809	total: 13.4s	remaining: 773ms
# 1145:	learn: 0.0568632	total: 13.4s	remaining: 761ms
# 1146:	learn: 0.0568527	total: 13.4s	remaining: 749ms
# 1147:	learn: 0.0568316	total: 13.4s	remaining: 737ms
# 1148:	learn: 0.0568157	total: 13.4s	remaining: 726ms
# 1149:	learn: 0.0567960	total: 13.5s	remaining: 714ms
# 1150:	learn: 0.0567776	total: 13.5s	remaining: 702ms
# 1151:	learn: 0.0567558	total: 13.5s	remaining: 690ms
# 1152:	learn: 0.0567170	total: 13.5s	remaining: 678ms
# 1153:	learn: 0.0566851	total: 13.5s	remaining: 667ms
# 1154:	learn: 0.0566509	total: 13.5s	remaining: 655ms
# 1155:	learn: 0.0566238	total: 13.5s	remaining: 643ms
# 1156:	learn: 0.0566028	total: 13.5s	remaining: 631ms
# 1157:	learn: 0.0565902	total: 13.5s	remaining: 620ms
# 1158:	learn: 0.0565644	total: 13.5s	remaining: 608ms
# 1159:	learn: 0.0565542	total: 13.6s	remaining: 596ms
# 1160:	learn: 0.0565281	total: 13.6s	remaining: 584ms
# 1161:	learn: 0.0565040	total: 13.6s	remaining: 573ms
# 1162:	learn: 0.0564799	total: 13.6s	remaining: 561ms
# 1163:	learn: 0.0564679	total: 13.6s	remaining: 549ms
# 1164:	learn: 0.0564420	total: 13.6s	remaining: 538ms
# 1165:	learn: 0.0564112	total: 13.6s	remaining: 526ms
# 1166:	learn: 0.0563848	total: 13.6s	remaining: 514ms
# 1167:	learn: 0.0563736	total: 13.6s	remaining: 502ms
# 1168:	learn: 0.0563498	total: 13.7s	remaining: 491ms
# 1169:	learn: 0.0563371	total: 13.7s	remaining: 479ms
# 1170:	learn: 0.0563207	total: 13.7s	remaining: 467ms
# 1171:	learn: 0.0562987	total: 13.7s	remaining: 455ms
# 1172:	learn: 0.0562663	total: 13.7s	remaining: 444ms
# 1173:	learn: 0.0562473	total: 13.7s	remaining: 432ms
# 1174:	learn: 0.0562224	total: 13.7s	remaining: 420ms
# 1175:	learn: 0.0562024	total: 13.7s	remaining: 409ms
# 1176:	learn: 0.0561857	total: 13.7s	remaining: 397ms
# 1177:	learn: 0.0561592	total: 13.7s	remaining: 385ms
# 1178:	learn: 0.0561375	total: 13.8s	remaining: 373ms
# 1179:	learn: 0.0561064	total: 13.8s	remaining: 362ms
# 1180:	learn: 0.0560828	total: 13.8s	remaining: 350ms
# 1181:	learn: 0.0560523	total: 13.8s	remaining: 338ms
# 1182:	learn: 0.0560331	total: 13.8s	remaining: 327ms
# 1183:	learn: 0.0560161	total: 13.8s	remaining: 315ms
# 1184:	learn: 0.0560016	total: 13.8s	remaining: 303ms
# 1185:	learn: 0.0559837	total: 13.8s	remaining: 292ms
# 1186:	learn: 0.0559720	total: 13.8s	remaining: 280ms
# 1187:	learn: 0.0559611	total: 13.8s	remaining: 268ms
# 1188:	learn: 0.0559423	total: 13.9s	remaining: 256ms
# 1189:	learn: 0.0559213	total: 13.9s	remaining: 245ms
# 1190:	learn: 0.0559079	total: 13.9s	remaining: 233ms
# 1191:	learn: 0.0558847	total: 13.9s	remaining: 221ms
# 1192:	learn: 0.0558643	total: 13.9s	remaining: 210ms
# 1193:	learn: 0.0558411	total: 13.9s	remaining: 198ms
# 1194:	learn: 0.0558178	total: 13.9s	remaining: 186ms
# 1195:	learn: 0.0558023	total: 13.9s	remaining: 175ms
# 1196:	learn: 0.0557906	total: 13.9s	remaining: 163ms
# 1197:	learn: 0.0557664	total: 14s	remaining: 151ms
# 1198:	learn: 0.0557425	total: 14s	remaining: 140ms
# 1199:	learn: 0.0557192	total: 14s	remaining: 128ms
# 1200:	learn: 0.0557142	total: 14s	remaining: 116ms
# 1201:	learn: 0.0556874	total: 14s	remaining: 105ms
# 1202:	learn: 0.0556698	total: 14s	remaining: 93.2ms
# 1203:	learn: 0.0556533	total: 14s	remaining: 81.5ms
# 1204:	learn: 0.0556318	total: 14s	remaining: 69.9ms
# 1205:	learn: 0.0556174	total: 14s	remaining: 58.2ms
# 1206:	learn: 0.0556093	total: 14.1s	remaining: 46.6ms
# 1207:	learn: 0.0555966	total: 14.1s	remaining: 34.9ms
# 1208:	learn: 0.0555782	total: 14.1s	remaining: 23.3ms
# 1209:	learn: 0.0555564	total: 14.1s	remaining: 11.6ms
# 1210:	learn: 0.0555427	total: 14.1s	remaining: 0us

# %% [markdown]
# ### Feature importance

# %%
feature_importances = model.get_feature_importance()
print("\nFeature Importances:\n")
for score, name in sorted(zip(feature_importances, X_train.columns), reverse=True):
    print(f'{name}: {score:.2f}')
# Out:
# Feature Importances:
#
# direct_rad:W: 13.62
# direct_rad_1h:J: 5.23
# interaction_clear_sky_rad_sun_elevation: 4.92
# clear_sky_rad:W: 4.92
# diffuse_rad:W: 4.20
# sun_elevation:d: 4.16
# wind_speed_u_10m:ms: 3.85
# dayofmonth: 3.80
# year: 2.86
# elevation:m: 2.61
# clear_sky_energy_1h:J: 2.40
# diffuse_rad_1h:J: 2.34
# t_1000hPa:K: 2.27
# visibility:m: 2.21
# interaction_clear_sky_rad_effective_cloud_cover: 2.18
# wind_speed_v_10m:ms: 2.17
# effective_cloud_cover:p: 2.10
# location_A: 2.09
# relative_humidity_1000hPa:p: 2.08
# total_cloud_cover:p: 2.00
# dayofweek: 2.00
# wind_speed_10m:ms: 1.93
# msl_pressure:hPa: 1.91
# dew_point_2m:K: 1.68
# dayofyear: 1.66
# absolute_humidity_2m:gm3: 1.66
# sun_azimuth:d: 1.54
# sin_sun_azimuth: 1.53
# cos_sun_azimuth: 1.49
# weekofyear: 1.29
# sfc_pressure:hPa: 1.15
# air_density_2m:kgm3: 1.15
# pressure_100m:hPa: 1.10
# snow_water:kgm2: 1.03
# hour: 1.03
# pressure_50m:hPa: 0.79
# precip_type_5min:idx: 0.69
# month: 0.66
# location_B: 0.62
# super_cooled_liquid_water:kgm2: 0.62
# is_weekend: 0.43
# sun_above_threshold: 0.32
# season: 0.31
# fresh_snow_24h:cm: 0.31
# quarter: 0.25
# precip_5min:mm: 0.24
# rain_water:kgm2: 0.19
# location_C: 0.18
# fresh_snow_12h:cm: 0.09
# snow_melt_10min:mm: 0.04
# snow_depth:cm: 0.03
# is_in_shadow:idx: 0.02
# is_day:idx: 0.01
# wind_speed_w_1000hPa:ms: 0.01
# fresh_snow_6h:cm: 0.00
# dew_or_rime:idx: 0.00
# fresh_snow_3h:cm: 0.00
# fresh_snow_1h:cm: 0.00
# prob_rime:p: 0.00
# snow_drift:idx: 0.00
# estimated: 0.00

# %% [markdown]
# ### Predict and make csv

# %%
predictions = model.predict(X_test)

# %%
predictions = pd.DataFrame(predictions, columns=['prediction'])

predictions.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Filling in the nightime values with zeroes

# %%
all_common_dates = pd.concat([pd.Series(common_dates) for _ in range(3)], ignore_index=True)
predictions['date_forecast'] = all_common_dates

# %%
predictions.head()
# Out:
#    prediction       date_forecast
# 0    0.008715 2023-05-01 03:00:00
# 1    0.069194 2023-05-01 04:00:00
# 2    0.157108 2023-05-01 05:00:00
# 3    0.326106 2023-05-01 06:00:00
# 4    0.462122 2023-05-01 07:00:00

# %%
loc_a = predictions.iloc[:len(predictions)//3]
loc_b = predictions.iloc[len(predictions)//3:2*len(predictions)//3]
loc_c = predictions.iloc[2*len(predictions)//3:]

# %%
n = len(predictions)

# De-normalizing

loc_a.loc[:, 'prediction'] = scaler_a.inverse_transform(loc_a['prediction'].values.reshape(-1, 1))
loc_b.loc[:, 'prediction'] = scaler_b.inverse_transform(loc_b['prediction'].values.reshape(-1, 1))
loc_c.loc[:, 'prediction'] = scaler_c.inverse_transform(loc_c['prediction'].values.reshape(-1, 1))

# %%
valid_dates_df = pd.DataFrame(valid_dates, columns=['date_forecast'])

loc_a = valid_dates_df.merge(loc_a, on='date_forecast', how='left')
loc_a['prediction'].fillna(0, inplace=True)
loc_a = loc_a.sort_values(by='date_forecast').reset_index(drop=True)

loc_b = valid_dates_df.merge(loc_b, on='date_forecast', how='left')
loc_b['prediction'].fillna(0, inplace=True)
loc_b = loc_b.sort_values(by='date_forecast').reset_index(drop=True)

loc_c = valid_dates_df.merge(loc_c, on='date_forecast', how='left')
loc_c['prediction'].fillna(0, inplace=True)
loc_c = loc_c.sort_values(by='date_forecast').reset_index(drop=True)

# %%
predictions = pd.concat([loc_a, loc_b, loc_c])

# %%
predictions.head(100)
# Out:
#          date_forecast  prediction
# 0  2023-05-01 00:00:00    0.000000
# 1  2023-05-01 01:00:00    0.000000
# 2  2023-05-01 02:00:00    0.000000
# 3  2023-05-01 03:00:00   49.964464
# 4  2023-05-01 04:00:00  396.718694
# ..                 ...         ...
# 95 2023-05-18 23:00:00    0.000000
# 96 2023-05-20 00:00:00    0.000000
# 97 2023-05-20 01:00:00    0.000000
# 98 2023-05-20 02:00:00   84.628933
# 99 2023-05-20 03:00:00  316.327111
#
# [100 rows x 2 columns]

# %%
predictions.drop('date_forecast', axis=1, inplace=True)

# %%
predictions.head(10)
# Out:
#     prediction
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3    49.964464
# 4   396.718694
# 5   900.764042
# 6  1869.704852
# 7  2649.542371
# 8  2892.055455
# 9  3144.107294

# %% [markdown]
# Renameing the index column to id

# %%
predictions.reset_index(inplace=True)
predictions.rename(columns={'index': 'id'}, inplace=True)
predictions.to_csv('predictions.csv', index=False)

# %% [markdown]
# Remove negative values

# %%
predictions.loc[predictions['prediction'] < 0, 'prediction'] = 0
predictions.to_csv('predictions.csv', index=False)

# %% [markdown]
# Redifing the training sets

# %%
train_a = pd.read_parquet('../../A/train_targets.parquet')
train_b = pd.read_parquet('../../B/train_targets.parquet')
train_c = pd.read_parquet('../../C/train_targets.parquet')

train_a.set_index('time', inplace=True)
train_b.set_index('time', inplace=True)
train_c.set_index('time', inplace=True)

# %% [markdown]
# ### Plotting A

# %%
loc_a.set_index(valid_dates, inplace=True)

plt.figure(figsize=(9, 4))

loc_a['prediction'].plot(style='.', label='Prediction')
train_a['pv_measurement'].plot(style='.', label='Actual', color='red', linewidth=2)

plt.legend(loc='upper left')
plt.title('Predictions vs. Actual A')
plt.xlabel('Time')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plotting B

# %%
loc_b.set_index(valid_dates, inplace=True)

plt.figure(figsize=(9, 4))

loc_b['prediction'].plot(style='.', label='Prediction')
train_b['pv_measurement'].plot(style='.', label='Actual', color='red', linewidth=2)

plt.legend(loc='upper left')
plt.title('Predictions vs. Actual B')
plt.xlabel('Time')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
loc_c.set_index(valid_dates, inplace=True)

plt.figure(figsize=(9, 4))

loc_c['prediction'].plot(style='.', label='Prediction')
train_c['pv_measurement'].plot(style='.', label='Actual', color='red', linewidth=2)

plt.legend(loc='upper left')
plt.title('Predictions vs. Actual C')
plt.xlabel('Time')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()
