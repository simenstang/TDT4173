# %% [markdown]
# # The Cat Boost Notebook notebook
#
# - The y-set for location A, B and C are concatonated (time index)
# - The X-set for location A, B and C are concatonated (time index)
# - One hot encoding for location and whether or not set is from the estimated column
# - The y-set and the X-set are merged on date and location
# - Having date features
# - y-sets are normalized (MinMax)
# - Removes repeated values in y-set B and C
#
# It takes over from feature_engineering_1
# Adds some ratio features from feature_engineering_3
#
# **Takes over from catboost_3.ipynb**
#
#
# Uses catboost
#
#
# ***What's new?***
#
# A new model of cat_boost_1.ipynb
#
# ### CATBOOST VERSION 2

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import math
import csv
import seaborn as sns
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
train_a = pd.read_parquet('../../A/train_targets.parquet')
train_b = pd.read_parquet('../../B/train_targets.parquet')
train_c = pd.read_parquet('../../C/train_targets.parquet')

X_train_estimated_a = pd.read_parquet('../../A/X_train_estimated.parquet')
X_train_estimated_b = pd.read_parquet('../../B/X_train_estimated.parquet')
X_train_estimated_c = pd.read_parquet('../../C/X_train_estimated.parquet')

X_train_observed_a = pd.read_parquet('../../A/X_train_observed.parquet')
X_train_observed_b = pd.read_parquet('../../B/X_train_observed.parquet')
X_train_observed_c = pd.read_parquet('../../C/X_train_observed.parquet')

X_test_estimated_a = pd.read_parquet('../../A/X_test_estimated.parquet')
X_test_estimated_b = pd.read_parquet('../../B/X_test_estimated.parquet')
X_test_estimated_c = pd.read_parquet('../../C/X_test_estimated.parquet')

# %% [markdown]
# ## Handling the Y-set

# %%
def find_repeated_rows(df):
    '''
    Returns all indicies (from, to) which have the largest intervals of being constant. The output is sorted from 
    largest to smallest.
    '''
    df = df.reset_index()
    repeated_temp = []
    intervals = []

    first = True

    for index, row in df.iterrows():
        if index == 0:
            continue
        if row['pv_measurement'] == df.iloc[index - 1]['pv_measurement']:
            repeated_temp.append(index)
            if first: 
                repeated_temp.insert(0, index - 1)
                first = False
        else:
            if len(repeated_temp) > 1:
                intervals.append((repeated_temp[0], repeated_temp[-1]))
            repeated_temp = []
            first = True
            
    threshold = 6

    return sorted([t for t in intervals if t[1] - t[0] >= threshold], key=lambda t: t[1] - t[0], reverse=True)

# %%
all_y = [train_a, train_b, train_c]
labels = ['A', 'B', 'C']

table = {}

i = 0
for y in all_y:
    loc, intervals = labels[i], find_repeated_rows(y)
    if isinstance(intervals[0], (int, float)):
        intervals = np.asarray(intervals, dtype=float)
    intervals = list(intervals) + [np.nan] * (1421 - len(intervals))
    table[loc] = intervals
    print("The largest interval for", loc, intervals[0])
    i += 1

table = pd.DataFrame(table)
table.head()
# Out:
# The largest interval for A (5176, 5218)
# The largest interval for B (13409, 14466)
# The largest interval for C (18105, 18727)
#                 A               B               C
# 0    (5176, 5218)  (13409, 14466)  (18105, 18727)
# 1    (4526, 4547)  (19138, 20141)  (26048, 26669)
# 2  (22429, 22450)  (18690, 19137)  (27224, 27748)
# 3  (22933, 22954)  (10966, 11307)  (25400, 25876)
# 4        (67, 87)  (26115, 26353)  (10047, 10375)

# %%
i = 1
for y in all_y[1:]:
    loc, intervals = labels[i], find_repeated_rows(y)
    for start, end in intervals:
        for row_index in range(start, end + 1):
            y.at[row_index, 'pv_measurement'] = np.nan

    test = y.set_index('time')
    test['pv_measurement'].plot(title="PV measurments when removing all constant intervals in " + loc)
    plt.show()
    i += 1

# %%
train_a.set_index('time', inplace=True)
train_b.set_index('time', inplace=True)
train_c.set_index('time', inplace=True)

# %% [markdown]
# Normalizing values

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_a = MinMaxScaler()
scaler_b = MinMaxScaler()
scaler_c = MinMaxScaler()

# %%
train_a['pv_measurement'] = scaler_a.fit_transform(train_a[['pv_measurement']])
train_b['pv_measurement'] = scaler_b.fit_transform(train_b[['pv_measurement']])
train_c['pv_measurement'] = scaler_c.fit_transform(train_c[['pv_measurement']])

# %%
train_a['location'] = 'A'
train_b['location'] = 'B'
train_c['location'] = 'C'

# %%
y = pd.concat([train_a, train_b, train_c])
y.index.name = 'time'
y = pd.get_dummies(y, prefix='location', columns=['location'])
encoded_columns = [col for col in y.columns if 'location_' in col]
y[encoded_columns] = y[encoded_columns].astype(int)

y.shape
y.head()
# Out:
#                      pv_measurement  location_A  location_B  location_C
# time
# 2019-06-02 22:00:00        0.000000           1           0           0
# 2019-06-02 23:00:00        0.000000           1           0           0
# 2019-06-03 00:00:00        0.000000           1           0           0
# 2019-06-03 01:00:00        0.000000           1           0           0
# 2019-06-03 02:00:00        0.003377           1           0           0

# %% [markdown]
# Setting the index to **date_forecast** and resampling with median.

# %%
X_train_observed_a['date_forecast'] = pd.to_datetime(X_train_observed_a['date_forecast'])
X_train_observed_a.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_observed_a:
    X_train_observed_a.drop("date_calc", axis=1, inplace=True)
X_train_observed_a = X_train_observed_a.resample('60min').median()


X_train_estimated_a['date_forecast'] = pd.to_datetime(X_train_estimated_a['date_forecast'])
X_train_estimated_a.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_observed_a:
    X_train_estimated_a.drop("date_calc", axis=1, inplace=True)
X_train_estimated_a = X_train_estimated_a.resample('60min').median()


X_train_observed_b['date_forecast'] = pd.to_datetime(X_train_observed_b['date_forecast'])
X_train_observed_b.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_observed_b:
    X_train_observed_b.drop("date_calc", axis=1, inplace=True)
X_train_observed_b = X_train_observed_b.resample('60min').median()


X_train_estimated_b['date_forecast'] = pd.to_datetime(X_train_estimated_b['date_forecast'])
X_train_estimated_b.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_estimated_b:
    X_train_estimated_b.drop("date_calc", axis=1, inplace=True)
X_train_estimated_b = X_train_estimated_b.resample('60min').median()


X_train_observed_c['date_forecast'] = pd.to_datetime(X_train_observed_c['date_forecast'])
X_train_observed_c.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_observed_c:
    X_train_observed_c.drop("date_calc", axis=1, inplace=True)
X_train_observed_c = X_train_observed_c.resample('60min').median()


X_train_estimated_c['date_forecast'] = pd.to_datetime(X_train_estimated_c['date_forecast'])
X_train_estimated_c.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_estimated_c:
    X_train_estimated_c.drop("date_calc", axis=1, inplace=True)
X_train_estimated_c = X_train_estimated_c.resample('60min').median()

# %%
X_train_observed_a.columns
# Out:
# Index(['absolute_humidity_2m:gm3', 'air_density_2m:kgm3',
#        'ceiling_height_agl:m', 'clear_sky_energy_1h:J', 'clear_sky_rad:W',
#        'cloud_base_agl:m', 'dew_or_rime:idx', 'dew_point_2m:K',
#        'diffuse_rad:W', 'diffuse_rad_1h:J', 'direct_rad:W', 'direct_rad_1h:J',
#        'effective_cloud_cover:p', 'elevation:m', 'fresh_snow_12h:cm',
#        'fresh_snow_1h:cm', 'fresh_snow_24h:cm', 'fresh_snow_3h:cm',
#        'fresh_snow_6h:cm', 'is_day:idx', 'is_in_shadow:idx',
#        'msl_pressure:hPa', 'precip_5min:mm', 'precip_type_5min:idx',
#        'pressure_100m:hPa', 'pressure_50m:hPa', 'prob_rime:p',
#        'rain_water:kgm2', 'relative_humidity_1000hPa:p', 'sfc_pressure:hPa',
#        'snow_density:kgm3', 'snow_depth:cm', 'snow_drift:idx',
#        'snow_melt_10min:mm', 'snow_water:kgm2', 'sun_azimuth:d',
#        'sun_elevation:d', 'super_cooled_liquid_water:kgm2', 't_1000hPa:K',
#        'total_cloud_cover:p', 'visibility:m', 'wind_speed_10m:ms',
#        'wind_speed_u_10m:ms', 'wind_speed_v_10m:ms',
#        'wind_speed_w_1000hPa:ms'],
#       dtype='object')

# %%
def replace_outliers_with_nan(df, feature):
    '''Replaces thr 0.01 and 0.99'''
    Q1 = df[feature].quantile(0.01)
    Q99 = df[feature].quantile(0.99)

    df[feature] = np.where(
        (df[feature] < Q1) | (df[feature] > Q99),
        np.nan,
        df[feature]
    )

# %% [markdown]
# ### Removing 'outlier' features as this gave us 0.1 better score on Kaggle

# %%
outliers = ['air_density_2m:kgm3', 'msl_pressure:hPa', 'sfc_pressure:hPa']


for o in outliers:
    replace_outliers_with_nan(X_train_observed_a, o)
    replace_outliers_with_nan(X_train_observed_b, o)
    replace_outliers_with_nan(X_train_observed_c, o)

# %%
X_train_observed_a['location'], X_train_estimated_a['location'] = 'A', 'A'
X_train_observed_b['location'], X_train_estimated_b['location']= 'B', 'B'
X_train_observed_c['location'], X_train_estimated_c['location']= 'C', 'C'

X_train_observed_a['estimated'], X_train_estimated_a['estimated'] = 0, 1
X_train_observed_b['estimated'], X_train_estimated_b['estimated'] = 0, 1
X_train_observed_c['estimated'], X_train_estimated_c['estimated'] = 0, 1

# %%
X = pd.concat([X_train_observed_a, X_train_estimated_a, X_train_observed_b,
               X_train_estimated_b, X_train_observed_c, X_train_estimated_c
               ], ignore_index=False)
X = X.sort_index()

# %% [markdown]
# One hot encoding on location

# %%
# One hot encoding
X = pd.get_dummies(X, prefix='location', columns=['location'])
encoded_columns = [col for col in X.columns if 'location_' in col]
X[encoded_columns] = X[encoded_columns].astype(int)

# %%
df = pd.merge(y, X, left_on=[y.index, 'location_A', 'location_B', 'location_C'],
              right_on=[X.index, 'location_A', 'location_B', 'location_C'])

df.set_index('key_0', inplace=True)
df.index.name = "time"
df = df.sort_index()

df.head()
# Out:
#                      pv_measurement  location_A  location_B  location_C  \
# time
# 2019-01-01 00:00:00             NaN           0           1           0
# 2019-01-01 00:00:00             NaN           0           0           1
# 2019-01-01 01:00:00             NaN           0           0           1
# 2019-01-01 01:00:00             NaN           0           1           0
# 2019-01-01 02:00:00             NaN           0           1           0
#
#                      absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# time
# 2019-01-01 00:00:00                      5.55               1.2395
# 2019-01-01 00:00:00                      5.45               1.2410
# 2019-01-01 01:00:00                      5.35               1.2400
# 2019-01-01 01:00:00                      5.40               1.2395
# 2019-01-01 02:00:00                      5.40               1.2385
#
#                      ceiling_height_agl:m  clear_sky_energy_1h:J  \
# time
# 2019-01-01 00:00:00           1200.700012                    0.0
# 2019-01-01 00:00:00           1130.049988                    0.0
# 2019-01-01 01:00:00           1066.699951                    0.0
# 2019-01-01 01:00:00           1131.449951                    0.0
# 2019-01-01 02:00:00           1061.049988                    0.0
#
#                      clear_sky_rad:W  cloud_base_agl:m  ...  \
# time                                                    ...
# 2019-01-01 00:00:00              0.0       1200.700012  ...
# 2019-01-01 00:00:00              0.0       1130.049988  ...
# 2019-01-01 01:00:00              0.0       1066.699951  ...
# 2019-01-01 01:00:00              0.0       1131.449951  ...
# 2019-01-01 02:00:00              0.0       1061.049988  ...
#
#                      super_cooled_liquid_water:kgm2  t_1000hPa:K  \
# time
# 2019-01-01 00:00:00                             0.0   278.250000
# 2019-01-01 00:00:00                             0.0   278.349991
# 2019-01-01 01:00:00                             0.0   278.200012
# 2019-01-01 01:00:00                             0.0   278.100006
# 2019-01-01 02:00:00                             0.1   278.050003
#
#                      total_cloud_cover:p  visibility:m  wind_speed_10m:ms  \
# time
# 2019-01-01 00:00:00            87.500000  16823.399902               2.80
# 2019-01-01 00:00:00            85.350002  16512.299805               2.90
# 2019-01-01 01:00:00            99.099998  13277.399902               3.65
# 2019-01-01 01:00:00            99.099998  12777.449707               3.55
# 2019-01-01 02:00:00            97.849998  11142.549805               4.05
#
#                      wind_speed_u_10m:ms  wind_speed_v_10m:ms  \
# time
# 2019-01-01 00:00:00                 1.20                 2.55
# 2019-01-01 00:00:00                 1.10                 2.65
# 2019-01-01 01:00:00                 1.40                 3.35
# 2019-01-01 01:00:00                 1.50                 3.20
# 2019-01-01 02:00:00                 2.15                 3.45
#
#                      wind_speed_w_1000hPa:ms  estimated  date_calc
# time
# 2019-01-01 00:00:00                     -0.0          0        NaT
# 2019-01-01 00:00:00                     -0.0          0        NaT
# 2019-01-01 01:00:00                     -0.0          0        NaT
# 2019-01-01 01:00:00                     -0.0          0        NaT
# 2019-01-01 02:00:00                     -0.0          0        NaT
#
# [5 rows x 51 columns]

# %%
def create_features(df):
    """
    Create Features
    """
    
    df = df.copy()
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week

    df['is_weekend'] = (df.index.weekday >= 5).astype(int)
    df['season'] = df.index.month.map(get_season)

    # Set a threshold for sun elevation (in degrees)
    elevation_threshold = 10  

    # Binary feature for significant sun elevation
    df['sun_above_threshold'] = (df['sun_elevation:d'] > elevation_threshold).astype(int)

    # Cosine and sine transformations of sun azimuth
    df['cos_sun_azimuth'] = np.cos(np.radians(df['sun_azimuth:d']))
    df['sin_sun_azimuth'] = np.sin(np.radians(df['sun_azimuth:d']))

    df['interaction_clear_sky_rad_sun_elevation'] = df['clear_sky_rad:W'] * df['sun_elevation:d']
    df['interaction_clear_sky_rad_effective_cloud_cover'] = df['clear_sky_rad:W'] * df['effective_cloud_cover:p']

    df['ratio_clear_sky_rad_to_cloud_cover'] = df['clear_sky_rad:W'] / (df['effective_cloud_cover:p'] + 1e-8)  # added a small number to avoid division by zero

    df['ratio_direct_to_diffuse_rad'] = df['direct_rad:W'] / (df['diffuse_rad:W'] + 1e-8)

    df['ratio_air_density_to_humidity'] = df['air_density_2m:kgm3'] / (df['absolute_humidity_2m:gm3'] + 1e-8)

    df['ratio_wind_speed_10m_to_1000hPa'] = df['wind_speed_v_10m:ms'] / (df['wind_speed_w_1000hPa:ms'] + 1e-8)

    return df

def get_season(month):
    if 3 <= month <= 5:
        return 0  # spring
    elif 6 <= month <= 8:
        return 1  # summer
    elif 9 <= month <= 11:
        return 2  # fall
    else:
        return 3  # winter

df = create_features(df)

df.head()
# Out:
#                      pv_measurement  location_A  location_B  location_C  \
# time
# 2019-01-01 00:00:00             NaN           0           1           0
# 2019-01-01 00:00:00             NaN           0           0           1
# 2019-01-01 01:00:00             NaN           0           0           1
# 2019-01-01 01:00:00             NaN           0           1           0
# 2019-01-01 02:00:00             NaN           0           1           0
#
#                      absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# time
# 2019-01-01 00:00:00                      5.55               1.2395
# 2019-01-01 00:00:00                      5.45               1.2410
# 2019-01-01 01:00:00                      5.35               1.2400
# 2019-01-01 01:00:00                      5.40               1.2395
# 2019-01-01 02:00:00                      5.40               1.2385
#
#                      ceiling_height_agl:m  clear_sky_energy_1h:J  \
# time
# 2019-01-01 00:00:00           1200.700012                    0.0
# 2019-01-01 00:00:00           1130.049988                    0.0
# 2019-01-01 01:00:00           1066.699951                    0.0
# 2019-01-01 01:00:00           1131.449951                    0.0
# 2019-01-01 02:00:00           1061.049988                    0.0
#
#                      clear_sky_rad:W  cloud_base_agl:m  ...  season  \
# time                                                    ...
# 2019-01-01 00:00:00              0.0       1200.700012  ...       3
# 2019-01-01 00:00:00              0.0       1130.049988  ...       3
# 2019-01-01 01:00:00              0.0       1066.699951  ...       3
# 2019-01-01 01:00:00              0.0       1131.449951  ...       3
# 2019-01-01 02:00:00              0.0       1061.049988  ...       3
#
#                      sun_above_threshold  cos_sun_azimuth  sin_sun_azimuth  \
# time
# 2019-01-01 00:00:00                    0         0.934996         0.354658
# 2019-01-01 00:00:00                    0         0.934934         0.354821
# 2019-01-01 01:00:00                    0         0.761584         0.648067
# 2019-01-01 01:00:00                    0         0.761815         0.647794
# 2019-01-01 02:00:00                    0         0.531894         0.846811
#
#                      interaction_clear_sky_rad_sun_elevation  \
# time
# 2019-01-01 00:00:00                                     -0.0
# 2019-01-01 00:00:00                                     -0.0
# 2019-01-01 01:00:00                                     -0.0
# 2019-01-01 01:00:00                                     -0.0
# 2019-01-01 02:00:00                                     -0.0
#
#                      interaction_clear_sky_rad_effective_cloud_cover  \
# time
# 2019-01-01 00:00:00                                              0.0
# 2019-01-01 00:00:00                                              0.0
# 2019-01-01 01:00:00                                              0.0
# 2019-01-01 01:00:00                                              0.0
# 2019-01-01 02:00:00                                              0.0
#
#                      ratio_clear_sky_rad_to_cloud_cover  \
# time
# 2019-01-01 00:00:00                                 0.0
# 2019-01-01 00:00:00                                 0.0
# 2019-01-01 01:00:00                                 0.0
# 2019-01-01 01:00:00                                 0.0
# 2019-01-01 02:00:00                                 0.0
#
#                      ratio_direct_to_diffuse_rad  \
# time
# 2019-01-01 00:00:00                          0.0
# 2019-01-01 00:00:00                          0.0
# 2019-01-01 01:00:00                          0.0
# 2019-01-01 01:00:00                          0.0
# 2019-01-01 02:00:00                          0.0
#
#                      ratio_air_density_to_humidity  \
# time
# 2019-01-01 00:00:00                       0.223333
# 2019-01-01 00:00:00                       0.227706
# 2019-01-01 01:00:00                       0.231776
# 2019-01-01 01:00:00                       0.229537
# 2019-01-01 02:00:00                       0.229352
#
#                      ratio_wind_speed_10m_to_1000hPa
# time
# 2019-01-01 00:00:00                     2.550000e+08
# 2019-01-01 00:00:00                     2.650000e+08
# 2019-01-01 01:00:00                     3.350000e+08
# 2019-01-01 01:00:00                     3.200000e+08
# 2019-01-01 02:00:00                     3.450000e+08
#
# [5 rows x 70 columns]

# %% [markdown]
# ### Selecting features
#
# Everything except:
#
# - snow_density:kgm3
# - cloud_base_agl:m
# - ceiling_height_agl:m
#
# They have a lot of NaN values.

# %%
FEATURES = [
    'absolute_humidity_2m:gm3', 'air_density_2m:kgm3',
    'clear_sky_energy_1h:J', 'clear_sky_rad:W',
    'dew_or_rime:idx', 'dew_point_2m:K',
    'diffuse_rad:W', 'diffuse_rad_1h:J', 'direct_rad:W', 'direct_rad_1h:J',
    'effective_cloud_cover:p', 'elevation:m', 'fresh_snow_12h:cm',
    'fresh_snow_1h:cm', 'fresh_snow_24h:cm', 'fresh_snow_3h:cm',
    'fresh_snow_6h:cm', 'is_day:idx', 'is_in_shadow:idx',
    'msl_pressure:hPa', 'precip_5min:mm', 'precip_type_5min:idx',
    'pressure_100m:hPa', 'pressure_50m:hPa', 'prob_rime:p',
    'rain_water:kgm2', 'relative_humidity_1000hPa:p', 'sfc_pressure:hPa',
    'snow_depth:cm', 'snow_drift:idx',
    'snow_melt_10min:mm', 'snow_water:kgm2', 'sun_azimuth:d',
    'sun_elevation:d', 'super_cooled_liquid_water:kgm2', 't_1000hPa:K',
    'total_cloud_cover:p', 'visibility:m', 'wind_speed_10m:ms',
    'wind_speed_u_10m:ms', 'wind_speed_v_10m:ms', 'wind_speed_w_1000hPa:ms',
    'hour', 'dayofweek', 'quarter', 'month', 'year', 'dayofyear',
    'dayofmonth', 'weekofyear', 'is_weekend', 'season', 'sun_above_threshold',
    'cos_sun_azimuth', 'sin_sun_azimuth', 'interaction_clear_sky_rad_sun_elevation',
    'interaction_clear_sky_rad_effective_cloud_cover',
    'location_A', 'location_B', 'location_C', 'estimated'
]

TARGET = 'pv_measurement'

# %%
relevant = FEATURES.copy()
relevant.append(TARGET)

df = df[relevant]

# %%
print(df.isna().sum())
before = df.shape

train = df.dropna()
print(train.isna().sum())
after = train.shape

dif = before[0] - after[0]

df = df.dropna()
print("DROPNA RESULTED IN", dif, "ROWS BEING DROPPED. THE DATASET HAS", after[0], "ROWS IN TOTAL.")
# Out:
# absolute_humidity_2m:gm3       72
# air_density_2m:kgm3          1824
# clear_sky_energy_1h:J          72
# clear_sky_rad:W                72
# dew_or_rime:idx                72
#                             ...
# location_A                      0
# location_B                      0
# location_C                      0
# estimated                       0
# pv_measurement              40896
# Length: 62, dtype: int64
# absolute_humidity_2m:gm3    0
# air_density_2m:kgm3         0
# clear_sky_energy_1h:J       0
# clear_sky_rad:W             0
# dew_or_rime:idx             0
#                            ..
# location_A                  0
# location_B                  0
# location_C                  0
# estimated                   0
# pv_measurement              0
# Length: 62, dtype: int64
# DROPNA RESULTED IN 42788 ROWS BEING DROPPED. THE DATASET HAS 56298 ROWS IN TOTAL.

# %%
color_pal = sns.color_palette()

df["pv_measurement"].plot(style='.',
        figsize=(15, 5),
        color=color_pal[1],
        title='PV measurment against time')
plt.show()

# %% [markdown]
# ### Preparing test data
#
# - Excluding dates that should not be tested
# - Including only the features we have defined

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

def prepare_test_data(x, location):
    x_test = x.copy()
    x_test.set_index('date_forecast', inplace = True)
    x_test.drop('date_calc', axis=1, inplace = True)
    x_test['estimated'] = 1

    x_test = x_test.resample('60min').median()

    x_test = create_features(x_test)

    if location == 'A':
        x_test['location_A'] =  1
        x_test['location_B'] = 0
        x_test['location_C'] = 0
    elif location == 'B':
        x_test['location_A'] =  0
        x_test['location_B'] = 1
        x_test['location_C'] = 0
    elif location == 'C':
        x_test['location_A'] =  0
        x_test['location_B'] = 0
        x_test['location_C'] = 1

    return x_test

# %%
x_test_a = prepare_test_data(X_test_estimated_a, 'A')
x_test_b = prepare_test_data(X_test_estimated_b, 'B')
x_test_c = prepare_test_data(X_test_estimated_c, 'C')

# %%
test_sub = pd.read_csv('../../test.csv')
valid_dates = pd.to_datetime(test_sub['time'].unique())

# %%
x_test_a = x_test_a.loc[valid_dates]
x_test_b = x_test_b.loc[valid_dates]
x_test_c = x_test_c.loc[valid_dates]

# %%
X_test = pd.concat([x_test_a, x_test_b, x_test_c])
X_test = X_test[FEATURES]

# %% [markdown]
# ### Disability Check
#
# Check if the training data and the test data contains the same columns.

# %%
check_df = df.copy()
check_train = check_df[FEATURES]
if X_test.columns.equals(check_train.columns):
    print("EQUAL")
else:
    print("NOT EQUAL")
    print("DIFFERENCE\n", X_test.columns.difference(check_train.columns))
# Out:
# EQUAL

# %% [markdown]
# Check if test data has the right amount of rows.

# %%
if X_test.shape[0] != 2160:
    print("X_test has wrong amount of rows!")
    print("Shape =", X_test.shape[0])
else:
    print("GOOD")
# Out:
# GOOD

# %%
X = df[FEATURES]
y = df[TARGET]

# %% [markdown]
# ### Define parameters you want to tune
#
# NOTE we have gotten issues by tuning too many paramters. Be carefull!

# %%
from sklearn.model_selection import validation_curve
from catboost import CatBoostRegressor
import optuna
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt

def custom_tscv_split(X):
    for year in [2020, 2021, 2022]:
        train_dates = X.index[X.index.year < year].to_list()
        test_dates = X.index[X.index.year == year].to_list()
        yield (train_dates, test_dates)

residuals = []

def objective(trial):
    
    number_of_folds = 3

    param = {
    "iterations": trial.suggest_int("iterations", 500, 1500),
    "learning_rate": trial.suggest_float("learning_rate", 1e-4, 1e-1, log=True),
    "depth": trial.suggest_int("depth", 1, 16),
    "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 1.0),
    "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 1, 300),
    "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1e-8, 10.0, log=True),
    "border_count": trial.suggest_int("border_count", 1, 255),
    "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 100.0),
    'loss_function':'MAE'
    }

    model = CatBoostRegressor(**param)

    maes = []

    predictions = []
    actuals = []
    dates_list = [] 

    fig, axs = plt.subplots(number_of_folds, figsize=(15, 15), sharex=True)
    
    fold = 0
    for train_dates, val_dates in custom_tscv_split(X):
        X_train, X_val = X.loc[train_dates], X.loc[val_dates]
        y_train, y_val = y.loc[train_dates], y.loc[val_dates]

        model.fit(X_train, y_train, verbose=0)
        y_pred = model.predict(X_val)
        mae = mean_absolute_error(y_val, y_pred)
        maes.append(mae)
        
        # Store results
        res = y_val - y_pred
        residuals.extend(res)
        predictions.extend(y_pred)
        actuals.extend(y_val)
        dates_list.extend(X_val.index)
        
        # Plot the train and validation data for each fold
        y_train.plot(ax=axs[fold], label='Training Set', title=f'Data Train/Test Split Fold {fold}')
        y_val.plot(ax=axs[fold], label='Test Set')
        axs[fold].axvline(X_val.index.min(), color='black', ls='--')
        fold += 1

    plt.tight_layout()
    plt.show()

    avg_mae = np.mean(maes)
    return avg_mae

# %% [markdown]
# ### Specify number of trials
#
# A higher number of trials tries out more parameters

# %%
trials = 1

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=trials, n_jobs=-1, show_progress_bar=True)
# Out:
# [I 2023-10-26 13:42:13,468] A new study created in memory with name: no-name-9978dc73-5b46-4cc9-9402-0aa9a858b552
#   0%|          | 0/1 [00:00<?, ?it/s]
# [I 2023-10-26 13:42:29,387] Trial 0 finished with value: 0.07871243952552788 and parameters: {'iterations': 1316, 'learning_rate': 0.0013227787883993165, 'depth': 4, 'colsample_bylevel': 0.06485495029338785, 'min_data_in_leaf': 248, 'l2_leaf_reg': 0.014863588388135241, 'border_count': 253, 'bagging_temperature': 71.53091623424272}. Best is trial 0 with value: 0.07871243952552788.

# %%
best_params = study.best_params
print('Best parameters:', best_params)

#Best parameters: {'iterations': 854, 'learning_rate': 0.017432099489773544, 'depth': 14, 'colsample_bylevel': 0.43559465187532453, 'min_data_in_leaf': 257, 'l2_leaf_reg': 9.179321889625692, 'border_count': 129, 'random_strength': 0.8781261706316226, 'bagging_temperature': 11.599929150721326, 'grow_policy': 'Lossguide', 'max_leaves': 192}
# Out:
# Best parameters: {'iterations': 608, 'learning_rate': 0.0037875756972882463, 'depth': 13, 'colsample_bylevel': 0.03081438685102631, 'min_data_in_leaf': 189, 'l2_leaf_reg': 0.049489374733526874, 'border_count': 243, 'bagging_temperature': 12.284599937481078}

# %% [markdown]
# # THE MAIN FIGURE TO WORRY ABOUT
#
# ### Residual = Actual - Pred

# %%
residuals
# Out:
# [-0.011256340049241406,
#  -0.011293344962015318,
#  -0.011125355461553889,
#  -0.011707001244002736,
#  -0.013145294130774011,
#  -0.018161046315302742,
#  -0.0174039744676074,
#  -0.017951843152878885,
#  -0.01732982073543604,
#  -0.015871381569969804,
#  -0.010639168580331038,
#  -0.02008987620755732,
#  -0.015871381569969804,
#  -0.010639168580331038,
#  -0.02008987620755732,
#  -0.015871381569969804,
#  -0.010639168580331038,
#  -0.02008987620755732,
#  -0.021253276748730024,
#  -0.006532795611357677,
#  -0.00483335493472286,
#  -0.021253276748730024,
#  -0.006532795611357677,
#  -0.00483335493472286,
#  -0.021253276748730024,
#  -0.006532795611357677,
#  -0.00483335493472286,
#  -0.024665742574142304,
#  -0.01365654103031327,
#  0.00043761918966686575,
#  -0.024665742574142304,
#  -0.01365654103031327,
#  0.00043761918966686575,
#  -0.024665742574142304,
#  -0.01365654103031327,
#  0.00043761918966686575,
#  -0.005282118841156019,
#  -0.0017768115502173505,
#  -0.023985542065850282,
#  -0.005282118841156019,
#  -0.0017768115502173505,
#  -0.023985542065850282,
#  -0.005282118841156019,
#  -0.0017768115502173505,
#  -0.023985542065850282,
#  -0.017430267550526783,
#  -0.01749476847295449,
#  -0.014555880623346715,
#  -0.013966170464116162,
#  -0.014151472203038147,
#  -0.012293535533377094,
#  -0.010496024579865489,
#  -0.010614369732597655,
#  -0.010490596779334997,
#  -0.010665840952697327,
#  -0.01299671223997994,
#  -0.011123160022627386,
#  -0.011372769128648909,
#  -0.011083274243247142,
#  -0.011208874635036725,
#  -0.01645295457425728,
#  -0.018008774642848634,
#  -0.018718374689882383,
#  -0.018483987175699407,
#  -0.01968135170789631,
#  -0.020220349502706916,
#  -0.022144943357826533,
#  -0.01677003917421839,
#  -0.01598832222336053,
#  -0.022144943357826533,
#  -0.01677003917421839,
#  -0.01598832222336053,
#  -0.022144943357826533,
#  -0.01677003917421839,
#  -0.01598832222336053,
#  -0.017805628418599603,
#  -0.02251649659821508,
#  -0.014459599075261013,
#  -0.017805628418599603,
#  -0.02251649659821508,
#  -0.014459599075261013,
#  -0.017805628418599603,
#  -0.02251649659821508,
#  -0.014459599075261013,
#  -0.01461574108001031,
#  -0.01905364470685694,
#  -0.022592065722592612,
#  -0.01461574108001031,
#  -0.01905364470685694,
#  -0.022592065722592612,
#  -0.01461574108001031,
#  -0.01905364470685694,
#  -0.022592065722592612,
#  -0.014670928979780937,
#  -0.013757888911872226,
#  -0.014168441778366028,
#  -0.014173226127047092,
#  -0.013768146711640047,
#  -0.01273024294368122,
#  -0.011238289673225862,
#  -0.011542751255259158,
#  -0.012213433703873684,
#  -0.012548978270517777,
#  -0.017030332565860958,
#  -0.011255957517932617,
#  -0.011532684551827849,
#  -0.011631299199616724,
#  -0.011439756916940158,
#  -0.012639542493049591,
#  -0.014537865704865954,
#  -0.013823279903386998,
#  -0.0130731250409349,
#  -0.012850252252023412,
#  -0.01465152847085451,
#  -0.019345811938590765,
#  -0.01998367218571226,
#  -0.01955746143747855,
#  -0.0179950171155053,
#  -0.013557989776737563,
#  -0.01298370225207051,
#  -0.013549448013030436,
#  -0.013659158255354388,
#  -0.014206710722821786,
#  -0.011052800060297255,
#  -0.011297450647793084,
#  -0.01121133517938816,
#  -0.010185651145843688,
#  -0.013623064317484113,
#  -0.011318588398642443,
#  -0.011057876000738515,
#  -0.011120084657454357,
#  -0.011345782284964093,
#  -0.012572658078144103,
#  -0.014256435088217653,
#  -0.01454973861286904,
#  -0.01418551835550784,
#  -0.014036288279460948,
#  -0.013223119027747896,
#  -0.017905385510236786,
#  -0.013223119027747896,
#  -0.017905385510236786,
#  -0.005546482023469145,
#  -0.014559751180474778,
#  -0.005546482023469145,
#  -0.014559751180474778,
#  -0.005380480323021044,
#  -0.013779297209426127,
#  -0.005380480323021044,
#  -0.013779297209426127,
#  -0.01448074894016504,
#  -0.02184564566298969,
#  -0.01448074894016504,
#  -0.02184564566298969,
#  -0.016956534870881047,
#  -0.015844443248916686,
#  -0.014806125212697287,
#  -0.01490856939461433,
#  -0.014172418079747132,
#  -0.012750421692888828,
#  -0.010897092937879119,
#  -0.011133963104736452,
#  -0.011465460426710233,
#  -0.011548179872395363,
#  -0.013852311126273782,
#  -0.011890081753894208,
#  -0.011725810149348537,
#  -0.011555299248885431,
#  -0.010662593118353852,
#  -0.01367556264247255,
#  -0.015000510068371734,
#  -0.01552644893750979,
#  -0.015621349957162259,
#  -0.013891366103184102,
#  -0.01662350734737264,
#  -0.021705473057311575,
#  -0.021694784836185685,
#  -0.02140374241469345,
#  -0.016137297961824476,
#  -0.01276121110743346,
#  -0.012469333921478157,
#  -0.012875048398683267,
#  -0.01217015708184109,
#  -0.011850739049109549,
#  -0.01263245706125711,
#  -0.012713913786591681,
#  -0.012357845785934726,
#  -0.012558663424595648,
#  -0.014169788304869688,
#  -0.011706487770044169,
#  -0.011078354583604524,
#  -0.010847962068076866,
#  -0.01388436169350104,
#  -0.01486481298361192,
#  -0.017237031596056232,
#  -0.01636356407968252,
#  -0.01319631989726703,
#  -0.013328770832042994,
#  -0.015690234357327682,
#  -0.01928756169572891,
#  -0.014802318381171157,
#  -0.021088994330393927,
#  -0.014802318381171157,
#  -0.021088994330393927,
#  -0.0178558761298709,
#  -0.021789945880428856,
#  -0.0178558761298709,
#  -0.021789945880428856,
#  -0.018194677179124635,
#  -0.014976103067054512,
#  -0.018194677179124635,
#  -0.014976103067054512,
#  -0.015863596280901716,
#  -0.0175700139765025,
#  -0.01720824963459011,
#  -0.01746661924869384,
#  -0.015929022210039,
#  -0.01318135196029413,
#  -0.013167514357411134,
#  -0.013671047126413288,
#  -0.012378745395223684,
#  -0.014617694995274426,
#  -0.013221357856124341,
#  -0.011232124505889216,
#  -0.010933132344825583,
#  -0.010795749426361759,
#  -0.011445037767230895,
#  -0.013090701417415834,
#  -0.01365165241620725,
#  -0.017168425450302983,
#  -0.016276940722047453,
#  -0.01543768581310991,
#  0.005433177093156414,
#  -0.01543768581310991,
#  0.005433177093156414,
#  -0.01538229465655142,
#  -0.007109174898147202,
#  0.02044147206674788,
#  -0.01538229465655142,
#  -0.007109174898147202,
#  0.02044147206674788,
#  -0.01538229465655142,
#  -0.007109174898147202,
#  0.02044147206674788,
#  -0.01485317347028917,
#  -0.022711137996805263,
#  -0.008025791536900556,
#  -0.01485317347028917,
#  -0.022711137996805263,
#  -0.008025791536900556,
#  -0.01485317347028917,
#  -0.022711137996805263,
#  -0.008025791536900556,
#  -0.02041769953306758,
#  -0.022687902087589876,
#  -0.02041769953306758,
#  -0.022687902087589876,
#  -0.020193920593113486,
#  -0.01651011775671813,
#  -0.017392938265710804,
#  -0.014015887125550727,
#  -0.013358586624372323,
#  -0.012641622275551712,
#  -0.012772954128818584,
#  -0.011822050189962727,
#  -0.011396572591644304,
#  -0.011807861819619674,
#  -0.014109624343503976,
#  -0.013998839776899363,
#  -0.012241314920496044,
#  -0.012393067431852603,
#  -0.01160950832463685,
#  -0.012358888793912559,
#  -0.014903787126690701,
#  -0.015060744563400869,
#  -0.014283919122247746,
#  -0.014508468192778817,
#  -0.010686191794674482,
#  -0.009490111938457219,
#  0.01933981164819127,
#  -0.010686191794674482,
#  -0.009490111938457219,
#  0.01933981164819127,
#  -0.010686191794674482,
#  -0.009490111938457219,
#  0.01933981164819127,
#  -0.0016630106499525947,
#  0.09156223077482745,
#  -0.005445826312693622,
#  -0.0016630106499525947,
#  0.09156223077482745,
#  -0.005445826312693622,
#  -0.0016630106499525947,
#  0.09156223077482745,
#  -0.005445826312693622,
#  -0.0066884670867400735,
#  -0.011610116968466873,
#  0.12257182625267454,
#  -0.0066884670867400735,
#  -0.011610116968466873,
#  0.12257182625267454,
#  -0.0066884670867400735,
#  -0.011610116968466873,
#  0.12257182625267454,
#  0.03128174775318824,
#  -0.007803542049077478,
#  -0.00160186757033174,
#  0.03128174775318824,
#  -0.007803542049077478,
#  -0.00160186757033174,
#  0.03128174775318824,
#  -0.007803542049077478,
#  -0.00160186757033174,
#  -0.013351037729272864,
#  -0.01618904473764647,
#  -0.013351037729272864,
#  -0.01618904473764647,
#  -0.01468273694249083,
#  -0.015113520220854389,
#  -0.014117574227480507,
#  -0.012635781392426423,
#  -0.011925663766358646,
#  -0.010018234690997524,
#  -0.010264937133694876,
#  -0.010231424819180213,
#  -0.009922967690854198,
#  -0.012986242703855566,
#  -0.01092683857530552,
#  -0.011831519178523625,
#  -0.012473412534040274,
#  -0.012507558391783809,
#  -0.016145184581340045,
#  -0.018025324032610493,
#  -0.018614947994073608,
#  -0.018892109331731716,
#  -0.018632704800099195,
#  -0.01231890240777627,
#  -0.020581593827542193,
#  -0.01231890240777627,
#  -0.020581593827542193,
#  -0.022616153685620623,
#  -0.007791522087486034,
#  -0.01536366661792314,
#  -0.022616153685620623,
#  -0.007791522087486034,
#  -0.01536366661792314,
#  -0.022616153685620623,
#  -0.007791522087486034,
#  -0.01536366661792314,
#  -0.0208287021875212,
#  0.012361439678359155,
#  -0.010737828899975467,
#  -0.0208287021875212,
#  0.012361439678359155,
#  -0.010737828899975467,
#  -0.0208287021875212,
#  0.012361439678359155,
#  -0.010737828899975467,
#  -0.019680801971190123,
#  -0.02540941132665398,
#  -0.007394235108792509,
#  -0.019680801971190123,
#  -0.02540941132665398,
#  -0.007394235108792509,
#  -0.019680801971190123,
#  -0.02540941132665398,
#  -0.007394235108792509,
#  -0.018287825802914187,
#  -0.015150452822282367,
#  -0.011494363938277834,
#  -0.018287825802914187,
#  -0.015150452822282367,
#  -0.011494363938277834,
#  -0.018287825802914187,
#  -0.015150452822282367,
#  -0.011494363938277834,
#  -0.018230940230608603,
#  -0.018098485394163144,
#  -0.01660980389756421,
#  -0.015985005506047575,
#  -0.014679045614482737,
#  -0.013574781013498759,
#  -0.013584435466814614,
#  -0.013250807292288981,
#  -0.013775652847975307,
#  -0.016010800056339716,
#  -0.01428329814778128,
#  -0.013995993264616362,
#  -0.013920589240776916,
#  -0.013822519404414167,
#  -0.014508658739330584,
#  -0.01680477503562805,
#  -0.017114037492468148,
#  -0.01577310355144744,
#  -0.014942664479093093,
#  -0.0166290879720872,
#  -0.003406181809497342,
#  -0.004014654290320219,
#  -0.007726858880794902,
#  -0.003406181809497342,
#  -0.004014654290320219,
#  -0.007726858880794902,
#  -0.003406181809497342,
#  -0.004014654290320219,
#  -0.007726858880794902,
#  -0.0062142719054312755,
#  -0.004133720818767863,
#  -0.007455963211479587,
#  -0.0062142719054312755,
#  -0.004133720818767863,
#  -0.007455963211479587,
#  -0.0062142719054312755,
#  -0.004133720818767863,
#  -0.007455963211479587,
#  0.004508631709116015,
#  -0.0025364992051579646,
#  -0.004886387069203229,
#  0.004508631709116015,
#  -0.0025364992051579646,
#  -0.004886387069203229,
#  0.004508631709116015,
#  -0.0025364992051579646,
#  -0.004886387069203229,
#  -0.010255428938951391,
#  -0.007742147185061275,
#  -0.013376251136035787,
#  -0.010255428938951391,
#  -0.007742147185061275,
#  -0.013376251136035787,
#  -0.010255428938951391,
#  -0.007742147185061275,
#  -0.013376251136035787,
#  -0.017015496672103697,
#  -0.016933700371041284,
#  -0.016242992190240155,
#  -0.015860440007767068,
#  -0.01318226410278528,
#  -0.011353834814347985,
#  -0.01134100313839704,
#  -0.012521522534171166,
#  -0.014570308815641413,
#  -0.017669921250844635,
#  -0.015604527808280429,
#  -0.01558899993283245,
#  -0.015558734375023912,
#  -0.015229795870528633,
#  -0.014083390638316672,
#  -0.015162135467155384,
#  -0.015231975941657379,
#  -0.015152802022809032,
#  -0.015276207928525874,
#  -0.017844042443721467,
#  -0.011043860228913764,
#  -0.008486630244454212,
#  -0.01307933443007447,
#  -0.011043860228913764,
#  -0.008486630244454212,
#  -0.01307933443007447,
#  -0.011043860228913764,
#  -0.008486630244454212,
#  -0.01307933443007447,
#  0.012868963201660755,
#  0.03297064655108179,
#  0.021235444473275966,
#  0.012868963201660755,
#  0.03297064655108179,
#  0.021235444473275966,
#  0.012868963201660755,
#  0.03297064655108179,
#  0.021235444473275966,
#  -0.012224702846279351,
#  -0.0027296113350168717,
#  -0.005360344604404297,
#  -0.012224702846279351,
#  -0.0027296113350168717,
#  -0.005360344604404297,
#  -0.012224702846279351,
#  -0.0027296113350168717,
#  -0.005360344604404297,
#  -0.0165044629493807,
#  -0.014152512205183584,
#  -0.014185261444801464,
#  -0.01465362689333529,
#  -0.012950318553849281,
#  -0.012681211865575331,
#  -0.01101853627621227,
#  -0.010995987334880539,
#  -0.010838278915388688,
#  -0.011196277522043219,
#  -0.01222183793064291,
#  -0.010414788472136755,
#  -0.010821234902386803,
#  -0.010605824103834247,
#  -0.010792968532233965,
#  -0.011821046357457024,
#  -0.01311749858103714,
#  -0.012946560710389646,
#  -0.013164994535945468,
#  -0.012434845470884345,
#  -0.010943510778531992,
#  -0.009837849712746127,
#  0.0018937069124465924,
#  -0.010943510778531992,
#  -0.009837849712746127,
#  0.0018937069124465924,
#  -0.010943510778531992,
#  -0.009837849712746127,
#  0.0018937069124465924,
#  -0.0025744110007044907,
#  0.01891019143096833,
#  -0.001727699183235943,
#  -0.0025744110007044907,
#  0.01891019143096833,
#  -0.001727699183235943,
#  -0.0025744110007044907,
#  0.01891019143096833,
#  -0.001727699183235943,
#  0.1876135632292711,
#  0.02347557588306079,
#  0.021696572716679983,
#  0.1876135632292711,
#  0.02347557588306079,
#  0.021696572716679983,
#  0.1876135632292711,
#  0.02347557588306079,
#  0.021696572716679983,
#  0.009585148049290969,
#  0.06797156154159611,
#  0.000923395087236125,
#  0.009585148049290969,
#  0.06797156154159611,
#  0.000923395087236125,
#  0.009585148049290969,
#  0.06797156154159611,
#  0.000923395087236125,
#  -0.012707351865844247,
#  -0.011322848207791905,
#  -0.014388680796358081,
#  -0.012707351865844247,
#  -0.011322848207791905,
#  -0.014388680796358081,
#  -0.012707351865844247,
#  -0.011322848207791905,
#  -0.014388680796358081,
#  -0.015506782877842913,
#  -0.013959793493401491,
#  -0.01588582810178823,
#  -0.016015206901216987,
#  -0.015344823761551891,
#  -0.012351892074962824,
#  -0.013274216313083571,
#  -0.012000939767399021,
#  -0.012557576782883648,
#  -0.016865630213226825,
#  -0.01503134406670327,
#  -0.014037799571614815,
#  -0.014422007744201562,
#  -0.014605636358398177,
#  -0.01598796750543717,
#  -0.018340557617671525,
#  -0.017227577881374627,
#  -0.016800692793314885,
#  -0.016633235266548745,
#  -0.016018660988154895,
#  0.0010479552563289578,
#  -0.014656292780019276,
#  -0.013623297357176807,
#  0.0010479552563289578,
#  -0.014656292780019276,
#  -0.013623297357176807,
#  0.0010479552563289578,
#  -0.014656292780019276,
#  -0.013623297357176807,
#  -0.0061904977644590305,
#  0.026134599213549214,
#  -0.012474166150783096,
#  -0.0061904977644590305,
#  0.026134599213549214,
#  -0.012474166150783096,
#  -0.0061904977644590305,
#  0.026134599213549214,
#  -0.012474166150783096,
#  -0.01599955969379168,
#  -0.01519946523971148,
#  -0.010576461899751616,
#  -0.01599955969379168,
#  -0.01519946523971148,
#  -0.010576461899751616,
#  -0.01599955969379168,
#  -0.01519946523971148,
#  -0.010576461899751616,
#  -0.012600518926746835,
#  -0.015173967077252984,
#  -0.012600518926746835,
#  -0.015173967077252984,
#  -0.012950731262533821,
#  -0.013075975608909038,
#  -0.013438320554890422,
#  -0.017263739968789875,
#  -0.016547087946990634,
#  -0.013596144158127738,
#  -0.013071807561257781,
#  -0.013179138522088504,
#  -0.013499909289644146,
#  -0.01603719182942242,
#  -0.014533978275503928,
#  -0.01499485243123233,
#  -0.015150911423440189,
#  -0.015176298364865497,
#  -0.013714440638156647,
#  -0.01549408889432647,
#  -0.018294873840638735,
#  -0.01815487398855569,
#  -0.017595091296464242,
#  -0.01282561216759784,
#  -0.018322108602909785,
#  -0.01564240377678866,
#  -0.01282561216759784,
#  -0.018322108602909785,
#  -0.01564240377678866,
#  -0.01282561216759784,
#  -0.018322108602909785,
#  -0.01564240377678866,
#  -0.00955061035744505,
#  -0.010926377724745896,
#  -0.021039784098539217,
#  -0.00955061035744505,
#  -0.010926377724745896,
#  -0.021039784098539217,
#  -0.00955061035744505,
#  -0.010926377724745896,
#  -0.021039784098539217,
#  -0.027363929469851566,
#  -0.025143174186944856,
#  0.014759749935789726,
#  -0.027363929469851566,
#  -0.025143174186944856,
#  0.014759749935789726,
#  -0.027363929469851566,
#  -0.025143174186944856,
#  0.014759749935789726,
#  -0.009786028039604742,
#  -0.014266628144913938,
#  0.06623242147027436,
#  -0.009786028039604742,
#  -0.014266628144913938,
#  0.06623242147027436,
#  -0.009786028039604742,
#  -0.014266628144913938,
#  0.06623242147027436,
#  -0.005790304940349173,
#  -0.01744745280433188,
#  -0.0008400982240451375,
#  -0.005790304940349173,
#  -0.01744745280433188,
#  -0.0008400982240451375,
#  -0.005790304940349173,
#  -0.01744745280433188,
#  -0.0008400982240451375,
#  -0.01579086409978649,
#  -0.014184888027236291,
#  -0.01579086409978649,
#  -0.014184888027236291,
#  -0.014601385668653925,
#  -0.014110286426487838,
#  -0.01485404901965371,
#  -0.015790727369990848,
#  -0.012918972027798847,
#  -0.012637992749433682,
#  -0.012961209605830984,
#  -0.013740666020314332,
#  -0.017125011108057087,
#  -0.014828262274737214,
#  -0.012050663608085987,
#  -0.012285352580320236,
#  -0.012211919020953893,
#  -0.013557202146193839,
#  -0.01596170940260872,
#  -0.01472002125790483,
#  -0.014024631347374097,
#  -0.012624764817703698,
#  -0.008279707384561342,
#  -0.00926010744749881,
#  0.00612346808400235,
#  -0.008279707384561342,
#  -0.00926010744749881,
#  0.00612346808400235,
#  -0.008279707384561342,
#  -0.00926010744749881,
#  0.00612346808400235,
#  0.0017385825553852714,
#  0.008360384524146457,
#  0.07726492441514782,
#  0.0017385825553852714,
#  0.008360384524146457,
#  0.07726492441514782,
#  0.0017385825553852714,
#  0.008360384524146457,
#  0.07726492441514782,
#  0.025315201592171523,
#  0.03174006770139051,
#  0.21988625863414676,
#  0.025315201592171523,
#  0.03174006770139051,
#  0.21988625863414676,
#  0.025315201592171523,
#  0.03174006770139051,
#  0.21988625863414676,
#  0.10812922331234794,
#  -0.014661974271693391,
#  -0.007077509361683113,
#  0.10812922331234794,
#  -0.014661974271693391,
#  -0.007077509361683113,
#  0.10812922331234794,
#  -0.014661974271693391,
#  -0.007077509361683113,
#  0.034678871724910354,
#  -0.018347604586970503,
#  -0.01506847577134932,
#  0.034678871724910354,
#  -0.018347604586970503,
#  -0.01506847577134932,
#  0.034678871724910354,
#  -0.018347604586970503,
#  -0.01506847577134932,
#  -0.015257143422158219,
#  -0.017137501772606055,
#  -0.016458937482854437,
#  -0.01630930559795827,
#  -0.01543440400629821,
#  -0.012730334260226517,
#  -0.012952334963421172,
#  -0.013067867817536369,
#  -0.01386735639740208,
#  -0.01756699423532338,
#  -0.014971413805391402,
#  -0.014421379579459381,
#  -0.01462105071946869,
#  -0.014882389055408937,
#  -0.013383650605263767,
#  -0.014460691314513628,
#  -0.014332233484149783,
#  -0.014271118608273452,
#  -0.0125107985233136,
#  0.0076628717454781115,
#  -0.01271549523074274,
#  -0.015274769119549973,
#  0.0076628717454781115,
#  -0.01271549523074274,
#  -0.015274769119549973,
#  0.0076628717454781115,
#  -0.01271549523074274,
#  -0.015274769119549973,
#  -0.019868414068665925,
#  -0.006762069795357515,
#  -0.00807685813294597,
#  -0.019868414068665925,
#  -0.006762069795357515,
#  -0.00807685813294597,
#  -0.019868414068665925,
#  -0.006762069795357515,
#  -0.00807685813294597,
#  -0.02528713195384248,
#  -0.021540229571956424,
#  -0.019192138563053584,
#  -0.02528713195384248,
#  -0.021540229571956424,
#  -0.019192138563053584,
#  -0.02528713195384248,
#  -0.021540229571956424,
#  -0.019192138563053584,
#  -0.019829808372902977,
#  -0.016658283174085728,
#  -0.015932560735120706,
#  -0.019829808372902977,
#  -0.016658283174085728,
#  -0.015932560735120706,
#  -0.019829808372902977,
#  -0.016658283174085728,
#  -0.015932560735120706,
#  -0.015002445189894135,
#  -0.01914456021612101,
#  -0.015002445189894135,
#  -0.01914456021612101,
#  -0.014010415368676324,
#  -0.013928437637233115,
#  -0.013786901684406563,
#  -0.01338547716192695,
#  -0.012299113693873272,
#  -0.011644940244340332,
#  -0.012870706766744927,
#  -0.01248716723732611,
#  -0.013626379514750174,
#  -0.01645691525650954,
#  -0.013945755464063986,
#  -0.014416459271205932,
#  -0.013985988340146562,
#  -0.01379042313283687,
#  -0.01490938359026795,
#  -0.016016389133867548,
#  -0.014187584513656731,
#  -0.01386098924447593,
#  -0.01387540125368987,
#  -0.01533877266257741,
#  -0.016812134436449355,
#  -0.01096818179501831,
#  -0.002244889745537524,
#  -0.016812134436449355,
#  -0.01096818179501831,
#  -0.002244889745537524,
#  -0.016812134436449355,
#  -0.01096818179501831,
#  -0.002244889745537524,
#  -0.0013156099199689436,
#  -0.0018751568387090738,
#  -0.0031378954895817553,
#  -0.0013156099199689436,
#  -0.0018751568387090738,
#  -0.0031378954895817553,
#  -0.0013156099199689436,
#  -0.0018751568387090738,
#  -0.0031378954895817553,
#  -0.011734206160017437,
#  -0.012197936644883636,
#  -0.011131929494429916,
#  -0.011734206160017437,
#  -0.012197936644883636,
#  -0.011131929494429916,
#  -0.011734206160017437,
#  -0.012197936644883636,
#  -0.011131929494429916,
#  -0.01938373876121262,
#  -0.016087157724820854,
#  -0.012671625522275324,
#  -0.01938373876121262,
#  -0.016087157724820854,
#  -0.012671625522275324,
#  -0.01938373876121262,
#  -0.016087157724820854,
#  -0.012671625522275324,
#  -0.016237716026173007,
#  -0.015849246171411008,
#  -0.015160881479901078,
#  -0.015966727192957546,
#  -0.012011003059781547,
#  -0.01035360897637494,
#  -0.011083529361124694,
#  -0.011583499624768262,
#  -0.01096947273273511,
#  -0.01313736964314928,
#  -0.01172431106307021,
#  -0.011408809087201127,
#  -0.012227417521521983,
#  -0.012404607488338534,
#  -0.01310025283069037,
#  -0.014464433069251888,
#  -0.015005732931714859,
#  -0.014094021798010836,
#  -0.012953948629069964,
#  -0.009138214703486905,
#  -0.006625659309888003,
#  -0.0007484844598021692,
#  -0.009138214703486905,
#  -0.006625659309888003,
#  -0.0007484844598021692,
#  -0.009138214703486905,
#  -0.006625659309888003,
#  -0.0007484844598021692,
#  0.02339069248617521,
#  0.012503732955336425,
#  0.01724542139933081,
#  0.02339069248617521,
#  0.012503732955336425,
#  0.01724542139933081,
#  0.02339069248617521,
#  0.012503732955336425,
#  0.01724542139933081,
#  0.012463593323940453,
#  0.03996789646865892,
#  0.017288594727682606,
#  0.012463593323940453,
#  0.03996789646865892,
#  0.017288594727682606,
#  0.012463593323940453,
#  0.03996789646865892,
#  0.017288594727682606,
#  0.04822608021383473,
#  0.016538680685924206,
#  0.013693382184759378,
#  0.04822608021383473,
#  0.016538680685924206,
#  0.013693382184759378,
#  0.04822608021383473,
#  0.016538680685924206,
#  0.013693382184759378,
#  -0.004678312315571621,
#  -0.008990379796663546,
#  -0.011202852718702363,
#  -0.004678312315571621,
#  -0.008990379796663546,
#  -0.011202852718702363,
#  -0.004678312315571621,
#  -0.008990379796663546,
#  -0.011202852718702363,
#  -0.011146609941884073,
#  -0.013855620064953111,
#  -0.015218695826550305,
#  -0.014280696466435663,
#  -0.013466288224579792,
#  -0.01173990141767952,
#  -0.01200786981304363,
#  -0.0108201428358903,
#  -0.010172312518198126,
#  -0.012547118634265234,
#  -0.010336402926650029,
#  -0.01084290469968513,
#  -0.011481982780294817,
#  -0.011577853163928398,
#  -0.012400192563385093,
#  -0.014226735016247757,
#  -0.014074770898168693,
#  -0.014521693291994306,
#  -0.014959082494054095,
#  -0.007014748291359962,
#  -0.010990660455978891,
#  -0.005644166006832867,
#  -0.007014748291359962,
#  -0.010990660455978891,
#  -0.005644166006832867,
#  -0.007014748291359962,
#  -0.010990660455978891,
#  -0.005644166006832867,
#  -0.009242470002785642,
#  0.011639134819844549,
#  -0.010950765445109367,
#  -0.009242470002785642,
#  0.011639134819844549,
#  -0.010950765445109367,
#  -0.009242470002785642,
#  0.011639134819844549,
#  -0.010950765445109367,
#  0.00024069467128082223,
#  -0.0009362484795374312,
#  -0.000551491339450462,
#  0.00024069467128082223,
#  -0.0009362484795374312,
#  -0.000551491339450462,
#  0.00024069467128082223,
#  -0.0009362484795374312,
#  -0.000551491339450462,
#  -0.008564924983605202,
#  -0.010920755217440719,
#  -0.008538419894443646,
#  -0.008564924983605202,
#  -0.010920755217440719,
#  -0.008538419894443646,
#  -0.008564924983605202,
#  -0.010920755217440719,
#  -0.008538419894443646,
#  -0.01902211770882903,
#  -0.01716344507178013,
#  -0.015304234578847302,
#  -0.01902211770882903,
#  -0.01716344507178013,
#  -0.015304234578847302,
#  -0.01902211770882903,
#  -0.01716344507178013,
#  -0.015304234578847302,
#  -0.018182989965825208,
#  -0.017240736262252754,
#  -0.016379853619045356,
#  -0.012978803650010223,
#  -0.011873249333064058,
#  -0.010977265706703314,
#  -0.010977387047621114,
#  -0.011167804562531448,
#  -0.011439649979943102,
#  -0.013564650046895818,
#  -0.011096920201274361,
#  -0.011147640545738809,
#  -0.011087579458624049,
#  -0.011408562081587754,
#  -0.012789532675199076,
#  -0.01411799379441913,
#  -0.014245761528516789,
#  -0.014074293206270787,
#  -0.013644901625233387,
#  -0.006470735551562225,
#  -0.009816210186742029,
#  -0.003711251948570471,
#  -0.006470735551562225,
#  -0.009816210186742029,
#  -0.003711251948570471,
#  -0.006470735551562225,
#  -0.009816210186742029,
#  -0.003711251948570471,
#  0.010845098774532685,
#  0.013191191598402818,
#  0.010863084115849783,
#  0.010845098774532685,
#  ...]

# %%
predictions = np.array(predictions)
print("The average residuals:")
print(np.mean(residuals))
# Out:
# The average residuals:
# 0.04728373961856886

# %%
model.fit(X_train, y_train)
# Out:
# 0:	learn: 0.2077726	total: 24.6ms	remaining: 13.1s
# 1:	learn: 0.2074561	total: 41.5ms	remaining: 11s
# 2:	learn: 0.2071333	total: 59.1ms	remaining: 10.4s
# 3:	learn: 0.2068104	total: 77.5ms	remaining: 10.2s
# 4:	learn: 0.2064874	total: 96.9ms	remaining: 10.2s
# 5:	learn: 0.2061675	total: 106ms	remaining: 9.25s
# 6:	learn: 0.2058465	total: 127ms	remaining: 9.54s
# 7:	learn: 0.2055387	total: 148ms	remaining: 9.72s
# 8:	learn: 0.2052228	total: 167ms	remaining: 9.69s
# 9:	learn: 0.2049158	total: 183ms	remaining: 9.57s
# 10:	learn: 0.2045961	total: 201ms	remaining: 9.53s
# 11:	learn: 0.2042809	total: 221ms	remaining: 9.56s
# 12:	learn: 0.2039681	total: 241ms	remaining: 9.6s
# 13:	learn: 0.2039681	total: 241ms	remaining: 8.93s
# 14:	learn: 0.2036571	total: 261ms	remaining: 8.99s
# 15:	learn: 0.2033544	total: 283ms	remaining: 9.13s
# 16:	learn: 0.2030509	total: 312ms	remaining: 9.44s
# 17:	learn: 0.2027310	total: 345ms	remaining: 9.84s
# 18:	learn: 0.2024111	total: 372ms	remaining: 10s
# 19:	learn: 0.2021008	total: 391ms	remaining: 10s
# 20:	learn: 0.2017961	total: 395ms	remaining: 9.61s
# 21:	learn: 0.2014824	total: 413ms	remaining: 9.57s
# 22:	learn: 0.2011698	total: 430ms	remaining: 9.51s
# 23:	learn: 0.2008629	total: 446ms	remaining: 9.44s
# 24:	learn: 0.2005529	total: 464ms	remaining: 9.41s
# 25:	learn: 0.2002599	total: 484ms	remaining: 9.42s
# 26:	learn: 0.1999586	total: 505ms	remaining: 9.45s
# 27:	learn: 0.1996506	total: 523ms	remaining: 9.41s
# 28:	learn: 0.1993390	total: 542ms	remaining: 9.4s
# 29:	learn: 0.1990385	total: 564ms	remaining: 9.44s
# 30:	learn: 0.1987288	total: 585ms	remaining: 9.46s
# 31:	learn: 0.1984200	total: 604ms	remaining: 9.43s
# 32:	learn: 0.1981141	total: 623ms	remaining: 9.42s
# 33:	learn: 0.1978082	total: 644ms	remaining: 9.43s
# 34:	learn: 0.1975107	total: 663ms	remaining: 9.41s
# 35:	learn: 0.1972244	total: 666ms	remaining: 9.18s
# 36:	learn: 0.1969258	total: 683ms	remaining: 9.14s
# 37:	learn: 0.1966257	total: 703ms	remaining: 9.14s
# 38:	learn: 0.1963353	total: 723ms	remaining: 9.14s
# 39:	learn: 0.1960420	total: 741ms	remaining: 9.12s
# 40:	learn: 0.1957400	total: 762ms	remaining: 9.12s
# 41:	learn: 0.1954451	total: 782ms	remaining: 9.12s
# 42:	learn: 0.1951388	total: 802ms	remaining: 9.13s
# 43:	learn: 0.1948394	total: 821ms	remaining: 9.11s
# 44:	learn: 0.1945419	total: 838ms	remaining: 9.07s
# 45:	learn: 0.1942526	total: 855ms	remaining: 9.04s
# 46:	learn: 0.1939508	total: 876ms	remaining: 9.04s
# 47:	learn: 0.1937172	total: 878ms	remaining: 8.85s
# 48:	learn: 0.1934195	total: 894ms	remaining: 8.82s
# 49:	learn: 0.1931299	total: 916ms	remaining: 8.82s
# 50:	learn: 0.1928494	total: 920ms	remaining: 8.67s
# 51:	learn: 0.1925578	total: 938ms	remaining: 8.66s
# 52:	learn: 0.1922706	total: 957ms	remaining: 8.64s
# 53:	learn: 0.1919862	total: 976ms	remaining: 8.64s
# 54:	learn: 0.1917027	total: 993ms	remaining: 8.61s
# 55:	learn: 0.1914174	total: 1.01s	remaining: 8.59s
# 56:	learn: 0.1911245	total: 1.03s	remaining: 8.6s
# 57:	learn: 0.1908296	total: 1.05s	remaining: 8.57s
# 58:	learn: 0.1905444	total: 1.06s	remaining: 8.54s
# 59:	learn: 0.1902929	total: 1.07s	remaining: 8.4s
# 60:	learn: 0.1899982	total: 1.08s	remaining: 8.38s
# 61:	learn: 0.1897353	total: 1.09s	remaining: 8.26s
# 62:	learn: 0.1894583	total: 1.11s	remaining: 8.27s
# 63:	learn: 0.1891693	total: 1.13s	remaining: 8.26s
# 64:	learn: 0.1888874	total: 1.15s	remaining: 8.25s
# 65:	learn: 0.1886110	total: 1.17s	remaining: 8.25s
# 66:	learn: 0.1883381	total: 1.17s	remaining: 8.14s
# 67:	learn: 0.1880530	total: 1.19s	remaining: 8.1s
# 68:	learn: 0.1877780	total: 1.21s	remaining: 8.09s
# 69:	learn: 0.1874921	total: 1.22s	remaining: 8.07s
# 70:	learn: 0.1872145	total: 1.24s	remaining: 8.06s
# 71:	learn: 0.1869394	total: 1.26s	remaining: 8.05s
# 72:	learn: 0.1866672	total: 1.28s	remaining: 8.07s
# 73:	learn: 0.1863739	total: 1.3s	remaining: 8.06s
# 74:	learn: 0.1860890	total: 1.32s	remaining: 8.06s
# 75:	learn: 0.1858090	total: 1.34s	remaining: 8.05s
# 76:	learn: 0.1855362	total: 1.36s	remaining: 8.05s
# 77:	learn: 0.1852429	total: 1.38s	remaining: 8.06s
# 78:	learn: 0.1849652	total: 1.4s	remaining: 8.05s
# 79:	learn: 0.1847008	total: 1.42s	remaining: 8.04s
# 80:	learn: 0.1844221	total: 1.43s	remaining: 7.96s
# 81:	learn: 0.1841390	total: 1.45s	remaining: 7.96s
# 82:	learn: 0.1838788	total: 1.47s	remaining: 7.95s
# 83:	learn: 0.1836058	total: 1.49s	remaining: 7.93s
# 84:	learn: 0.1833319	total: 1.5s	remaining: 7.91s
# 85:	learn: 0.1830566	total: 1.52s	remaining: 7.89s
# 86:	learn: 0.1828285	total: 1.52s	remaining: 7.79s
# 87:	learn: 0.1825489	total: 1.54s	remaining: 7.76s
# 88:	learn: 0.1824657	total: 1.54s	remaining: 7.66s
# 89:	learn: 0.1821912	total: 1.56s	remaining: 7.66s
# 90:	learn: 0.1819252	total: 1.58s	remaining: 7.66s
# 91:	learn: 0.1816575	total: 1.59s	remaining: 7.62s
# 92:	learn: 0.1813874	total: 1.61s	remaining: 7.61s
# 93:	learn: 0.1811284	total: 1.63s	remaining: 7.59s
# 94:	learn: 0.1808671	total: 1.65s	remaining: 7.57s
# 95:	learn: 0.1806066	total: 1.67s	remaining: 7.57s
# 96:	learn: 0.1803303	total: 1.68s	remaining: 7.55s
# 97:	learn: 0.1800661	total: 1.7s	remaining: 7.55s
# 98:	learn: 0.1798055	total: 1.72s	remaining: 7.54s
# 99:	learn: 0.1795389	total: 1.74s	remaining: 7.53s
# 100:	learn: 0.1792805	total: 1.76s	remaining: 7.51s
# 101:	learn: 0.1790108	total: 1.78s	remaining: 7.51s
# 102:	learn: 0.1787545	total: 1.8s	remaining: 7.49s
# 103:	learn: 0.1785021	total: 1.81s	remaining: 7.47s
# 104:	learn: 0.1782418	total: 1.83s	remaining: 7.45s
# 105:	learn: 0.1779801	total: 1.85s	remaining: 7.44s
# 106:	learn: 0.1777233	total: 1.87s	remaining: 7.42s
# 107:	learn: 0.1774557	total: 1.89s	remaining: 7.41s
# 108:	learn: 0.1771806	total: 1.9s	remaining: 7.39s
# 109:	learn: 0.1769235	total: 1.92s	remaining: 7.38s
# 110:	learn: 0.1766975	total: 1.93s	remaining: 7.3s
# 111:	learn: 0.1764349	total: 1.94s	remaining: 7.29s
# 112:	learn: 0.1761765	total: 1.96s	remaining: 7.29s
# 113:	learn: 0.1759247	total: 1.98s	remaining: 7.28s
# 114:	learn: 0.1756599	total: 2s	remaining: 7.25s
# 115:	learn: 0.1753966	total: 2.02s	remaining: 7.25s
# 116:	learn: 0.1751479	total: 2.04s	remaining: 7.23s
# 117:	learn: 0.1748993	total: 2.06s	remaining: 7.22s
# 118:	learn: 0.1746504	total: 2.08s	remaining: 7.2s
# 119:	learn: 0.1743923	total: 2.09s	remaining: 7.19s
# 120:	learn: 0.1741401	total: 2.11s	remaining: 7.17s
# 121:	learn: 0.1738857	total: 2.13s	remaining: 7.16s
# 122:	learn: 0.1736326	total: 2.15s	remaining: 7.14s
# 123:	learn: 0.1733867	total: 2.17s	remaining: 7.13s
# 124:	learn: 0.1731383	total: 2.19s	remaining: 7.12s
# 125:	learn: 0.1728900	total: 2.2s	remaining: 7.1s
# 126:	learn: 0.1726346	total: 2.22s	remaining: 7.09s
# 127:	learn: 0.1723959	total: 2.24s	remaining: 7.08s
# 128:	learn: 0.1721492	total: 2.27s	remaining: 7.08s
# 129:	learn: 0.1719382	total: 2.27s	remaining: 7.01s
# 130:	learn: 0.1716938	total: 2.29s	remaining: 6.99s
# 131:	learn: 0.1714428	total: 2.31s	remaining: 6.99s
# 132:	learn: 0.1712010	total: 2.33s	remaining: 6.97s
# 133:	learn: 0.1709672	total: 2.33s	remaining: 6.91s
# 134:	learn: 0.1707175	total: 2.35s	remaining: 6.9s
# 135:	learn: 0.1704665	total: 2.37s	remaining: 6.89s
# 136:	learn: 0.1702274	total: 2.38s	remaining: 6.87s
# 137:	learn: 0.1699887	total: 2.4s	remaining: 6.86s
# 138:	learn: 0.1697504	total: 2.42s	remaining: 6.85s
# 139:	learn: 0.1695127	total: 2.44s	remaining: 6.83s
# 140:	learn: 0.1692622	total: 2.46s	remaining: 6.82s
# 141:	learn: 0.1690246	total: 2.47s	remaining: 6.8s
# 142:	learn: 0.1687835	total: 2.49s	remaining: 6.78s
# 143:	learn: 0.1685378	total: 2.51s	remaining: 6.77s
# 144:	learn: 0.1685378	total: 2.51s	remaining: 6.71s
# 145:	learn: 0.1682929	total: 2.53s	remaining: 6.69s
# 146:	learn: 0.1680558	total: 2.55s	remaining: 6.68s
# 147:	learn: 0.1678220	total: 2.57s	remaining: 6.68s
# 148:	learn: 0.1675936	total: 2.59s	remaining: 6.66s
# 149:	learn: 0.1673517	total: 2.61s	remaining: 6.65s
# 150:	learn: 0.1671218	total: 2.62s	remaining: 6.6s
# 151:	learn: 0.1668822	total: 2.63s	remaining: 6.59s
# 152:	learn: 0.1666571	total: 2.65s	remaining: 6.57s
# 153:	learn: 0.1664059	total: 2.67s	remaining: 6.56s
# 154:	learn: 0.1661716	total: 2.69s	remaining: 6.54s
# 155:	learn: 0.1659321	total: 2.7s	remaining: 6.52s
# 156:	learn: 0.1656914	total: 2.73s	remaining: 6.51s
# 157:	learn: 0.1654883	total: 2.73s	remaining: 6.46s
# 158:	learn: 0.1652604	total: 2.74s	remaining: 6.44s
# 159:	learn: 0.1650348	total: 2.75s	remaining: 6.39s
# 160:	learn: 0.1647942	total: 2.77s	remaining: 6.38s
# 161:	learn: 0.1645584	total: 2.78s	remaining: 6.36s
# 162:	learn: 0.1643297	total: 2.81s	remaining: 6.35s
# 163:	learn: 0.1640919	total: 2.82s	remaining: 6.34s
# 164:	learn: 0.1638586	total: 2.85s	remaining: 6.33s
# 165:	learn: 0.1636328	total: 2.86s	remaining: 6.32s
# 166:	learn: 0.1634001	total: 2.88s	remaining: 6.3s
# 167:	learn: 0.1631799	total: 2.9s	remaining: 6.29s
# 168:	learn: 0.1629620	total: 2.91s	remaining: 6.26s
# 169:	learn: 0.1627250	total: 2.93s	remaining: 6.25s
# 170:	learn: 0.1624914	total: 2.95s	remaining: 6.24s
# 171:	learn: 0.1622608	total: 2.97s	remaining: 6.22s
# 172:	learn: 0.1620329	total: 3s	remaining: 6.21s
# 173:	learn: 0.1618027	total: 3.01s	remaining: 6.2s
# 174:	learn: 0.1615602	total: 3.03s	remaining: 6.18s
# 175:	learn: 0.1613334	total: 3.05s	remaining: 6.17s
# 176:	learn: 0.1611056	total: 3.07s	remaining: 6.17s
# 177:	learn: 0.1608861	total: 3.08s	remaining: 6.13s
# 178:	learn: 0.1606733	total: 3.08s	remaining: 6.08s
# 179:	learn: 0.1604503	total: 3.1s	remaining: 6.07s
# 180:	learn: 0.1602067	total: 3.12s	remaining: 6.05s
# 181:	learn: 0.1599798	total: 3.14s	remaining: 6.04s
# 182:	learn: 0.1597469	total: 3.16s	remaining: 6.02s
# 183:	learn: 0.1595308	total: 3.18s	remaining: 6.01s
# 184:	learn: 0.1593140	total: 3.2s	remaining: 5.99s
# 185:	learn: 0.1590942	total: 3.21s	remaining: 5.98s
# 186:	learn: 0.1588710	total: 3.23s	remaining: 5.97s
# 187:	learn: 0.1586452	total: 3.25s	remaining: 5.96s
# 188:	learn: 0.1584316	total: 3.27s	remaining: 5.94s
# 189:	learn: 0.1582200	total: 3.29s	remaining: 5.92s
# 190:	learn: 0.1580049	total: 3.31s	remaining: 5.92s
# 191:	learn: 0.1577830	total: 3.33s	remaining: 5.9s
# 192:	learn: 0.1575698	total: 3.35s	remaining: 5.89s
# 193:	learn: 0.1573559	total: 3.37s	remaining: 5.88s
# 194:	learn: 0.1571376	total: 3.39s	remaining: 5.86s
# 195:	learn: 0.1569260	total: 3.42s	remaining: 5.86s
# 196:	learn: 0.1567094	total: 3.44s	remaining: 5.85s
# 197:	learn: 0.1564993	total: 3.46s	remaining: 5.84s
# 198:	learn: 0.1562832	total: 3.48s	remaining: 5.82s
# 199:	learn: 0.1560639	total: 3.49s	remaining: 5.8s
# 200:	learn: 0.1558764	total: 3.5s	remaining: 5.76s
# 201:	learn: 0.1556599	total: 3.51s	remaining: 5.74s
# 202:	learn: 0.1554478	total: 3.53s	remaining: 5.72s
# 203:	learn: 0.1552320	total: 3.55s	remaining: 5.7s
# 204:	learn: 0.1550187	total: 3.57s	remaining: 5.69s
# 205:	learn: 0.1548062	total: 3.59s	remaining: 5.68s
# 206:	learn: 0.1545954	total: 3.61s	remaining: 5.67s
# 207:	learn: 0.1543960	total: 3.63s	remaining: 5.65s
# 208:	learn: 0.1541882	total: 3.65s	remaining: 5.64s
# 209:	learn: 0.1539772	total: 3.67s	remaining: 5.62s
# 210:	learn: 0.1537886	total: 3.67s	remaining: 5.59s
# 211:	learn: 0.1535801	total: 3.69s	remaining: 5.57s
# 212:	learn: 0.1533705	total: 3.71s	remaining: 5.56s
# 213:	learn: 0.1531593	total: 3.73s	remaining: 5.54s
# 214:	learn: 0.1529552	total: 3.75s	remaining: 5.53s
# 215:	learn: 0.1527426	total: 3.77s	remaining: 5.52s
# 216:	learn: 0.1525269	total: 3.79s	remaining: 5.5s
# 217:	learn: 0.1523154	total: 3.81s	remaining: 5.49s
# 218:	learn: 0.1520968	total: 3.83s	remaining: 5.47s
# 219:	learn: 0.1518730	total: 3.85s	remaining: 5.45s
# 220:	learn: 0.1516857	total: 3.85s	remaining: 5.42s
# 221:	learn: 0.1514786	total: 3.87s	remaining: 5.41s
# 222:	learn: 0.1512691	total: 3.89s	remaining: 5.39s
# 223:	learn: 0.1510582	total: 3.91s	remaining: 5.38s
# 224:	learn: 0.1508589	total: 3.93s	remaining: 5.36s
# 225:	learn: 0.1506460	total: 3.94s	remaining: 5.34s
# 226:	learn: 0.1504423	total: 3.96s	remaining: 5.33s
# 227:	learn: 0.1502287	total: 3.98s	remaining: 5.31s
# 228:	learn: 0.1500273	total: 4s	remaining: 5.3s
# 229:	learn: 0.1498183	total: 4.02s	remaining: 5.28s
# 230:	learn: 0.1496164	total: 4.04s	remaining: 5.27s
# 231:	learn: 0.1494211	total: 4.06s	remaining: 5.25s
# 232:	learn: 0.1492220	total: 4.08s	remaining: 5.23s
# 233:	learn: 0.1490389	total: 4.1s	remaining: 5.22s
# 234:	learn: 0.1488442	total: 4.12s	remaining: 5.21s
# 235:	learn: 0.1486581	total: 4.13s	remaining: 5.18s
# 236:	learn: 0.1484670	total: 4.15s	remaining: 5.16s
# 237:	learn: 0.1482688	total: 4.17s	remaining: 5.14s
# 238:	learn: 0.1480575	total: 4.18s	remaining: 5.13s
# 239:	learn: 0.1478526	total: 4.2s	remaining: 5.11s
# 240:	learn: 0.1476612	total: 4.22s	remaining: 5.1s
# 241:	learn: 0.1474572	total: 4.25s	remaining: 5.09s
# 242:	learn: 0.1472612	total: 4.26s	remaining: 5.07s
# 243:	learn: 0.1470600	total: 4.29s	remaining: 5.06s
# 244:	learn: 0.1468647	total: 4.3s	remaining: 5.04s
# 245:	learn: 0.1466585	total: 4.32s	remaining: 5.02s
# 246:	learn: 0.1464473	total: 4.34s	remaining: 5.01s
# 247:	learn: 0.1462516	total: 4.36s	remaining: 4.99s
# 248:	learn: 0.1460530	total: 4.38s	remaining: 4.98s
# 249:	learn: 0.1458590	total: 4.4s	remaining: 4.97s
# 250:	learn: 0.1456708	total: 4.42s	remaining: 4.95s
# 251:	learn: 0.1454924	total: 4.44s	remaining: 4.93s
# 252:	learn: 0.1453048	total: 4.46s	remaining: 4.92s
# 253:	learn: 0.1451091	total: 4.48s	remaining: 4.9s
# 254:	learn: 0.1449180	total: 4.5s	remaining: 4.88s
# 255:	learn: 0.1447216	total: 4.51s	remaining: 4.87s
# 256:	learn: 0.1445352	total: 4.53s	remaining: 4.85s
# 257:	learn: 0.1443324	total: 4.55s	remaining: 4.83s
# 258:	learn: 0.1441549	total: 4.57s	remaining: 4.82s
# 259:	learn: 0.1439867	total: 4.59s	remaining: 4.8s
# 260:	learn: 0.1438031	total: 4.6s	remaining: 4.78s
# 261:	learn: 0.1436102	total: 4.62s	remaining: 4.76s
# 262:	learn: 0.1433999	total: 4.64s	remaining: 4.75s
# 263:	learn: 0.1432147	total: 4.66s	remaining: 4.73s
# 264:	learn: 0.1430328	total: 4.67s	remaining: 4.71s
# 265:	learn: 0.1428493	total: 4.69s	remaining: 4.69s
# 266:	learn: 0.1426716	total: 4.71s	remaining: 4.68s
# 267:	learn: 0.1424820	total: 4.73s	remaining: 4.66s
# 268:	learn: 0.1423014	total: 4.75s	remaining: 4.64s
# 269:	learn: 0.1421115	total: 4.76s	remaining: 4.62s
# 270:	learn: 0.1419299	total: 4.78s	remaining: 4.61s
# 271:	learn: 0.1417524	total: 4.8s	remaining: 4.59s
# 272:	learn: 0.1415683	total: 4.82s	remaining: 4.57s
# 273:	learn: 0.1413694	total: 4.84s	remaining: 4.56s
# 274:	learn: 0.1411860	total: 4.86s	remaining: 4.54s
# 275:	learn: 0.1410045	total: 4.88s	remaining: 4.52s
# 276:	learn: 0.1408137	total: 4.9s	remaining: 4.51s
# 277:	learn: 0.1406324	total: 4.92s	remaining: 4.49s
# 278:	learn: 0.1404458	total: 4.93s	remaining: 4.47s
# 279:	learn: 0.1402632	total: 4.95s	remaining: 4.46s
# 280:	learn: 0.1400873	total: 4.98s	remaining: 4.45s
# 281:	learn: 0.1399248	total: 4.99s	remaining: 4.43s
# 282:	learn: 0.1397410	total: 5.01s	remaining: 4.41s
# 283:	learn: 0.1395573	total: 5.03s	remaining: 4.39s
# 284:	learn: 0.1393781	total: 5.05s	remaining: 4.38s
# 285:	learn: 0.1392292	total: 5.05s	remaining: 4.34s
# 286:	learn: 0.1390472	total: 5.07s	remaining: 4.33s
# 287:	learn: 0.1388579	total: 5.09s	remaining: 4.31s
# 288:	learn: 0.1386869	total: 5.11s	remaining: 4.3s
# 289:	learn: 0.1385121	total: 5.13s	remaining: 4.28s
# 290:	learn: 0.1383301	total: 5.14s	remaining: 4.26s
# 291:	learn: 0.1381643	total: 5.16s	remaining: 4.24s
# 292:	learn: 0.1379791	total: 5.18s	remaining: 4.23s
# 293:	learn: 0.1378034	total: 5.2s	remaining: 4.21s
# 294:	learn: 0.1376223	total: 5.22s	remaining: 4.19s
# 295:	learn: 0.1374310	total: 5.24s	remaining: 4.18s
# 296:	learn: 0.1372585	total: 5.26s	remaining: 4.16s
# 297:	learn: 0.1370883	total: 5.28s	remaining: 4.15s
# 298:	learn: 0.1369172	total: 5.3s	remaining: 4.13s
# 299:	learn: 0.1367352	total: 5.32s	remaining: 4.11s
# 300:	learn: 0.1365663	total: 5.34s	remaining: 4.09s
# 301:	learn: 0.1363987	total: 5.36s	remaining: 4.08s
# 302:	learn: 0.1362236	total: 5.38s	remaining: 4.06s
# 303:	learn: 0.1360513	total: 5.39s	remaining: 4.04s
# 304:	learn: 0.1358654	total: 5.42s	remaining: 4.03s
# 305:	learn: 0.1356982	total: 5.44s	remaining: 4.02s
# 306:	learn: 0.1355167	total: 5.46s	remaining: 4s
# 307:	learn: 0.1353486	total: 5.49s	remaining: 3.99s
# 308:	learn: 0.1351667	total: 5.51s	remaining: 3.98s
# 309:	learn: 0.1349874	total: 5.53s	remaining: 3.96s
# 310:	learn: 0.1348124	total: 5.55s	remaining: 3.94s
# 311:	learn: 0.1346249	total: 5.57s	remaining: 3.93s
# 312:	learn: 0.1344565	total: 5.59s	remaining: 3.91s
# 313:	learn: 0.1342839	total: 5.62s	remaining: 3.9s
# 314:	learn: 0.1341238	total: 5.64s	remaining: 3.88s
# 315:	learn: 0.1339626	total: 5.66s	remaining: 3.87s
# 316:	learn: 0.1338069	total: 5.68s	remaining: 3.85s
# 317:	learn: 0.1336380	total: 5.71s	remaining: 3.84s
# 318:	learn: 0.1334758	total: 5.73s	remaining: 3.83s
# 319:	learn: 0.1333085	total: 5.75s	remaining: 3.81s
# 320:	learn: 0.1331411	total: 5.78s	remaining: 3.8s
# 321:	learn: 0.1329810	total: 5.79s	remaining: 3.78s
# 322:	learn: 0.1328108	total: 5.82s	remaining: 3.76s
# 323:	learn: 0.1326320	total: 5.83s	remaining: 3.74s
# 324:	learn: 0.1324701	total: 5.86s	remaining: 3.73s
# 325:	learn: 0.1323090	total: 5.88s	remaining: 3.71s
# 326:	learn: 0.1321480	total: 5.89s	remaining: 3.69s
# 327:	learn: 0.1319829	total: 5.91s	remaining: 3.67s
# 328:	learn: 0.1318050	total: 5.93s	remaining: 3.66s
# 329:	learn: 0.1316475	total: 5.95s	remaining: 3.64s
# 330:	learn: 0.1314873	total: 5.97s	remaining: 3.62s
# 331:	learn: 0.1313258	total: 5.98s	remaining: 3.6s
# 332:	learn: 0.1311677	total: 6s	remaining: 3.59s
# 333:	learn: 0.1309924	total: 6.03s	remaining: 3.57s
# 334:	learn: 0.1308399	total: 6.05s	remaining: 3.56s
# 335:	learn: 0.1306730	total: 6.07s	remaining: 3.54s
# 336:	learn: 0.1305160	total: 6.09s	remaining: 3.52s
# 337:	learn: 0.1303420	total: 6.11s	remaining: 3.5s
# 338:	learn: 0.1301899	total: 6.12s	remaining: 3.49s
# 339:	learn: 0.1300397	total: 6.14s	remaining: 3.47s
# 340:	learn: 0.1298833	total: 6.16s	remaining: 3.45s
# 341:	learn: 0.1297255	total: 6.18s	remaining: 3.43s
# 342:	learn: 0.1295710	total: 6.2s	remaining: 3.42s
# 343:	learn: 0.1294049	total: 6.22s	remaining: 3.4s
# 344:	learn: 0.1292653	total: 6.23s	remaining: 3.38s
# 345:	learn: 0.1291083	total: 6.25s	remaining: 3.36s
# 346:	learn: 0.1289414	total: 6.26s	remaining: 3.34s
# 347:	learn: 0.1287925	total: 6.28s	remaining: 3.32s
# 348:	learn: 0.1286363	total: 6.3s	remaining: 3.3s
# 349:	learn: 0.1284774	total: 6.32s	remaining: 3.29s
# 350:	learn: 0.1283362	total: 6.34s	remaining: 3.27s
# 351:	learn: 0.1281780	total: 6.36s	remaining: 3.25s
# 352:	learn: 0.1280381	total: 6.38s	remaining: 3.23s
# 353:	learn: 0.1278764	total: 6.4s	remaining: 3.22s
# 354:	learn: 0.1277329	total: 6.42s	remaining: 3.2s
# 355:	learn: 0.1275839	total: 6.44s	remaining: 3.19s
# 356:	learn: 0.1274228	total: 6.46s	remaining: 3.17s
# 357:	learn: 0.1272656	total: 6.48s	remaining: 3.15s
# 358:	learn: 0.1271184	total: 6.5s	remaining: 3.13s
# 359:	learn: 0.1269741	total: 6.51s	remaining: 3.11s
# 360:	learn: 0.1268218	total: 6.52s	remaining: 3.09s
# 361:	learn: 0.1266764	total: 6.54s	remaining: 3.07s
# 362:	learn: 0.1265226	total: 6.57s	remaining: 3.06s
# 363:	learn: 0.1263672	total: 6.59s	remaining: 3.04s
# 364:	learn: 0.1262252	total: 6.6s	remaining: 3.02s
# 365:	learn: 0.1260759	total: 6.63s	remaining: 3.01s
# 366:	learn: 0.1259110	total: 6.65s	remaining: 2.99s
# 367:	learn: 0.1257606	total: 6.66s	remaining: 2.97s
# 368:	learn: 0.1256087	total: 6.68s	remaining: 2.95s
# 369:	learn: 0.1254706	total: 6.7s	remaining: 2.93s
# 370:	learn: 0.1253224	total: 6.72s	remaining: 2.92s
# 371:	learn: 0.1251799	total: 6.74s	remaining: 2.9s
# 372:	learn: 0.1250349	total: 6.76s	remaining: 2.88s
# 373:	learn: 0.1248890	total: 6.79s	remaining: 2.87s
# 374:	learn: 0.1247300	total: 6.8s	remaining: 2.85s
# 375:	learn: 0.1245710	total: 6.82s	remaining: 2.83s
# 376:	learn: 0.1244174	total: 6.84s	remaining: 2.81s
# 377:	learn: 0.1242702	total: 6.86s	remaining: 2.79s
# 378:	learn: 0.1241417	total: 6.86s	remaining: 2.77s
# 379:	learn: 0.1239906	total: 6.88s	remaining: 2.75s
# 380:	learn: 0.1238457	total: 6.9s	remaining: 2.73s
# 381:	learn: 0.1236944	total: 6.92s	remaining: 2.72s
# 382:	learn: 0.1235613	total: 6.94s	remaining: 2.7s
# 383:	learn: 0.1234114	total: 6.96s	remaining: 2.68s
# 384:	learn: 0.1232812	total: 6.98s	remaining: 2.66s
# 385:	learn: 0.1231498	total: 7s	remaining: 2.65s
# 386:	learn: 0.1230046	total: 7.02s	remaining: 2.63s
# 387:	learn: 0.1228513	total: 7.04s	remaining: 2.61s
# 388:	learn: 0.1227117	total: 7.06s	remaining: 2.59s
# 389:	learn: 0.1225677	total: 7.08s	remaining: 2.58s
# 390:	learn: 0.1224332	total: 7.09s	remaining: 2.56s
# 391:	learn: 0.1222832	total: 7.11s	remaining: 2.54s
# 392:	learn: 0.1221262	total: 7.13s	remaining: 2.52s
# 393:	learn: 0.1219809	total: 7.16s	remaining: 2.51s
# 394:	learn: 0.1218329	total: 7.18s	remaining: 2.49s
# 395:	learn: 0.1217065	total: 7.18s	remaining: 2.46s
# 396:	learn: 0.1215511	total: 7.2s	remaining: 2.45s
# 397:	learn: 0.1214176	total: 7.22s	remaining: 2.43s
# 398:	learn: 0.1213169	total: 7.22s	remaining: 2.41s
# 399:	learn: 0.1211711	total: 7.24s	remaining: 2.39s
# 400:	learn: 0.1210351	total: 7.26s	remaining: 2.37s
# 401:	learn: 0.1208945	total: 7.28s	remaining: 2.35s
# 402:	learn: 0.1207566	total: 7.29s	remaining: 2.33s
# 403:	learn: 0.1206165	total: 7.32s	remaining: 2.32s
# 404:	learn: 0.1204723	total: 7.34s	remaining: 2.3s
# 405:	learn: 0.1203339	total: 7.35s	remaining: 2.28s
# 406:	learn: 0.1202021	total: 7.37s	remaining: 2.26s
# 407:	learn: 0.1200579	total: 7.39s	remaining: 2.25s
# 408:	learn: 0.1199432	total: 7.39s	remaining: 2.22s
# 409:	learn: 0.1198058	total: 7.41s	remaining: 2.21s
# 410:	learn: 0.1196792	total: 7.43s	remaining: 2.19s
# 411:	learn: 0.1195370	total: 7.45s	remaining: 2.17s
# 412:	learn: 0.1193993	total: 7.47s	remaining: 2.15s
# 413:	learn: 0.1192558	total: 7.5s	remaining: 2.14s
# 414:	learn: 0.1191211	total: 7.52s	remaining: 2.12s
# 415:	learn: 0.1190016	total: 7.53s	remaining: 2.1s
# 416:	learn: 0.1188761	total: 7.55s	remaining: 2.08s
# 417:	learn: 0.1187518	total: 7.57s	remaining: 2.06s
# 418:	learn: 0.1185934	total: 7.59s	remaining: 2.05s
# 419:	learn: 0.1184481	total: 7.61s	remaining: 2.03s
# 420:	learn: 0.1183115	total: 7.63s	remaining: 2.01s
# 421:	learn: 0.1181741	total: 7.65s	remaining: 1.99s
# 422:	learn: 0.1180463	total: 7.67s	remaining: 1.98s
# 423:	learn: 0.1179071	total: 7.7s	remaining: 1.96s
# 424:	learn: 0.1179071	total: 7.7s	remaining: 1.94s
# 425:	learn: 0.1177818	total: 7.71s	remaining: 1.92s
# 426:	learn: 0.1176587	total: 7.73s	remaining: 1.9s
# 427:	learn: 0.1175234	total: 7.74s	remaining: 1.88s
# 428:	learn: 0.1173923	total: 7.76s	remaining: 1.86s
# 429:	learn: 0.1172672	total: 7.78s	remaining: 1.84s
# 430:	learn: 0.1171358	total: 7.8s	remaining: 1.83s
# 431:	learn: 0.1170182	total: 7.82s	remaining: 1.81s
# 432:	learn: 0.1168881	total: 7.84s	remaining: 1.79s
# 433:	learn: 0.1167527	total: 7.86s	remaining: 1.77s
# 434:	learn: 0.1166126	total: 7.88s	remaining: 1.76s
# 435:	learn: 0.1164804	total: 7.9s	remaining: 1.74s
# 436:	learn: 0.1163410	total: 7.92s	remaining: 1.72s
# 437:	learn: 0.1162032	total: 7.94s	remaining: 1.7s
# 438:	learn: 0.1160753	total: 7.96s	remaining: 1.69s
# 439:	learn: 0.1159422	total: 7.98s	remaining: 1.67s
# 440:	learn: 0.1158094	total: 8s	remaining: 1.65s
# 441:	learn: 0.1156752	total: 8.02s	remaining: 1.63s
# 442:	learn: 0.1155492	total: 8.04s	remaining: 1.62s
# 443:	learn: 0.1154178	total: 8.06s	remaining: 1.6s
# 444:	learn: 0.1152987	total: 8.08s	remaining: 1.58s
# 445:	learn: 0.1151785	total: 8.1s	remaining: 1.56s
# 446:	learn: 0.1150564	total: 8.12s	remaining: 1.54s
# 447:	learn: 0.1149464	total: 8.15s	remaining: 1.53s
# 448:	learn: 0.1148078	total: 8.18s	remaining: 1.51s
# 449:	learn: 0.1146819	total: 8.2s	remaining: 1.49s
# 450:	learn: 0.1145504	total: 8.22s	remaining: 1.48s
# 451:	learn: 0.1144197	total: 8.23s	remaining: 1.46s
# 452:	learn: 0.1142915	total: 8.26s	remaining: 1.44s
# 453:	learn: 0.1141698	total: 8.28s	remaining: 1.42s
# 454:	learn: 0.1140506	total: 8.29s	remaining: 1.4s
# 455:	learn: 0.1139291	total: 8.31s	remaining: 1.39s
# 456:	learn: 0.1137872	total: 8.33s	remaining: 1.37s
# 457:	learn: 0.1136527	total: 8.35s	remaining: 1.35s
# 458:	learn: 0.1135156	total: 8.37s	remaining: 1.33s
# 459:	learn: 0.1133965	total: 8.39s	remaining: 1.31s
# 460:	learn: 0.1132720	total: 8.41s	remaining: 1.29s
# 461:	learn: 0.1131365	total: 8.43s	remaining: 1.28s
# 462:	learn: 0.1130217	total: 8.45s	remaining: 1.26s
# 463:	learn: 0.1128902	total: 8.47s	remaining: 1.24s
# 464:	learn: 0.1127733	total: 8.49s	remaining: 1.22s
# 465:	learn: 0.1126561	total: 8.51s	remaining: 1.21s
# 466:	learn: 0.1125390	total: 8.53s	remaining: 1.19s
# 467:	learn: 0.1124230	total: 8.55s	remaining: 1.17s
# 468:	learn: 0.1122965	total: 8.57s	remaining: 1.15s
# 469:	learn: 0.1122078	total: 8.57s	remaining: 1.13s
# 470:	learn: 0.1120948	total: 8.59s	remaining: 1.11s
# 471:	learn: 0.1120948	total: 8.59s	remaining: 1.09s
# 472:	learn: 0.1119834	total: 8.61s	remaining: 1.07s
# 473:	learn: 0.1118513	total: 8.63s	remaining: 1.05s
# 474:	learn: 0.1117420	total: 8.65s	remaining: 1.04s
# 475:	learn: 0.1116184	total: 8.67s	remaining: 1.02s
# 476:	learn: 0.1114949	total: 8.69s	remaining: 1s
# 477:	learn: 0.1113823	total: 8.7s	remaining: 983ms
# 478:	learn: 0.1112699	total: 8.73s	remaining: 966ms
# 479:	learn: 0.1111607	total: 8.74s	remaining: 947ms
# 480:	learn: 0.1110297	total: 8.76s	remaining: 929ms
# 481:	learn: 0.1109127	total: 8.78s	remaining: 911ms
# 482:	learn: 0.1107891	total: 8.8s	remaining: 892ms
# 483:	learn: 0.1106740	total: 8.82s	remaining: 874ms
# 484:	learn: 0.1105649	total: 8.84s	remaining: 856ms
# 485:	learn: 0.1104490	total: 8.86s	remaining: 838ms
# 486:	learn: 0.1103387	total: 8.88s	remaining: 821ms
# 487:	learn: 0.1102498	total: 8.88s	remaining: 801ms
# 488:	learn: 0.1101404	total: 8.91s	remaining: 783ms
# 489:	learn: 0.1100045	total: 8.92s	remaining: 765ms
# 490:	learn: 0.1098828	total: 8.95s	remaining: 747ms
# 491:	learn: 0.1097503	total: 8.97s	remaining: 729ms
# 492:	learn: 0.1096461	total: 8.99s	remaining: 711ms
# 493:	learn: 0.1095356	total: 9.01s	remaining: 693ms
# 494:	learn: 0.1094233	total: 9.03s	remaining: 675ms
# 495:	learn: 0.1092815	total: 9.05s	remaining: 657ms
# 496:	learn: 0.1091578	total: 9.07s	remaining: 639ms
# 497:	learn: 0.1090399	total: 9.09s	remaining: 621ms
# 498:	learn: 0.1089289	total: 9.11s	remaining: 603ms
# 499:	learn: 0.1088161	total: 9.13s	remaining: 585ms
# 500:	learn: 0.1086983	total: 9.15s	remaining: 566ms
# 501:	learn: 0.1085758	total: 9.17s	remaining: 548ms
# 502:	learn: 0.1084586	total: 9.19s	remaining: 530ms
# 503:	learn: 0.1083529	total: 9.21s	remaining: 511ms
# 504:	learn: 0.1082411	total: 9.23s	remaining: 493ms
# 505:	learn: 0.1081215	total: 9.25s	remaining: 475ms
# 506:	learn: 0.1080171	total: 9.27s	remaining: 457ms
# 507:	learn: 0.1079034	total: 9.29s	remaining: 439ms
# 508:	learn: 0.1077971	total: 9.31s	remaining: 421ms
# 509:	learn: 0.1076831	total: 9.32s	remaining: 402ms
# 510:	learn: 0.1075703	total: 9.34s	remaining: 384ms
# 511:	learn: 0.1074636	total: 9.36s	remaining: 366ms
# 512:	learn: 0.1073437	total: 9.38s	remaining: 347ms
# 513:	learn: 0.1072199	total: 9.4s	remaining: 329ms
# 514:	learn: 0.1070963	total: 9.42s	remaining: 311ms
# 515:	learn: 0.1069823	total: 9.44s	remaining: 293ms
# 516:	learn: 0.1068744	total: 9.45s	remaining: 274ms
# 517:	learn: 0.1067660	total: 9.47s	remaining: 256ms
# 518:	learn: 0.1066669	total: 9.49s	remaining: 238ms
# 519:	learn: 0.1065581	total: 9.51s	remaining: 219ms
# 520:	learn: 0.1064320	total: 9.53s	remaining: 201ms
# 521:	learn: 0.1063314	total: 9.55s	remaining: 183ms
# 522:	learn: 0.1062187	total: 9.57s	remaining: 165ms
# 523:	learn: 0.1061078	total: 9.6s	remaining: 146ms
# 524:	learn: 0.1059976	total: 9.61s	remaining: 128ms
# 525:	learn: 0.1058926	total: 9.63s	remaining: 110ms
# 526:	learn: 0.1057983	total: 9.65s	remaining: 91.6ms
# 527:	learn: 0.1057000	total: 9.65s	remaining: 73.2ms
# 528:	learn: 0.1055915	total: 9.68s	remaining: 54.9ms
# 529:	learn: 0.1054905	total: 9.7s	remaining: 36.6ms
# 530:	learn: 0.1053719	total: 9.72s	remaining: 18.3ms
# 531:	learn: 0.1052686	total: 9.73s	remaining: 0us

# %% [markdown]
# ### Feature importance

# %%
feature_importances = model.get_feature_importance()
print("\nFeature Importances:\n")
for score, name in sorted(zip(feature_importances, X_train.columns), reverse=True):
    print(f'{name}: {score:.2f}')
# Out:
# Feature Importances:
#
# direct_rad:W: 36.58
# clear_sky_rad:W: 10.70
# interaction_clear_sky_rad_sun_elevation: 10.64
# sun_elevation:d: 10.51
# direct_rad_1h:J: 9.06
# diffuse_rad:W: 3.20
# clear_sky_energy_1h:J: 2.39
# location_A: 1.84
# elevation:m: 1.71
# visibility:m: 1.69
# wind_speed_u_10m:ms: 1.22
# sun_above_threshold: 1.18
# effective_cloud_cover:p: 1.03
# diffuse_rad_1h:J: 0.98
# cos_sun_azimuth: 0.89
# interaction_clear_sky_rad_effective_cloud_cover: 0.74
# hour: 0.73
# precip_type_5min:idx: 0.71
# fresh_snow_24h:cm: 0.52
# sun_azimuth:d: 0.49
# sin_sun_azimuth: 0.42
# t_1000hPa:K: 0.41
# precip_5min:mm: 0.32
# snow_water:kgm2: 0.31
# rain_water:kgm2: 0.19
# relative_humidity_1000hPa:p: 0.19
# wind_speed_10m:ms: 0.14
# fresh_snow_12h:cm: 0.14
# absolute_humidity_2m:gm3: 0.13
# weekofyear: 0.13
# is_in_shadow:idx: 0.12
# total_cloud_cover:p: 0.08
# pressure_100m:hPa: 0.08
# msl_pressure:hPa: 0.08
# dew_point_2m:K: 0.08
# dayofyear: 0.07
# pressure_50m:hPa: 0.07
# sfc_pressure:hPa: 0.06
# month: 0.06
# is_day:idx: 0.04
# year: 0.02
# season: 0.01
# super_cooled_liquid_water:kgm2: 0.01
# location_B: 0.01
# snow_depth:cm: 0.00
# location_C: 0.00
# wind_speed_v_10m:ms: 0.00
# air_density_2m:kgm3: 0.00
# quarter: 0.00
# snow_melt_10min:mm: 0.00
# dew_or_rime:idx: 0.00
# wind_speed_w_1000hPa:ms: 0.00
# snow_drift:idx: 0.00
# prob_rime:p: 0.00
# is_weekend: 0.00
# fresh_snow_6h:cm: 0.00
# fresh_snow_3h:cm: 0.00
# fresh_snow_1h:cm: 0.00
# estimated: 0.00
# dayofweek: 0.00
# dayofmonth: 0.00

# %% [markdown]
# ### Predict and make csv

# %%
predictions = model.predict(X_test)

# %%
predictions = pd.DataFrame(predictions, columns=['prediction'])

predictions.reset_index(drop=True, inplace=True)

predictions.head()
# Out:
#    prediction
# 0    0.010956
# 1    0.011081
# 2    0.011057
# 3    0.013675
# 4    0.059663

# %%
loc_a = predictions.iloc[:len(predictions)//3]
loc_b = predictions.iloc[len(predictions)//3:2*len(predictions)//3]
loc_c = predictions.iloc[2*len(predictions)//3:]

# %%
n = len(predictions)

# De-normalizing

loc_a.loc[:, 'prediction'] = scaler_a.inverse_transform(loc_a['prediction'].values.reshape(-1, 1))
loc_b.loc[:, 'prediction'] = scaler_b.inverse_transform(loc_b['prediction'].values.reshape(-1, 1))
loc_c.loc[:, 'prediction'] = scaler_c.inverse_transform(loc_c['prediction'].values.reshape(-1, 1))

# %%
predictions = pd.concat([loc_a, loc_b, loc_c])

# %%
predictions.head(10)
# Out:
#     prediction
# 0    62.816769
# 1    63.531212
# 2    63.394067
# 3    78.404117
# 4   342.071048
# 5   831.629472
# 6  1530.558704
# 7  2115.867588
# 8  2602.457461
# 9  2938.523886

# %%
predictions.reset_index(inplace=True)
predictions.rename(columns={'index': 'id'}, inplace=True)
predictions.to_csv('predictions.csv', index=False)

# %% [markdown]
# Remove negative values

# %%
predictions.loc[predictions['prediction'] < 0, 'prediction'] = 0
predictions.to_csv('predictions.csv', index=False)

# %% [markdown]
# Redifing the training sets

# %%
train_a = pd.read_parquet('../../A/train_targets.parquet')
train_b = pd.read_parquet('../../B/train_targets.parquet')
train_c = pd.read_parquet('../../C/train_targets.parquet')

train_a.set_index('time', inplace=True)
train_b.set_index('time', inplace=True)
train_c.set_index('time', inplace=True)

# %% [markdown]
# ### Plotting A

# %%
loc_a.set_index(valid_dates, inplace=True)

plt.figure(figsize=(9, 4))

loc_a['prediction'].plot(style='.', label='Prediction')
train_a['pv_measurement'].plot(style='.', label='Actual', color='red', linewidth=2)

plt.legend(loc='upper left')
plt.title('Predictions vs. Actual A')
plt.xlabel('Time')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plotting B

# %%
loc_b.set_index(valid_dates, inplace=True)

plt.figure(figsize=(9, 4))

loc_b['prediction'].plot(style='.', label='Prediction')
train_b['pv_measurement'].plot(style='.', label='Actual', color='red', linewidth=2)

plt.legend(loc='upper left')
plt.title('Predictions vs. Actual B')
plt.xlabel('Time')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
loc_c.set_index(valid_dates, inplace=True)

plt.figure(figsize=(9, 4))

loc_c['prediction'].plot(style='.', label='Prediction')
train_c['pv_measurement'].plot(style='.', label='Actual', color='red', linewidth=2)

plt.legend(loc='upper left')
plt.title('Predictions vs. Actual C')
plt.xlabel('Time')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()
