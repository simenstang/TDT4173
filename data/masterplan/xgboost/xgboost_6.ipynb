# %% [markdown]
# # XGBoost with trig tranformations on time feature
#
# - The y-set for location A, B and C are concatonated (time index)
# - The X-set for location A, B and C are concatonated (time index)
# - One hot encoding for location and whether or not set is from the estimated column
# - The y-set and the X-set are merged on date and location
# - Having date features
# - y-sets are normalized (MinMax)
# - Removes repeated values in y-set B and C
#
# It takes over from feature_engineering_1
# Adds some ratio features from feature_engineering_3
#
# **Takes over from cat_boost_clean_1.ipynb**

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import math
import csv
import seaborn as sns
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
train_a = pd.read_parquet('../../A/train_targets.parquet')
train_b = pd.read_parquet('../../B/train_targets.parquet')
train_c = pd.read_parquet('../../C/train_targets.parquet')

X_train_estimated_a = pd.read_parquet('../../A/X_train_estimated.parquet')
X_train_estimated_b = pd.read_parquet('../../B/X_train_estimated.parquet')
X_train_estimated_c = pd.read_parquet('../../C/X_train_estimated.parquet')

X_train_observed_a = pd.read_parquet('../../A/X_train_observed.parquet')
X_train_observed_b = pd.read_parquet('../../B/X_train_observed.parquet')
X_train_observed_c = pd.read_parquet('../../C/X_train_observed.parquet')

X_test_estimated_a = pd.read_parquet('../../A/X_test_estimated.parquet')
X_test_estimated_b = pd.read_parquet('../../B/X_test_estimated.parquet')
X_test_estimated_c = pd.read_parquet('../../C/X_test_estimated.parquet')

# %% [markdown]
# ## Handling the Y-set

# %%
def find_repeated_rows(df):
    '''
    Returns all indicies (from, to) which have the largest intervals of being constant. The output is sorted from 
    largest to smallest.
    '''
    df = df.reset_index()
    repeated_temp = []
    intervals = []

    first = True

    for index, row in df.iterrows():
        if index == 0:
            continue
        if row['pv_measurement'] == df.iloc[index - 1]['pv_measurement']:
            repeated_temp.append(index)
            if first: 
                repeated_temp.insert(0, index - 1)
                first = False
        else:
            if len(repeated_temp) > 1:
                intervals.append((repeated_temp[0], repeated_temp[-1]))
            repeated_temp = []
            first = True
            
    threshold = 6

    return sorted([t for t in intervals if t[1] - t[0] >= threshold], key=lambda t: t[1] - t[0], reverse=True)

# %%
all_y = [train_a, train_b, train_c]
labels = ['A', 'B', 'C']

table = {}

i = 0
for y in all_y:
    loc, intervals = labels[i], find_repeated_rows(y)
    if isinstance(intervals[0], (int, float)):
        intervals = np.asarray(intervals, dtype=float)
    intervals = list(intervals) + [np.nan] * (1421 - len(intervals))
    table[loc] = intervals
    print("The largest interval for", loc, intervals[0])
    i += 1

table = pd.DataFrame(table)
table.head()
# Out:
# The largest interval for A (5176, 5218)
# The largest interval for B (13409, 14466)
# The largest interval for C (18105, 18727)
#                 A               B               C
# 0    (5176, 5218)  (13409, 14466)  (18105, 18727)
# 1    (4526, 4547)  (19138, 20141)  (26048, 26669)
# 2  (22429, 22450)  (18690, 19137)  (27224, 27748)
# 3  (22933, 22954)  (10966, 11307)  (25400, 25876)
# 4        (67, 87)  (26115, 26353)  (10047, 10375)

# %%
i = 1
for y in all_y[1:]:
    loc, intervals = labels[i], find_repeated_rows(y)
    for start, end in intervals:
        for row_index in range(start, end + 1):
            y.at[row_index, 'pv_measurement'] = np.nan

    test = y.set_index('time')
    test['pv_measurement'].plot(title="PV measurments when removing all constant intervals in " + loc)
    plt.show()
    i += 1

# %%
train_a.set_index('time', inplace=True)
train_b.set_index('time', inplace=True)
train_c.set_index('time', inplace=True)

# %% [markdown]
# Normalizing values

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_a = MinMaxScaler()
scaler_b = MinMaxScaler()
scaler_c = MinMaxScaler()

# %%
train_a['pv_measurement'] = scaler_a.fit_transform(train_a[['pv_measurement']])
train_b['pv_measurement'] = scaler_b.fit_transform(train_b[['pv_measurement']])
train_c['pv_measurement'] = scaler_c.fit_transform(train_c[['pv_measurement']])

# %%
train_a['location'] = 'A'
train_b['location'] = 'B'
train_c['location'] = 'C'

# %%
y = pd.concat([train_a, train_b, train_c])
y.index.name = 'time'

y.shape
y.head()
# Out:
#                      pv_measurement location
# time
# 2019-06-02 22:00:00        0.000000        A
# 2019-06-02 23:00:00        0.000000        A
# 2019-06-03 00:00:00        0.000000        A
# 2019-06-03 01:00:00        0.000000        A
# 2019-06-03 02:00:00        0.003377        A

# %% [markdown]
# Setting the index to **date_forecast** and resampling with median.

# %%
X_train_observed_a['date_forecast'] = pd.to_datetime(X_train_observed_a['date_forecast'])
X_train_observed_a.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_observed_a:
    X_train_observed_a.drop("date_calc", axis=1, inplace=True)
X_train_observed_a = X_train_observed_a.resample('60min').median()


X_train_estimated_a['date_forecast'] = pd.to_datetime(X_train_estimated_a['date_forecast'])
X_train_estimated_a.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_estimated_a:
    X_train_estimated_a.drop("date_calc", axis=1, inplace=True)
X_train_estimated_a = X_train_estimated_a.resample('60min').median()


X_train_observed_b['date_forecast'] = pd.to_datetime(X_train_observed_b['date_forecast'])
X_train_observed_b.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_observed_b:
    X_train_observed_b.drop("date_calc", axis=1, inplace=True)
X_train_observed_b = X_train_observed_b.resample('60min').median()


X_train_estimated_b['date_forecast'] = pd.to_datetime(X_train_estimated_b['date_forecast'])
X_train_estimated_b.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_estimated_b:
    X_train_estimated_b.drop("date_calc", axis=1, inplace=True)
X_train_estimated_b = X_train_estimated_b.resample('60min').median()


X_train_observed_c['date_forecast'] = pd.to_datetime(X_train_observed_c['date_forecast'])
X_train_observed_c.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_observed_c:
    X_train_observed_c.drop("date_calc", axis=1, inplace=True)
X_train_observed_c = X_train_observed_c.resample('60min').median()


X_train_estimated_c['date_forecast'] = pd.to_datetime(X_train_estimated_c['date_forecast'])
X_train_estimated_c.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_estimated_c:
    X_train_estimated_c.drop("date_calc", axis=1, inplace=True)
X_train_estimated_c = X_train_estimated_c.resample('60min').median()

# %%
def replace_outliers_with_nan(df, feature):
    '''Replaces thr 0.01 and 0.99'''
    Q1 = df[feature].quantile(0.01)
    Q99 = df[feature].quantile(0.99)

    df[feature] = np.where(
        (df[feature] < Q1) | (df[feature] > Q99),
        np.nan,
        df[feature]
    )

# %% [markdown]
# ### Removing 'outlier' features as this gave us 0.1 better score on Kaggle

# %%
outliers = ['air_density_2m:kgm3', 'msl_pressure:hPa', 'sfc_pressure:hPa']


for o in outliers:
    replace_outliers_with_nan(X_train_observed_a, o)
    replace_outliers_with_nan(X_train_observed_b, o)
    replace_outliers_with_nan(X_train_observed_c, o)

# %%
X_train_observed_a['location'], X_train_estimated_a['location'] = 'A', 'A'
X_train_observed_b['location'], X_train_estimated_b['location']= 'B', 'B'
X_train_observed_c['location'], X_train_estimated_c['location']= 'C', 'C'

X_train_observed_a['estimated'], X_train_estimated_a['estimated'] = 0, 1
X_train_observed_b['estimated'], X_train_estimated_b['estimated'] = 0, 1
X_train_observed_c['estimated'], X_train_estimated_c['estimated'] = 0, 1

# %%
X = pd.concat([X_train_observed_a, X_train_estimated_a, X_train_observed_b,
               X_train_estimated_b, X_train_observed_c, X_train_estimated_c
               ], ignore_index=False)
X = X.sort_index()

# %%
df = pd.merge(y, X, left_on=[y.index, 'location'],
              right_on=[X.index, 'location'])

df.set_index('key_0', inplace=True)
df.index.name = "time"
df = df.sort_index()

df.head()
# Out:
#                      pv_measurement location  absolute_humidity_2m:gm3  \
# time
# 2019-01-01 00:00:00             NaN        B                      5.55
# 2019-01-01 00:00:00             NaN        C                      5.45
# 2019-01-01 01:00:00             NaN        C                      5.35
# 2019-01-01 01:00:00             NaN        B                      5.40
# 2019-01-01 02:00:00             NaN        B                      5.40
#
#                      air_density_2m:kgm3  ceiling_height_agl:m  \
# time
# 2019-01-01 00:00:00               1.2395           1200.700012
# 2019-01-01 00:00:00               1.2410           1130.049988
# 2019-01-01 01:00:00               1.2400           1066.699951
# 2019-01-01 01:00:00               1.2395           1131.449951
# 2019-01-01 02:00:00               1.2385           1061.049988
#
#                      clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  \
# time
# 2019-01-01 00:00:00                    0.0              0.0       1200.700012
# 2019-01-01 00:00:00                    0.0              0.0       1130.049988
# 2019-01-01 01:00:00                    0.0              0.0       1066.699951
# 2019-01-01 01:00:00                    0.0              0.0       1131.449951
# 2019-01-01 02:00:00                    0.0              0.0       1061.049988
#
#                      dew_or_rime:idx  dew_point_2m:K  ...  sun_elevation:d  \
# time                                                  ...
# 2019-01-01 00:00:00              0.0      275.150009  ...       -48.389500
# 2019-01-01 00:00:00              1.0      275.000000  ...       -48.426498
# 2019-01-01 01:00:00              1.0      274.650009  ...       -45.002501
# 2019-01-01 01:00:00              0.0      274.849991  ...       -44.971498
# 2019-01-01 02:00:00              0.0      274.800003  ...       -39.896000
#
#                      super_cooled_liquid_water:kgm2  t_1000hPa:K  \
# time
# 2019-01-01 00:00:00                             0.0   278.250000
# 2019-01-01 00:00:00                             0.0   278.349991
# 2019-01-01 01:00:00                             0.0   278.200012
# 2019-01-01 01:00:00                             0.0   278.100006
# 2019-01-01 02:00:00                             0.1   278.050003
#
#                      total_cloud_cover:p  visibility:m  wind_speed_10m:ms  \
# time
# 2019-01-01 00:00:00            87.500000  16823.399902               2.80
# 2019-01-01 00:00:00            85.350002  16512.299805               2.90
# 2019-01-01 01:00:00            99.099998  13277.399902               3.65
# 2019-01-01 01:00:00            99.099998  12777.449707               3.55
# 2019-01-01 02:00:00            97.849998  11142.549805               4.05
#
#                      wind_speed_u_10m:ms  wind_speed_v_10m:ms  \
# time
# 2019-01-01 00:00:00                 1.20                 2.55
# 2019-01-01 00:00:00                 1.10                 2.65
# 2019-01-01 01:00:00                 1.40                 3.35
# 2019-01-01 01:00:00                 1.50                 3.20
# 2019-01-01 02:00:00                 2.15                 3.45
#
#                      wind_speed_w_1000hPa:ms  estimated
# time
# 2019-01-01 00:00:00                     -0.0          0
# 2019-01-01 00:00:00                     -0.0          0
# 2019-01-01 01:00:00                     -0.0          0
# 2019-01-01 01:00:00                     -0.0          0
# 2019-01-01 02:00:00                     -0.0          0
#
# [5 rows x 48 columns]

# %%
def create_features(df):
    """
    Create Features
    """
    
    df = df.copy()
    df['month_sin'] = np.sin(2 * np.pi * df.index.month / 12)
    df['month_cos'] = np.cos(2 * np.pi * df.index.month / 12)
    df['hour_sin'] = np.sin(2 * np.pi * df.index.hour / 23)
    df['hour_cos'] = np.cos(2 * np.pi * df.index.hour / 23)

    return df

def get_season(month):
    if 3 <= month <= 5:
        return 0  # spring
    elif 6 <= month <= 8:
        return 1  # summer
    elif 9 <= month <= 11:
        return 2  # fall
    else:
        return 3  # winter

df = create_features(df)

df.head()
# Out:
#                      pv_measurement location  absolute_humidity_2m:gm3  \
# time
# 2019-01-01 00:00:00             NaN        B                      5.55
# 2019-01-01 00:00:00             NaN        C                      5.45
# 2019-01-01 01:00:00             NaN        C                      5.35
# 2019-01-01 01:00:00             NaN        B                      5.40
# 2019-01-01 02:00:00             NaN        B                      5.40
#
#                      air_density_2m:kgm3  ceiling_height_agl:m  \
# time
# 2019-01-01 00:00:00               1.2395           1200.700012
# 2019-01-01 00:00:00               1.2410           1130.049988
# 2019-01-01 01:00:00               1.2400           1066.699951
# 2019-01-01 01:00:00               1.2395           1131.449951
# 2019-01-01 02:00:00               1.2385           1061.049988
#
#                      clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  \
# time
# 2019-01-01 00:00:00                    0.0              0.0       1200.700012
# 2019-01-01 00:00:00                    0.0              0.0       1130.049988
# 2019-01-01 01:00:00                    0.0              0.0       1066.699951
# 2019-01-01 01:00:00                    0.0              0.0       1131.449951
# 2019-01-01 02:00:00                    0.0              0.0       1061.049988
#
#                      dew_or_rime:idx  dew_point_2m:K  ...  visibility:m  \
# time                                                  ...
# 2019-01-01 00:00:00              0.0      275.150009  ...  16823.399902
# 2019-01-01 00:00:00              1.0      275.000000  ...  16512.299805
# 2019-01-01 01:00:00              1.0      274.650009  ...  13277.399902
# 2019-01-01 01:00:00              0.0      274.849991  ...  12777.449707
# 2019-01-01 02:00:00              0.0      274.800003  ...  11142.549805
#
#                      wind_speed_10m:ms  wind_speed_u_10m:ms  \
# time
# 2019-01-01 00:00:00               2.80                 1.20
# 2019-01-01 00:00:00               2.90                 1.10
# 2019-01-01 01:00:00               3.65                 1.40
# 2019-01-01 01:00:00               3.55                 1.50
# 2019-01-01 02:00:00               4.05                 2.15
#
#                      wind_speed_v_10m:ms  wind_speed_w_1000hPa:ms  estimated  \
# time
# 2019-01-01 00:00:00                 2.55                     -0.0          0
# 2019-01-01 00:00:00                 2.65                     -0.0          0
# 2019-01-01 01:00:00                 3.35                     -0.0          0
# 2019-01-01 01:00:00                 3.20                     -0.0          0
# 2019-01-01 02:00:00                 3.45                     -0.0          0
#
#                      month_sin  month_cos  hour_sin  hour_cos
# time
# 2019-01-01 00:00:00        0.5   0.866025  0.000000  1.000000
# 2019-01-01 00:00:00        0.5   0.866025  0.000000  1.000000
# 2019-01-01 01:00:00        0.5   0.866025  0.269797  0.962917
# 2019-01-01 01:00:00        0.5   0.866025  0.269797  0.962917
# 2019-01-01 02:00:00        0.5   0.866025  0.519584  0.854419
#
# [5 rows x 52 columns]

# %% [markdown]
# ### Selecting features
#
# Everything except:
#
# - snow_density:kgm3
# - cloud_base_agl:m
# - ceiling_height_agl:m
#
# They have a lot of NaN values.

# %%
FEATURES = [
    'absolute_humidity_2m:gm3', 'air_density_2m:kgm3',
    'clear_sky_energy_1h:J', 'clear_sky_rad:W',
    'dew_or_rime:idx', 'dew_point_2m:K',
    'diffuse_rad:W', 'diffuse_rad_1h:J', 'direct_rad:W', 'direct_rad_1h:J',
    'effective_cloud_cover:p', 'elevation:m', 'fresh_snow_12h:cm',
    'fresh_snow_1h:cm', 'fresh_snow_24h:cm', 'fresh_snow_3h:cm',
    'fresh_snow_6h:cm', 'is_day:idx', 'is_in_shadow:idx',
    'msl_pressure:hPa', 'precip_5min:mm', 'precip_type_5min:idx',
    'pressure_100m:hPa', 'pressure_50m:hPa', 'prob_rime:p',
    'rain_water:kgm2', 'relative_humidity_1000hPa:p', 'sfc_pressure:hPa',
    'snow_depth:cm', 'snow_drift:idx',
    'snow_melt_10min:mm', 'snow_water:kgm2', 'sun_azimuth:d',
    'sun_elevation:d', 'super_cooled_liquid_water:kgm2', 't_1000hPa:K',
    'total_cloud_cover:p', 'visibility:m', 'wind_speed_10m:ms',
    'wind_speed_u_10m:ms', 'wind_speed_v_10m:ms', 'wind_speed_w_1000hPa:ms',
    'month_sin', 'month_cos', 'hour_sin', 'hour_cos',
    'location'
]

TARGET = 'pv_measurement'

# %%
relevant = FEATURES.copy()
relevant.append(TARGET)

df = df[relevant]

# %%
print(df.isna().sum())
before = df.shape

train = df.dropna()
print(train.isna().sum())
after = train.shape

dif = before[0] - after[0]

df = df.dropna()
print("DROPNA RESULTED IN", dif, "ROWS BEING DROPPED. THE DATASET HAS", after[0], "ROWS IN TOTAL.")
# Out:
# absolute_humidity_2m:gm3             72
# air_density_2m:kgm3                1824
# clear_sky_energy_1h:J                72
# clear_sky_rad:W                      72
# dew_or_rime:idx                      72
# dew_point_2m:K                       72
# diffuse_rad:W                        72
# diffuse_rad_1h:J                     72
# direct_rad:W                         72
# direct_rad_1h:J                      72
# effective_cloud_cover:p              72
# elevation:m                          72
# fresh_snow_12h:cm                    72
# fresh_snow_1h:cm                     72
# fresh_snow_24h:cm                    72
# fresh_snow_3h:cm                     72
# fresh_snow_6h:cm                     72
# is_day:idx                           72
# is_in_shadow:idx                     72
# msl_pressure:hPa                   1832
# precip_5min:mm                       72
# precip_type_5min:idx                 72
# pressure_100m:hPa                    72
# pressure_50m:hPa                     72
# prob_rime:p                          72
# rain_water:kgm2                      72
# relative_humidity_1000hPa:p          72
# sfc_pressure:hPa                   1829
# snow_depth:cm                        72
# snow_drift:idx                       72
# snow_melt_10min:mm                   72
# snow_water:kgm2                      72
# sun_azimuth:d                        72
# sun_elevation:d                      72
# super_cooled_liquid_water:kgm2       72
# t_1000hPa:K                          72
# total_cloud_cover:p                  72
# visibility:m                         72
# wind_speed_10m:ms                    72
# wind_speed_u_10m:ms                  72
# wind_speed_v_10m:ms                  72
# wind_speed_w_1000hPa:ms              72
# month_sin                             0
# month_cos                             0
# hour_sin                              0
# hour_cos                              0
# location                              0
# pv_measurement                    40896
# dtype: int64
# absolute_humidity_2m:gm3          0
# air_density_2m:kgm3               0
# clear_sky_energy_1h:J             0
# clear_sky_rad:W                   0
# dew_or_rime:idx                   0
# dew_point_2m:K                    0
# diffuse_rad:W                     0
# diffuse_rad_1h:J                  0
# direct_rad:W                      0
# direct_rad_1h:J                   0
# effective_cloud_cover:p           0
# elevation:m                       0
# fresh_snow_12h:cm                 0
# fresh_snow_1h:cm                  0
# fresh_snow_24h:cm                 0
# fresh_snow_3h:cm                  0
# fresh_snow_6h:cm                  0
# is_day:idx                        0
# is_in_shadow:idx                  0
# msl_pressure:hPa                  0
# precip_5min:mm                    0
# precip_type_5min:idx              0
# pressure_100m:hPa                 0
# pressure_50m:hPa                  0
# prob_rime:p                       0
# rain_water:kgm2                   0
# relative_humidity_1000hPa:p       0
# sfc_pressure:hPa                  0
# snow_depth:cm                     0
# snow_drift:idx                    0
# snow_melt_10min:mm                0
# snow_water:kgm2                   0
# sun_azimuth:d                     0
# sun_elevation:d                   0
# super_cooled_liquid_water:kgm2    0
# t_1000hPa:K                       0
# total_cloud_cover:p               0
# visibility:m                      0
# wind_speed_10m:ms                 0
# wind_speed_u_10m:ms               0
# wind_speed_v_10m:ms               0
# wind_speed_w_1000hPa:ms           0
# month_sin                         0
# month_cos                         0
# hour_sin                          0
# hour_cos                          0
# location                          0
# pv_measurement                    0
# dtype: int64
# DROPNA RESULTED IN 42788 ROWS BEING DROPPED. THE DATASET HAS 56298 ROWS IN TOTAL.

# %%
color_pal = sns.color_palette()

df["pv_measurement"].plot(style='.',
        figsize=(15, 5),
        color=color_pal[1],
        title='PV measurment against time')
plt.show()

# %% [markdown]
# ### Preparing test data
#
# - Excluding dates that should not be tested
# - Including only the features we have defined

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

def prepare_test_data(x, location):
    x_test = x.copy()
    x_test.set_index('date_forecast', inplace = True)
    x_test.drop('date_calc', axis=1, inplace = True)
    x_test['estimated'] = 1

    x_test = x_test.resample('60min').median()

    x_test = create_features(x_test)

    x_test['location'] = location

    return x_test

# %%
x_test_a = prepare_test_data(X_test_estimated_a, 'A')
x_test_b = prepare_test_data(X_test_estimated_b, 'B')
x_test_c = prepare_test_data(X_test_estimated_c, 'C')

# %%
test_sub = pd.read_csv('../../test.csv')
valid_dates = pd.to_datetime(test_sub['time'].unique())

# %%
x_test_a = x_test_a.loc[valid_dates]
x_test_b = x_test_b.loc[valid_dates]
x_test_c = x_test_c.loc[valid_dates]

# %%
X_test = pd.concat([x_test_a, x_test_b, x_test_c])
X_test = X_test[FEATURES]

# %%
X_test_kaggle = X_test

# %% [markdown]
# ### Disability Check
#
# Check if the training data and the test data contains the same columns.

# %%
check_df = df.copy()
check_train = check_df[FEATURES]
if X_test.columns.equals(check_train.columns):
    print("EQUAL")
else:
    print("NOT EQUAL")
    print("DIFFERENCE\n", X_test.columns.difference(check_train.columns))
# Out:
# EQUAL

# %% [markdown]
# Check if test data has the right amount of rows.

# %%
if X_test.shape[0] != 2160:
    print("X_test has wrong amount of rows!")
    print("Shape =", X_test.shape[0])
else:
    print("GOOD")
# Out:
# GOOD

# %%
X, y = df[FEATURES], df[TARGET]

# %%
X['location'] = X['location'].astype('category')
# Out:
# /var/folders/s2/v6q39rgs1xs8ww30dn78jkb00000gn/T/ipykernel_24536/1794122678.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['location'] = X['location'].astype('category')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test_local, y_train, y_test_local = train_test_split(X, y, test_size=0.15, random_state=42, shuffle=False)

# %% [markdown]
# ### Define parameters you want to tune
#
# NOTE we have gotten issues by tuning too many paramters. Be carefull!

# %%
import optuna
import xgboost as xg
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import KFold
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)


def objective(trial):
    param = {
        "eval_metric": 'mae',  
        "learning_rate": trial.suggest_float("learning_rate", 1e-4, 0.3, log=True),
        "n_estimators": trial.suggest_int("n_estimators", 50, 1500),
        "max_depth": trial.suggest_int("max_depth", 1, 15),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.1, 1.0),
        'enable_categorical':True
    }

    cv = KFold(n_splits=5)

    model = XGBRegressor(**param)

    maes = []

    for train_index, val_index in cv.split(X_train):
        train_x, val_x = X_train.iloc[train_index], X_train.iloc[val_index]
        train_y , val_y = y_train.iloc[train_index], y_train.iloc[val_index]

        model.fit(train_x, train_y, verbose=0)
        y_pred = model.predict(val_x)
        mae = mean_absolute_error(val_y, y_pred)
        maes.append(mae)
        
    avg_mae = np.mean(maes)

    return avg_mae

# %%
xg.__version__
# Out:
# '2.0.0'

# %% [markdown]
# ### Specify number of trials
#
# A higher number of trials tries out more parameters

# %%
trials = 60

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=trials, n_jobs=-1, show_progress_bar=True)
# Out:
# [I 2023-10-29 14:16:39,995] A new study created in memory with name: no-name-9eb284dd-1469-4925-aa4d-a1a8f0ded6d5
#   0%|          | 0/60 [00:00<?, ?it/s]
# [I 2023-10-29 14:19:19,082] Trial 2 finished with value: 0.12043235091064948 and parameters: {'learning_rate': 0.0016698550966825238, 'n_estimators': 231, 'max_depth': 9, 'colsample_bytree': 0.740080900697981}. Best is trial 2 with value: 0.12043235091064948.
# [I 2023-10-29 14:22:27,187] Trial 6 finished with value: 0.04576892195885113 and parameters: {'learning_rate': 0.0215214183986516, 'n_estimators': 565, 'max_depth': 8, 'colsample_bytree': 0.17262354953994752}. Best is trial 6 with value: 0.04576892195885113.
# [I 2023-10-29 14:23:39,845] Trial 9 finished with value: 0.04450535355987053 and parameters: {'learning_rate': 0.06423758751589076, 'n_estimators': 86, 'max_depth': 10, 'colsample_bytree': 0.5904006393553469}. Best is trial 9 with value: 0.04450535355987053.
# [I 2023-10-29 14:24:47,830] Trial 5 finished with value: 0.044974487717835854 and parameters: {'learning_rate': 0.02891340388632746, 'n_estimators': 452, 'max_depth': 12, 'colsample_bytree': 0.9162691589753645}. Best is trial 9 with value: 0.04450535355987053.
# [I 2023-10-29 14:24:53,773] Trial 8 finished with value: 0.04505933784450093 and parameters: {'learning_rate': 0.006622901434324798, 'n_estimators': 631, 'max_depth': 7, 'colsample_bytree': 0.3229699898177348}. Best is trial 9 with value: 0.04450535355987053.
# [I 2023-10-29 14:25:15,416] Trial 3 finished with value: 0.14065521452596258 and parameters: {'learning_rate': 0.00022795681302211515, 'n_estimators': 839, 'max_depth': 8, 'colsample_bytree': 0.7316281927346255}. Best is trial 9 with value: 0.04450535355987053.
# [I 2023-10-29 14:25:51,116] Trial 10 finished with value: 0.04726464638492224 and parameters: {'learning_rate': 0.00928943206587945, 'n_estimators': 603, 'max_depth': 3, 'colsample_bytree': 0.551133485984533}. Best is trial 9 with value: 0.04450535355987053.
# [I 2023-10-29 14:27:16,339] Trial 1 finished with value: 0.1495869594103432 and parameters: {'learning_rate': 0.0002389046118104937, 'n_estimators': 812, 'max_depth': 10, 'colsample_bytree': 0.10388034872987961}. Best is trial 9 with value: 0.04450535355987053.
# [I 2023-10-29 14:29:57,523] Trial 15 finished with value: 0.047542443672818804 and parameters: {'learning_rate': 0.00713682563347387, 'n_estimators': 694, 'max_depth': 3, 'colsample_bytree': 0.8351807218538493}. Best is trial 9 with value: 0.04450535355987053.
# [I 2023-10-29 14:30:31,850] Trial 11 finished with value: 0.04777045716824635 and parameters: {'learning_rate': 0.24479001733757555, 'n_estimators': 929, 'max_depth': 10, 'colsample_bytree': 0.4302951629371462}. Best is trial 9 with value: 0.04450535355987053.
# [I 2023-10-29 14:32:20,814] Trial 4 finished with value: 0.04908112425621556 and parameters: {'learning_rate': 0.00731643856021347, 'n_estimators': 1142, 'max_depth': 10, 'colsample_bytree': 0.12294910007390353}. Best is trial 9 with value: 0.04450535355987053.
# [I 2023-10-29 14:32:21,814] Trial 12 finished with value: 0.07040827299268866 and parameters: {'learning_rate': 0.0013692247660697656, 'n_estimators': 947, 'max_depth': 6, 'colsample_bytree': 0.7399724236666704}. Best is trial 9 with value: 0.04450535355987053.
# [I 2023-10-29 14:33:54,810] Trial 16 finished with value: 0.1464620202323089 and parameters: {'learning_rate': 0.0001497594890831228, 'n_estimators': 1338, 'max_depth': 2, 'colsample_bytree': 0.18382973853875917}. Best is trial 9 with value: 0.04450535355987053.
# [I 2023-10-29 14:36:42,863] Trial 14 finished with value: 0.05016384765915345 and parameters: {'learning_rate': 0.13907638918126483, 'n_estimators': 1428, 'max_depth': 11, 'colsample_bytree': 0.157179176053233}. Best is trial 9 with value: 0.04450535355987053.
# [I 2023-10-29 14:37:50,010] Trial 0 finished with value: 0.04653092089709512 and parameters: {'learning_rate': 0.0027208712968221577, 'n_estimators': 1250, 'max_depth': 10, 'colsample_bytree': 0.8971233420854114}. Best is trial 9 with value: 0.04450535355987053.
# [I 2023-10-29 14:37:54,697] Trial 19 finished with value: 0.0473713019186828 and parameters: {'learning_rate': 0.06588051017649839, 'n_estimators': 56, 'max_depth': 14, 'colsample_bytree': 0.9406525347759117}. Best is trial 9 with value: 0.04450535355987053.
# [I 2023-10-29 14:39:24,813] Trial 17 finished with value: 0.0461299160566878 and parameters: {'learning_rate': 0.15776647987630002, 'n_estimators': 1312, 'max_depth': 15, 'colsample_bytree': 0.5839177671386179}. Best is trial 9 with value: 0.04450535355987053.
# [I 2023-10-29 14:44:21,009] Trial 21 finished with value: 0.047913034142611916 and parameters: {'learning_rate': 0.055434698276718736, 'n_estimators': 60, 'max_depth': 14, 'colsample_bytree': 0.9445001939872546}. Best is trial 9 with value: 0.04450535355987053.
# [I 2023-10-29 14:44:45,333] Trial 18 finished with value: 0.046151193931327675 and parameters: {'learning_rate': 0.06496268515364576, 'n_estimators': 93, 'max_depth': 15, 'colsample_bytree': 0.967198376259378}. Best is trial 9 with value: 0.04450535355987053.
# [I 2023-10-29 14:47:28,183] Trial 20 finished with value: 0.04612715200685715 and parameters: {'learning_rate': 0.04611342493051696, 'n_estimators': 125, 'max_depth': 14, 'colsample_bytree': 0.9998515193289536}. Best is trial 9 with value: 0.04450535355987053.
# [I 2023-10-29 14:51:25,331] Trial 22 finished with value: 0.046045766007393754 and parameters: {'learning_rate': 0.042287617247691166, 'n_estimators': 126, 'max_depth': 14, 'colsample_bytree': 0.9750469636885418}. Best is trial 9 with value: 0.04450535355987053.
# [I 2023-10-29 14:53:42,630] Trial 13 finished with value: 0.04482380808289693 and parameters: {'learning_rate': 0.033776675458347186, 'n_estimators': 580, 'max_depth': 15, 'colsample_bytree': 0.6776385083293227}. Best is trial 9 with value: 0.04450535355987053.
# [I 2023-10-29 14:54:26,779] Trial 28 finished with value: 0.04435022590632495 and parameters: {'learning_rate': 0.01832214226369805, 'n_estimators': 407, 'max_depth': 6, 'colsample_bytree': 0.35136588574834193}. Best is trial 28 with value: 0.04435022590632495.
# [I 2023-10-29 14:56:14,696] Trial 30 finished with value: 0.04474986032590576 and parameters: {'learning_rate': 0.01882465422571104, 'n_estimators': 327, 'max_depth': 5, 'colsample_bytree': 0.6274284557349805}. Best is trial 28 with value: 0.04435022590632495.
# [I 2023-10-29 14:57:01,114] Trial 24 finished with value: 0.04468684083292448 and parameters: {'learning_rate': 0.04101240106719622, 'n_estimators': 375, 'max_depth': 13, 'colsample_bytree': 0.628923415376065}. Best is trial 28 with value: 0.04435022590632495.
# [I 2023-10-29 14:57:32,116] Trial 25 finished with value: 0.044467171595820865 and parameters: {'learning_rate': 0.03004136913779941, 'n_estimators': 384, 'max_depth': 12, 'colsample_bytree': 0.6307476914053136}. Best is trial 28 with value: 0.04435022590632495.
# [I 2023-10-29 14:58:29,782] Trial 23 finished with value: 0.04599554492284361 and parameters: {'learning_rate': 0.04936398137202894, 'n_estimators': 358, 'max_depth': 14, 'colsample_bytree': 0.9996186631407846}. Best is trial 28 with value: 0.04435022590632495.
# [I 2023-10-29 14:58:33,390] Trial 31 finished with value: 0.04432534054220878 and parameters: {'learning_rate': 0.016041571482886253, 'n_estimators': 331, 'max_depth': 6, 'colsample_bytree': 0.47290394609318864}. Best is trial 31 with value: 0.04432534054220878.
# [I 2023-10-29 14:59:23,087] Trial 33 finished with value: 0.04590798698737951 and parameters: {'learning_rate': 0.014130548380127419, 'n_estimators': 257, 'max_depth': 6, 'colsample_bytree': 0.4806249639823408}. Best is trial 31 with value: 0.04432534054220878.
# [I 2023-10-29 14:59:56,831] Trial 34 finished with value: 0.04666659596675789 and parameters: {'learning_rate': 0.01586866765438035, 'n_estimators': 232, 'max_depth': 5, 'colsample_bytree': 0.41466580232957106}. Best is trial 31 with value: 0.04432534054220878.
# [I 2023-10-29 15:00:19,409] Trial 26 finished with value: 0.044488038333128796 and parameters: {'learning_rate': 0.027876295789976403, 'n_estimators': 351, 'max_depth': 13, 'colsample_bytree': 0.6514834120521221}. Best is trial 31 with value: 0.04432534054220878.
# [I 2023-10-29 15:00:21,658] Trial 27 finished with value: 0.044388276991899456 and parameters: {'learning_rate': 0.017990052059322127, 'n_estimators': 364, 'max_depth': 12, 'colsample_bytree': 0.63294604113946}. Best is trial 31 with value: 0.04432534054220878.
# [I 2023-10-29 15:01:16,866] Trial 35 finished with value: 0.04488863580350329 and parameters: {'learning_rate': 0.01594785862316426, 'n_estimators': 455, 'max_depth': 5, 'colsample_bytree': 0.4435988043899641}. Best is trial 31 with value: 0.04432534054220878.
# [I 2023-10-29 15:01:47,552] Trial 37 finished with value: 0.07160808822454852 and parameters: {'learning_rate': 0.0034971372542553, 'n_estimators': 380, 'max_depth': 4, 'colsample_bytree': 0.5213888506971277}. Best is trial 31 with value: 0.04432534054220878.
# [I 2023-10-29 15:01:48,332] Trial 36 finished with value: 0.06413650778759519 and parameters: {'learning_rate': 0.003335490605196237, 'n_estimators': 490, 'max_depth': 4, 'colsample_bytree': 0.4946725793978012}. Best is trial 31 with value: 0.04432534054220878.
# [I 2023-10-29 15:02:48,703] Trial 39 finished with value: 0.0593575193832173 and parameters: {'learning_rate': 0.003957365803219431, 'n_estimators': 481, 'max_depth': 4, 'colsample_bytree': 0.5231794453247527}. Best is trial 31 with value: 0.04432534054220878.
# [I 2023-10-29 15:03:42,506] Trial 42 finished with value: 0.05203053220491096 and parameters: {'learning_rate': 0.011563197450241484, 'n_estimators': 203, 'max_depth': 7, 'colsample_bytree': 0.3505992309444489}. Best is trial 31 with value: 0.04432534054220878.
# [I 2023-10-29 15:03:52,554] Trial 29 finished with value: 0.044366441716500934 and parameters: {'learning_rate': 0.022381837523113044, 'n_estimators': 426, 'max_depth': 12, 'colsample_bytree': 0.6430167539026868}. Best is trial 31 with value: 0.04432534054220878.
# [I 2023-10-29 15:05:40,778] Trial 40 finished with value: 0.04393770337097472 and parameters: {'learning_rate': 0.011543267706118018, 'n_estimators': 487, 'max_depth': 7, 'colsample_bytree': 0.5018801564972353}. Best is trial 40 with value: 0.04393770337097472.
# [I 2023-10-29 15:05:44,009] Trial 32 finished with value: 0.044302228080746096 and parameters: {'learning_rate': 0.018907336790109655, 'n_estimators': 382, 'max_depth': 12, 'colsample_bytree': 0.4651834001456619}. Best is trial 40 with value: 0.04393770337097472.
# [I 2023-10-29 15:06:10,298] Trial 41 finished with value: 0.04403060296319108 and parameters: {'learning_rate': 0.013200582872707858, 'n_estimators': 486, 'max_depth': 7, 'colsample_bytree': 0.36803584659119304}. Best is trial 40 with value: 0.04393770337097472.
# [I 2023-10-29 15:10:38,581] Trial 38 finished with value: 0.04436287376077534 and parameters: {'learning_rate': 0.012083972075057263, 'n_estimators': 476, 'max_depth': 12, 'colsample_bytree': 0.48078751591648644}. Best is trial 40 with value: 0.04393770337097472.
# [I 2023-10-29 15:11:56,859] Trial 43 finished with value: 0.04398787231086463 and parameters: {'learning_rate': 0.01112222952707085, 'n_estimators': 741, 'max_depth': 9, 'colsample_bytree': 0.6959730722773027}. Best is trial 40 with value: 0.04393770337097472.
# [I 2023-10-29 15:12:53,613] Trial 45 finished with value: 0.043982499802629076 and parameters: {'learning_rate': 0.009658842826155553, 'n_estimators': 732, 'max_depth': 9, 'colsample_bytree': 0.6982651844082006}. Best is trial 40 with value: 0.04393770337097472.
# [I 2023-10-29 15:13:02,223] Trial 44 finished with value: 0.0439455723633023 and parameters: {'learning_rate': 0.008855410828232069, 'n_estimators': 754, 'max_depth': 9, 'colsample_bytree': 0.6892179807353742}. Best is trial 40 with value: 0.04393770337097472.
# [I 2023-10-29 15:14:22,051] Trial 46 finished with value: 0.043896654144140665 and parameters: {'learning_rate': 0.009404675794756939, 'n_estimators': 723, 'max_depth': 9, 'colsample_bytree': 0.37417247716189267}. Best is trial 46 with value: 0.043896654144140665.
# [I 2023-10-29 15:14:38,260] Trial 47 finished with value: 0.04387545502358951 and parameters: {'learning_rate': 0.009942930918014781, 'n_estimators': 748, 'max_depth': 9, 'colsample_bytree': 0.37000028004607477}. Best is trial 47 with value: 0.04387545502358951.
# [I 2023-10-29 15:14:54,370] Trial 48 finished with value: 0.04387484820793768 and parameters: {'learning_rate': 0.010173804776066291, 'n_estimators': 736, 'max_depth': 9, 'colsample_bytree': 0.36245941037419044}. Best is trial 48 with value: 0.04387484820793768.
# [I 2023-10-29 15:18:26,670] Trial 49 finished with value: 0.043946880161788895 and parameters: {'learning_rate': 0.00839171034677626, 'n_estimators': 720, 'max_depth': 9, 'colsample_bytree': 0.3747520651611558}. Best is trial 48 with value: 0.04387484820793768.
# [I 2023-10-29 15:19:36,872] Trial 50 finished with value: 0.043866681464112725 and parameters: {'learning_rate': 0.009026841762096033, 'n_estimators': 751, 'max_depth': 9, 'colsample_bytree': 0.557778406022136}. Best is trial 50 with value: 0.043866681464112725.
# [I 2023-10-29 15:20:13,793] Trial 51 finished with value: 0.04395147577118248 and parameters: {'learning_rate': 0.009331575901684524, 'n_estimators': 733, 'max_depth': 9, 'colsample_bytree': 0.7030017486288759}. Best is trial 50 with value: 0.043866681464112725.
# [I 2023-10-29 15:20:34,088] Trial 52 finished with value: 0.04457480881805636 and parameters: {'learning_rate': 0.005847320379649822, 'n_estimators': 747, 'max_depth': 9, 'colsample_bytree': 0.6917397108782168}. Best is trial 50 with value: 0.043866681464112725.
# [I 2023-10-29 15:21:34,993] Trial 53 finished with value: 0.044680838556572074 and parameters: {'learning_rate': 0.0057257114835129914, 'n_estimators': 737, 'max_depth': 9, 'colsample_bytree': 0.7015719085636997}. Best is trial 50 with value: 0.043866681464112725.
# [I 2023-10-29 15:22:10,071] Trial 55 finished with value: 0.0444872581557179 and parameters: {'learning_rate': 0.00566344543601362, 'n_estimators': 869, 'max_depth': 8, 'colsample_bytree': 0.28993321769215064}. Best is trial 50 with value: 0.043866681464112725.
# [I 2023-10-29 15:22:46,086] Trial 54 finished with value: 0.0445881537662175 and parameters: {'learning_rate': 0.005249587201257182, 'n_estimators': 857, 'max_depth': 9, 'colsample_bytree': 0.779695287257155}. Best is trial 50 with value: 0.043866681464112725.
# [I 2023-10-29 15:24:38,053] Trial 56 finished with value: 0.044308353800380104 and parameters: {'learning_rate': 0.00586693480846636, 'n_estimators': 895, 'max_depth': 8, 'colsample_bytree': 0.28781483203374697}. Best is trial 50 with value: 0.043866681464112725.
# [I 2023-10-29 15:25:14,246] Trial 57 finished with value: 0.044035639118889865 and parameters: {'learning_rate': 0.007047590060559238, 'n_estimators': 878, 'max_depth': 8, 'colsample_bytree': 0.2983439261671673}. Best is trial 50 with value: 0.043866681464112725.
# [I 2023-10-29 15:25:32,779] Trial 59 finished with value: 0.0448789736935824 and parameters: {'learning_rate': 0.005114951681824785, 'n_estimators': 840, 'max_depth': 8, 'colsample_bytree': 0.3016569538692495}. Best is trial 50 with value: 0.043866681464112725.
# [I 2023-10-29 15:25:35,691] Trial 58 finished with value: 0.044185321074848974 and parameters: {'learning_rate': 0.0063395258616804565, 'n_estimators': 901, 'max_depth': 8, 'colsample_bytree': 0.2884119477589285}. Best is trial 50 with value: 0.043866681464112725.
# [I 2023-10-29 15:25:41,112] Trial 7 finished with value: 0.04530565522157939 and parameters: {'learning_rate': 0.0036015872297307664, 'n_estimators': 1366, 'max_depth': 15, 'colsample_bytree': 0.7493740613202933}. Best is trial 50 with value: 0.043866681464112725.

# %%
best_params = study.best_params
print('Best parameters:', best_params)

#Best parameters: {'iterations': 854, 'learning_rate': 0.017432099489773544, 'depth': 14, 'colsample_bylevel': 0.43559465187532453, 'min_data_in_leaf': 257, 'l2_leaf_reg': 9.179321889625692, 'border_count': 129, 'random_strength': 0.8781261706316226, 'bagging_temperature': 11.599929150721326, 'grow_policy': 'Lossguide', 'max_leaves': 192}
# Out:
# Best parameters: {'learning_rate': 0.009026841762096033, 'n_estimators': 751, 'max_depth': 9, 'colsample_bytree': 0.557778406022136}

# %% [markdown]
# ### Now visualising the predictions
#
# This is done by using the validation sets from cross validation. We have used Timeseries cross validation with a test size of three months (that which we are trying to predict in our test sets).

# %%
model = XGBRegressor(**best_params, enable_categorical=True)

# %%
model.fit(X_train, y_train, verbose=0)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.557778406022136, device=None,
#              early_stopping_rounds=None, enable_categorical=True,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.009026841762096033, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=9, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=751, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
pred_local = model.predict(X_test_local)

# %%
from sklearn.metrics import mean_squared_error
test_score = mean_squared_error(y_test_local, pred_local)
print("Test Score:", test_score)
# Out:
# Test Score: 0.004519007309189388

# %%
residuals = y_test_local - pred_local

# %%
color_pal = sns.color_palette()

# %%
# RESIDUALS
plt.figure(figsize=(10, 6))
plt.scatter(pred_local, residuals, color=color_pal[2])
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs. Predicted Values')
plt.show()

# PRED vs. ACTUAL
plt.scatter(y_test_local, pred_local, color=color_pal[5])
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs. Actual Values')
plt.plot([min(y_test_local), max(y_test_local)], [min(y_test_local), max(y_test_local)], color=color_pal[2], linestyle='--', label='Perfect Predictions')
plt.legend()

# %% [markdown]
# # THE MAIN FIGURE TO WORRY ABOUT
#
# ### Residual = Actual - Pred

# %%
print("The average residuals:")
print(np.mean(residuals))
# Out:
# The average residuals:
# -0.002569126326148723

# %%
model.fit(X, y)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.557778406022136, device=None,
#              early_stopping_rounds=None, enable_categorical=True,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.009026841762096033, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=9, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=751, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ### Predict and make csv

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
X_test_kaggle['location'] = le.fit_transform(X_test_kaggle['location'])

# %%
predictions = model.predict(X_test_kaggle)

# %%
predictions = pd.DataFrame(predictions, columns=['prediction'])

predictions.reset_index(drop=True, inplace=True)

predictions.head()
# Out:
#    prediction
# 0    0.000254
# 1    0.000327
# 2    0.000318
# 3    0.011110
# 4    0.061982

# %%
loc_a = predictions.iloc[:len(predictions)//3]
loc_b = predictions.iloc[len(predictions)//3:2*len(predictions)//3]
loc_c = predictions.iloc[2*len(predictions)//3:]

# %%
n = len(predictions)

# De-normalizing

loc_a.loc[:, 'prediction'] = scaler_a.inverse_transform(loc_a['prediction'].values.reshape(-1, 1))
loc_b.loc[:, 'prediction'] = scaler_b.inverse_transform(loc_b['prediction'].values.reshape(-1, 1))
loc_c.loc[:, 'prediction'] = scaler_c.inverse_transform(loc_c['prediction'].values.reshape(-1, 1))

# %%
predictions = pd.concat([loc_a, loc_b, loc_c])

# %%
predictions.head(10)
# Out:
#     prediction
# 0     1.456085
# 1     1.872980
# 2     1.822709
# 3    63.697384
# 4   355.371368
# 5   722.062683
# 6  1660.092773
# 7  2800.284668
# 8  2781.822998
# 9  2648.345459

# %%
predictions.reset_index(inplace=True)
predictions.rename(columns={'index': 'id'}, inplace=True)
predictions.to_csv('predictions.csv', index=False)

# %% [markdown]
# Remove negative values

# %%
predictions.loc[predictions['prediction'] < 0, 'prediction'] = 0
predictions.to_csv('predictions.csv', index=False)

# %% [markdown]
# Redifing the training sets

# %%
train_a = pd.read_parquet('../../A/train_targets.parquet')
train_b = pd.read_parquet('../../B/train_targets.parquet')
train_c = pd.read_parquet('../../C/train_targets.parquet')

train_a.set_index('time', inplace=True)
train_b.set_index('time', inplace=True)
train_c.set_index('time', inplace=True)

# %% [markdown]
# ### Plotting A

# %%
loc_a.set_index(valid_dates, inplace=True)

plt.figure(figsize=(9, 4))

loc_a['prediction'].plot(style='.', label='Prediction')
train_a['pv_measurement'].plot(style='.', label='Actual', color='red', linewidth=2)

plt.legend(loc='upper left')
plt.title('Predictions vs. Actual A')
plt.xlabel('Time')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plotting B

# %%
loc_b.set_index(valid_dates, inplace=True)

plt.figure(figsize=(9, 4))

loc_b['prediction'].plot(style='.', label='Prediction')
train_b['pv_measurement'].plot(style='.', label='Actual', color='red', linewidth=2)

plt.legend(loc='upper left')
plt.title('Predictions vs. Actual B')
plt.xlabel('Time')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
loc_c.set_index(valid_dates, inplace=True)

plt.figure(figsize=(9, 4))

loc_c['prediction'].plot(style='.', label='Prediction')
train_c['pv_measurement'].plot(style='.', label='Actual', color='red', linewidth=2)

plt.legend(loc='upper left')
plt.title('Predictions vs. Actual C')
plt.xlabel('Time')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()
