# %% [markdown]
# # XGBoost with trig tranformations on time feature
#
# - The y-set for location A, B and C are concatonated (time index)
# - The X-set for location A, B and C are concatonated (time index)
# - One hot encoding for location and whether or not set is from the estimated column
# - The y-set and the X-set are merged on date and location
# - Having date features
# - y-sets are normalized (MinMax)
# - Removes repeated values in y-set B and C
#
# It takes over from feature_engineering_1
# Adds some ratio features from feature_engineering_3
#
# **Takes over from cat_boost_clean_1.ipynb**

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import math
import csv
import seaborn as sns
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
train_a = pd.read_parquet('../../A/train_targets.parquet')
train_b = pd.read_parquet('../../B/train_targets.parquet')
train_c = pd.read_parquet('../../C/train_targets.parquet')

X_train_estimated_a = pd.read_parquet('../../A/X_train_estimated.parquet')
X_train_estimated_b = pd.read_parquet('../../B/X_train_estimated.parquet')
X_train_estimated_c = pd.read_parquet('../../C/X_train_estimated.parquet')

X_train_observed_a = pd.read_parquet('../../A/X_train_observed.parquet')
X_train_observed_b = pd.read_parquet('../../B/X_train_observed.parquet')
X_train_observed_c = pd.read_parquet('../../C/X_train_observed.parquet')

X_test_estimated_a = pd.read_parquet('../../A/X_test_estimated.parquet')
X_test_estimated_b = pd.read_parquet('../../B/X_test_estimated.parquet')
X_test_estimated_c = pd.read_parquet('../../C/X_test_estimated.parquet')

# %% [markdown]
# ## Handling the Y-set

# %%
def find_repeated_rows(df):
    '''
    Returns all indicies (from, to) which have the largest intervals of being constant. The output is sorted from 
    largest to smallest.
    '''
    df = df.reset_index()
    repeated_temp = []
    intervals = []

    first = True

    for index, row in df.iterrows():
        if index == 0:
            continue
        if row['pv_measurement'] == df.iloc[index - 1]['pv_measurement']:
            repeated_temp.append(index)
            if first: 
                repeated_temp.insert(0, index - 1)
                first = False
        else:
            if len(repeated_temp) > 1:
                intervals.append((repeated_temp[0], repeated_temp[-1]))
            repeated_temp = []
            first = True
            
    threshold = 6

    return sorted([t for t in intervals if t[1] - t[0] >= threshold], key=lambda t: t[1] - t[0], reverse=True)

# %%
all_y = [train_a, train_b, train_c]
labels = ['A', 'B', 'C']

table = {}

i = 0
for y in all_y:
    loc, intervals = labels[i], find_repeated_rows(y)
    if isinstance(intervals[0], (int, float)):
        intervals = np.asarray(intervals, dtype=float)
    intervals = list(intervals) + [np.nan] * (1421 - len(intervals))
    table[loc] = intervals
    print("The largest interval for", loc, intervals[0])
    i += 1

table = pd.DataFrame(table)
table.head()
# Out:
# The largest interval for A (5176, 5218)
# The largest interval for B (13409, 14466)
# The largest interval for C (18105, 18727)
#                 A               B               C
# 0    (5176, 5218)  (13409, 14466)  (18105, 18727)
# 1    (4526, 4547)  (19138, 20141)  (26048, 26669)
# 2  (22429, 22450)  (18690, 19137)  (27224, 27748)
# 3  (22933, 22954)  (10966, 11307)  (25400, 25876)
# 4        (67, 87)  (26115, 26353)  (10047, 10375)

# %%
i = 1
for y in all_y[1:]:
    loc, intervals = labels[i], find_repeated_rows(y)
    for start, end in intervals:
        for row_index in range(start, end + 1):
            y.at[row_index, 'pv_measurement'] = np.nan

    test = y.set_index('time')
    test['pv_measurement'].plot(title="PV measurments when removing all constant intervals in " + loc)
    plt.show()
    i += 1

# %%
train_a.set_index('time', inplace=True)
train_b.set_index('time', inplace=True)
train_c.set_index('time', inplace=True)

# %% [markdown]
# Normalizing values

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_a = MinMaxScaler()
scaler_b = MinMaxScaler()
scaler_c = MinMaxScaler()

# %%
train_a['pv_measurement'] = scaler_a.fit_transform(train_a[['pv_measurement']])
train_b['pv_measurement'] = scaler_b.fit_transform(train_b[['pv_measurement']])
train_c['pv_measurement'] = scaler_c.fit_transform(train_c[['pv_measurement']])

# %%
train_a['location'] = 'A'
train_b['location'] = 'B'
train_c['location'] = 'C'

# %%
y = pd.concat([train_a, train_b, train_c])
y.index.name = 'time'

y.shape
y.head()
# Out:
#                      pv_measurement location
# time
# 2019-06-02 22:00:00        0.000000        A
# 2019-06-02 23:00:00        0.000000        A
# 2019-06-03 00:00:00        0.000000        A
# 2019-06-03 01:00:00        0.000000        A
# 2019-06-03 02:00:00        0.003377        A

# %% [markdown]
# Setting the index to **date_forecast** and resampling with median.

# %%
X_train_observed_a['date_forecast'] = pd.to_datetime(X_train_observed_a['date_forecast'])
X_train_observed_a.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_observed_a:
    X_train_observed_a.drop("date_calc", axis=1, inplace=True)
X_train_observed_a = X_train_observed_a.resample('60min').median()


X_train_estimated_a['date_forecast'] = pd.to_datetime(X_train_estimated_a['date_forecast'])
X_train_estimated_a.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_estimated_a:
    X_train_estimated_a.drop("date_calc", axis=1, inplace=True)
X_train_estimated_a = X_train_estimated_a.resample('60min').median()


X_train_observed_b['date_forecast'] = pd.to_datetime(X_train_observed_b['date_forecast'])
X_train_observed_b.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_observed_b:
    X_train_observed_b.drop("date_calc", axis=1, inplace=True)
X_train_observed_b = X_train_observed_b.resample('60min').median()


X_train_estimated_b['date_forecast'] = pd.to_datetime(X_train_estimated_b['date_forecast'])
X_train_estimated_b.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_estimated_b:
    X_train_estimated_b.drop("date_calc", axis=1, inplace=True)
X_train_estimated_b = X_train_estimated_b.resample('60min').median()


X_train_observed_c['date_forecast'] = pd.to_datetime(X_train_observed_c['date_forecast'])
X_train_observed_c.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_observed_c:
    X_train_observed_c.drop("date_calc", axis=1, inplace=True)
X_train_observed_c = X_train_observed_c.resample('60min').median()


X_train_estimated_c['date_forecast'] = pd.to_datetime(X_train_estimated_c['date_forecast'])
X_train_estimated_c.set_index('date_forecast', inplace=True)
if "date_calc" in X_train_estimated_c:
    X_train_estimated_c.drop("date_calc", axis=1, inplace=True)
X_train_estimated_c = X_train_estimated_c.resample('60min').median()

# %%
def replace_outliers_with_nan(df, feature):
    '''Replaces thr 0.01 and 0.99'''
    Q1 = df[feature].quantile(0.01)
    Q99 = df[feature].quantile(0.99)

    df[feature] = np.where(
        (df[feature] < Q1) | (df[feature] > Q99),
        np.nan,
        df[feature]
    )

# %% [markdown]
# ### Removing 'outlier' features as this gave us 0.1 better score on Kaggle

# %%
outliers = ['air_density_2m:kgm3', 'msl_pressure:hPa', 'sfc_pressure:hPa']


for o in outliers:
    replace_outliers_with_nan(X_train_observed_a, o)
    replace_outliers_with_nan(X_train_observed_b, o)
    replace_outliers_with_nan(X_train_observed_c, o)

# %%
X_train_observed_a['location'], X_train_estimated_a['location'] = 'A', 'A'
X_train_observed_b['location'], X_train_estimated_b['location']= 'B', 'B'
X_train_observed_c['location'], X_train_estimated_c['location']= 'C', 'C'

X_train_observed_a['estimated'], X_train_estimated_a['estimated'] = 0, 1
X_train_observed_b['estimated'], X_train_estimated_b['estimated'] = 0, 1
X_train_observed_c['estimated'], X_train_estimated_c['estimated'] = 0, 1

# %%
X = pd.concat([X_train_observed_a, X_train_estimated_a, X_train_observed_b,
               X_train_estimated_b, X_train_observed_c, X_train_estimated_c
               ], ignore_index=False)
X = X.sort_index()

# %%
df = pd.merge(y, X, left_on=[y.index, 'location'],
              right_on=[X.index, 'location'])

df.set_index('key_0', inplace=True)
df.index.name = "time"
df = df.sort_index()

df.head()
# Out:
#                      pv_measurement location  absolute_humidity_2m:gm3  \
# time
# 2019-01-01 00:00:00             NaN        B                      5.55
# 2019-01-01 00:00:00             NaN        C                      5.45
# 2019-01-01 01:00:00             NaN        C                      5.35
# 2019-01-01 01:00:00             NaN        B                      5.40
# 2019-01-01 02:00:00             NaN        B                      5.40
#
#                      air_density_2m:kgm3  ceiling_height_agl:m  \
# time
# 2019-01-01 00:00:00               1.2395           1200.700012
# 2019-01-01 00:00:00               1.2410           1130.049988
# 2019-01-01 01:00:00               1.2400           1066.699951
# 2019-01-01 01:00:00               1.2395           1131.449951
# 2019-01-01 02:00:00               1.2385           1061.049988
#
#                      clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  \
# time
# 2019-01-01 00:00:00                    0.0              0.0       1200.700012
# 2019-01-01 00:00:00                    0.0              0.0       1130.049988
# 2019-01-01 01:00:00                    0.0              0.0       1066.699951
# 2019-01-01 01:00:00                    0.0              0.0       1131.449951
# 2019-01-01 02:00:00                    0.0              0.0       1061.049988
#
#                      dew_or_rime:idx  dew_point_2m:K  ...  sun_elevation:d  \
# time                                                  ...
# 2019-01-01 00:00:00              0.0      275.150009  ...       -48.389500
# 2019-01-01 00:00:00              1.0      275.000000  ...       -48.426498
# 2019-01-01 01:00:00              1.0      274.650009  ...       -45.002501
# 2019-01-01 01:00:00              0.0      274.849991  ...       -44.971498
# 2019-01-01 02:00:00              0.0      274.800003  ...       -39.896000
#
#                      super_cooled_liquid_water:kgm2  t_1000hPa:K  \
# time
# 2019-01-01 00:00:00                             0.0   278.250000
# 2019-01-01 00:00:00                             0.0   278.349991
# 2019-01-01 01:00:00                             0.0   278.200012
# 2019-01-01 01:00:00                             0.0   278.100006
# 2019-01-01 02:00:00                             0.1   278.050003
#
#                      total_cloud_cover:p  visibility:m  wind_speed_10m:ms  \
# time
# 2019-01-01 00:00:00            87.500000  16823.399902               2.80
# 2019-01-01 00:00:00            85.350002  16512.299805               2.90
# 2019-01-01 01:00:00            99.099998  13277.399902               3.65
# 2019-01-01 01:00:00            99.099998  12777.449707               3.55
# 2019-01-01 02:00:00            97.849998  11142.549805               4.05
#
#                      wind_speed_u_10m:ms  wind_speed_v_10m:ms  \
# time
# 2019-01-01 00:00:00                 1.20                 2.55
# 2019-01-01 00:00:00                 1.10                 2.65
# 2019-01-01 01:00:00                 1.40                 3.35
# 2019-01-01 01:00:00                 1.50                 3.20
# 2019-01-01 02:00:00                 2.15                 3.45
#
#                      wind_speed_w_1000hPa:ms  estimated
# time
# 2019-01-01 00:00:00                     -0.0          0
# 2019-01-01 00:00:00                     -0.0          0
# 2019-01-01 01:00:00                     -0.0          0
# 2019-01-01 01:00:00                     -0.0          0
# 2019-01-01 02:00:00                     -0.0          0
#
# [5 rows x 48 columns]

# %%
def create_features(df):
    """
    Create Features
    """
    
    df = df.copy()
    df['month_sin'] = np.sin(2 * np.pi * df.index.month / 12)
    df['month_cos'] = np.cos(2 * np.pi * df.index.month / 12)
    df['hour_sin'] = np.sin(2 * np.pi * df.index.hour / 23)
    df['hour_cos'] = np.cos(2 * np.pi * df.index.hour / 23)

    return df

def get_season(month):
    if 3 <= month <= 5:
        return 0  # spring
    elif 6 <= month <= 8:
        return 1  # summer
    elif 9 <= month <= 11:
        return 2  # fall
    else:
        return 3  # winter

df = create_features(df)

df.head()
# Out:
#                      pv_measurement location  absolute_humidity_2m:gm3  \
# time
# 2019-01-01 00:00:00             NaN        B                      5.55
# 2019-01-01 00:00:00             NaN        C                      5.45
# 2019-01-01 01:00:00             NaN        C                      5.35
# 2019-01-01 01:00:00             NaN        B                      5.40
# 2019-01-01 02:00:00             NaN        B                      5.40
#
#                      air_density_2m:kgm3  ceiling_height_agl:m  \
# time
# 2019-01-01 00:00:00               1.2395           1200.700012
# 2019-01-01 00:00:00               1.2410           1130.049988
# 2019-01-01 01:00:00               1.2400           1066.699951
# 2019-01-01 01:00:00               1.2395           1131.449951
# 2019-01-01 02:00:00               1.2385           1061.049988
#
#                      clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  \
# time
# 2019-01-01 00:00:00                    0.0              0.0       1200.700012
# 2019-01-01 00:00:00                    0.0              0.0       1130.049988
# 2019-01-01 01:00:00                    0.0              0.0       1066.699951
# 2019-01-01 01:00:00                    0.0              0.0       1131.449951
# 2019-01-01 02:00:00                    0.0              0.0       1061.049988
#
#                      dew_or_rime:idx  dew_point_2m:K  ...  visibility:m  \
# time                                                  ...
# 2019-01-01 00:00:00              0.0      275.150009  ...  16823.399902
# 2019-01-01 00:00:00              1.0      275.000000  ...  16512.299805
# 2019-01-01 01:00:00              1.0      274.650009  ...  13277.399902
# 2019-01-01 01:00:00              0.0      274.849991  ...  12777.449707
# 2019-01-01 02:00:00              0.0      274.800003  ...  11142.549805
#
#                      wind_speed_10m:ms  wind_speed_u_10m:ms  \
# time
# 2019-01-01 00:00:00               2.80                 1.20
# 2019-01-01 00:00:00               2.90                 1.10
# 2019-01-01 01:00:00               3.65                 1.40
# 2019-01-01 01:00:00               3.55                 1.50
# 2019-01-01 02:00:00               4.05                 2.15
#
#                      wind_speed_v_10m:ms  wind_speed_w_1000hPa:ms  estimated  \
# time
# 2019-01-01 00:00:00                 2.55                     -0.0          0
# 2019-01-01 00:00:00                 2.65                     -0.0          0
# 2019-01-01 01:00:00                 3.35                     -0.0          0
# 2019-01-01 01:00:00                 3.20                     -0.0          0
# 2019-01-01 02:00:00                 3.45                     -0.0          0
#
#                      month_sin  month_cos  hour_sin  hour_cos
# time
# 2019-01-01 00:00:00        0.5   0.866025  0.000000  1.000000
# 2019-01-01 00:00:00        0.5   0.866025  0.000000  1.000000
# 2019-01-01 01:00:00        0.5   0.866025  0.269797  0.962917
# 2019-01-01 01:00:00        0.5   0.866025  0.269797  0.962917
# 2019-01-01 02:00:00        0.5   0.866025  0.519584  0.854419
#
# [5 rows x 52 columns]

# %% [markdown]
# ### Selecting features
#
# Everything except:
#
# - snow_density:kgm3
# - cloud_base_agl:m
# - ceiling_height_agl:m
#
# They have a lot of NaN values.

# %%
FEATURES = [
    'absolute_humidity_2m:gm3', 'air_density_2m:kgm3',
    'clear_sky_energy_1h:J', 'clear_sky_rad:W',
    'dew_or_rime:idx', 'dew_point_2m:K',
    'diffuse_rad:W', 'diffuse_rad_1h:J', 'direct_rad:W', 'direct_rad_1h:J',
    'effective_cloud_cover:p', 'elevation:m', 'fresh_snow_12h:cm',
    'fresh_snow_1h:cm', 'fresh_snow_24h:cm', 'fresh_snow_3h:cm',
    'fresh_snow_6h:cm', 'is_day:idx', 'is_in_shadow:idx',
    'msl_pressure:hPa', 'precip_5min:mm', 'precip_type_5min:idx',
    'pressure_100m:hPa', 'pressure_50m:hPa', 'prob_rime:p',
    'rain_water:kgm2', 'relative_humidity_1000hPa:p', 'sfc_pressure:hPa',
    'snow_depth:cm', 'snow_drift:idx',
    'snow_melt_10min:mm', 'snow_water:kgm2', 'sun_azimuth:d',
    'sun_elevation:d', 'super_cooled_liquid_water:kgm2', 't_1000hPa:K',
    'total_cloud_cover:p', 'visibility:m', 'wind_speed_10m:ms',
    'wind_speed_u_10m:ms', 'wind_speed_v_10m:ms', 'wind_speed_w_1000hPa:ms',
    'month_sin', 'month_cos', 'hour_sin', 'hour_cos',
    'location'
]

TARGET = 'pv_measurement'

# %%
relevant = FEATURES.copy()
relevant.append(TARGET)

df = df[relevant]

# %%
print(df.isna().sum())
before = df.shape

train = df.dropna()
print(train.isna().sum())
after = train.shape

dif = before[0] - after[0]

df = df.dropna()
print("DROPNA RESULTED IN", dif, "ROWS BEING DROPPED. THE DATASET HAS", after[0], "ROWS IN TOTAL.")
# Out:
# absolute_humidity_2m:gm3             72
# air_density_2m:kgm3                1824
# clear_sky_energy_1h:J                72
# clear_sky_rad:W                      72
# dew_or_rime:idx                      72
# dew_point_2m:K                       72
# diffuse_rad:W                        72
# diffuse_rad_1h:J                     72
# direct_rad:W                         72
# direct_rad_1h:J                      72
# effective_cloud_cover:p              72
# elevation:m                          72
# fresh_snow_12h:cm                    72
# fresh_snow_1h:cm                     72
# fresh_snow_24h:cm                    72
# fresh_snow_3h:cm                     72
# fresh_snow_6h:cm                     72
# is_day:idx                           72
# is_in_shadow:idx                     72
# msl_pressure:hPa                   1832
# precip_5min:mm                       72
# precip_type_5min:idx                 72
# pressure_100m:hPa                    72
# pressure_50m:hPa                     72
# prob_rime:p                          72
# rain_water:kgm2                      72
# relative_humidity_1000hPa:p          72
# sfc_pressure:hPa                   1829
# snow_depth:cm                        72
# snow_drift:idx                       72
# snow_melt_10min:mm                   72
# snow_water:kgm2                      72
# sun_azimuth:d                        72
# sun_elevation:d                      72
# super_cooled_liquid_water:kgm2       72
# t_1000hPa:K                          72
# total_cloud_cover:p                  72
# visibility:m                         72
# wind_speed_10m:ms                    72
# wind_speed_u_10m:ms                  72
# wind_speed_v_10m:ms                  72
# wind_speed_w_1000hPa:ms              72
# month_sin                             0
# month_cos                             0
# hour_sin                              0
# hour_cos                              0
# location                              0
# pv_measurement                    40896
# dtype: int64
# absolute_humidity_2m:gm3          0
# air_density_2m:kgm3               0
# clear_sky_energy_1h:J             0
# clear_sky_rad:W                   0
# dew_or_rime:idx                   0
# dew_point_2m:K                    0
# diffuse_rad:W                     0
# diffuse_rad_1h:J                  0
# direct_rad:W                      0
# direct_rad_1h:J                   0
# effective_cloud_cover:p           0
# elevation:m                       0
# fresh_snow_12h:cm                 0
# fresh_snow_1h:cm                  0
# fresh_snow_24h:cm                 0
# fresh_snow_3h:cm                  0
# fresh_snow_6h:cm                  0
# is_day:idx                        0
# is_in_shadow:idx                  0
# msl_pressure:hPa                  0
# precip_5min:mm                    0
# precip_type_5min:idx              0
# pressure_100m:hPa                 0
# pressure_50m:hPa                  0
# prob_rime:p                       0
# rain_water:kgm2                   0
# relative_humidity_1000hPa:p       0
# sfc_pressure:hPa                  0
# snow_depth:cm                     0
# snow_drift:idx                    0
# snow_melt_10min:mm                0
# snow_water:kgm2                   0
# sun_azimuth:d                     0
# sun_elevation:d                   0
# super_cooled_liquid_water:kgm2    0
# t_1000hPa:K                       0
# total_cloud_cover:p               0
# visibility:m                      0
# wind_speed_10m:ms                 0
# wind_speed_u_10m:ms               0
# wind_speed_v_10m:ms               0
# wind_speed_w_1000hPa:ms           0
# month_sin                         0
# month_cos                         0
# hour_sin                          0
# hour_cos                          0
# location                          0
# pv_measurement                    0
# dtype: int64
# DROPNA RESULTED IN 42788 ROWS BEING DROPPED. THE DATASET HAS 56298 ROWS IN TOTAL.

# %%
color_pal = sns.color_palette()

df["pv_measurement"].plot(style='.',
        figsize=(15, 5),
        color=color_pal[1],
        title='PV measurment against time')
plt.show()

# %% [markdown]
# ### Preparing test data
#
# - Excluding dates that should not be tested
# - Including only the features we have defined

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

def prepare_test_data(x, location):
    x_test = x.copy()
    x_test.set_index('date_forecast', inplace = True)
    x_test.drop('date_calc', axis=1, inplace = True)
    x_test['estimated'] = 1

    x_test = x_test.resample('60min').median()

    x_test = create_features(x_test)

    x_test['location'] = location

    return x_test

# %%
x_test_a = prepare_test_data(X_test_estimated_a, 'A')
x_test_b = prepare_test_data(X_test_estimated_b, 'B')
x_test_c = prepare_test_data(X_test_estimated_c, 'C')

# %%
test_sub = pd.read_csv('../../test.csv')
valid_dates = pd.to_datetime(test_sub['time'].unique())

# %%
x_test_a = x_test_a.loc[valid_dates]
x_test_b = x_test_b.loc[valid_dates]
x_test_c = x_test_c.loc[valid_dates]

# %%
X_test = pd.concat([x_test_a, x_test_b, x_test_c])
X_test = X_test[FEATURES]

# %%
X_test_kaggle = X_test

# %% [markdown]
# ### Disability Check
#
# Check if the training data and the test data contains the same columns.

# %%
check_df = df.copy()
check_train = check_df[FEATURES]
if X_test.columns.equals(check_train.columns):
    print("EQUAL")
else:
    print("NOT EQUAL")
    print("DIFFERENCE\n", X_test.columns.difference(check_train.columns))
# Out:
# EQUAL

# %% [markdown]
# Check if test data has the right amount of rows.

# %%
if X_test.shape[0] != 2160:
    print("X_test has wrong amount of rows!")
    print("Shape =", X_test.shape[0])
else:
    print("GOOD")
# Out:
# GOOD

# %%
X, y = df[FEATURES], df[TARGET]

# %%
X['location'] = X['location'].astype('category')
# Out:
# /var/folders/s2/v6q39rgs1xs8ww30dn78jkb00000gn/T/ipykernel_6403/1794122678.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['location'] = X['location'].astype('category')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test_local, y_train, y_test_local = train_test_split(X, y, test_size=0.15, random_state=42)

# %% [markdown]
# ### Define parameters you want to tune
#
# NOTE we have gotten issues by tuning too many paramters. Be carefull!

# %%
import optuna
import xgboost as xg
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import KFold
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)


def objective(trial):
    param = {
        "eval_metric": 'mae',  
        "learning_rate": trial.suggest_float("learning_rate", 1e-4, 0.3, log=True),
        "n_estimators": trial.suggest_int("n_estimators", 50, 1500),
        "max_depth": trial.suggest_int("max_depth", 1, 15),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.1, 1.0),
        'enable_categorical':True
    }

    cv = KFold(n_splits=5)

    model = XGBRegressor(**param)

    maes = []

    for train_index, val_index in cv.split(X_train):
        train_x, val_x = X_train.iloc[train_index], X_train.iloc[val_index]
        train_y , val_y = y_train.iloc[train_index], y_train.iloc[val_index]

        model.fit(train_x, train_y, verbose=0)
        y_pred = model.predict(val_x)
        mae = mean_absolute_error(val_y, y_pred)
        maes.append(mae)
        
    avg_mae = np.mean(maes)

    return avg_mae

# %%
xg.__version__
# Out:
# '2.0.0'

# %% [markdown]
# ### Specify number of trials
#
# A higher number of trials tries out more parameters

# %%
trials = 60

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=trials, n_jobs=-1, show_progress_bar=True)
# Out:
# [I 2023-10-28 23:34:01,322] A new study created in memory with name: no-name-1c6311c5-a1dd-441f-84a0-27faf0cbafcb
#   0%|          | 0/60 [00:00<?, ?it/s]
# [I 2023-10-28 23:34:28,558] Trial 3 finished with value: 0.11859464749481133 and parameters: {'learning_rate': 0.006617105398437119, 'n_estimators': 64, 'max_depth': 8, 'colsample_bytree': 0.1490978625814382}. Best is trial 3 with value: 0.11859464749481133.
# [I 2023-10-28 23:36:03,550] Trial 7 finished with value: 0.04018942761164117 and parameters: {'learning_rate': 0.2063032858410021, 'n_estimators': 805, 'max_depth': 3, 'colsample_bytree': 0.24293737874881377}. Best is trial 7 with value: 0.04018942761164117.
# [I 2023-10-28 23:38:03,674] Trial 2 finished with value: 0.03448439681432367 and parameters: {'learning_rate': 0.009449235940674192, 'n_estimators': 502, 'max_depth': 9, 'colsample_bytree': 0.863268807428833}. Best is trial 2 with value: 0.03448439681432367.
# [I 2023-10-28 23:39:00,037] Trial 5 finished with value: 0.04130533788424024 and parameters: {'learning_rate': 0.009086907602114105, 'n_estimators': 1370, 'max_depth': 4, 'colsample_bytree': 0.30426023098490196}. Best is trial 2 with value: 0.03448439681432367.
# [I 2023-10-28 23:39:06,047] Trial 0 finished with value: 0.05715726333155369 and parameters: {'learning_rate': 0.0013176513323084253, 'n_estimators': 1391, 'max_depth': 4, 'colsample_bytree': 0.8987549145982752}. Best is trial 2 with value: 0.03448439681432367.
# [I 2023-10-28 23:40:08,142] Trial 8 finished with value: 0.13203296414690918 and parameters: {'learning_rate': 0.00020743326788192238, 'n_estimators': 1039, 'max_depth': 6, 'colsample_bytree': 0.6848900953433132}. Best is trial 2 with value: 0.03448439681432367.
# [I 2023-10-28 23:40:38,681] Trial 11 finished with value: 0.04545499404899002 and parameters: {'learning_rate': 0.008640112657762562, 'n_estimators': 501, 'max_depth': 3, 'colsample_bytree': 0.7377227635233062}. Best is trial 2 with value: 0.03448439681432367.
# [I 2023-10-28 23:43:10,761] Trial 1 finished with value: 0.0304091352673982 and parameters: {'learning_rate': 0.041435738466590016, 'n_estimators': 1236, 'max_depth': 13, 'colsample_bytree': 0.6240018537307485}. Best is trial 1 with value: 0.0304091352673982.
# [I 2023-10-28 23:43:25,566] Trial 10 finished with value: 0.0471597058552621 and parameters: {'learning_rate': 0.002638997698273125, 'n_estimators': 916, 'max_depth': 6, 'colsample_bytree': 0.4769066691178949}. Best is trial 1 with value: 0.0304091352673982.
# [I 2023-10-28 23:43:32,974] Trial 6 finished with value: 0.031954370232635566 and parameters: {'learning_rate': 0.009253367367159303, 'n_estimators': 998, 'max_depth': 10, 'colsample_bytree': 0.996665730354302}. Best is trial 1 with value: 0.0304091352673982.
# [I 2023-10-28 23:43:33,816] Trial 15 finished with value: 0.11415135823011062 and parameters: {'learning_rate': 0.007300151624327894, 'n_estimators': 54, 'max_depth': 7, 'colsample_bytree': 0.8330524391629808}. Best is trial 1 with value: 0.0304091352673982.
# [I 2023-10-28 23:43:54,000] Trial 12 finished with value: 0.030958954500466984 and parameters: {'learning_rate': 0.19838907973734507, 'n_estimators': 784, 'max_depth': 10, 'colsample_bytree': 0.4361299897840215}. Best is trial 1 with value: 0.0304091352673982.
# [I 2023-10-28 23:44:51,090] Trial 9 finished with value: 0.1441205334579979 and parameters: {'learning_rate': 0.0002642811415102512, 'n_estimators': 407, 'max_depth': 14, 'colsample_bytree': 0.4577586460100439}. Best is trial 1 with value: 0.0304091352673982.
# [I 2023-10-28 23:45:05,026] Trial 14 finished with value: 0.03104037644707495 and parameters: {'learning_rate': 0.19902792959028232, 'n_estimators': 617, 'max_depth': 7, 'colsample_bytree': 0.9578229751892515}. Best is trial 1 with value: 0.0304091352673982.
# [I 2023-10-28 23:46:35,938] Trial 4 finished with value: 0.02946379745831832 and parameters: {'learning_rate': 0.02747988388231568, 'n_estimators': 1423, 'max_depth': 9, 'colsample_bytree': 0.717462356336225}. Best is trial 4 with value: 0.02946379745831832.
# [I 2023-10-28 23:47:37,236] Trial 16 finished with value: 0.031217936523771306 and parameters: {'learning_rate': 0.03716874639895956, 'n_estimators': 308, 'max_depth': 10, 'colsample_bytree': 0.6485386247152689}. Best is trial 4 with value: 0.02946379745831832.
# [I 2023-10-28 23:49:19,642] Trial 19 finished with value: 0.032264586198324154 and parameters: {'learning_rate': 0.17169840108454223, 'n_estimators': 1212, 'max_depth': 14, 'colsample_bytree': 0.508999954585742}. Best is trial 4 with value: 0.02946379745831832.
# [I 2023-10-28 23:51:07,037] Trial 20 finished with value: 0.03141512795749535 and parameters: {'learning_rate': 0.1555962984809294, 'n_estimators': 1192, 'max_depth': 13, 'colsample_bytree': 0.5827490309048213}. Best is trial 4 with value: 0.02946379745831832.
# [I 2023-10-28 23:51:33,068] Trial 17 finished with value: 0.031751330398731056 and parameters: {'learning_rate': 0.10010763864687426, 'n_estimators': 1216, 'max_depth': 15, 'colsample_bytree': 0.5049403390047453}. Best is trial 4 with value: 0.02946379745831832.
# [I 2023-10-28 23:54:46,118] Trial 18 finished with value: 0.03151498805834002 and parameters: {'learning_rate': 0.06298960729892991, 'n_estimators': 1133, 'max_depth': 14, 'colsample_bytree': 0.9445889063163745}. Best is trial 4 with value: 0.02946379745831832.
# [I 2023-10-28 23:56:39,622] Trial 21 finished with value: 0.030582215506227018 and parameters: {'learning_rate': 0.06651268170059814, 'n_estimators': 1183, 'max_depth': 13, 'colsample_bytree': 0.6025388462081861}. Best is trial 4 with value: 0.02946379745831832.
# [I 2023-10-29 00:02:51,669] Trial 22 finished with value: 0.03046745315661853 and parameters: {'learning_rate': 0.046107504184392835, 'n_estimators': 1198, 'max_depth': 13, 'colsample_bytree': 0.6402310799036687}. Best is trial 4 with value: 0.02946379745831832.
# [I 2023-10-29 00:03:43,094] Trial 13 finished with value: 0.032132862963104136 and parameters: {'learning_rate': 0.012391207384694184, 'n_estimators': 1394, 'max_depth': 11, 'colsample_bytree': 0.20020505872377803}. Best is trial 4 with value: 0.02946379745831832.
# [I 2023-10-29 00:07:00,341] Trial 23 finished with value: 0.0302709472803671 and parameters: {'learning_rate': 0.037282565563450984, 'n_estimators': 1192, 'max_depth': 13, 'colsample_bytree': 0.5931663853181914}. Best is trial 4 with value: 0.02946379745831832.
# [I 2023-10-29 00:07:12,566] Trial 24 finished with value: 0.030496120209724514 and parameters: {'learning_rate': 0.04401375117374781, 'n_estimators': 1481, 'max_depth': 13, 'colsample_bytree': 0.761418274427411}. Best is trial 4 with value: 0.02946379745831832.
# [I 2023-10-29 00:09:58,291] Trial 32 finished with value: 0.05039076797803348 and parameters: {'learning_rate': 0.020278671845227886, 'n_estimators': 1323, 'max_depth': 1, 'colsample_bytree': 0.7287879672047819}. Best is trial 4 with value: 0.02946379745831832.
# [I 2023-10-29 00:11:22,506] Trial 25 finished with value: 0.03049494179843142 and parameters: {'learning_rate': 0.03608102376821085, 'n_estimators': 1477, 'max_depth': 13, 'colsample_bytree': 0.7706202897468075}. Best is trial 4 with value: 0.02946379745831832.
# [I 2023-10-29 00:13:41,217] Trial 27 finished with value: 0.030005755562938895 and parameters: {'learning_rate': 0.044725025084294705, 'n_estimators': 1446, 'max_depth': 12, 'colsample_bytree': 0.7748598619719776}. Best is trial 4 with value: 0.02946379745831832.
# [I 2023-10-29 00:16:54,818] Trial 26 finished with value: 0.029889252901979253 and parameters: {'learning_rate': 0.03095176944835454, 'n_estimators': 1493, 'max_depth': 12, 'colsample_bytree': 0.761265044588887}. Best is trial 4 with value: 0.02946379745831832.
# [I 2023-10-29 00:20:12,884] Trial 28 finished with value: 0.029991570366385924 and parameters: {'learning_rate': 0.03166907320522333, 'n_estimators': 1466, 'max_depth': 12, 'colsample_bytree': 0.7824207811778673}. Best is trial 4 with value: 0.02946379745831832.
# [I 2023-10-29 00:27:02,337] Trial 34 finished with value: 0.029749456742375814 and parameters: {'learning_rate': 0.021590914430133237, 'n_estimators': 1038, 'max_depth': 11, 'colsample_bytree': 0.5844550899461294}. Best is trial 4 with value: 0.02946379745831832.
# [I 2023-10-29 00:28:15,513] Trial 29 finished with value: 0.0298641565460107 and parameters: {'learning_rate': 0.026453301713507127, 'n_estimators': 1495, 'max_depth': 12, 'colsample_bytree': 0.7436397109512946}. Best is trial 4 with value: 0.02946379745831832.
# [I 2023-10-29 00:28:46,381] Trial 35 finished with value: 0.030016146165343028 and parameters: {'learning_rate': 0.020059666466304322, 'n_estimators': 1007, 'max_depth': 11, 'colsample_bytree': 0.7861466659388013}. Best is trial 4 with value: 0.02946379745831832.
# [I 2023-10-29 00:29:32,121] Trial 30 finished with value: 0.029890567349914753 and parameters: {'learning_rate': 0.024060050399429437, 'n_estimators': 1448, 'max_depth': 12, 'colsample_bytree': 0.7457396072815968}. Best is trial 4 with value: 0.02946379745831832.
# [I 2023-10-29 00:31:27,255] Trial 33 finished with value: 0.02933017424520934 and parameters: {'learning_rate': 0.024973076814249425, 'n_estimators': 1485, 'max_depth': 11, 'colsample_bytree': 0.5677717157665053}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:31:40,080] Trial 31 finished with value: 0.02982901758792155 and parameters: {'learning_rate': 0.023965757495497567, 'n_estimators': 1472, 'max_depth': 12, 'colsample_bytree': 0.7401404335483786}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:34:48,194] Trial 36 finished with value: 0.029939324202675994 and parameters: {'learning_rate': 0.01668510202133912, 'n_estimators': 1331, 'max_depth': 11, 'colsample_bytree': 0.823775960078844}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:37:06,400] Trial 37 finished with value: 0.029831280452484364 and parameters: {'learning_rate': 0.018848817746478255, 'n_estimators': 1311, 'max_depth': 11, 'colsample_bytree': 0.8487184957553002}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:40:40,274] Trial 40 finished with value: 0.030446305334297052 and parameters: {'learning_rate': 0.016576479233091766, 'n_estimators': 1324, 'max_depth': 9, 'colsample_bytree': 0.6992858584679703}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:41:16,991] Trial 41 finished with value: 0.03056086758704891 and parameters: {'learning_rate': 0.015469845930868151, 'n_estimators': 1315, 'max_depth': 9, 'colsample_bytree': 0.6824445035722437}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:42:35,848] Trial 38 finished with value: 0.02992775338729962 and parameters: {'learning_rate': 0.016800784069489504, 'n_estimators': 1349, 'max_depth': 11, 'colsample_bytree': 0.8245574678174253}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:42:53,371] Trial 42 finished with value: 0.030503926537111075 and parameters: {'learning_rate': 0.015876143161134105, 'n_estimators': 1310, 'max_depth': 9, 'colsample_bytree': 0.6783496421948629}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:42:56,025] Trial 39 finished with value: 0.029899312952625313 and parameters: {'learning_rate': 0.01568087837432676, 'n_estimators': 1304, 'max_depth': 11, 'colsample_bytree': 0.7015329807327688}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:43:06,386] Trial 43 finished with value: 0.03088879452161636 and parameters: {'learning_rate': 0.013282641730405649, 'n_estimators': 1315, 'max_depth': 9, 'colsample_bytree': 0.6859580347146631}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:46:08,039] Trial 44 finished with value: 0.03363024723117688 and parameters: {'learning_rate': 0.004343040368046184, 'n_estimators': 1330, 'max_depth': 9, 'colsample_bytree': 0.6723765722012911}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:46:23,386] Trial 45 finished with value: 0.03418529631903387 and parameters: {'learning_rate': 0.004617891600583183, 'n_estimators': 1101, 'max_depth': 9, 'colsample_bytree': 0.5470972664423455}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:48:58,275] Trial 47 finished with value: 0.03534672843904282 and parameters: {'learning_rate': 0.004850634374433179, 'n_estimators': 1091, 'max_depth': 8, 'colsample_bytree': 0.5555011666686247}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:49:29,095] Trial 46 finished with value: 0.033685593991745984 and parameters: {'learning_rate': 0.005323201496293206, 'n_estimators': 1073, 'max_depth': 9, 'colsample_bytree': 0.6731053564308187}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:50:46,020] Trial 48 finished with value: 0.03507186021497029 and parameters: {'learning_rate': 0.0051872371493262605, 'n_estimators': 1102, 'max_depth': 8, 'colsample_bytree': 0.8688934387663014}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:50:55,297] Trial 50 finished with value: 0.03585226621615682 and parameters: {'learning_rate': 0.004410521968168691, 'n_estimators': 1073, 'max_depth': 8, 'colsample_bytree': 0.9134986879235566}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:51:07,605] Trial 51 finished with value: 0.034556518404356376 and parameters: {'learning_rate': 0.006400776168040636, 'n_estimators': 1082, 'max_depth': 8, 'colsample_bytree': 0.8798996276390637}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:51:13,096] Trial 49 finished with value: 0.03298857210791302 and parameters: {'learning_rate': 0.011352703710720675, 'n_estimators': 1127, 'max_depth': 8, 'colsample_bytree': 0.8685885863969319}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:53:22,416] Trial 53 finished with value: 0.033717653690249184 and parameters: {'learning_rate': 0.010778477254241066, 'n_estimators': 884, 'max_depth': 8, 'colsample_bytree': 0.8918933330302167}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:54:41,419] Trial 52 finished with value: 0.033312618407853836 and parameters: {'learning_rate': 0.01024411886430495, 'n_estimators': 1095, 'max_depth': 8, 'colsample_bytree': 0.8664560259719506}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:57:45,538] Trial 54 finished with value: 0.03187187218010923 and parameters: {'learning_rate': 0.00991818124627575, 'n_estimators': 890, 'max_depth': 10, 'colsample_bytree': 0.9008423691967701}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:57:59,392] Trial 55 finished with value: 0.031722875519521423 and parameters: {'learning_rate': 0.010625394864488968, 'n_estimators': 896, 'max_depth': 10, 'colsample_bytree': 0.9146370735951559}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:58:49,351] Trial 59 finished with value: 0.029790279151601116 and parameters: {'learning_rate': 0.025546872279464825, 'n_estimators': 920, 'max_depth': 10, 'colsample_bytree': 0.6138479397340837}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:58:50,238] Trial 57 finished with value: 0.03133696113163974 and parameters: {'learning_rate': 0.01095587305565639, 'n_estimators': 936, 'max_depth': 10, 'colsample_bytree': 0.6355532869326032}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:58:51,636] Trial 56 finished with value: 0.03185374809674984 and parameters: {'learning_rate': 0.008363094071307827, 'n_estimators': 954, 'max_depth': 10, 'colsample_bytree': 0.6283641718402253}. Best is trial 33 with value: 0.02933017424520934.
# [I 2023-10-29 00:59:25,318] Trial 58 finished with value: 0.029223000773293612 and parameters: {'learning_rate': 0.026677849047960514, 'n_estimators': 1407, 'max_depth': 10, 'colsample_bytree': 0.6216020606305356}. Best is trial 58 with value: 0.029223000773293612.

# %%
best_params = study.best_params
print('Best parameters:', best_params)

#Best parameters: {'iterations': 854, 'learning_rate': 0.017432099489773544, 'depth': 14, 'colsample_bylevel': 0.43559465187532453, 'min_data_in_leaf': 257, 'l2_leaf_reg': 9.179321889625692, 'border_count': 129, 'random_strength': 0.8781261706316226, 'bagging_temperature': 11.599929150721326, 'grow_policy': 'Lossguide', 'max_leaves': 192}
# Out:
# Best parameters: {'learning_rate': 0.026677849047960514, 'n_estimators': 1407, 'max_depth': 10, 'colsample_bytree': 0.6216020606305356}

# %% [markdown]
# ### Now visualising the predictions
#
# This is done by using the validation sets from cross validation. We have used Timeseries cross validation with a test size of three months (that which we are trying to predict in our test sets).

# %%
model = XGBRegressor(**best_params, enable_categorical=True)

# %%
model.fit(X_train, y_train, verbose=0)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.6216020606305356, device=None,
#              early_stopping_rounds=None, enable_categorical=True,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.026677849047960514, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1407, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
pred_local = model.predict(X_test_local)

# %%
from sklearn.metrics import mean_squared_error
test_score = mean_squared_error(y_test_local, pred_local)
print("Test Score:", test_score)
# Out:
# Test Score: 0.003054853099137965

# %%
residuals = y_test_local - pred_local

# %%
color_pal = sns.color_palette()

# %%
# RESIDUALS
plt.figure(figsize=(10, 6))
plt.scatter(pred_local, residuals, color=color_pal[2])
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs. Predicted Values')
plt.show()

# PRED vs. ACTUAL
plt.scatter(y_test_local, pred_local, color=color_pal[5])
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs. Actual Values')
plt.plot([min(y_test_local), max(y_test_local)], [min(y_test_local), max(y_test_local)], color=color_pal[2], linestyle='--', label='Perfect Predictions')
plt.legend()

# %% [markdown]
# # THE MAIN FIGURE TO WORRY ABOUT
#
# ### Residual = Actual - Pred

# %%
print("The average residuals:")
print(np.mean(residuals))
# Out:
# The average residuals:
# -9.383242831948019e-05

# %%
model.fit(X, y)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.6216020606305356, device=None,
#              early_stopping_rounds=None, enable_categorical=True,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.026677849047960514, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1407, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ### Predict and make csv

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
X_test_kaggle['location'] = le.fit_transform(X_test_kaggle['location'])

# %%
predictions = model.predict(X_test_kaggle)

# %%
predictions = pd.DataFrame(predictions, columns=['prediction'])

predictions.reset_index(drop=True, inplace=True)

predictions.head()
# Out:
#    prediction
# 0   -0.000448
# 1    0.000178
# 2    0.000113
# 3    0.010504
# 4    0.061457

# %%
loc_a = predictions.iloc[:len(predictions)//3]
loc_b = predictions.iloc[len(predictions)//3:2*len(predictions)//3]
loc_c = predictions.iloc[2*len(predictions)//3:]

# %%
n = len(predictions)

# De-normalizing

loc_a.loc[:, 'prediction'] = scaler_a.inverse_transform(loc_a['prediction'].values.reshape(-1, 1))
loc_b.loc[:, 'prediction'] = scaler_b.inverse_transform(loc_b['prediction'].values.reshape(-1, 1))
loc_c.loc[:, 'prediction'] = scaler_c.inverse_transform(loc_c['prediction'].values.reshape(-1, 1))

# %%
predictions = pd.concat([loc_a, loc_b, loc_c])

# %%
predictions.head(10)
# Out:
#     prediction
# 0    -2.567349
# 1     1.021431
# 2     0.648480
# 3    60.225681
# 4   352.356567
# 5   733.777405
# 6  1543.819580
# 7  2793.329834
# 8  2877.330566
# 9  2629.053955

# %%
predictions.reset_index(inplace=True)
predictions.rename(columns={'index': 'id'}, inplace=True)
predictions.to_csv('predictions.csv', index=False)

# %% [markdown]
# Remove negative values

# %%
predictions.loc[predictions['prediction'] < 0, 'prediction'] = 0
predictions.to_csv('predictions.csv', index=False)

# %% [markdown]
# Redifing the training sets

# %%
train_a = pd.read_parquet('../../A/train_targets.parquet')
train_b = pd.read_parquet('../../B/train_targets.parquet')
train_c = pd.read_parquet('../../C/train_targets.parquet')

train_a.set_index('time', inplace=True)
train_b.set_index('time', inplace=True)
train_c.set_index('time', inplace=True)

# %% [markdown]
# ### Plotting A

# %%
loc_a.set_index(valid_dates, inplace=True)

plt.figure(figsize=(9, 4))

loc_a['prediction'].plot(style='.', label='Prediction')
train_a['pv_measurement'].plot(style='.', label='Actual', color='red', linewidth=2)

plt.legend(loc='upper left')
plt.title('Predictions vs. Actual A')
plt.xlabel('Time')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plotting B

# %%
loc_b.set_index(valid_dates, inplace=True)

plt.figure(figsize=(9, 4))

loc_b['prediction'].plot(style='.', label='Prediction')
train_b['pv_measurement'].plot(style='.', label='Actual', color='red', linewidth=2)

plt.legend(loc='upper left')
plt.title('Predictions vs. Actual B')
plt.xlabel('Time')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
loc_c.set_index(valid_dates, inplace=True)

plt.figure(figsize=(9, 4))

loc_c['prediction'].plot(style='.', label='Prediction')
train_c['pv_measurement'].plot(style='.', label='Actual', color='red', linewidth=2)

plt.legend(loc='upper left')
plt.title('Predictions vs. Actual C')
plt.xlabel('Time')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()
